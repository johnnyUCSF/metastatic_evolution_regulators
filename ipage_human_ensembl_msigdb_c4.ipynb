# %% [markdown]
# # This is used for running data vs human_msigdb_c4 annotations located in:
# ### /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import scipy.stats

# %% [markdown]
# ### get index of file names to loop through

# %%
# %%bash
#
# cd fc_values
# ls FC* > filelist.txt
# cd ..

# %% [markdown]
# ### get ensembl genes represented in iPAGE database

# %%
# %%bash
#
# cp /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4_index.txt human_ensembl_index.txt
# awk '{print $1}' human_ensembl_index.txt > ensembl_index.txt

# %% [markdown]
# ### make sure that genes in file match the index

# %%
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
###################REMEMBER TO SPECIFY INDEX USED IN THE IPAGE COMMAND!!!!!!!!
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#####################
#######read in data from logfc calculations
#####################
####define index file to loop through
index_file = "fc_values/filelist.txt"
####define matching ensg index
GO_index_filename = "ensembl_index.txt"
genes_with_GOs = []
with open(GO_index_filename,'r') as rf:
    for line in rf:
        gene_name = line.split('\n')[0]
        genes_with_GOs.append(gene_name)
genes_with_GOs_set = set(genes_with_GOs)
####open file and loop through each line
###
iPAGE_sh = "iPAGE_JY.sh"
cwd = os.getcwd()+"/"
os.system("rm "+iPAGE_sh)
###
with open(index_file,'r') as rf:
    for line in rf:
        #####do this to each file
        ###read in file into pandas df
        FC_file = "fc_values/"+line.split('\n')[0]
        FC_df = pd.read_csv(FC_file,sep=',',index_col=0)
        FC_df.columns = ['log2FoldChange']
        FC_df.index.names = ['Gene']
        ###filter
        FC_df = FC_df.loc[[x for x in FC_df.index if x in genes_with_GOs_set]]
        ###save
        save_file = "fc_values/filt_"+line.split('\n')[0]
        FC_df.to_csv(save_file,sep='\t',header=True)
        ###write final iPAGE command to an ipage .sh file
        iPAGE_cmd = "perl /nvme/bins/iPAGEv1.0/page.pl --expfile "+cwd+save_file+" --species=human_ensembl_msigdb_c4 --exptype=continuous --ebins=9 \n"
        with open(iPAGE_sh, "a") as myfile:
            myfile.write(iPAGE_cmd)

# %% [markdown]
# ## then run the command from this folder:
#
# nohup sh run.sh iPAGE_JY.sh &

# %%
# %%bash
#
# nohup sh run.sh iPAGE_JY.sh &
# Out:
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv --species=human_ensembl_msigdb_c4 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv --species=human_ensembl_msigdb_c4 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv --species=human_ensembl_msigdb_c4 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c4.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	858
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 858
# cat 774, mi = 0.01125916, MORF_NPM1
# cat 667, mi = 0.00973429, MORF_ACTG1
# cat 772, mi = 0.00880374, MORF_NME2
# cat 131, mi = 0.00879342, GNF2_EIF3S6
# cat 847, mi = 0.00820652, MORF_TPT1
# cat 83, mi = 0.00765990, GCM_TPT1
# cat 56, mi = 0.00689069, GCM_NPM1
# cat 705, mi = 0.00685305, MORF_DAP3
# cat 715, mi = 0.00615633, MORF_EIF3S6
# cat 134, mi = 0.00568636, GNF2_FBL
# cat 217, mi = 0.00568204, GNF2_ST13
# cat 668, mi = 0.00562315, MORF_ANP32B
# cat 831, mi = 0.00496927, MORF_SKP1A
# cat 733, mi = 0.00493293, MORF_G22P1
# cat 6, mi = 0.00471576, GCM_ACTG1
#
# RESULTS
# Passed: cat 774, mi = 0.011, pvalue = 0.000, MORF_NPM1
# Passed: cat 806, mi = 0.004, pvalue = 0.000, MORF_RAB1A
# Passed: cat 625, mi = 0.004, pvalue = 0.000, MODULE_62
# Passed: cat 421, mi = 0.004, pvalue = 0.000, MODULE_297
# Passed: cat 318, mi = 0.003, pvalue = 0.000, MODULE_180
# Passed: cat 50, mi = 0.003, pvalue = 0.000, GCM_MLL
# Passed: cat 262, mi = 0.003, pvalue = 0.000, MODULE_125
# Passed: cat 656, mi = 0.002, pvalue = 0.000, MODULE_91
# Passed: cat 158, mi = 0.002, pvalue = 0.000, GNF2_KPNB1
# Passed: cat 46, mi = 0.002, pvalue = 0.001, GCM_MAP1B
# Passed: cat 389, mi = 0.002, pvalue = 0.001, MODULE_257
# Passed: cat 657, mi = 0.002, pvalue = 0.001, MODULE_92
# Passed: cat 247, mi = 0.002, pvalue = 0.001, MODULE_111
# Passed: cat 106, mi = 0.002, pvalue = 0.001, GNF2_CD14
# Passed: cat 148, mi = 0.001, pvalue = 0.003, GNF2_HPX
# Didn't pass (cutoff=0.0050): cat 151, mi = 0.001, pvalue = 0.005, GNF2_IGFBP1
# Didn't pass (cutoff=0.0050): cat 115, mi = 0.001, pvalue = 0.011, GNF2_CDC27
# Didn't pass (cutoff=0.0050): cat 547, mi = 0.001, pvalue = 0.014, MODULE_456
# Didn't pass (cutoff=0.0050): cat 112, mi = 0.001, pvalue = 0.013, GNF2_CD97
# Didn't pass (cutoff=0.0050): cat 583, mi = 0.001, pvalue = 0.007, MODULE_512
# Didn't pass (cutoff=0.0050): cat 370, mi = 0.001, pvalue = 0.020, MODULE_237
# Didn't pass (cutoff=0.0050): cat 116, mi = 0.001, pvalue = 0.016, GNF2_CDH11
# Didn't pass (cutoff=0.0050): cat 126, mi = 0.001, pvalue = 0.028, GNF2_DDX5
# Didn't pass (cutoff=0.0050): cat 229, mi = 0.001, pvalue = 0.042, GNF2_TYK2
# Didn't pass (cutoff=0.0050): cat 10, mi = 0.001, pvalue = 0.045, GCM_AQP4
# Didn't pass (cutoff=0.0050): cat 222, mi = 0.001, pvalue = 0.042, GNF2_TM4SF2
# Didn't pass (cutoff=0.0050): cat 450, mi = 0.001, pvalue = 0.050, MODULE_329
# Didn't pass (cutoff=0.0050): cat 494, mi = 0.001, pvalue = 0.049, MODULE_387
# Didn't pass (cutoff=0.0050): cat 172, mi = 0.001, pvalue = 0.047, GNF2_MMP11
# Didn't pass (cutoff=0.0050): cat 419, mi = 0.001, pvalue = 0.036, MODULE_294
# Didn't pass (cutoff=0.0050): cat 177, mi = 0.001, pvalue = 0.037, GNF2_MYL2
# Didn't pass (cutoff=0.0050): cat 271, mi = 0.001, pvalue = 0.068, MODULE_133
# Didn't pass (cutoff=0.0050): cat 515, mi = 0.001, pvalue = 0.021, MODULE_412
# Didn't pass (cutoff=0.0050): cat 192, mi = 0.001, pvalue = 0.082, GNF2_RAB3A
# Didn't pass (cutoff=0.0050): cat 717, mi = 0.001, pvalue = 0.057, MORF_EIF4E
# Total number of categories evaluated = 276.
# Number of categories that passed the tests = 15
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 3, 4, 0.0152996283979816
# best merge is 1, 8, 0.0313024035114984
# best merge is 3, 11, 0.0527945083117771
# best merge is 3, 12, 0.085368504606294
# best merge is 0, 2, 0.16084294571994
# best merge is 5, 10, 0.167204686366881
# best merge is 1, 5, 0.250887157678902
# best merge is 3, 14, 0.277249633642279
# best merge is 1, 7, 0.415090526783593
# best merge is 3, 13, 0.542568845126714
# best merge is 0, 1, 0.598935532558175
# order classes
# 2 - 0.603161046449777
# 5 - 0.686980278654807
# 6 - 0.583171794311542
# 3 4 11 12 14 13
# 1 8 5 10 7
# 0 2
# 6
# 9
# Done.Start drawing
# 23.77	0.00
# MODULE_125
# GNF2_CD14
# MODULE_257
# GCM_MLL
# GCM_MAP1B
# MODULE_91
# MORF_RAB1A
# GNF2_KPNB1
# MORF_NPM1
# MODULE_62
# MODULE_297
# MODULE_180
# MODULE_92
# MODULE_111
# GNF2_HPX
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 3, 4, 0.0152996283979816
# best merge is 1, 8, 0.0313024035114984
# best merge is 3, 11, 0.0527945083117771
# best merge is 3, 12, 0.085368504606294
# best merge is 0, 2, 0.16084294571994
# best merge is 5, 10, 0.167204686366881
# best merge is 1, 5, 0.250887157678902
# best merge is 3, 14, 0.277249633642279
# best merge is 1, 7, 0.415090526783593
# best merge is 3, 13, 0.542568845126714
# best merge is 0, 1, 0.598935532558175
# order classes
# 2 - 0.603161046449777
# 5 - 0.686980278654807
# 6 - 0.583171794311542
# 3 4 11 12 14 13
# 1 8 5 10 7
# 0 2
# 6
# 9
# Done.-19.2932267564156	42	0
# -18.4450988641144	42	1.4135464871687
# -18.2153975599495	42	1.69625578460244
# -18.056373580143	42	1.87294909549853
# -17.8973496003366	42	2.0143037442154
# -17.7206562894405	42	2.19099705511149
# -17.51745898191	42	2.36769036600757
# -17.2082456878418	42	2.59739167017249
# 2.49305847707194	42	2.98611695414388
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c4.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	858
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 858
# cat 774, mi = 0.01237509, MORF_NPM1
# cat 114, mi = 0.01053003, GNF2_CDC20
# cat 105, mi = 0.01046176, GNF2_CCNB2
# cat 667, mi = 0.01012326, MORF_ACTG1
# cat 131, mi = 0.00992777, GNF2_EIF3S6
# cat 772, mi = 0.00955972, MORF_NME2
# cat 113, mi = 0.00904745, GNF2_CDC2
# cat 104, mi = 0.00886678, GNF2_CCNA2
# cat 847, mi = 0.00879267, MORF_TPT1
# cat 83, mi = 0.00873241, GCM_TPT1
# cat 56, mi = 0.00825770, GCM_NPM1
# cat 146, mi = 0.00795023, GNF2_HMMR
# cat 121, mi = 0.00774535, GNF2_CENPF
# cat 120, mi = 0.00748223, GNF2_CENPE
# cat 668, mi = 0.00656407, MORF_ANP32B
#
# RESULTS
# Passed: cat 774, mi = 0.012, pvalue = 0.000, MORF_NPM1
# Passed: cat 114, mi = 0.011, pvalue = 0.000, GNF2_CDC20
# Passed: cat 625, mi = 0.006, pvalue = 0.000, MODULE_62
# Passed: cat 806, mi = 0.004, pvalue = 0.000, MORF_RAB1A
# Passed: cat 318, mi = 0.004, pvalue = 0.000, MODULE_180
# Passed: cat 180, mi = 0.003, pvalue = 0.000, GNF2_NS
# Passed: cat 67, mi = 0.003, pvalue = 0.000, GCM_RAB10
# Passed: cat 657, mi = 0.003, pvalue = 0.000, MODULE_92
# Passed: cat 421, mi = 0.003, pvalue = 0.000, MODULE_297
# Passed: cat 247, mi = 0.003, pvalue = 0.000, MODULE_111
# Passed: cat 158, mi = 0.003, pvalue = 0.000, GNF2_KPNB1
# Passed: cat 403, mi = 0.002, pvalue = 0.000, MODULE_277
# Passed: cat 29, mi = 0.002, pvalue = 0.001, GCM_DENR
# Passed: cat 151, mi = 0.002, pvalue = 0.000, GNF2_IGFBP1
# Passed: cat 126, mi = 0.001, pvalue = 0.003, GNF2_DDX5
# Didn't pass (cutoff=0.0050): cat 129, mi = 0.001, pvalue = 0.007, GNF2_DNM1
# Didn't pass (cutoff=0.0050): cat 442, mi = 0.001, pvalue = 0.007, MODULE_321
# Didn't pass (cutoff=0.0050): cat 719, mi = 0.001, pvalue = 0.008, MORF_ERCC2
# Didn't pass (cutoff=0.0050): cat 369, mi = 0.001, pvalue = 0.006, MODULE_236
# Didn't pass (cutoff=0.0050): cat 692, mi = 0.001, pvalue = 0.009, MORF_CD8A
# Didn't pass (cutoff=0.0050): cat 48, mi = 0.001, pvalue = 0.010, GCM_MAPK10
# Didn't pass (cutoff=0.0050): cat 425, mi = 0.001, pvalue = 0.015, MODULE_300
# Didn't pass (cutoff=0.0050): cat 642, mi = 0.001, pvalue = 0.015, MODULE_79
# Didn't pass (cutoff=0.0050): cat 519, mi = 0.001, pvalue = 0.015, MODULE_417
# Didn't pass (cutoff=0.0050): cat 558, mi = 0.001, pvalue = 0.013, MODULE_474
# Didn't pass (cutoff=0.0050): cat 419, mi = 0.001, pvalue = 0.007, MODULE_294
# Didn't pass (cutoff=0.0050): cat 462, mi = 0.001, pvalue = 0.020, MODULE_343
# Didn't pass (cutoff=0.0050): cat 159, mi = 0.001, pvalue = 0.023, GNF2_LCAT
# Didn't pass (cutoff=0.0050): cat 590, mi = 0.001, pvalue = 0.028, MODULE_524
# Didn't pass (cutoff=0.0050): cat 515, mi = 0.001, pvalue = 0.007, MODULE_412
# Didn't pass (cutoff=0.0050): cat 116, mi = 0.001, pvalue = 0.025, GNF2_CDH11
# Didn't pass (cutoff=0.0050): cat 165, mi = 0.001, pvalue = 0.031, GNF2_MCL1
# Didn't pass (cutoff=0.0050): cat 156, mi = 0.001, pvalue = 0.032, GNF2_JAK1
# Didn't pass (cutoff=0.0050): cat 417, mi = 0.001, pvalue = 0.023, MODULE_292
# Didn't pass (cutoff=0.0050): cat 848, mi = 0.001, pvalue = 0.036, MORF_TTN
# Total number of categories evaluated = 290.
# Number of categories that passed the tests = 15
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 4, 8, 0.00336497611208886
# best merge is 4, 13, 0.0334946421209826
# best merge is 2, 5, 0.0444166428897198
# best merge is 4, 9, 0.0488568554874267
# best merge is 4, 7, 0.0989590457366556
# best merge is 0, 2, 0.124365490407274
# best merge is 3, 6, 0.154544564309219
# best merge is 3, 12, 0.244425760167164
# best merge is 3, 14, 0.332202745886323
# best merge is 3, 10, 0.481657923825894
# best merge is 3, 11, 0.607578624443042
# order classes
# 3 - 0.325719581893631
# 5 - 0.855992644225462
# 5 - 0.14706264234311
# 4 8 13 9 7
# 1
# 3 6 12 14 10
# 0 2 5
# 11
# Done.Start drawing
# 62.96	0.00
# GNF2_CDC20
# GCM_RAB10
# MORF_RAB1A
# GCM_DENR
# MODULE_277
# GNF2_DDX5
# GNF2_KPNB1
# MORF_NPM1
# MODULE_62
# GNF2_NS
# MODULE_180
# MODULE_297
# GNF2_IGFBP1
# MODULE_111
# MODULE_92
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 4, 8, 0.00336497611208886
# best merge is 4, 13, 0.0334946421209826
# best merge is 2, 5, 0.0444166428897198
# best merge is 4, 9, 0.0488568554874267
# best merge is 4, 7, 0.0989590457366556
# best merge is 0, 2, 0.124365490407274
# best merge is 3, 6, 0.154544564309219
# best merge is 3, 12, 0.244425760167164
# best merge is 3, 14, 0.332202745886323
# best merge is 3, 10, 0.481657923825894
# best merge is 3, 11, 0.607578624443042
# order classes
# 3 - 0.325719581893631
# 5 - 0.855992644225462
# 5 - 0.14706264234311
# 4 8 13 9 7
# 1
# 3 6 12 14 10
# 0 2 5
# 11
# Done.-19.7198221092757	42	0
# -19.3562579415502	42	0.560355781448539
# -19.2195044472681	42	0.72712833545108
# -19.1227763659466	42	0.833862770012706
# -19.0360546378653	42	0.920584498094028
# -18.9459974587039	42	1.00730622617535
# -18.8359275730623	42	1.10069885641677
# -18.6558132147395	42	1.2274459974587
# 1.73046378653113	42	1.46092757306226
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv --species=human_ensembl_msigdb_c4 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv --species=human_ensembl_msigdb_c4 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_2.csv --species=human_ensembl_msigdb_c4 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_3.csv --species=human_ensembl_msigdb_c4 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c4.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	858
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 858
# cat 104, mi = 0.01437045, GNF2_CCNA2
# cat 113, mi = 0.01335098, GNF2_CDC2
# cat 121, mi = 0.01264711, GNF2_CENPF
# cat 114, mi = 0.01254780, GNF2_CDC20
# cat 105, mi = 0.01247954, GNF2_CCNB2
# cat 184, mi = 0.01227916, GNF2_PCNA
# cat 201, mi = 0.01166544, GNF2_RRM1
# cat 146, mi = 0.01084331, GNF2_HMMR
# cat 210, mi = 0.01053550, GNF2_SMC4L1
# cat 120, mi = 0.00999303, GNF2_CENPE
# cat 123, mi = 0.00883107, GNF2_CKS2
# cat 135, mi = 0.00853330, GNF2_FEN1
# cat 166, mi = 0.00840117, GNF2_MCM4
# cat 199, mi = 0.00830572, GNF2_RFC4
# cat 96, mi = 0.00826520, GNF2_BUB1B
#
# RESULTS
# Passed: cat 104, mi = 0.014, pvalue = 0.000, GNF2_CCNA2
# Passed: cat 774, mi = 0.008, pvalue = 0.000, MORF_NPM1
# Passed: cat 806, mi = 0.004, pvalue = 0.000, MORF_RAB1A
# Passed: cat 289, mi = 0.004, pvalue = 0.000, MODULE_152
# Passed: cat 308, mi = 0.003, pvalue = 0.000, MODULE_171
# Passed: cat 50, mi = 0.003, pvalue = 0.000, GCM_MLL
# Passed: cat 129, mi = 0.002, pvalue = 0.000, GNF2_DNM1
# Passed: cat 126, mi = 0.002, pvalue = 0.000, GNF2_DDX5
# Passed: cat 97, mi = 0.002, pvalue = 0.000, GNF2_BUB3
# Passed: cat 472, mi = 0.002, pvalue = 0.000, MODULE_357
# Passed: cat 318, mi = 0.002, pvalue = 0.000, MODULE_180
# Passed: cat 381, mi = 0.002, pvalue = 0.000, MODULE_248
# Passed: cat 137, mi = 0.002, pvalue = 0.000, GNF2_FOS
# Passed: cat 657, mi = 0.002, pvalue = 0.001, MODULE_92
# Passed: cat 205, mi = 0.002, pvalue = 0.001, GNF2_SELL
# Passed: cat 363, mi = 0.001, pvalue = 0.000, MODULE_227
# Didn't pass (cutoff=0.0050): cat 521, mi = 0.001, pvalue = 0.006, MODULE_419
# Passed: cat 116, mi = 0.001, pvalue = 0.005, GNF2_CDH11
# Didn't pass (cutoff=0.0050): cat 590, mi = 0.001, pvalue = 0.008, MODULE_524
# Didn't pass (cutoff=0.0050): cat 748, mi = 0.001, pvalue = 0.007, MORF_ITGA2
# Passed: cat 327, mi = 0.001, pvalue = 0.002, MODULE_190
# Didn't pass (cutoff=0.0050): cat 759, mi = 0.001, pvalue = 0.008, MORF_MAP2K7
# Didn't pass (cutoff=0.0050): cat 32, mi = 0.001, pvalue = 0.013, GCM_DPF2
# Didn't pass (cutoff=0.0050): cat 609, mi = 0.001, pvalue = 0.011, MODULE_56
# Didn't pass (cutoff=0.0050): cat 804, mi = 0.001, pvalue = 0.018, MORF_PTPRR
# Didn't pass (cutoff=0.0050): cat 800, mi = 0.001, pvalue = 0.013, MORF_PTEN
# Didn't pass (cutoff=0.0050): cat 825, mi = 0.001, pvalue = 0.017, MORF_RFC5
# Didn't pass (cutoff=0.0050): cat 696, mi = 0.001, pvalue = 0.015, MORF_CDH4
# Didn't pass (cutoff=0.0050): cat 152, mi = 0.001, pvalue = 0.020, GNF2_IL2RB
# Didn't pass (cutoff=0.0050): cat 432, mi = 0.001, pvalue = 0.021, MODULE_310
# Didn't pass (cutoff=0.0050): cat 692, mi = 0.001, pvalue = 0.027, MORF_CD8A
# Didn't pass (cutoff=0.0050): cat 20, mi = 0.001, pvalue = 0.024, GCM_CDH5
# Didn't pass (cutoff=0.0050): cat 237, mi = 0.001, pvalue = 0.034, MODULE_102
# Didn't pass (cutoff=0.0050): cat 473, mi = 0.001, pvalue = 0.025, MODULE_358
# Didn't pass (cutoff=0.0050): cat 28, mi = 0.001, pvalue = 0.041, GCM_DEAF1
# Didn't pass (cutoff=0.0050): cat 3, mi = 0.001, pvalue = 0.047, CAR_MYST2
# Didn't pass (cutoff=0.0050): cat 169, mi = 0.001, pvalue = 0.045, GNF2_MLF1
# Didn't pass (cutoff=0.0050): cat 74, mi = 0.001, pvalue = 0.051, GCM_SIRT2
# Didn't pass (cutoff=0.0050): cat 717, mi = 0.001, pvalue = 0.038, MORF_EIF4E
# Didn't pass (cutoff=0.0050): cat 567, mi = 0.001, pvalue = 0.044, MODULE_489
# Didn't pass (cutoff=0.0050): cat 450, mi = 0.001, pvalue = 0.075, MODULE_329
# Total number of categories evaluated = 315.
# Number of categories that passed the tests = 18
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 9, 10, 0.028975075515473
# best merge is 1, 8, 0.0385726739754944
# best merge is 4, 17, 0.0529329866170813
# best merge is 0, 9, 0.0608940874338618
# best merge is 2, 5, 0.132869385579051
# best merge is 4, 13, 0.150882384645352
# best merge is 11, 12, 0.204792974188539
# best merge is 4, 16, 0.20745348410543
# best merge is 0, 6, 0.212315312978386
# best merge is 4, 11, 0.240149744216171
# best merge is 1, 3, 0.257737143586409
# best merge is 2, 7, 0.394768489326612
# best merge is 4, 14, 0.425489279494786
# best merge is 2, 15, 0.637634391222916
# order classes
# 4 - 0.443086418991575
# 3 - 0.738729281531082
# 3 - 1.2298751523097
# 7 - 0.593631059101998
# 0 9 10 6
# 1 8 3
# 2 5 7
# 4 17 13 16 11 12 14
# 15
# Done.Start drawing
# 84.94	0.00
# MODULE_171
# MODULE_190
# MODULE_92
# GNF2_CDH11
# MODULE_248
# GNF2_FOS
# GNF2_SELL
# GNF2_DDX5
# MODULE_227
# MORF_RAB1A
# GCM_MLL
# MORF_NPM1
# GNF2_BUB3
# MODULE_152
# GNF2_CCNA2
# MODULE_357
# MODULE_180
# GNF2_DNM1
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 9, 10, 0.028975075515473
# best merge is 1, 8, 0.0385726739754944
# best merge is 4, 17, 0.0529329866170813
# best merge is 0, 9, 0.0608940874338618
# best merge is 2, 5, 0.132869385579051
# best merge is 4, 13, 0.150882384645352
# best merge is 11, 12, 0.204792974188539
# best merge is 4, 16, 0.20745348410543
# best merge is 0, 6, 0.212315312978386
# best merge is 4, 11, 0.240149744216171
# best merge is 1, 3, 0.257737143586409
# best merge is 2, 7, 0.394768489326612
# best merge is 4, 14, 0.425489279494786
# best merge is 2, 15, 0.637634391222916
# order classes
# 4 - 0.443086418991575
# 3 - 0.738729281531082
# 3 - 1.2298751523097
# 7 - 0.593631059101998
# 0 9 10 6
# 1 8 3
# 2 5 7
# 4 17 13 16 11 12 14
# 15
# Done.-19.849187661879	42	0
# -19.6588179891688	42	0.301624676242053
# -19.5920649870497	42	0.380739345420297
# -19.5401459854015	42	0.435130680480339
# -19.4931716505769	42	0.484577348716741
# -19.4437249823405	42	0.529079350129503
# -19.3769719802213	42	0.583470685189545
# -19.2706616435131	42	0.662585354367789
# 1.39804567930304	42	0.796091358606075
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c4.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	858
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 858
# cat 774, mi = 0.00972082, MORF_NPM1
# cat 131, mi = 0.00946339, GNF2_EIF3S6
# cat 667, mi = 0.00852759, MORF_ACTG1
# cat 847, mi = 0.00794739, MORF_TPT1
# cat 772, mi = 0.00712728, MORF_NME2
# cat 668, mi = 0.00696218, MORF_ANP32B
# cat 56, mi = 0.00692513, GCM_NPM1
# cat 83, mi = 0.00691388, GCM_TPT1
# cat 811, mi = 0.00675859, MORF_RAD21
# cat 705, mi = 0.00670551, MORF_DAP3
# cat 831, mi = 0.00656586, MORF_SKP1A
# cat 783, mi = 0.00629461, MORF_PPP1CA
# cat 721, mi = 0.00622761, MORF_ERH
# cat 715, mi = 0.00603311, MORF_EIF3S6
# cat 114, mi = 0.00553065, GNF2_CDC20
#
# RESULTS
# Passed: cat 774, mi = 0.010, pvalue = 0.000, MORF_NPM1
# Passed: cat 114, mi = 0.006, pvalue = 0.000, GNF2_CDC20
# Passed: cat 813, mi = 0.005, pvalue = 0.000, MORF_RAD23B
# Passed: cat 421, mi = 0.004, pvalue = 0.000, MODULE_297
# Passed: cat 318, mi = 0.004, pvalue = 0.000, MODULE_180
# Passed: cat 67, mi = 0.004, pvalue = 0.000, GCM_RAB10
# Passed: cat 158, mi = 0.003, pvalue = 0.000, GNF2_KPNB1
# Passed: cat 247, mi = 0.002, pvalue = 0.000, MODULE_111
# Passed: cat 657, mi = 0.002, pvalue = 0.000, MODULE_92
# Passed: cat 357, mi = 0.002, pvalue = 0.000, MODULE_22
# Passed: cat 162, mi = 0.002, pvalue = 0.000, GNF2_MAPT
# Passed: cat 846, mi = 0.002, pvalue = 0.000, MORF_TPR
# Passed: cat 126, mi = 0.002, pvalue = 0.000, GNF2_DDX5
# Passed: cat 29, mi = 0.002, pvalue = 0.001, GCM_DENR
# Passed: cat 177, mi = 0.002, pvalue = 0.000, GNF2_MYL2
# Passed: cat 642, mi = 0.002, pvalue = 0.002, MODULE_79
# Passed: cat 130, mi = 0.001, pvalue = 0.001, GNF2_EGFR
# Passed: cat 116, mi = 0.001, pvalue = 0.002, GNF2_CDH11
# Didn't pass (cutoff=0.0050): cat 590, mi = 0.001, pvalue = 0.007, MODULE_524
# Didn't pass (cutoff=0.0050): cat 99, mi = 0.001, pvalue = 0.007, GNF2_CASP1
# Passed: cat 653, mi = 0.001, pvalue = 0.003, MODULE_89
# Didn't pass (cutoff=0.0050): cat 188, mi = 0.001, pvalue = 0.008, GNF2_PTPN4
# Didn't pass (cutoff=0.0050): cat 662, mi = 0.001, pvalue = 0.006, MODULE_97
# Didn't pass (cutoff=0.0050): cat 476, mi = 0.001, pvalue = 0.009, MODULE_361
# Didn't pass (cutoff=0.0050): cat 377, mi = 0.001, pvalue = 0.007, MODULE_243
# Didn't pass (cutoff=0.0050): cat 411, mi = 0.001, pvalue = 0.013, MODULE_286
# Didn't pass (cutoff=0.0050): cat 609, mi = 0.001, pvalue = 0.007, MODULE_56
# Didn't pass (cutoff=0.0050): cat 502, mi = 0.001, pvalue = 0.014, MODULE_399
# Didn't pass (cutoff=0.0050): cat 119, mi = 0.001, pvalue = 0.011, GNF2_CEBPA
# Didn't pass (cutoff=0.0050): cat 111, mi = 0.001, pvalue = 0.010, GNF2_CD7
# Passed: cat 348, mi = 0.001, pvalue = 0.004, MODULE_21
# Didn't pass (cutoff=0.0050): cat 442, mi = 0.001, pvalue = 0.012, MODULE_321
# Didn't pass (cutoff=0.0050): cat 320, mi = 0.001, pvalue = 0.017, MODULE_182
# Didn't pass (cutoff=0.0050): cat 562, mi = 0.001, pvalue = 0.022, MODULE_481
# Didn't pass (cutoff=0.0050): cat 519, mi = 0.001, pvalue = 0.023, MODULE_417
# Didn't pass (cutoff=0.0050): cat 567, mi = 0.001, pvalue = 0.016, MODULE_489
# Didn't pass (cutoff=0.0050): cat 603, mi = 0.001, pvalue = 0.029, MODULE_544
# Didn't pass (cutoff=0.0050): cat 426, mi = 0.001, pvalue = 0.026, MODULE_301
# Didn't pass (cutoff=0.0050): cat 459, mi = 0.001, pvalue = 0.033, MODULE_340
# Didn't pass (cutoff=0.0050): cat 374, mi = 0.001, pvalue = 0.045, MODULE_240
# Didn't pass (cutoff=0.0050): cat 420, mi = 0.001, pvalue = 0.040, MODULE_295
# Didn't pass (cutoff=0.0050): cat 435, mi = 0.001, pvalue = 0.038, MODULE_313
# Didn't pass (cutoff=0.0050): cat 571, mi = 0.001, pvalue = 0.035, MODULE_493
# Didn't pass (cutoff=0.0050): cat 322, mi = 0.001, pvalue = 0.050, MODULE_184
# Didn't pass (cutoff=0.0050): cat 359, mi = 0.001, pvalue = 0.052, MODULE_221
# Didn't pass (cutoff=0.0050): cat 475, mi = 0.001, pvalue = 0.028, MODULE_360
# Didn't pass (cutoff=0.0050): cat 753, mi = 0.001, pvalue = 0.051, MORF_LCAT
# Didn't pass (cutoff=0.0050): cat 635, mi = 0.001, pvalue = 0.049, MODULE_71
# Didn't pass (cutoff=0.0050): cat 175, mi = 0.001, pvalue = 0.066, GNF2_MSN
# Didn't pass (cutoff=0.0050): cat 284, mi = 0.001, pvalue = 0.016, MODULE_148
# Didn't pass (cutoff=0.0050): cat 169, mi = 0.001, pvalue = 0.067, GNF2_MLF1
# Total number of categories evaluated = 312.
# Number of categories that passed the tests = 20
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 1, 4, 0.0157964636787757
# best merge is 1, 14, 0.0222453707487008
# best merge is 2, 11, 0.0280637733240884
# best merge is 1, 3, 0.0320301001739722
# best merge is 8, 16, 0.0771212789602927
# best merge is 8, 10, 0.100861509431174
# best merge is 15, 17, 0.14322764475213
# best merge is 1, 8, 0.171195117399346
# best merge is 5, 6, 0.194305607125101
# best merge is 7, 18, 0.221051177227887
# best merge is 2, 12, 0.226866921990783
# best merge is 2, 9, 0.26259702929608
# best merge is 2, 5, 0.348844974176164
# best merge is 1, 7, 0.505787747282733
# best merge is 2, 13, 0.522470988023535
# best merge is 2, 19, 0.60389404988589
# order classes
# 9 - 0.537264353991717
# 7 - 0.861746942725309
# 2 - 0.71613822376065
# 1 4 14 3 8 16 10 7 18
# 0
# 2 11 12 9 5 6 13
# 15 17
# 19
# Done.Start drawing
# 70.09	0.00
# MODULE_79
# GNF2_CDH11
# GCM_DENR
# MORF_TPR
# GCM_RAB10
# GNF2_KPNB1
# MODULE_21
# MORF_RAD23B
# GNF2_DDX5
# MODULE_22
# MODULE_89
# MORF_NPM1
# GNF2_CDC20
# MODULE_180
# GNF2_MYL2
# MODULE_297
# MODULE_92
# GNF2_EGFR
# GNF2_MAPT
# MODULE_111
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv_PAGE/filt_FC_LVM2_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv_PAGE/filt_FC_LVM2_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 1, 4, 0.0157964636787757
# best merge is 1, 14, 0.0222453707487008
# best merge is 2, 11, 0.0280637733240884
# best merge is 1, 3, 0.0320301001739722
# best merge is 8, 16, 0.0771212789602927
# best merge is 8, 10, 0.100861509431174
# best merge is 15, 17, 0.14322764475213
# best merge is 1, 8, 0.171195117399346
# best merge is 5, 6, 0.194305607125101
# best merge is 7, 18, 0.221051177227887
# best merge is 2, 12, 0.226866921990783
# best merge is 2, 9, 0.26259702929608
# best merge is 2, 5, 0.348844974176164
# best merge is 1, 7, 0.505787747282733
# best merge is 2, 13, 0.522470988023535
# best merge is 2, 19, 0.60389404988589
# order classes
# 9 - 0.537264353991717
# 7 - 0.861746942725309
# 2 - 0.71613822376065
# 1 4 14 3 8 16 10 7 18
# 0
# 2 11 12 9 5 6 13
# 15 17
# 19
# Done.-19.784277357683	42	0
# -19.5056356113568	42	0.431445284634042
# -19.4037665858182	42	0.557283492652304
# -19.3318590383792	42	0.635183335711228
# -19.2689399343701	42	0.701098587530318
# -19.203024682551	42	0.761021543729491
# -19.1221286916821	42	0.832929091168498
# -18.9902981880439	42	0.922813525467256
# 1.54829504922243	42	1.09659009844486
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c4.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	858
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 858
# cat 705, mi = 0.00763277, MORF_DAP3
# cat 831, mi = 0.00717723, MORF_SKP1A
# cat 131, mi = 0.00694120, GNF2_EIF3S6
# cat 847, mi = 0.00680069, MORF_TPT1
# cat 774, mi = 0.00651034, MORF_NPM1
# cat 733, mi = 0.00647360, MORF_G22P1
# cat 783, mi = 0.00640914, MORF_PPP1CA
# cat 83, mi = 0.00640171, GCM_TPT1
# cat 701, mi = 0.00638947, MORF_CTBP1
# cat 811, mi = 0.00634032, MORF_RAD21
# cat 797, mi = 0.00611293, MORF_PSMC1
# cat 813, mi = 0.00584317, MORF_RAD23B
# cat 806, mi = 0.00579497, MORF_RAB1A
# cat 667, mi = 0.00565946, MORF_ACTG1
# cat 794, mi = 0.00553990, MORF_PRKAR1A
#
# RESULTS
# Passed: cat 705, mi = 0.008, pvalue = 0.000, MORF_DAP3
# Passed: cat 131, mi = 0.007, pvalue = 0.000, GNF2_EIF3S6
# Passed: cat 790, mi = 0.003, pvalue = 0.000, MORF_PPP6C
# Passed: cat 318, mi = 0.003, pvalue = 0.000, MODULE_180
# Passed: cat 421, mi = 0.003, pvalue = 0.000, MODULE_297
# Passed: cat 67, mi = 0.003, pvalue = 0.000, GCM_RAB10
# Passed: cat 132, mi = 0.003, pvalue = 0.000, GNF2_ELAC2
# Passed: cat 657, mi = 0.002, pvalue = 0.000, MODULE_92
# Passed: cat 162, mi = 0.002, pvalue = 0.000, GNF2_MAPT
# Passed: cat 294, mi = 0.002, pvalue = 0.000, MODULE_157
# Passed: cat 21, mi = 0.002, pvalue = 0.000, GCM_CHUK
# Passed: cat 442, mi = 0.002, pvalue = 0.001, MODULE_321
# Passed: cat 502, mi = 0.002, pvalue = 0.001, MODULE_399
# Passed: cat 151, mi = 0.002, pvalue = 0.000, GNF2_IGFBP1
# Didn't pass (cutoff=0.0050): cat 642, mi = 0.001, pvalue = 0.007, MODULE_79
# Didn't pass (cutoff=0.0050): cat 356, mi = 0.001, pvalue = 0.007, MODULE_219
# Didn't pass (cutoff=0.0050): cat 140, mi = 0.001, pvalue = 0.008, GNF2_GSTM1
# Didn't pass (cutoff=0.0050): cat 737, mi = 0.001, pvalue = 0.008, MORF_GSPT1
# Didn't pass (cutoff=0.0050): cat 307, mi = 0.001, pvalue = 0.009, MODULE_170
# Didn't pass (cutoff=0.0050): cat 262, mi = 0.001, pvalue = 0.012, MODULE_125
# Didn't pass (cutoff=0.0050): cat 265, mi = 0.001, pvalue = 0.011, MODULE_128
# Didn't pass (cutoff=0.0050): cat 484, mi = 0.001, pvalue = 0.014, MODULE_372
# Didn't pass (cutoff=0.0050): cat 159, mi = 0.001, pvalue = 0.014, GNF2_LCAT
# Didn't pass (cutoff=0.0050): cat 226, mi = 0.001, pvalue = 0.018, GNF2_TST
# Didn't pass (cutoff=0.0050): cat 148, mi = 0.001, pvalue = 0.019, GNF2_HPX
# Didn't pass (cutoff=0.0050): cat 389, mi = 0.001, pvalue = 0.016, MODULE_257
# Passed: cat 327, mi = 0.001, pvalue = 0.004, MODULE_190
# Didn't pass (cutoff=0.0050): cat 367, mi = 0.001, pvalue = 0.027, MODULE_234
# Didn't pass (cutoff=0.0050): cat 147, mi = 0.001, pvalue = 0.025, GNF2_HPN
# Didn't pass (cutoff=0.0050): cat 348, mi = 0.001, pvalue = 0.021, MODULE_21
# Didn't pass (cutoff=0.0050): cat 51, mi = 0.001, pvalue = 0.034, GCM_MSN
# Didn't pass (cutoff=0.0050): cat 459, mi = 0.001, pvalue = 0.031, MODULE_340
# Didn't pass (cutoff=0.0050): cat 823, mi = 0.001, pvalue = 0.025, MORF_RFC1
# Passed: cat 284, mi = 0.001, pvalue = 0.005, MODULE_148
# Didn't pass (cutoff=0.0050): cat 410, mi = 0.001, pvalue = 0.034, MODULE_285
# Didn't pass (cutoff=0.0050): cat 283, mi = 0.001, pvalue = 0.026, MODULE_147
# Didn't pass (cutoff=0.0050): cat 567, mi = 0.001, pvalue = 0.019, MODULE_489
# Didn't pass (cutoff=0.0050): cat 177, mi = 0.001, pvalue = 0.015, GNF2_MYL2
# Didn't pass (cutoff=0.0050): cat 854, mi = 0.001, pvalue = 0.042, MORF_WNT1
# Didn't pass (cutoff=0.0050): cat 471, mi = 0.001, pvalue = 0.031, MODULE_356
# Didn't pass (cutoff=0.0050): cat 331, mi = 0.001, pvalue = 0.029, MODULE_195
# Didn't pass (cutoff=0.0050): cat 746, mi = 0.001, pvalue = 0.032, MORF_IL4
# Didn't pass (cutoff=0.0050): cat 644, mi = 0.001, pvalue = 0.054, MODULE_80
# Didn't pass (cutoff=0.0050): cat 59, mi = 0.001, pvalue = 0.053, GCM_PPM1D
# Didn't pass (cutoff=0.0050): cat 119, mi = 0.001, pvalue = 0.055, GNF2_CEBPA
# Didn't pass (cutoff=0.0050): cat 115, mi = 0.001, pvalue = 0.053, GNF2_CDC27
# Didn't pass (cutoff=0.0050): cat 428, mi = 0.001, pvalue = 0.069, MODULE_305
# Didn't pass (cutoff=0.0050): cat 549, mi = 0.001, pvalue = 0.065, MODULE_458
# Didn't pass (cutoff=0.0050): cat 609, mi = 0.001, pvalue = 0.063, MODULE_56
# Didn't pass (cutoff=0.0050): cat 154, mi = 0.001, pvalue = 0.065, GNF2_ITGAL
# Didn't pass (cutoff=0.0050): cat 141, mi = 0.001, pvalue = 0.069, GNF2_H2AFX
# Didn't pass (cutoff=0.0050): cat 581, mi = 0.001, pvalue = 0.072, MODULE_51
# Didn't pass (cutoff=0.0050): cat 684, mi = 0.001, pvalue = 0.064, MORF_BUB1
# Didn't pass (cutoff=0.0050): cat 789, mi = 0.001, pvalue = 0.056, MORF_PPP5C
# Total number of categories evaluated = 286.
# Number of categories that passed the tests = 16
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 7, 13, 0.0247894462033673
# best merge is 4, 8, 0.0398240577638597
# best merge is 4, 9, 0.0538847308453447
# best merge is 3, 4, 0.0672806335586365
# best merge is 3, 7, 0.0761961232124531
# best merge is 0, 2, 0.089907854691983
# best merge is 11, 12, 0.136220118884992
# best merge is 0, 5, 0.196550522290092
# best merge is 0, 10, 0.328019363744152
# best merge is 11, 14, 0.340034668852278
# best merge is 3, 15, 0.371345352533281
# best merge is 0, 6, 0.420939005358068
# order classes
# 4 - 0.733533495252312
# 7 - 0.299649303065482
# 3 - 0.967454170772797
# 3 4 8 9 7 13 15
# 1
# 0 2 5 10
# 6
# 11 12 14
# Done.Start drawing
# 26.31	0.00
# MODULE_321
# MODULE_399
# MODULE_190
# MORF_DAP3
# MORF_PPP6C
# GNF2_ELAC2
# GCM_CHUK
# GCM_RAB10
# GNF2_EIF3S6
# MODULE_180
# MODULE_297
# GNF2_MAPT
# MODULE_157
# MODULE_92
# GNF2_IGFBP1
# MODULE_148
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv_PAGE/filt_FC_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv_PAGE/filt_FC_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 7, 13, 0.0247894462033673
# best merge is 4, 8, 0.0398240577638597
# best merge is 4, 9, 0.0538847308453447
# best merge is 3, 4, 0.0672806335586365
# best merge is 3, 7, 0.0761961232124531
# best merge is 0, 2, 0.089907854691983
# best merge is 11, 12, 0.136220118884992
# best merge is 0, 5, 0.196550522290092
# best merge is 0, 10, 0.328019363744152
# best merge is 11, 14, 0.340034668852278
# best merge is 3, 15, 0.371345352533281
# best merge is 0, 6, 0.420939005358068
# order classes
# 4 - 0.733533495252312
# 7 - 0.299649303065482
# 3 - 0.967454170772797
# 3 4 8 9 7 13 15
# 1
# 0 2 5 10
# 6
# 11 12 14
# Done.-19.5290763968073	42	0
# -18.9064994298746	42	0.941847206385405
# -18.6590649942987	42	1.24515393386545
# -18.4754846066135	42	1.43671607753706
# -18.3158494868871	42	1.61231470923603
# -18.1641961231471	42	1.75598631698974
# -17.9806157354618	42	1.91562143671608
# -17.709236031927	42	2.12314709236032
# 2.22919042189282	42	2.45838084378563
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c4.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	858
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 858
# cat 774, mi = 0.01079430, MORF_NPM1
# cat 667, mi = 0.00994122, MORF_ACTG1
# cat 772, mi = 0.00899582, MORF_NME2
# cat 131, mi = 0.00888110, GNF2_EIF3S6
# cat 847, mi = 0.00886568, MORF_TPT1
# cat 83, mi = 0.00784895, GCM_TPT1
# cat 56, mi = 0.00750909, GCM_NPM1
# cat 783, mi = 0.00671397, MORF_PPP1CA
# cat 705, mi = 0.00666627, MORF_DAP3
# cat 831, mi = 0.00635904, MORF_SKP1A
# cat 715, mi = 0.00578344, MORF_EIF3S6
# cat 811, mi = 0.00547245, MORF_RAD21
# cat 6, mi = 0.00536349, GCM_ACTG1
# cat 217, mi = 0.00535770, GNF2_ST13
# cat 721, mi = 0.00529723, MORF_ERH
#
# RESULTS
# Passed: cat 774, mi = 0.011, pvalue = 0.000, MORF_NPM1
# Passed: cat 813, mi = 0.005, pvalue = 0.000, MORF_RAD23B
# Passed: cat 318, mi = 0.005, pvalue = 0.000, MODULE_180
# Passed: cat 421, mi = 0.003, pvalue = 0.000, MODULE_297
# Passed: cat 247, mi = 0.003, pvalue = 0.000, MODULE_111
# Passed: cat 67, mi = 0.003, pvalue = 0.000, GCM_RAB10
# Passed: cat 184, mi = 0.003, pvalue = 0.000, GNF2_PCNA
# Passed: cat 357, mi = 0.003, pvalue = 0.000, MODULE_22
# Passed: cat 657, mi = 0.002, pvalue = 0.000, MODULE_92
# Passed: cat 158, mi = 0.002, pvalue = 0.000, GNF2_KPNB1
# Passed: cat 162, mi = 0.002, pvalue = 0.000, GNF2_MAPT
# Passed: cat 177, mi = 0.002, pvalue = 0.000, GNF2_MYL2
# Passed: cat 126, mi = 0.002, pvalue = 0.001, GNF2_DDX5
# Passed: cat 392, mi = 0.002, pvalue = 0.001, MODULE_261
# Passed: cat 846, mi = 0.002, pvalue = 0.001, MORF_TPR
# Passed: cat 151, mi = 0.002, pvalue = 0.000, GNF2_IGFBP1
# Passed: cat 377, mi = 0.002, pvalue = 0.001, MODULE_243
# Passed: cat 115, mi = 0.002, pvalue = 0.001, GNF2_CDC27
# Passed: cat 544, mi = 0.002, pvalue = 0.002, MODULE_453
# Passed: cat 77, mi = 0.002, pvalue = 0.002, GCM_SMO
# Passed: cat 264, mi = 0.001, pvalue = 0.002, MODULE_127
# Passed: cat 442, mi = 0.001, pvalue = 0.003, MODULE_321
# Passed: cat 99, mi = 0.001, pvalue = 0.004, GNF2_CASP1
# Didn't pass (cutoff=0.0050): cat 175, mi = 0.001, pvalue = 0.006, GNF2_MSN
# Didn't pass (cutoff=0.0050): cat 148, mi = 0.001, pvalue = 0.016, GNF2_HPX
# Didn't pass (cutoff=0.0050): cat 244, mi = 0.001, pvalue = 0.014, MODULE_109
# Didn't pass (cutoff=0.0050): cat 116, mi = 0.001, pvalue = 0.011, GNF2_CDH11
# Didn't pass (cutoff=0.0050): cat 147, mi = 0.001, pvalue = 0.018, GNF2_HPN
# Didn't pass (cutoff=0.0050): cat 502, mi = 0.001, pvalue = 0.027, MODULE_399
# Passed: cat 284, mi = 0.001, pvalue = 0.003, MODULE_148
# Didn't pass (cutoff=0.0050): cat 13, mi = 0.001, pvalue = 0.028, GCM_BCL2L1
# Didn't pass (cutoff=0.0050): cat 610, mi = 0.001, pvalue = 0.022, MODULE_560
# Didn't pass (cutoff=0.0050): cat 340, mi = 0.001, pvalue = 0.042, MODULE_202
# Didn't pass (cutoff=0.0050): cat 156, mi = 0.001, pvalue = 0.051, GNF2_JAK1
# Didn't pass (cutoff=0.0050): cat 455, mi = 0.001, pvalue = 0.054, MODULE_333
# Didn't pass (cutoff=0.0050): cat 731, mi = 0.001, pvalue = 0.050, MORF_FRK
# Didn't pass (cutoff=0.0050): cat 747, mi = 0.001, pvalue = 0.054, MORF_IL9
# Didn't pass (cutoff=0.0050): cat 567, mi = 0.001, pvalue = 0.053, MODULE_489
# Didn't pass (cutoff=0.0050): cat 573, mi = 0.001, pvalue = 0.064, MODULE_497
# Didn't pass (cutoff=0.0050): cat 459, mi = 0.001, pvalue = 0.063, MODULE_340
# Didn't pass (cutoff=0.0050): cat 159, mi = 0.001, pvalue = 0.093, GNF2_LCAT
# Didn't pass (cutoff=0.0050): cat 453, mi = 0.001, pvalue = 0.074, MODULE_331
# Didn't pass (cutoff=0.0050): cat 680, mi = 0.001, pvalue = 0.093, MORF_BMI1
# Didn't pass (cutoff=0.0050): cat 519, mi = 0.001, pvalue = 0.177, MODULE_417
# Didn't pass (cutoff=0.0050): cat 570, mi = 0.001, pvalue = 0.150, MODULE_492
# Didn't pass (cutoff=0.0050): cat 140, mi = 0.001, pvalue = 0.142, GNF2_GSTM1
# Didn't pass (cutoff=0.0050): cat 507, mi = 0.001, pvalue = 0.083, MODULE_402
# Didn't pass (cutoff=0.0050): cat 226, mi = 0.001, pvalue = 0.148, GNF2_TST
# Didn't pass (cutoff=0.0050): cat 367, mi = 0.001, pvalue = 0.199, MODULE_234
# Didn't pass (cutoff=0.0050): cat 848, mi = 0.001, pvalue = 0.203, MORF_TTN
# Total number of categories evaluated = 367.
# Number of categories that passed the tests = 24
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_LVM2_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 2, 3, 0.0246078509201917
# best merge is 1, 14, 0.0414212921004876
# best merge is 2, 23, 0.0420631844975333
# best merge is 4, 15, 0.0664088588750256
# best merge is 2, 11, 0.0701405798055674
# best merge is 2, 4, 0.0810504554549348
# best merge is 12, 18, 0.100204298074565
# best merge is 2, 8, 0.102489428717011
# best merge is 1, 5, 0.109531250689071
# best merge is 7, 16, 0.113877946638495
# best merge is 20, 21, 0.147840289354866
# best merge is 1, 9, 0.168120850310038
# best merge is 2, 10, 0.21312028002057
# best merge is 6, 20, 0.215098544278217
# best merge is 0, 7, 0.294563846042624
# best merge is 1, 13, 0.344308976836212
# best merge is 1, 12, 0.463376010472991
# best merge is 6, 22, 0.562695856468472
# best merge is 1, 19, 0.625132098800576
# best merge is 0, 17, 0.636080184921755
# order classes
# 3 - 1.24978780217554
# 8 - 1.0548723137027
# 8 - 0.294445030714924
# ...
# best merge is 7, 12, 0.195287643276966
# best merge is 3, 4, 0.20228495903341
# best merge is 3, 9, 0.244623931822784
# best merge is 7, 10, 0.272053139663013
# best merge is 1, 6, 0.315181817843317
# best merge is 7, 14, 0.340766806234218
# best merge is 1, 3, 0.596752159030243
# order classes
# 3 - 0.219704722040335
# 3 - 0.827641594952864
# 4 - 0.572115117103508
# 4 - 0.825794222487021
# 0 13 8
# 1 2 6
# 3 5 4 9
# 7 12 10 14
# 11
# Done.Start drawing
# 5.29	0.00
# GNF2_CCNB2
# GNF2_CCNA1
# MODULE_127
# GCM_RAB10
# MORF_RAB1A
# MODULE_239
# MODULE_277
# GNF2_EIF3S6
# GNF2_XRCC5
# MODULE_152
# MODULE_286
# MODULE_316
# MODULE_436
# MODULE_180
# GNF2_TNFSF10
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_2.csv_PAGE/filt_FC_P_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_2.csv_PAGE/filt_FC_P_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 13, 0.0350653797538616
# best merge is 0, 8, 0.0813344350412197
# best merge is 3, 5, 0.0820705362856463
# best merge is 1, 2, 0.114513799770944
# best merge is 7, 12, 0.195287643276966
# best merge is 3, 4, 0.20228495903341
# best merge is 3, 9, 0.244623931822784
# best merge is 7, 10, 0.272053139663013
# best merge is 1, 6, 0.315181817843317
# best merge is 7, 14, 0.340766806234218
# best merge is 1, 3, 0.596752159030243
# order classes
# 3 - 0.219704722040335
# 3 - 0.827641594952864
# 4 - 0.572115117103508
# 4 - 0.825794222487021
# 0 13 8
# 1 2 6
# 3 5 4 9
# 7 12 10 14
# 11
# Done.-16.8638941398866	42	0
# -13.2117202268431	42	6.27221172022684
# -12.3780718336484	42	7.30434782608696
# -11.8223062381853	42	7.93950850661626
# -11.3856332703214	42	8.41587901701323
# -10.9092627599244	42	8.81285444234405
# -10.3137996219282	42	9.36862003780718
# -9.44045368620038	42	10.0037807183365
# 6.55765595463138	42	11.1153119092628
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c4.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	858
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 858
# cat 774, mi = 0.01926170, MORF_NPM1
# cat 772, mi = 0.01828361, MORF_NME2
# cat 668, mi = 0.01807300, MORF_ANP32B
# cat 667, mi = 0.01709044, MORF_ACTG1
# cat 733, mi = 0.01493772, MORF_G22P1
# cat 131, mi = 0.01471423, GNF2_EIF3S6
# cat 705, mi = 0.01414026, MORF_DAP3
# cat 134, mi = 0.01409456, GNF2_FBL
# cat 726, mi = 0.01365477, MORF_FBL
# cat 56, mi = 0.01364062, GCM_NPM1
# cat 721, mi = 0.01354858, MORF_ERH
# cat 847, mi = 0.01337719, MORF_TPT1
# cat 783, mi = 0.01331282, MORF_PPP1CA
# cat 831, mi = 0.01289972, MORF_SKP1A
# cat 6, mi = 0.01270956, GCM_ACTG1
#
# RESULTS
# Passed: cat 774, mi = 0.019, pvalue = 0.000, MORF_NPM1
# Passed: cat 797, mi = 0.011, pvalue = 0.000, MORF_PSMC1
# Passed: cat 670, mi = 0.008, pvalue = 0.000, MORF_AP3D1
# Passed: cat 181, mi = 0.006, pvalue = 0.000, GNF2_PA2G4
# Passed: cat 132, mi = 0.003, pvalue = 0.000, GNF2_ELAC2
# Passed: cat 126, mi = 0.002, pvalue = 0.000, GNF2_DDX5
# Passed: cat 240, mi = 0.002, pvalue = 0.001, MODULE_105
# Passed: cat 294, mi = 0.001, pvalue = 0.005, MODULE_157
# Passed: cat 340, mi = 0.001, pvalue = 0.002, MODULE_202
# Passed: cat 456, mi = 0.001, pvalue = 0.004, MODULE_334
# Didn't pass (cutoff=0.0050): cat 649, mi = 0.001, pvalue = 0.009, MODULE_85
# Didn't pass (cutoff=0.0050): cat 848, mi = 0.001, pvalue = 0.008, MORF_TTN
# Didn't pass (cutoff=0.0050): cat 789, mi = 0.001, pvalue = 0.011, MORF_PPP5C
# Didn't pass (cutoff=0.0050): cat 377, mi = 0.001, pvalue = 0.013, MODULE_243
# Didn't pass (cutoff=0.0050): cat 314, mi = 0.001, pvalue = 0.013, MODULE_177
# Didn't pass (cutoff=0.0050): cat 520, mi = 0.001, pvalue = 0.017, MODULE_418
# Didn't pass (cutoff=0.0050): cat 748, mi = 0.001, pvalue = 0.018, MORF_ITGA2
# Didn't pass (cutoff=0.0050): cat 33, mi = 0.001, pvalue = 0.019, GCM_ERBB2IP
# Didn't pass (cutoff=0.0050): cat 692, mi = 0.001, pvalue = 0.025, MORF_CD8A
# Didn't pass (cutoff=0.0050): cat 24, mi = 0.001, pvalue = 0.032, GCM_CSNK1D
# Didn't pass (cutoff=0.0050): cat 804, mi = 0.001, pvalue = 0.036, MORF_PTPRR
# Didn't pass (cutoff=0.0050): cat 136, mi = 0.001, pvalue = 0.044, GNF2_FGR
# Didn't pass (cutoff=0.0050): cat 318, mi = 0.001, pvalue = 0.027, MODULE_180
# Didn't pass (cutoff=0.0050): cat 549, mi = 0.001, pvalue = 0.043, MODULE_458
# Didn't pass (cutoff=0.0050): cat 335, mi = 0.001, pvalue = 0.046, MODULE_199
# Didn't pass (cutoff=0.0050): cat 547, mi = 0.001, pvalue = 0.032, MODULE_456
# Didn't pass (cutoff=0.0050): cat 187, mi = 0.001, pvalue = 0.058, GNF2_PRDX2
# Didn't pass (cutoff=0.0050): cat 219, mi = 0.001, pvalue = 0.061, GNF2_TAL1
# Didn't pass (cutoff=0.0050): cat 212, mi = 0.001, pvalue = 0.069, GNF2_SPI1
# Didn't pass (cutoff=0.0050): cat 546, mi = 0.001, pvalue = 0.072, MODULE_455
# Total number of categories evaluated = 219.
# Number of categories that passed the tests = 10
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 1, 3, 0.0191723273663442
# best merge is 1, 2, 0.0226534380035393
# best merge is 0, 4, 0.0331607305187859
# best merge is 1, 5, 0.0999609865639213
# best merge is 0, 1, 0.242270030798003
# best merge is 0, 6, 0.288372183951788
# order classes
# 6 - 0.216266957404444
# 0 4 1 3 2 5
# 6
# 7
# 8
# 9
# Done.Start drawing
# 110.21	0.00
# MODULE_334
# GNF2_ELAC2
# MORF_PSMC1
# GNF2_PA2G4
# MORF_AP3D1
# GNF2_DDX5
# MODULE_105
# MORF_NPM1
# MODULE_202
# MODULE_157
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 1, 3, 0.0191723273663442
# best merge is 1, 2, 0.0226534380035393
# best merge is 0, 4, 0.0331607305187859
# best merge is 1, 5, 0.0999609865639213
# best merge is 0, 1, 0.242270030798003
# best merge is 0, 6, 0.288372183951788
# order classes
# 6 - 0.216266957404444
# 0 4 1 3 2 5
# 6
# 7
# 8
# 9
# Done.-19.9980945467743	42	0
# -19.9923781870974	42	0.00381090645132021
# -19.9847563741947	42	0.0114327193539606
# -19.9790400145177	42	0.019054532256601
# -19.9733236548408	42	0.0228654387079212
# -19.9676072951638	42	0.0304872516105617
# -19.8361310225932	42	0.0342981580618819
# -19.4912439887488	42	0.293439796751656
# 1.36203611287542	42	0.724072225750839
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c4.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c4/human_ensembl_msigdb_c4.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	858
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 858
# cat 104, mi = 0.01775284, GNF2_CCNA2
# cat 184, mi = 0.01578305, GNF2_PCNA
# cat 113, mi = 0.01500342, GNF2_CDC2
# cat 121, mi = 0.01500342, GNF2_CENPF
# cat 201, mi = 0.01496874, GNF2_RRM1
# cat 105, mi = 0.01481300, GNF2_CCNB2
# cat 210, mi = 0.01471150, GNF2_SMC4L1
# cat 114, mi = 0.01454624, GNF2_CDC20
# cat 146, mi = 0.01241514, GNF2_HMMR
# cat 166, mi = 0.01239511, GNF2_MCM4
# cat 199, mi = 0.01180306, GNF2_RFC4
# cat 135, mi = 0.01146347, GNF2_FEN1
# cat 123, mi = 0.01103631, GNF2_CKS2
# cat 96, mi = 0.01100859, GNF2_BUB1B
# cat 120, mi = 0.01055475, GNF2_CENPE
#
# RESULTS
# Passed: cat 104, mi = 0.018, pvalue = 0.000, GNF2_CCNA2
# Passed: cat 738, mi = 0.007, pvalue = 0.000, MORF_HAT1
# Passed: cat 772, mi = 0.005, pvalue = 0.000, MORF_NME2
# Passed: cat 533, mi = 0.003, pvalue = 0.000, MODULE_436
# Passed: cat 372, mi = 0.003, pvalue = 0.000, MODULE_239
# Passed: cat 788, mi = 0.002, pvalue = 0.000, MORF_PPP2R5E
# Passed: cat 186, mi = 0.002, pvalue = 0.000, GNF2_PPP6C
# Passed: cat 249, mi = 0.002, pvalue = 0.000, MODULE_113
# Passed: cat 23, mi = 0.002, pvalue = 0.000, GCM_CSNK1A1
# Passed: cat 347, mi = 0.002, pvalue = 0.000, MODULE_209
# Passed: cat 149, mi = 0.002, pvalue = 0.001, GNF2_ICAM3
# Passed: cat 454, mi = 0.002, pvalue = 0.001, MODULE_332
# Passed: cat 44, mi = 0.002, pvalue = 0.002, GCM_ING1
# Passed: cat 559, mi = 0.001, pvalue = 0.000, MODULE_478
# Didn't pass (cutoff=0.0050): cat 92, mi = 0.001, pvalue = 0.007, GNF2_ATM
# Didn't pass (cutoff=0.0050): cat 486, mi = 0.001, pvalue = 0.009, MODULE_375
# Didn't pass (cutoff=0.0050): cat 49, mi = 0.001, pvalue = 0.007, GCM_MAX
# Didn't pass (cutoff=0.0050): cat 823, mi = 0.001, pvalue = 0.005, MORF_RFC1
# Didn't pass (cutoff=0.0050): cat 431, mi = 0.001, pvalue = 0.009, MODULE_308
# Didn't pass (cutoff=0.0050): cat 259, mi = 0.001, pvalue = 0.010, MODULE_122
# Didn't pass (cutoff=0.0050): cat 192, mi = 0.001, pvalue = 0.012, GNF2_RAB3A
# Didn't pass (cutoff=0.0050): cat 137, mi = 0.001, pvalue = 0.015, GNF2_FOS
# Didn't pass (cutoff=0.0050): cat 641, mi = 0.001, pvalue = 0.014, MODULE_78
# Didn't pass (cutoff=0.0050): cat 98, mi = 0.001, pvalue = 0.019, GNF2_CARD15
# Didn't pass (cutoff=0.0050): cat 276, mi = 0.001, pvalue = 0.023, MODULE_138
# Didn't pass (cutoff=0.0050): cat 538, mi = 0.001, pvalue = 0.005, MODULE_444
# Didn't pass (cutoff=0.0050): cat 337, mi = 0.001, pvalue = 0.028, MODULE_20
# Didn't pass (cutoff=0.0050): cat 103, mi = 0.001, pvalue = 0.040, GNF2_CCNA1
# Didn't pass (cutoff=0.0050): cat 129, mi = 0.001, pvalue = 0.035, GNF2_DNM1
# Didn't pass (cutoff=0.0050): cat 412, mi = 0.001, pvalue = 0.053, MODULE_287
# Didn't pass (cutoff=0.0050): cat 571, mi = 0.001, pvalue = 0.045, MODULE_493
# Didn't pass (cutoff=0.0050): cat 437, mi = 0.001, pvalue = 0.070, MODULE_316
# Didn't pass (cutoff=0.0050): cat 477, mi = 0.001, pvalue = 0.045, MODULE_362
# Didn't pass (cutoff=0.0050): cat 278, mi = 0.001, pvalue = 0.022, MODULE_14
# Total number of categories evaluated = 289.
# Number of categories that passed the tests = 14
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 9, 10, 0.0334620237007557
# best merge is 3, 9, 0.0815849539999725
# best merge is 2, 5, 0.187174888973373
# best merge is 2, 4, 0.229847320255968
# best merge is 6, 8, 0.23429562168949
# best merge is 3, 7, 0.242794773106974
# best merge is 1, 12, 0.244458878175741
# best merge is 3, 13, 0.353064739827775
# best merge is 2, 6, 0.358732288417511
# best merge is 1, 2, 0.493476188173912
# order classes
# 2 - 0.855606073615093
# 5 - 0.67951718949629
# 5 - 0.52354964711453
# 3 9 10 7 13
# 1 12
# 2 5 4 6 8
# 0
# 11
# Done.Start drawing
# 11.42	0.00
# MODULE_436
# MODULE_209
# GNF2_ICAM3
# MODULE_113
# MODULE_478
# MODULE_239
# MORF_NME2
# MORF_PPP2R5E
# GNF2_PPP6C
# GCM_CSNK1A1
# MODULE_332
# MORF_HAT1
# GCM_ING1
# GNF2_CCNA2
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 9, 10, 0.0334620237007557
# best merge is 3, 9, 0.0815849539999725
# best merge is 2, 5, 0.187174888973373
# best merge is 2, 4, 0.229847320255968
# best merge is 6, 8, 0.23429562168949
# best merge is 3, 7, 0.242794773106974
# best merge is 1, 12, 0.244458878175741
# best merge is 3, 13, 0.353064739827775
# best merge is 2, 6, 0.358732288417511
# best merge is 1, 2, 0.493476188173912
# order classes
# 2 - 0.855606073615093
# 5 - 0.67951718949629
# 5 - 0.52354964711453
# 3 9 10 7 13
# 1 12
# 2 5 4 6 8
# 0
# 11
# Done.-19.1725043782837	42	0
# -18.1059544658494	42	1.65499124343257
# -17.7381786339755	42	2.13309982486865
# -17.4807355516637	42	2.39054290718039
# -17.223292469352	42	2.64798598949212
# -16.9658493870403	42	2.90542907180385
# -16.6348511383538	42	3.16287215411559
# -16.0831873905429	42	3.56742556917688
# 3.13309982486865	42	4.2661996497373
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c4/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# sem --wait done
