# %% [markdown]
# # This is used for running data vs human_msigdb_c5 annotations located in:
# ### /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c5

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import scipy.stats

# %% [markdown]
# ### get index of file names to loop through

# %%
# %%bash
#
# cd fc_values
# ls FC* > filelist.txt
# cd ..

# %% [markdown]
# ### get ensembl genes represented in iPAGE database

# %%
# %%bash
#
# cp /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c5/human_ensembl_msigdb_c5_index.txt human_ensembl_index.txt
# awk '{print $1}' human_ensembl_index.txt > ensembl_index.txt

# %% [markdown]
# ### make sure that genes in file match the index

# %%
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
###################REMEMBER TO SPECIFY INDEX USED IN THE IPAGE COMMAND!!!!!!!!
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#####################
#######read in data from logfc calculations
#####################
####define index file to loop through
index_file = "fc_values/filelist.txt"
####define matching ensg index
GO_index_filename = "ensembl_index.txt"
genes_with_GOs = []
with open(GO_index_filename,'r') as rf:
    for line in rf:
        gene_name = line.split('\n')[0]
        genes_with_GOs.append(gene_name)
genes_with_GOs_set = set(genes_with_GOs)
####open file and loop through each line
###
iPAGE_sh = "iPAGE_JY.sh"
cwd = os.getcwd()+"/"
os.system("rm "+iPAGE_sh)
###
with open(index_file,'r') as rf:
    for line in rf:
        #####do this to each file
        ###read in file into pandas df
        FC_file = "fc_values/"+line.split('\n')[0]
        FC_df = pd.read_csv(FC_file,sep=',',index_col=0)
        FC_df.columns = ['log2FoldChange']
        FC_df.index.names = ['Gene']
        ###filter
        FC_df = FC_df.loc[[x for x in FC_df.index if x in genes_with_GOs_set]]
        ###save
        save_file = "fc_values/filt_"+line.split('\n')[0]
        FC_df.to_csv(save_file,sep='\t',header=True)
        ###write final iPAGE command to an ipage .sh file
        iPAGE_cmd = "perl /nvme/bins/iPAGEv1.0/page.pl --expfile "+cwd+save_file+" --species=human_ensembl_msigdb_c5 --exptype=continuous --ebins=9 \n"
        with open(iPAGE_sh, "a") as myfile:
            myfile.write(iPAGE_cmd)

# %% [markdown]
# ## then run the command from this folder:
#
# nohup sh run.sh iPAGE_JY.sh &

# %%
# %%bash
#
# nohup sh run.sh iPAGE_JY.sh &
# Out:
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv --species=human_ensembl_msigdb_c5 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv --species=human_ensembl_msigdb_c5 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c5.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c5/human_ensembl_msigdb_c5.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 5917
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	5917
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 5917
# cat 5718, mi = 0.00908166, GO_TRANSLATIONAL_INITIATION
# cat 957, mi = 0.00768792, GO_CYTOSOLIC_RIBOSOME
# cat 1292, mi = 0.00753814, GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 3995, mi = 0.00728464, GO_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 2928, mi = 0.00724583, GO_NUCLEAR_TRANSCRIBED_MRNA_CATABOLIC_PROCESS_NONSENSE_MEDIATED_DECAY
# cat 5245, mi = 0.00701733, GO_RIBOSOMAL_SUBUNIT
# cat 2330, mi = 0.00688124, GO_MULTI_ORGANISM_METABOLIC_PROCESS
# cat 954, mi = 0.00543160, GO_CYTOSOLIC_LARGE_RIBOSOMAL_SUBUNIT
# cat 1742, mi = 0.00482901, GO_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX
# cat 2219, mi = 0.00474518, GO_MITOCHONDRIAL_PROTEIN_COMPLEX
# cat 1889, mi = 0.00473827, GO_LARGE_RIBOSOMAL_SUBUNIT
# cat 5028, mi = 0.00441530, GO_RESPIRATORY_CHAIN
# cat 4041, mi = 0.00439074, GO_PROTEIN_TARGETING_TO_MEMBRANE
# cat 5499, mi = 0.00419922, GO_SPLICEOSOMAL_COMPLEX
# cat 2224, mi = 0.00399003, GO_MITOCHONDRIAL_TRANSLATION
#
# RESULTS
# Passed: cat 5718, mi = 0.009, pvalue = 0.000, GO_TRANSLATIONAL_INITIATION
# Passed: cat 1742, mi = 0.005, pvalue = 0.000, GO_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX
# Passed: cat 5499, mi = 0.004, pvalue = 0.000, GO_SPLICEOSOMAL_COMPLEX
# Passed: cat 2224, mi = 0.004, pvalue = 0.000, GO_MITOCHONDRIAL_TRANSLATION
# Passed: cat 1066, mi = 0.004, pvalue = 0.000, GO_DNA_DEPENDENT_DNA_REPLICATION
# Passed: cat 1670, mi = 0.003, pvalue = 0.000, GO_HORMONE_ACTIVITY
# Passed: cat 3734, mi = 0.003, pvalue = 0.000, GO_POSITIVE_REGULATION_OF_PROTEIN_MODIFICATION_BY_SMALL_PROTEIN_CONJUGATION_OR_REMOVAL
# Passed: cat 3073, mi = 0.002, pvalue = 0.000, GO_OUTER_MEMBRANE
# Passed: cat 536, mi = 0.002, pvalue = 0.000, GO_CELLULAR_RESPONSE_TO_AMINO_ACID_STARVATION
# Passed: cat 1925, mi = 0.002, pvalue = 0.000, GO_LIGAND_GATED_CHANNEL_ACTIVITY
# Passed: cat 2097, mi = 0.002, pvalue = 0.000, GO_MEMBRANE_BUDDING
# Passed: cat 1738, mi = 0.002, pvalue = 0.000, GO_INNER_EAR_MORPHOGENESIS
# Passed: cat 4711, mi = 0.002, pvalue = 0.000, GO_REGULATION_OF_ODONTOGENESIS
# Passed: cat 1994, mi = 0.002, pvalue = 0.001, GO_LYMPHOCYTE_MEDIATED_IMMUNITY
# Passed: cat 5181, mi = 0.002, pvalue = 0.002, GO_RESPONSE_TO_TYPE_I_INTERFERON
# Passed: cat 5023, mi = 0.002, pvalue = 0.001, GO_REPRESSING_TRANSCRIPTION_FACTOR_BINDING
# Passed: cat 5266, mi = 0.002, pvalue = 0.001, GO_RNA_MODIFICATION
# Passed: cat 5813, mi = 0.002, pvalue = 0.002, GO_UNFOLDED_PROTEIN_BINDING
# Passed: cat 3883, mi = 0.002, pvalue = 0.002, GO_PRESYNAPTIC_MEMBRANE
# Passed: cat 3323, mi = 0.002, pvalue = 0.001, GO_POLYAMINE_METABOLIC_PROCESS
# Passed: cat 4122, mi = 0.002, pvalue = 0.001, GO_RAC_PROTEIN_SIGNAL_TRANSDUCTION
# Passed: cat 1342, mi = 0.001, pvalue = 0.002, GO_EXTRACELLULAR_MATRIX_COMPONENT
# Passed: cat 1238, mi = 0.001, pvalue = 0.003, GO_EPHRIN_RECEPTOR_SIGNALING_PATHWAY
# Passed: cat 723, mi = 0.001, pvalue = 0.000, GO_CEREBELLAR_GRANULAR_LAYER_DEVELOPMENT
# Passed: cat 1654, mi = 0.001, pvalue = 0.003, GO_HISTONE_METHYLTRANSFERASE_COMPLEX
# Passed: cat 361, mi = 0.001, pvalue = 0.004, GO_BRANCHED_CHAIN_AMINO_ACID_METABOLIC_PROCESS
# Passed: cat 3599, mi = 0.001, pvalue = 0.001, GO_POSITIVE_REGULATION_OF_LIPID_CATABOLIC_PROCESS
# Passed: cat 1862, mi = 0.001, pvalue = 0.004, GO_KERATIN_FILAMENT
# Passed: cat 746, mi = 0.001, pvalue = 0.001, GO_CHEMOKINE_MEDIATED_SIGNALING_PATHWAY
# Didn't pass (cutoff=0.0050): cat 2266, mi = 0.001, pvalue = 0.006, GO_MONOCARBOXYLIC_ACID_BINDING
# Passed: cat 3960, mi = 0.001, pvalue = 0.005, GO_PROTEIN_HYDROXYLATION
# Didn't pass (cutoff=0.0050): cat 997, mi = 0.001, pvalue = 0.013, GO_DEOXYRIBOSE_PHOSPHATE_CATABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 710, mi = 0.001, pvalue = 0.009, GO_CENTRIOLE
# Didn't pass (cutoff=0.0050): cat 5406, mi = 0.001, pvalue = 0.015, GO_SKELETAL_MUSCLE_CELL_DIFFERENTIATION
# Didn't pass (cutoff=0.0050): cat 5218, mi = 0.001, pvalue = 0.019, GO_RETROMER_COMPLEX
# Didn't pass (cutoff=0.0050): cat 1923, mi = 0.001, pvalue = 0.016, GO_LIGAND_DEPENDENT_NUCLEAR_RECEPTOR_TRANSCRIPTION_COACTIVATOR_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 1458, mi = 0.001, pvalue = 0.010, GO_GENETIC_IMPRINTING
# Didn't pass (cutoff=0.0050): cat 1817, mi = 0.001, pvalue = 0.019, GO_INTRINSIC_COMPONENT_OF_GOLGI_MEMBRANE
# Didn't pass (cutoff=0.0050): cat 3181, mi = 0.001, pvalue = 0.009, GO_PERIPHERAL_NERVOUS_SYSTEM_NEURON_DIFFERENTIATION
# Didn't pass (cutoff=0.0050): cat 214, mi = 0.001, pvalue = 0.010, GO_APICOLATERAL_PLASMA_MEMBRANE
# Didn't pass (cutoff=0.0050): cat 5371, mi = 0.001, pvalue = 0.016, GO_SH3_DOMAIN_BINDING
# Didn't pass (cutoff=0.0050): cat 127, mi = 0.001, pvalue = 0.019, GO_ALPHA_TUBULIN_BINDING
# Didn't pass (cutoff=0.0050): cat 4102, mi = 0.001, pvalue = 0.017, GO_PYRIMIDINE_NUCLEOSIDE_MONOPHOSPHATE_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 5310, mi = 0.001, pvalue = 0.022, GO_R_SMAD_BINDING
# Didn't pass (cutoff=0.0050): cat 5731, mi = 0.001, pvalue = 0.016, GO_TRANSMEMBRANE_RECEPTOR_PROTEIN_SERINE_THREONINE_KINASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 2878, mi = 0.001, pvalue = 0.012, GO_NITRIC_OXIDE_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 4454, mi = 0.001, pvalue = 0.013, GO_REGULATION_OF_GENE_EXPRESSION_BY_GENETIC_IMPRINTING
# Didn't pass (cutoff=0.0050): cat 932, mi = 0.001, pvalue = 0.028, GO_CYTOPLASMIC_MICROTUBULE
# Didn't pass (cutoff=0.0050): cat 542, mi = 0.001, pvalue = 0.020, GO_CELLULAR_RESPONSE_TO_CADMIUM_ION
# Didn't pass (cutoff=0.0050): cat 3110, mi = 0.001, pvalue = 0.017, GO_OXIDOREDUCTASE_ACTIVITY_OXIDIZING_METAL_IONS
# Didn't pass (cutoff=0.0050): cat 2985, mi = 0.001, pvalue = 0.032, GO_NUCLEOTIDE_TRANSPORT
# Total number of categories evaluated = 418.
# Number of categories that passed the tests = 30
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 12, 23, 0.0052478442730709
# best merge is 5, 12, 0.0207763187412832
# best merge is 13, 21, 0.0444739757580203
# best merge is 1, 16, 0.0584737223168321
# best merge is 5, 27, 0.0829552139236666
# best merge is 19, 25, 0.0956511774867197
# best merge is 2, 3, 0.101732079185604
# best merge is 13, 28, 0.115450127865432
# best merge is 6, 10, 0.134401221478078
# best merge is 5, 9, 0.136186395805336
# best merge is 2, 17, 0.176289257391166
# best merge is 14, 20, 0.194284166320666
# best merge is 5, 18, 0.204394241918466
# best merge is 0, 1, 0.206681618878764
# best merge is 0, 2, 0.297564942398941
# best merge is 26, 29, 0.302273884730809
# best merge is 11, 13, 0.31701388310209
# best merge is 5, 11, 0.406790430618636
# best merge is 0, 6, 0.458498211295158
# best merge is 7, 24, 0.465404502904768
# best merge is 7, 26, 0.487066619909038
# best merge is 0, 19, 0.498057654927583
# best merge is 14, 22, 0.519322498998774
# best merge is 14, 15, 0.721340010616328
# best merge is 4, 5, 0.803497811398898
# best merge is 0, 14, 0.849027796071848
# order classes
# 10 - 1.03831112693885
# 11 - 0.941551340915328
# 4 - 2.54619831306725
# 4 - 3.18463987140675
# 4 5 12 23 27 9 18 11 13 21 28
# 0 1 16 2 3 17 6 10 19 25
# 7 24 26 29
# 8
# 14 20 22 15
# Done.Start drawing
# 23.77	0.00
# GO_DNA_DEPENDENT_DNA_REPLICATION
# GO_INNER_EAR_MORPHOGENESIS
# GO_EXTRACELLULAR_MATRIX_COMPONENT
# GO_CHEMOKINE_MEDIATED_SIGNALING_PATHWAY
# GO_CELLULAR_RESPONSE_TO_AMINO_ACID_STARVATION
# GO_RAC_PROTEIN_SIGNAL_TRANSDUCTION
# GO_REPRESSING_TRANSCRIPTION_FACTOR_BINDING
# GO_OUTER_MEMBRANE
# GO_HISTONE_METHYLTRANSFERASE_COMPLEX
# GO_POSITIVE_REGULATION_OF_LIPID_CATABOLIC_PROCESS
# GO_PROTEIN_HYDROXYLATION
# GO_SPLICEOSOMAL_COMPLEX
# GO_POSITIVE_REGULATION_OF_PROTEIN_MODIFICATION_BY_SMALL_PROTEIN_CONJUGATION_OR_REMOVAL
# GO_MEMBRANE_BUDDING
# GO_RESPONSE_TO_TYPE_I_INTERFERON
# GO_TRANSLATIONAL_INITIATION
# GO_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX
# GO_RNA_MODIFICATION
# GO_MITOCHONDRIAL_TRANSLATION
# GO_POLYAMINE_METABOLIC_PROCESS
# GO_BRANCHED_CHAIN_AMINO_ACID_METABOLIC_PROCESS
# GO_UNFOLDED_PROTEIN_BINDING
# GO_HORMONE_ACTIVITY
# GO_REGULATION_OF_ODONTOGENESIS
# GO_CEREBELLAR_GRANULAR_LAYER_DEVELOPMENT
# GO_KERATIN_FILAMENT
# GO_LIGAND_GATED_CHANNEL_ACTIVITY
# GO_PRESYNAPTIC_MEMBRANE
# GO_LYMPHOCYTE_MEDIATED_IMMUNITY
# GO_EPHRIN_RECEPTOR_SIGNALING_PATHWAY
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 12, 23, 0.0052478442730709
# best merge is 5, 12, 0.0207763187412832
# best merge is 13, 21, 0.0444739757580203
# best merge is 1, 16, 0.0584737223168321
# best merge is 5, 27, 0.0829552139236666
# best merge is 19, 25, 0.0956511774867197
# best merge is 2, 3, 0.101732079185604
# best merge is 13, 28, 0.115450127865432
# best merge is 6, 10, 0.134401221478078
# best merge is 5, 9, 0.136186395805336
# best merge is 2, 17, 0.176289257391166
# best merge is 14, 20, 0.194284166320666
# best merge is 5, 18, 0.204394241918466
# best merge is 0, 1, 0.206681618878764
# best merge is 0, 2, 0.297564942398941
# best merge is 26, 29, 0.302273884730809
# best merge is 11, 13, 0.31701388310209
# best merge is 5, 11, 0.406790430618636
# best merge is 0, 6, 0.458498211295158
# best merge is 7, 24, 0.465404502904768
# best merge is 7, 26, 0.487066619909038
# best merge is 0, 19, 0.498057654927583
# best merge is 14, 22, 0.519322498998774
# best merge is 14, 15, 0.721340010616328
# best merge is 4, 5, 0.803497811398898
# best merge is 0, 14, 0.849027796071848
# order classes
# 10 - 1.03831112693885
# 11 - 0.941551340915328
# 4 - 2.54619831306725
# 4 - 3.18463987140675
# 4 5 12 23 27 9 18 11 13 21 28
# 0 1 16 2 3 17 6 10 19 25
# 7 24 26 29
# 8
# 14 20 22 15
# Done.-19.2932267564156	42	0
# -18.4450988641144	42	1.4135464871687
# -18.2153975599495	42	1.69625578460244
# -18.056373580143	42	1.87294909549853
# -17.8973496003366	42	2.0143037442154
# -17.7206562894405	42	2.19099705511149
# -17.51745898191	42	2.36769036600757
# -17.2082456878418	42	2.59739167017249
# 2.49305847707194	42	2.98611695414388
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv --species=human_ensembl_msigdb_c5 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_4.csv --species=human_ensembl_msigdb_c5 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM2_1.csv --species=human_ensembl_msigdb_c5 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c5.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c5/human_ensembl_msigdb_c5.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 5917
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	5917
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 5917
# cat 5718, mi = 0.01013899, GO_TRANSLATIONAL_INITIATION
# cat 5245, mi = 0.00953739, GO_RIBOSOMAL_SUBUNIT
# cat 957, mi = 0.00937893, GO_CYTOSOLIC_RIBOSOME
# cat 1292, mi = 0.00937749, GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 3995, mi = 0.00920386, GO_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 2928, mi = 0.00740830, GO_NUCLEAR_TRANSCRIBED_MRNA_CATABOLIC_PROCESS_NONSENSE_MEDIATED_DECAY
# cat 5402, mi = 0.00730854, GO_SISTER_CHROMATID_SEGREGATION
# cat 954, mi = 0.00705280, GO_CYTOSOLIC_LARGE_RIBOSOMAL_SUBUNIT
# cat 775, mi = 0.00696452, GO_CHROMOSOME_CENTROMERIC_REGION
# cat 1889, mi = 0.00668053, GO_LARGE_RIBOSOMAL_SUBUNIT
# cat 2219, mi = 0.00651516, GO_MITOCHONDRIAL_PROTEIN_COMPLEX
# cat 5401, mi = 0.00628640, GO_SISTER_CHROMATID_COHESION
# cat 1742, mi = 0.00617964, GO_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX
# cat 4041, mi = 0.00611530, GO_PROTEIN_TARGETING_TO_MEMBRANE
# cat 2330, mi = 0.00590350, GO_MULTI_ORGANISM_METABOLIC_PROCESS
#
# RESULTS
# Passed: cat 5718, mi = 0.010, pvalue = 0.000, GO_TRANSLATIONAL_INITIATION
# Passed: cat 5402, mi = 0.007, pvalue = 0.000, GO_SISTER_CHROMATID_SEGREGATION
# Passed: cat 2219, mi = 0.007, pvalue = 0.000, GO_MITOCHONDRIAL_PROTEIN_COMPLEX
# Passed: cat 5499, mi = 0.005, pvalue = 0.000, GO_SPLICEOSOMAL_COMPLEX
# Passed: cat 2224, mi = 0.004, pvalue = 0.000, GO_MITOCHONDRIAL_TRANSLATION
# Passed: cat 1680, mi = 0.003, pvalue = 0.000, GO_HUMORAL_IMMUNE_RESPONSE
# Passed: cat 5888, mi = 0.002, pvalue = 0.000, GO_VOLTAGE_GATED_POTASSIUM_CHANNEL_ACTIVITY
# Passed: cat 3910, mi = 0.002, pvalue = 0.000, GO_PROTEASOME_COMPLEX
# Passed: cat 5678, mi = 0.002, pvalue = 0.000, GO_TRANSCRIPTION_ELONGATION_FROM_RNA_POLYMERASE_II_PROMOTER
# Passed: cat 5266, mi = 0.002, pvalue = 0.000, GO_RNA_MODIFICATION
# Passed: cat 875, mi = 0.002, pvalue = 0.000, GO_CORE_PROMOTER_SEQUENCE_SPECIFIC_DNA_BINDING
# Passed: cat 640, mi = 0.002, pvalue = 0.000, GO_CELL_CHEMOTAXIS
# Passed: cat 4838, mi = 0.002, pvalue = 0.000, GO_REGULATION_OF_RESPONSE_TO_EXTRACELLULAR_STIMULUS
# Passed: cat 1397, mi = 0.002, pvalue = 0.000, GO_FIBROBLAST_GROWTH_FACTOR_RECEPTOR_BINDING
# Passed: cat 5802, mi = 0.002, pvalue = 0.000, GO_UBIQUITIN_LIKE_PROTEIN_CONJUGATING_ENZYME_ACTIVITY
# Passed: cat 3201, mi = 0.002, pvalue = 0.000, GO_PHOSPHATASE_COMPLEX
# Passed: cat 4228, mi = 0.002, pvalue = 0.000, GO_REGULATION_OF_CALCIUM_MEDIATED_SIGNALING
# Passed: cat 1700, mi = 0.002, pvalue = 0.000, GO_HYDRO_LYASE_ACTIVITY
# Passed: cat 2266, mi = 0.002, pvalue = 0.000, GO_MONOCARBOXYLIC_ACID_BINDING
# Passed: cat 25, mi = 0.002, pvalue = 0.001, GO_ACID_SECRETION
# Passed: cat 3114, mi = 0.002, pvalue = 0.000, GO_OXYGEN_BINDING
# Passed: cat 4903, mi = 0.002, pvalue = 0.001, GO_REGULATION_OF_SYNAPSE_ASSEMBLY
# Passed: cat 5268, mi = 0.002, pvalue = 0.001, GO_RNA_PHOSPHODIESTER_BOND_HYDROLYSIS_ENDONUCLEOLYTIC
# Passed: cat 4127, mi = 0.002, pvalue = 0.001, GO_RAS_PROTEIN_SIGNAL_TRANSDUCTION
# Passed: cat 2137, mi = 0.002, pvalue = 0.001, GO_METALLO_SULFUR_CLUSTER_ASSEMBLY
# Passed: cat 2807, mi = 0.002, pvalue = 0.002, GO_NEURAL_PRECURSOR_CELL_PROLIFERATION
# Passed: cat 1808, mi = 0.002, pvalue = 0.004, GO_INTRA_GOLGI_VESICLE_MEDIATED_TRANSPORT
# Passed: cat 3702, mi = 0.001, pvalue = 0.002, GO_POSITIVE_REGULATION_OF_PEPTIDYL_THREONINE_PHOSPHORYLATION
# Passed: cat 4924, mi = 0.001, pvalue = 0.003, GO_REGULATION_OF_TELOMERE_MAINTENANCE_VIA_TELOMERE_LENGTHENING
# Passed: cat 930, mi = 0.001, pvalue = 0.002, GO_CYTOPLASMIC_DYNEIN_COMPLEX
# Passed: cat 508, mi = 0.001, pvalue = 0.004, GO_CELLULAR_DEFENSE_RESPONSE
# Passed: cat 4011, mi = 0.001, pvalue = 0.001, GO_PROTEIN_NEDDYLATION
# Passed: cat 5571, mi = 0.001, pvalue = 0.005, GO_SWI_SNF_SUPERFAMILY_TYPE_COMPLEX
# Didn't pass (cutoff=0.0050): cat 536, mi = 0.001, pvalue = 0.007, GO_CELLULAR_RESPONSE_TO_AMINO_ACID_STARVATION
# Passed: cat 1946, mi = 0.001, pvalue = 0.001, GO_LIPID_PARTICLE_ORGANIZATION
# Didn't pass (cutoff=0.0050): cat 464, mi = 0.001, pvalue = 0.007, GO_CARGO_RECEPTOR_ACTIVITY
# Passed: cat 2106, mi = 0.001, pvalue = 0.004, GO_MEMBRANE_LIPID_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 693, mi = 0.001, pvalue = 0.007, GO_CELL_REDOX_HOMEOSTASIS
# Didn't pass (cutoff=0.0050): cat 1597, mi = 0.001, pvalue = 0.006, GO_HEAT_SHOCK_PROTEIN_BINDING
# Didn't pass (cutoff=0.0050): cat 1630, mi = 0.001, pvalue = 0.008, GO_HIPPO_SIGNALING
# Passed: cat 2254, mi = 0.001, pvalue = 0.001, GO_MODIFIED_AMINO_ACID_TRANSMEMBRANE_TRANSPORTER_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 2114, mi = 0.001, pvalue = 0.009, GO_MEMBRANE_PROTEIN_PROTEOLYSIS
# Didn't pass (cutoff=0.0050): cat 1862, mi = 0.001, pvalue = 0.008, GO_KERATIN_FILAMENT
# Didn't pass (cutoff=0.0050): cat 88, mi = 0.001, pvalue = 0.008, GO_ADENYLATE_CYCLASE_INHIBITING_G_PROTEIN_COUPLED_RECEPTOR_SIGNALING_PATHWAY
# Didn't pass (cutoff=0.0050): cat 5407, mi = 0.001, pvalue = 0.010, GO_SKELETAL_MUSCLE_CONTRACTION
# Didn't pass (cutoff=0.0050): cat 1779, mi = 0.001, pvalue = 0.011, GO_INTERMEDIATE_FILAMENT
# Didn't pass (cutoff=0.0050): cat 4161, mi = 0.001, pvalue = 0.014, GO_REGULATION_OF_ACTIN_FILAMENT_DEPOLYMERIZATION
# Didn't pass (cutoff=0.0050): cat 1752, mi = 0.001, pvalue = 0.006, GO_INOSITOL_PHOSPHATE_CATABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 2112, mi = 0.001, pvalue = 0.015, GO_MEMBRANE_PROTEIN_ECTODOMAIN_PROTEOLYSIS
# Didn't pass (cutoff=0.0050): cat 1511, mi = 0.001, pvalue = 0.007, GO_GLYCINE_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 210, mi = 0.001, pvalue = 0.012, GO_APICAL_JUNCTION_COMPLEX
# Didn't pass (cutoff=0.0050): cat 4089, mi = 0.001, pvalue = 0.015, GO_PYRIDINE_CONTAINING_COMPOUND_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 1483, mi = 0.001, pvalue = 0.015, GO_GLUCOSE_6_PHOSPHATE_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 1412, mi = 0.001, pvalue = 0.018, GO_FOLIC_ACID_CONTAINING_COMPOUND_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 5356, mi = 0.001, pvalue = 0.021, GO_SERINE_FAMILY_AMINO_ACID_METABOLIC_PROCESS
# Passed: cat 3922, mi = 0.001, pvalue = 0.003, GO_PROTEIN_BINDING_INVOLVED_IN_CELL_CELL_ADHESION
# Didn't pass (cutoff=0.0050): cat 5554, mi = 0.001, pvalue = 0.022, GO_SULFOTRANSFERASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3943, mi = 0.001, pvalue = 0.027, GO_PROTEIN_DISULFIDE_OXIDOREDUCTASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 241, mi = 0.001, pvalue = 0.022, GO_ASPARTATE_FAMILY_AMINO_ACID_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 233, mi = 0.001, pvalue = 0.020, GO_ARP2_3_COMPLEX_MEDIATED_ACTIN_NUCLEATION
# Didn't pass (cutoff=0.0050): cat 657, mi = 0.001, pvalue = 0.025, GO_CELL_DIFFERENTIATION_INVOLVED_IN_EMBRYONIC_PLACENTA_DEVELOPMENT
# Didn't pass (cutoff=0.0050): cat 3011, mi = 0.001, pvalue = 0.017, GO_OMEGA_PEPTIDASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 1859, mi = 0.001, pvalue = 0.020, GO_KERATINIZATION
# Didn't pass (cutoff=0.0050): cat 1656, mi = 0.001, pvalue = 0.022, GO_HISTONE_MRNA_CATABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 2941, mi = 0.001, pvalue = 0.029, GO_NUCLEOBASE_CONTAINING_SMALL_MOLECULE_INTERCONVERSION
# Didn't pass (cutoff=0.0050): cat 2315, mi = 0.001, pvalue = 0.031, GO_MULTICELLULAR_ORGANISMAL_MOVEMENT
# Didn't pass (cutoff=0.0050): cat 4481, mi = 0.001, pvalue = 0.014, GO_REGULATION_OF_HAIR_FOLLICLE_DEVELOPMENT
# Didn't pass (cutoff=0.0050): cat 143, mi = 0.001, pvalue = 0.035, GO_AMINOPEPTIDASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3185, mi = 0.001, pvalue = 0.024, GO_PEROXISOME_PROLIFERATOR_ACTIVATED_RECEPTOR_BINDING
# Didn't pass (cutoff=0.0050): cat 3804, mi = 0.001, pvalue = 0.039, GO_POSITIVE_REGULATION_OF_TOR_SIGNALING
# Didn't pass (cutoff=0.0050): cat 285, mi = 0.001, pvalue = 0.014, GO_AXONEMAL_DYNEIN_COMPLEX_ASSEMBLY
# Didn't pass (cutoff=0.0050): cat 1196, mi = 0.001, pvalue = 0.018, GO_ENDOPLASMIC_RETICULUM_CHAPERONE_COMPLEX
# Didn't pass (cutoff=0.0050): cat 4383, mi = 0.001, pvalue = 0.034, GO_REGULATION_OF_DNA_RECOMBINATION
# Didn't pass (cutoff=0.0050): cat 152, mi = 0.001, pvalue = 0.014, GO_AMINO_SUGAR_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 2048, mi = 0.001, pvalue = 0.015, GO_MALE_MEIOSIS_I
# Didn't pass (cutoff=0.0050): cat 1049, mi = 0.001, pvalue = 0.044, GO_DISULFIDE_OXIDOREDUCTASE_ACTIVITY
# Total number of categories evaluated = 683.
# Number of categories that passed the tests = 37
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 11, 20, 0.0186537847460208
# best merge is 7, 12, 0.0278861958208704
# best merge is 11, 13, 0.029873471542103
# best merge is 21, 36, 0.0389975847187496
# best merge is 11, 21, 0.0601389647910748
# best merge is 3, 7, 0.0651457837717133
# best merge is 5, 6, 0.0743952199802784
# best merge is 11, 19, 0.0842054963874696
# best merge is 0, 17, 0.109152107455912
# best merge is 14, 15, 0.12972979765357
# best merge is 0, 2, 0.149675543646246
# best merge is 5, 11, 0.162906798310565
# best merge is 27, 33, 0.17533431886939
# best merge is 3, 4, 0.178472009725652
# best merge is 1, 23, 0.191195099158667
# best merge is 8, 26, 0.20162017194658
# best merge is 24, 31, 0.240440962972062
# best merge is 9, 22, 0.240654265111348
# best merge is 10, 14, 0.266227705770157
# best merge is 3, 8, 0.331008340235601
# best merge is 10, 27, 0.352586794041688
# best merge is 5, 18, 0.375149099041071
# best merge is 0, 9, 0.422818687620827
# best merge is 29, 32, 0.444326413162644
# best merge is 5, 35, 0.468960147134373
# best merge is 1, 16, 0.481566344857805
# best merge is 3, 28, 0.539542579485109
# best merge is 1, 25, 0.574627847553499
# best merge is 3, 24, 0.644743245888819
# best merge is 3, 29, 0.658786514550419
# best merge is 1, 30, 0.702628579365791
# best merge is 0, 3, 0.785253900526703
# best merge is 1, 10, 0.830128047378323
# order classes
# 16 - 1.35001040686422
# 5 - 3.36772558420678
# 10 - 0.751127416961354
# 5 - 1.74819985304953
# 5 6 11 20 13 21 36 19 18 35
# 1 23 16 25 30
# 0 17 2 9 22 3 7 12 4 8 26 28 24 31 29 32
# 10 14 15 27 33
# 34
# Done.Start drawing
# 62.96	0.00
# GO_SISTER_CHROMATID_SEGREGATION
# GO_RAS_PROTEIN_SIGNAL_TRANSDUCTION
# GO_REGULATION_OF_CALCIUM_MEDIATED_SIGNALING
# GO_NEURAL_PRECURSOR_CELL_PROLIFERATION
# GO_CELLULAR_DEFENSE_RESPONSE
# GO_MEMBRANE_LIPID_BIOSYNTHETIC_PROCESS
# GO_PROTEASOME_COMPLEX
# GO_CORE_PROMOTER_SEQUENCE_SPECIFIC_DNA_BINDING
# GO_UBIQUITIN_LIKE_PROTEIN_CONJUGATING_ENZYME_ACTIVITY
# GO_PHOSPHATASE_COMPLEX
# GO_POSITIVE_REGULATION_OF_PEPTIDYL_THREONINE_PHOSPHORYLATION
# GO_LIPID_PARTICLE_ORGANIZATION
# GO_TRANSCRIPTION_ELONGATION_FROM_RNA_POLYMERASE_II_PROMOTER
# GO_CYTOPLASMIC_DYNEIN_COMPLEX
# GO_SPLICEOSOMAL_COMPLEX
# GO_METALLO_SULFUR_CLUSTER_ASSEMBLY
# GO_PROTEIN_NEDDYLATION
# GO_SWI_SNF_SUPERFAMILY_TYPE_COMPLEX
# GO_RNA_MODIFICATION
# GO_REGULATION_OF_RESPONSE_TO_EXTRACELLULAR_STIMULUS
# GO_INTRA_GOLGI_VESICLE_MEDIATED_TRANSPORT
# GO_REGULATION_OF_TELOMERE_MAINTENANCE_VIA_TELOMERE_LENGTHENING
# GO_TRANSLATIONAL_INITIATION
# GO_HYDRO_LYASE_ACTIVITY
# GO_MITOCHONDRIAL_PROTEIN_COMPLEX
# GO_MITOCHONDRIAL_TRANSLATION
# GO_RNA_PHOSPHODIESTER_BOND_HYDROLYSIS_ENDONUCLEOLYTIC
# GO_HUMORAL_IMMUNE_RESPONSE
# GO_VOLTAGE_GATED_POTASSIUM_CHANNEL_ACTIVITY
# GO_CELL_CHEMOTAXIS
# GO_OXYGEN_BINDING
# GO_FIBROBLAST_GROWTH_FACTOR_RECEPTOR_BINDING
# GO_REGULATION_OF_SYNAPSE_ASSEMBLY
# GO_PROTEIN_BINDING_INVOLVED_IN_CELL_CELL_ADHESION
# GO_ACID_SECRETION
# GO_MONOCARBOXYLIC_ACID_BINDING
# GO_MODIFIED_AMINO_ACID_TRANSMEMBRANE_TRANSPORTER_ACTIVITY
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 11, 20, 0.0186537847460208
# best merge is 7, 12, 0.0278861958208704
# best merge is 11, 13, 0.029873471542103
# best merge is 21, 36, 0.0389975847187496
# best merge is 11, 21, 0.0601389647910748
# best merge is 3, 7, 0.0651457837717133
# best merge is 5, 6, 0.0743952199802784
# best merge is 11, 19, 0.0842054963874696
# best merge is 0, 17, 0.109152107455912
# best merge is 14, 15, 0.12972979765357
# best merge is 0, 2, 0.149675543646246
# best merge is 5, 11, 0.162906798310565
# best merge is 27, 33, 0.17533431886939
# best merge is 3, 4, 0.178472009725652
# best merge is 1, 23, 0.191195099158667
# best merge is 8, 26, 0.20162017194658
# best merge is 24, 31, 0.240440962972062
# best merge is 9, 22, 0.240654265111348
# best merge is 10, 14, 0.266227705770157
# best merge is 3, 8, 0.331008340235601
# best merge is 10, 27, 0.352586794041688
# best merge is 5, 18, 0.375149099041071
# best merge is 0, 9, 0.422818687620827
# best merge is 29, 32, 0.444326413162644
# best merge is 5, 35, 0.468960147134373
# best merge is 1, 16, 0.481566344857805
# best merge is 3, 28, 0.539542579485109
# best merge is 1, 25, 0.574627847553499
# best merge is 3, 24, 0.644743245888819
# best merge is 3, 29, 0.658786514550419
# best merge is 1, 30, 0.702628579365791
# best merge is 0, 3, 0.785253900526703
# best merge is 1, 10, 0.830128047378323
# order classes
# 16 - 1.35001040686422
# 5 - 3.36772558420678
# 10 - 0.751127416961354
# 5 - 1.74819985304953
# 5 6 11 20 13 21 36 19 18 35
# 1 23 16 25 30
# 0 17 2 9 22 3 7 12 4 8 26 28 24 31 29 32
# 10 14 15 27 33
# 34
# Done.-19.7198221092757	42	0
# -19.3562579415502	42	0.560355781448539
# -19.2195044472681	42	0.72712833545108
# -19.1227763659466	42	0.833862770012706
# -19.0360546378653	42	0.920584498094028
# -18.9459974587039	42	1.00730622617535
# -18.8359275730623	42	1.10069885641677
# -18.6558132147395	42	1.2274459974587
# 1.73046378653113	42	1.46092757306226
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c5.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c5/human_ensembl_msigdb_c5.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 5917
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	5917
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 5917
# cat 5245, mi = 0.00970964, GO_RIBOSOMAL_SUBUNIT
# cat 957, mi = 0.00802317, GO_CYTOSOLIC_RIBOSOME
# cat 2928, mi = 0.00792258, GO_NUCLEAR_TRANSCRIBED_MRNA_CATABOLIC_PROCESS_NONSENSE_MEDIATED_DECAY
# cat 1292, mi = 0.00787130, GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 3995, mi = 0.00750510, GO_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 854, mi = 0.00742650, GO_CONDENSED_CHROMOSOME
# cat 5718, mi = 0.00735425, GO_TRANSLATIONAL_INITIATION
# cat 1889, mi = 0.00671222, GO_LARGE_RIBOSOMAL_SUBUNIT
# cat 5402, mi = 0.00666214, GO_SISTER_CHROMATID_SEGREGATION
# cat 2330, mi = 0.00606449, GO_MULTI_ORGANISM_METABOLIC_PROCESS
# cat 4041, mi = 0.00573502, GO_PROTEIN_TARGETING_TO_MEMBRANE
# cat 1086, mi = 0.00526906, GO_DNA_PACKAGING
# cat 855, mi = 0.00523244, GO_CONDENSED_CHROMOSOME_CENTROMERIC_REGION
# cat 5401, mi = 0.00516008, GO_SISTER_CHROMATID_COHESION
# cat 5719, mi = 0.00499723, GO_TRANSLATIONAL_TERMINATION
#
# RESULTS
# Passed: cat 5245, mi = 0.010, pvalue = 0.000, GO_RIBOSOMAL_SUBUNIT
# Passed: cat 854, mi = 0.007, pvalue = 0.000, GO_CONDENSED_CHROMOSOME
# Passed: cat 2217, mi = 0.005, pvalue = 0.000, GO_MITOCHONDRIAL_MEMBRANE_PART
# Passed: cat 1102, mi = 0.003, pvalue = 0.000, GO_DNA_STRAND_ELONGATION_INVOLVED_IN_DNA_REPLICATION
# Passed: cat 5062, mi = 0.003, pvalue = 0.000, GO_RESPONSE_TO_CORTICOSTEROID
# Passed: cat 2187, mi = 0.003, pvalue = 0.000, GO_MICROTUBULE_ORGANIZING_CENTER_PART
# Passed: cat 5499, mi = 0.003, pvalue = 0.000, GO_SPLICEOSOMAL_COMPLEX
# Passed: cat 5755, mi = 0.003, pvalue = 0.000, GO_TRNA_METABOLIC_PROCESS
# Passed: cat 3910, mi = 0.003, pvalue = 0.000, GO_PROTEASOME_COMPLEX
# Passed: cat 5678, mi = 0.002, pvalue = 0.000, GO_TRANSCRIPTION_ELONGATION_FROM_RNA_POLYMERASE_II_PROMOTER
# Passed: cat 2861, mi = 0.002, pvalue = 0.000, GO_NEUROTRANSMITTER_RECEPTOR_ACTIVITY
# Passed: cat 4349, mi = 0.002, pvalue = 0.000, GO_REGULATION_OF_CYTOKINE_BIOSYNTHETIC_PROCESS
# Passed: cat 1867, mi = 0.002, pvalue = 0.000, GO_KIDNEY_MORPHOGENESIS
# Passed: cat 25, mi = 0.002, pvalue = 0.000, GO_ACID_SECRETION
# Passed: cat 4272, mi = 0.002, pvalue = 0.000, GO_REGULATION_OF_CELLULAR_RESPONSE_TO_TRANSFORMING_GROWTH_FACTOR_BETA_STIMULUS
# Passed: cat 5568, mi = 0.002, pvalue = 0.000, GO_SUPEROXIDE_METABOLIC_PROCESS
# Passed: cat 836, mi = 0.002, pvalue = 0.000, GO_COFACTOR_BIOSYNTHETIC_PROCESS
# Passed: cat 2317, mi = 0.002, pvalue = 0.001, GO_MULTICELLULAR_ORGANISMAL_SIGNALING
# Passed: cat 5722, mi = 0.002, pvalue = 0.001, GO_TRANSLATION_INITIATION_FACTOR_ACTIVITY
# Passed: cat 1283, mi = 0.002, pvalue = 0.001, GO_ESTABLISHMENT_OF_EPITHELIAL_CELL_POLARITY
# Passed: cat 3317, mi = 0.002, pvalue = 0.002, GO_PLATELET_DERIVED_GROWTH_FACTOR_RECEPTOR_SIGNALING_PATHWAY
# Passed: cat 4818, mi = 0.002, pvalue = 0.002, GO_REGULATION_OF_RECEPTOR_INTERNALIZATION
# Passed: cat 879, mi = 0.001, pvalue = 0.002, GO_CORTICAL_ACTIN_CYTOSKELETON
# Passed: cat 4111, mi = 0.001, pvalue = 0.003, GO_PYRIMIDINE_RIBONUCLEOTIDE_METABOLIC_PROCESS
# Passed: cat 2087, mi = 0.001, pvalue = 0.002, GO_MEGAKARYOCYTE_DIFFERENTIATION
# Passed: cat 2966, mi = 0.001, pvalue = 0.004, GO_NUCLEOSOMAL_DNA_BINDING
# Passed: cat 5585, mi = 0.001, pvalue = 0.003, GO_SYNAPTIC_VESICLE_CYTOSKELETAL_TRANSPORT
# Passed: cat 5831, mi = 0.001, pvalue = 0.002, GO_VACUOLE_ORGANIZATION
# Passed: cat 5744, mi = 0.001, pvalue = 0.005, GO_TRANS_GOLGI_NETWORK_MEMBRANE
# Passed: cat 657, mi = 0.001, pvalue = 0.004, GO_CELL_DIFFERENTIATION_INVOLVED_IN_EMBRYONIC_PLACENTA_DEVELOPMENT
# Didn't pass (cutoff=0.0050): cat 926, mi = 0.001, pvalue = 0.005, GO_CYTOKINE_RECEPTOR_ACTIVITY
# Passed: cat 1735, mi = 0.001, pvalue = 0.002, GO_INNERVATION
# Passed: cat 4645, mi = 0.001, pvalue = 0.004, GO_REGULATION_OF_MRNA_CATABOLIC_PROCESS
# Passed: cat 2082, mi = 0.001, pvalue = 0.001, GO_MCM_COMPLEX
# Passed: cat 4082, mi = 0.001, pvalue = 0.003, GO_PURINE_NUCLEOBASE_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 5610, mi = 0.001, pvalue = 0.008, GO_TELOMERE_CAPPING
# Didn't pass (cutoff=0.0050): cat 1501, mi = 0.001, pvalue = 0.009, GO_GLUTATHIONE_METABOLIC_PROCESS
# Passed: cat 2887, mi = 0.001, pvalue = 0.004, GO_NONRIBOSOMAL_PEPTIDE_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 261, mi = 0.001, pvalue = 0.006, GO_ATP_DEPENDENT_MICROTUBULE_MOTOR_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 1043, mi = 0.001, pvalue = 0.012, GO_DIOXYGENASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3258, mi = 0.001, pvalue = 0.010, GO_PHOSPHOLIPID_DEPHOSPHORYLATION
# Didn't pass (cutoff=0.0050): cat 5424, mi = 0.001, pvalue = 0.014, GO_SMALL_SUBUNIT_PROCESSOME
# Passed: cat 2745, mi = 0.001, pvalue = 0.003, GO_NEGATIVE_REGULATION_OF_SMOOTH_MUSCLE_CELL_MIGRATION
# Passed: cat 893, mi = 0.001, pvalue = 0.004, GO_CULLIN_FAMILY_PROTEIN_BINDING
# Didn't pass (cutoff=0.0050): cat 5872, mi = 0.001, pvalue = 0.010, GO_VIRUS_RECEPTOR_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3184, mi = 0.001, pvalue = 0.022, GO_PEROXISOME_ORGANIZATION
# Didn't pass (cutoff=0.0050): cat 136, mi = 0.001, pvalue = 0.017, GO_AMINE_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 3152, mi = 0.001, pvalue = 0.020, GO_PEPTIDE_RECEPTOR_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 760, mi = 0.001, pvalue = 0.021, GO_CHONDROITIN_SULFATE_PROTEOGLYCAN_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 3238, mi = 0.001, pvalue = 0.029, GO_PHOSPHATIDYLINOSITOL_DEPHOSPHORYLATION
# Didn't pass (cutoff=0.0050): cat 4789, mi = 0.001, pvalue = 0.027, GO_REGULATION_OF_PROTEIN_LOCALIZATION_TO_CELL_SURFACE
# Didn't pass (cutoff=0.0050): cat 3242, mi = 0.001, pvalue = 0.017, GO_PHOSPHATIDYLINOSITOL_PHOSPHATE_5_PHOSPHATASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 4326, mi = 0.001, pvalue = 0.010, GO_REGULATION_OF_CHOLESTEROL_STORAGE
# Didn't pass (cutoff=0.0050): cat 2944, mi = 0.001, pvalue = 0.036, GO_NUCLEOCYTOPLASMIC_TRANSPORTER_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3281, mi = 0.001, pvalue = 0.039, GO_PHOTORECEPTOR_OUTER_SEGMENT
# Didn't pass (cutoff=0.0050): cat 5435, mi = 0.001, pvalue = 0.041, GO_SNORNA_BINDING
# Didn't pass (cutoff=0.0050): cat 3086, mi = 0.001, pvalue = 0.025, GO_OXIDIZED_NAD_BINDING
# Didn't pass (cutoff=0.0050): cat 3208, mi = 0.001, pvalue = 0.023, GO_PHOSPHATIDATE_PHOSPHATASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 759, mi = 0.001, pvalue = 0.045, GO_CHONDROITIN_SULFATE_PROTEOGLYCAN_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 4921, mi = 0.001, pvalue = 0.042, GO_REGULATION_OF_TELOMERASE_RNA_LOCALIZATION_TO_CAJAL_BODY
# Didn't pass (cutoff=0.0050): cat 3116, mi = 0.001, pvalue = 0.047, GO_O_ACYLTRANSFERASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 2312, mi = 0.001, pvalue = 0.035, GO_MUCOPOLYSACCHARIDE_METABOLIC_PROCESS
# Passed: cat 1006, mi = 0.001, pvalue = 0.001, GO_DETECTION_OF_CHEMICAL_STIMULUS_INVOLVED_IN_SENSORY_PERCEPTION_OF_TASTE
# Passed: cat 1572, mi = 0.001, pvalue = 0.001, GO_G_PROTEIN_COUPLED_CHEMOATTRACTANT_RECEPTOR_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3400, mi = 0.001, pvalue = 0.034, GO_POSITIVE_REGULATION_OF_CARDIAC_MUSCLE_CELL_PROLIFERATION
# Didn't pass (cutoff=0.0050): cat 1397, mi = 0.001, pvalue = 0.039, GO_FIBROBLAST_GROWTH_FACTOR_RECEPTOR_BINDING
# Didn't pass (cutoff=0.0050): cat 2780, mi = 0.001, pvalue = 0.038, GO_NEGATIVE_REGULATION_OF_TUMOR_NECROSIS_FACTOR_MEDIATED_SIGNALING_PATHWAY
# Didn't pass (cutoff=0.0050): cat 3323, mi = 0.001, pvalue = 0.054, GO_POLYAMINE_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 1200, mi = 0.001, pvalue = 0.058, GO_ENDOPLASMIC_RETICULUM_ORGANIZATION
# Didn't pass (cutoff=0.0050): cat 845, mi = 0.001, pvalue = 0.061, GO_COLLAGEN_TRIMER
# Didn't pass (cutoff=0.0050): cat 5527, mi = 0.001, pvalue = 0.040, GO_STEROL_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 3981, mi = 0.001, pvalue = 0.066, GO_PROTEIN_LIPID_COMPLEX
# Didn't pass (cutoff=0.0050): cat 2004, mi = 0.001, pvalue = 0.063, GO_LYSOPHOSPHOLIPID_ACYLTRANSFERASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 5851, mi = 0.001, pvalue = 0.063, GO_VENTRICULAR_SYSTEM_DEVELOPMENT
# Didn't pass (cutoff=0.0050): cat 757, mi = 0.001, pvalue = 0.058, GO_CHONDROITIN_SULFATE_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 1364, mi = 0.001, pvalue = 0.063, GO_FATTY_ACID_BETA_OXIDATION_USING_ACYL_COA_DEHYDROGENASE
# Didn't pass (cutoff=0.0050): cat 80, mi = 0.001, pvalue = 0.070, GO_ADA2_GCN5_ADA3_TRANSCRIPTION_ACTIVATOR_COMPLEX
# Didn't pass (cutoff=0.0050): cat 157, mi = 0.001, pvalue = 0.037, GO_AMMONIUM_TRANSMEMBRANE_TRANSPORT
# Didn't pass (cutoff=0.0050): cat 5133, mi = 0.001, pvalue = 0.065, GO_RESPONSE_TO_MISFOLDED_PROTEIN
# Didn't pass (cutoff=0.0050): cat 5855, mi = 0.001, pvalue = 0.052, GO_VESICLE_COATING
# Didn't pass (cutoff=0.0050): cat 5813, mi = 0.001, pvalue = 0.053, GO_UNFOLDED_PROTEIN_BINDING
# Didn't pass (cutoff=0.0050): cat 4125, mi = 0.001, pvalue = 0.067, GO_RAN_GTPASE_BINDING
# Didn't pass (cutoff=0.0050): cat 78, mi = 0.001, pvalue = 0.082, GO_ACYLGLYCEROL_O_ACYLTRANSFERASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 5358, mi = 0.001, pvalue = 0.045, GO_SERINE_TYPE_CARBOXYPEPTIDASE_ACTIVITY
# Total number of categories evaluated = 1028.
# Number of categories that passed the tests = 39
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 37, 38, 0
# best merge is 3, 5, 0.0188948603484824
# best merge is 6, 7, 0.0387915308459444
# best merge is 13, 30, 0.0563883752403964
# best merge is 1, 3, 0.0638397060608967
# best merge is 14, 35, 0.0853186660356534
# best merge is 8, 9, 0.0899606030584174
# best merge is 1, 13, 0.0982299363135472
# best merge is 2, 6, 0.102467101480649
# best merge is 4, 19, 0.118056971979675
# best merge is 8, 16, 0.119805583069857
# best merge is 14, 37, 0.124370850503396
# best merge is 26, 36, 0.138475868593457
# best merge is 0, 33, 0.169163473873044
# best merge is 11, 14, 0.185496561577424
# best merge is 2, 8, 0.211924277414762
# best merge is 17, 29, 0.219262489721119
# best merge is 11, 12, 0.220047799105543
# best merge is 1, 10, 0.234905701155728
# best merge is 18, 24, 0.248262003574209
# best merge is 15, 32, 0.286987311988544
# best merge is 4, 22, 0.302685787229969
# best merge is 0, 34, 0.302911851574634
# best merge is 1, 17, 0.310941916462459
# best merge is 18, 31, 0.338605470603046
# best merge is 11, 20, 0.385182929333578
# best merge is 0, 25, 0.393978783859255
# best merge is 4, 11, 0.447848243531644
# best merge is 27, 28, 0.50522168309916
# best merge is 15, 23, 0.532524070812801
# best merge is 2, 18, 0.575737840386758
# best merge is 2, 26, 0.710455040858508
# best merge is 21, 27, 0.732014346412227
# best merge is 0, 2, 0.804191255603292
# best merge is 0, 21, 0.93113431965367
# order classes
# 15 - 1.47997489930441
# 8 - 0.901484430027374
# 10 - 1.1594205906264
# 3 - 3.90588019932975
# 3 - 5.68894553044599
# 1 3 5 13 30 10 17 29
# 0 33 34 25 2 6 7 8 9 16 18 24 31 26 36
# 4 19 22 11 14 35 37 38 12 20
# 15 32 23
# 21 27 28
# Done.Start drawing
# 84.94	0.00
# GO_RESPONSE_TO_CORTICOSTEROID
# GO_ESTABLISHMENT_OF_EPITHELIAL_CELL_POLARITY
# GO_CORTICAL_ACTIN_CYTOSKELETON
# GO_REGULATION_OF_CYTOKINE_BIOSYNTHETIC_PROCESS
# GO_REGULATION_OF_CELLULAR_RESPONSE_TO_TRANSFORMING_GROWTH_FACTOR_BETA_STIMULUS
# GO_NEGATIVE_REGULATION_OF_SMOOTH_MUSCLE_CELL_MIGRATION
# GO_DETECTION_OF_CHEMICAL_STIMULUS_INVOLVED_IN_SENSORY_PERCEPTION_OF_TASTE
# GO_G_PROTEIN_COUPLED_CHEMOATTRACTANT_RECEPTOR_ACTIVITY
# GO_KIDNEY_MORPHOGENESIS
# GO_PLATELET_DERIVED_GROWTH_FACTOR_RECEPTOR_SIGNALING_PATHWAY
# GO_REGULATION_OF_RECEPTOR_INTERNALIZATION
# GO_VACUOLE_ORGANIZATION
# GO_TRANSLATION_INITIATION_FACTOR_ACTIVITY
# GO_MEGAKARYOCYTE_DIFFERENTIATION
# GO_TRANS_GOLGI_NETWORK_MEMBRANE
# GO_REGULATION_OF_MRNA_CATABOLIC_PROCESS
# GO_SYNAPTIC_VESICLE_CYTOSKELETAL_TRANSPORT
# GO_CULLIN_FAMILY_PROTEIN_BINDING
# GO_TRNA_METABOLIC_PROCESS
# GO_TRANSCRIPTION_ELONGATION_FROM_RNA_POLYMERASE_II_PROMOTER
# GO_RIBOSOMAL_SUBUNIT
# GO_PURINE_NUCLEOBASE_BIOSYNTHETIC_PROCESS
# GO_NONRIBOSOMAL_PEPTIDE_BIOSYNTHETIC_PROCESS
# GO_NUCLEOSOMAL_DNA_BINDING
# GO_PROTEASOME_COMPLEX
# GO_COFACTOR_BIOSYNTHETIC_PROCESS
# GO_MITOCHONDRIAL_MEMBRANE_PART
# GO_SPLICEOSOMAL_COMPLEX
# GO_SUPEROXIDE_METABOLIC_PROCESS
# GO_MCM_COMPLEX
# GO_PYRIMIDINE_RIBONUCLEOTIDE_METABOLIC_PROCESS
# GO_CONDENSED_CHROMOSOME
# GO_DNA_STRAND_ELONGATION_INVOLVED_IN_DNA_REPLICATION
# GO_MICROTUBULE_ORGANIZING_CENTER_PART
# GO_ACID_SECRETION
# GO_INNERVATION
# GO_NEUROTRANSMITTER_RECEPTOR_ACTIVITY
# GO_MULTICELLULAR_ORGANISMAL_SIGNALING
# GO_CELL_DIFFERENTIATION_INVOLVED_IN_EMBRYONIC_PLACENTA_DEVELOPMENT
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 37, 38, 0
# best merge is 3, 5, 0.0188948603484824
# best merge is 6, 7, 0.0387915308459444
# best merge is 13, 30, 0.0563883752403964
# best merge is 1, 3, 0.0638397060608967
# best merge is 14, 35, 0.0853186660356534
# best merge is 8, 9, 0.0899606030584174
# best merge is 1, 13, 0.0982299363135472
# best merge is 2, 6, 0.102467101480649
# best merge is 4, 19, 0.118056971979675
# best merge is 8, 16, 0.119805583069857
# best merge is 14, 37, 0.124370850503396
# best merge is 26, 36, 0.138475868593457
# best merge is 0, 33, 0.169163473873044
# best merge is 11, 14, 0.185496561577424
# best merge is 2, 8, 0.211924277414762
# best merge is 17, 29, 0.219262489721119
# best merge is 11, 12, 0.220047799105543
# best merge is 1, 10, 0.234905701155728
# best merge is 18, 24, 0.248262003574209
# best merge is 15, 32, 0.286987311988544
# best merge is 4, 22, 0.302685787229969
# best merge is 0, 34, 0.302911851574634
# best merge is 1, 17, 0.310941916462459
# best merge is 18, 31, 0.338605470603046
# best merge is 11, 20, 0.385182929333578
# best merge is 0, 25, 0.393978783859255
# best merge is 4, 11, 0.447848243531644
# best merge is 27, 28, 0.50522168309916
# best merge is 15, 23, 0.532524070812801
# best merge is 2, 18, 0.575737840386758
# best merge is 2, 26, 0.710455040858508
# best merge is 21, 27, 0.732014346412227
# best merge is 0, 2, 0.804191255603292
# best merge is 0, 21, 0.93113431965367
# order classes
# 15 - 1.47997489930441
# 8 - 0.901484430027374
# 10 - 1.1594205906264
# 3 - 3.90588019932975
# 3 - 5.68894553044599
# 1 3 5 13 30 10 17 29
# 0 33 34 25 2 6 7 8 9 16 18 24 31 26 36
# 4 19 22 11 14 35 37 38 12 20
# 15 32 23
# 21 27 28
# Done.-19.849187661879	42	0
# -19.6588179891688	42	0.301624676242053
# -19.5920649870497	42	0.380739345420297
# -19.5401459854015	42	0.435130680480339
# -19.4931716505769	42	0.484577348716741
# -19.4437249823405	42	0.529079350129503
# -19.3769719802213	42	0.583470685189545
# -19.2706616435131	42	0.662585354367789
# 1.39804567930304	42	0.796091358606075
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c5.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c5/human_ensembl_msigdb_c5.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 5917
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	5917
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 5917
# cat 957, mi = 0.00794861, GO_CYTOSOLIC_RIBOSOME
# cat 1292, mi = 0.00792590, GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 2330, mi = 0.00731835, GO_MULTI_ORGANISM_METABOLIC_PROCESS
# cat 5718, mi = 0.00692234, GO_TRANSLATIONAL_INITIATION
# cat 3995, mi = 0.00689173, GO_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 2928, mi = 0.00678756, GO_NUCLEAR_TRANSCRIBED_MRNA_CATABOLIC_PROCESS_NONSENSE_MEDIATED_DECAY
# cat 4041, mi = 0.00563404, GO_PROTEIN_TARGETING_TO_MEMBRANE
# cat 954, mi = 0.00546837, GO_CYTOSOLIC_LARGE_RIBOSOMAL_SUBUNIT
# cat 5245, mi = 0.00527919, GO_RIBOSOMAL_SUBUNIT
# cat 5499, mi = 0.00465835, GO_SPLICEOSOMAL_COMPLEX
# cat 2219, mi = 0.00414434, GO_MITOCHONDRIAL_PROTEIN_COMPLEX
# cat 1889, mi = 0.00386908, GO_LARGE_RIBOSOMAL_SUBUNIT
# cat 3085, mi = 0.00365856, GO_OXIDATIVE_PHOSPHORYLATION
# cat 1742, mi = 0.00364092, GO_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX
# cat 4852, mi = 0.00357067, GO_REGULATION_OF_RNA_STABILITY
#
# RESULTS
# Passed: cat 957, mi = 0.008, pvalue = 0.000, GO_CYTOSOLIC_RIBOSOME
# Passed: cat 5499, mi = 0.005, pvalue = 0.000, GO_SPLICEOSOMAL_COMPLEX
# Passed: cat 2219, mi = 0.004, pvalue = 0.000, GO_MITOCHONDRIAL_PROTEIN_COMPLEX
# Passed: cat 4852, mi = 0.004, pvalue = 0.000, GO_REGULATION_OF_RNA_STABILITY
# Passed: cat 5719, mi = 0.003, pvalue = 0.000, GO_TRANSLATIONAL_TERMINATION
# Passed: cat 5755, mi = 0.003, pvalue = 0.000, GO_TRNA_METABOLIC_PROCESS
# Passed: cat 1342, mi = 0.002, pvalue = 0.000, GO_EXTRACELLULAR_MATRIX_COMPONENT
# ...
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 2, 0.0114404379355395
# best merge is 0, 5, 0.0219305004515488
# best merge is 0, 10, 0.034381217601871
# best merge is 16, 32, 0.0412712204738644
# best merge is 14, 16, 0.104975122925462
# best merge is 12, 17, 0.107250291955358
# best merge is 15, 22, 0.118176538577349
# best merge is 23, 28, 0.127508873506686
# best merge is 14, 34, 0.152007975186159
# best merge is 6, 7, 0.160276867721691
# best merge is 3, 9, 0.196936914521718
# best merge is 4, 23, 0.209243196524067
# best merge is 14, 15, 0.210678755783959
# best merge is 0, 12, 0.230233873108791
# best merge is 6, 20, 0.23404235753228
# best merge is 1, 21, 0.251061459849756
# best merge is 18, 27, 0.26215888830499
# best merge is 3, 6, 0.294543607513474
# best merge is 14, 31, 0.298820406801166
# best merge is 25, 30, 0.306630321650122
# best merge is 3, 18, 0.381033160240692
# best merge is 19, 24, 0.406552633998064
# best merge is 14, 25, 0.435096549732305
# best merge is 13, 33, 0.513945548364787
# best merge is 3, 4, 0.538402843733481
# best merge is 3, 11, 0.552868491084966
# best merge is 26, 29, 0.656739371911441
# best merge is 13, 14, 0.759442861847179
# best merge is 1, 8, 0.797759334789504
# best merge is 0, 26, 0.799219543486661
# best merge is 1, 19, 0.860047483586617
# order classes
# 8 - 1.68915198897557
# 3 - 4.78742996518568
# 11 - 1.26463811947677
# 11 - 1.30878823801194
# 2 - 3.55733554748306
# 3 9 6 7 20 18 27 4 23 28 11
# 1 21 8
# 0 2 5 10 12 17 26 29
# 13 33 14 16 32 34 15 22 31 25 30
# 19 24
# Done.-19.1725043782837	42	0
# -18.1059544658494	42	1.65499124343257
# -17.7381786339755	42	2.13309982486865
# -17.4807355516637	42	2.39054290718039
# -17.223292469352	42	2.64798598949212
# -16.9658493870403	42	2.90542907180385
# -16.6348511383538	42	3.16287215411559
# -16.0831873905429	42	3.56742556917688
# 3.13309982486865	42	4.2661996497373
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c5.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c5/human_ensembl_msigdb_c5.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 5917
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	5917
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 5917
# cat 5245, mi = 0.01359510, GO_RIBOSOMAL_SUBUNIT
# cat 1292, mi = 0.01347320, GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 3995, mi = 0.01327650, GO_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# cat 5718, mi = 0.01321226, GO_TRANSLATIONAL_INITIATION
# cat 957, mi = 0.01176857, GO_CYTOSOLIC_RIBOSOME
# cat 2928, mi = 0.00983797, GO_NUCLEAR_TRANSCRIBED_MRNA_CATABOLIC_PROCESS_NONSENSE_MEDIATED_DECAY
# cat 2330, mi = 0.00971932, GO_MULTI_ORGANISM_METABOLIC_PROCESS
# cat 954, mi = 0.00854899, GO_CYTOSOLIC_LARGE_RIBOSOMAL_SUBUNIT
# cat 1889, mi = 0.00853365, GO_LARGE_RIBOSOMAL_SUBUNIT
# cat 4041, mi = 0.00824073, GO_PROTEIN_TARGETING_TO_MEMBRANE
# cat 1742, mi = 0.00709964, GO_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX
# cat 2219, mi = 0.00626369, GO_MITOCHONDRIAL_PROTEIN_COMPLEX
# cat 5028, mi = 0.00602933, GO_RESPIRATORY_CHAIN
# cat 2217, mi = 0.00579070, GO_MITOCHONDRIAL_MEMBRANE_PART
# cat 3085, mi = 0.00534551, GO_OXIDATIVE_PHOSPHORYLATION
#
# RESULTS
# Passed: cat 5245, mi = 0.014, pvalue = 0.000, GO_RIBOSOMAL_SUBUNIT
# Passed: cat 1742, mi = 0.007, pvalue = 0.000, GO_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX
# Passed: cat 5499, mi = 0.005, pvalue = 0.000, GO_SPLICEOSOMAL_COMPLEX
# Passed: cat 4852, mi = 0.003, pvalue = 0.000, GO_REGULATION_OF_RNA_STABILITY
# Passed: cat 4921, mi = 0.002, pvalue = 0.000, GO_REGULATION_OF_TELOMERASE_RNA_LOCALIZATION_TO_CAJAL_BODY
# Passed: cat 3847, mi = 0.002, pvalue = 0.000, GO_POSITIVE_REGULATION_OF_VIRAL_PROCESS
# Passed: cat 4551, mi = 0.002, pvalue = 0.000, GO_REGULATION_OF_INTRINSIC_APOPTOTIC_SIGNALING_PATHWAY
# Passed: cat 2966, mi = 0.002, pvalue = 0.000, GO_NUCLEOSOMAL_DNA_BINDING
# Passed: cat 3633, mi = 0.002, pvalue = 0.000, GO_POSITIVE_REGULATION_OF_MITOTIC_NUCLEAR_DIVISION
# Passed: cat 3871, mi = 0.002, pvalue = 0.000, GO_POTASSIUM_ION_TRANSPORT
# Passed: cat 3374, mi = 0.002, pvalue = 0.001, GO_POSITIVE_REGULATION_OF_AXON_EXTENSION
# Passed: cat 5722, mi = 0.002, pvalue = 0.001, GO_TRANSLATION_INITIATION_FACTOR_ACTIVITY
# Passed: cat 144, mi = 0.002, pvalue = 0.000, GO_AMINO_ACID_ACTIVATION
# Passed: cat 3323, mi = 0.002, pvalue = 0.000, GO_POLYAMINE_METABOLIC_PROCESS
# Passed: cat 171, mi = 0.002, pvalue = 0.001, GO_ANCHORED_COMPONENT_OF_MEMBRANE
# Passed: cat 4118, mi = 0.002, pvalue = 0.002, GO_RAB_GUANYL_NUCLEOTIDE_EXCHANGE_FACTOR_ACTIVITY
# Passed: cat 1162, mi = 0.001, pvalue = 0.003, GO_EMBRYONIC_SKELETAL_SYSTEM_MORPHOGENESIS
# Passed: cat 149, mi = 0.001, pvalue = 0.003, GO_AMINO_ACID_TRANSMEMBRANE_TRANSPORT
# Passed: cat 5262, mi = 0.001, pvalue = 0.002, GO_RNA_INTERFERENCE
# Didn't pass (cutoff=0.0050): cat 2178, mi = 0.001, pvalue = 0.007, GO_MICROTUBULE_BUNDLE_FORMATION
# Passed: cat 339, mi = 0.001, pvalue = 0.005, GO_BLASTOCYST_GROWTH
# Passed: cat 1082, mi = 0.001, pvalue = 0.001, GO_DNA_METHYLATION_INVOLVED_IN_GAMETE_GENERATION
# Didn't pass (cutoff=0.0050): cat 4451, mi = 0.001, pvalue = 0.009, GO_REGULATION_OF_FILOPODIUM_ASSEMBLY
# Didn't pass (cutoff=0.0050): cat 984, mi = 0.001, pvalue = 0.010, GO_DENDRITE_MORPHOGENESIS
# Didn't pass (cutoff=0.0050): cat 4053, mi = 0.001, pvalue = 0.011, GO_PROTEIN_TYROSINE_SERINE_THREONINE_PHOSPHATASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 2384, mi = 0.001, pvalue = 0.010, GO_NAD_BINDING
# Didn't pass (cutoff=0.0050): cat 398, mi = 0.001, pvalue = 0.007, GO_CALCIUM_ION_REGULATED_EXOCYTOSIS_OF_NEUROTRANSMITTER
# Didn't pass (cutoff=0.0050): cat 2428, mi = 0.001, pvalue = 0.011, GO_NEGATIVE_REGULATION_OF_BLOOD_PRESSURE
# Passed: cat 4082, mi = 0.001, pvalue = 0.003, GO_PURINE_NUCLEOBASE_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 4846, mi = 0.001, pvalue = 0.005, GO_REGULATION_OF_RETINOIC_ACID_RECEPTOR_SIGNALING_PATHWAY
# Didn't pass (cutoff=0.0050): cat 3519, mi = 0.001, pvalue = 0.012, GO_POSITIVE_REGULATION_OF_FILOPODIUM_ASSEMBLY
# Didn't pass (cutoff=0.0050): cat 1663, mi = 0.001, pvalue = 0.013, GO_HOMEOSTASIS_OF_NUMBER_OF_CELLS_WITHIN_A_TISSUE
# Didn't pass (cutoff=0.0050): cat 5802, mi = 0.001, pvalue = 0.012, GO_UBIQUITIN_LIKE_PROTEIN_CONJUGATING_ENZYME_ACTIVITY
# Passed: cat 5846, mi = 0.001, pvalue = 0.004, GO_VENTRICULAR_CARDIAC_MUSCLE_CELL_DEVELOPMENT
# Passed: cat 3919, mi = 0.001, pvalue = 0.003, GO_PROTEIN_AUTOPROCESSING
# Didn't pass (cutoff=0.0050): cat 5538, mi = 0.001, pvalue = 0.013, GO_STRUCTURAL_CONSTITUENT_OF_CYTOSKELETON
# Didn't pass (cutoff=0.0050): cat 3197, mi = 0.001, pvalue = 0.008, GO_PHENOL_CONTAINING_COMPOUND_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 5373, mi = 0.001, pvalue = 0.007, GO_SHORT_CHAIN_FATTY_ACID_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 5823, mi = 0.001, pvalue = 0.010, GO_VACUOLAR_ACIDIFICATION
# Didn't pass (cutoff=0.0050): cat 286, mi = 0.001, pvalue = 0.019, GO_AXONEME_ASSEMBLY
# Didn't pass (cutoff=0.0050): cat 3239, mi = 0.001, pvalue = 0.018, GO_PHOSPHATIDYLINOSITOL_KINASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 1522, mi = 0.001, pvalue = 0.018, GO_GLYCOSPHINGOLIPID_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 750, mi = 0.001, pvalue = 0.017, GO_CHLORIDE_CHANNEL_COMPLEX
# Didn't pass (cutoff=0.0050): cat 1944, mi = 0.001, pvalue = 0.018, GO_LIPID_OXIDATION
# Passed: cat 5311, mi = 0.001, pvalue = 0.004, GO_S100_PROTEIN_BINDING
# Didn't pass (cutoff=0.0050): cat 1967, mi = 0.001, pvalue = 0.018, GO_LONG_CHAIN_FATTY_ACID_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 3709, mi = 0.001, pvalue = 0.006, GO_POSITIVE_REGULATION_OF_PHOSPHOPROTEIN_PHOSPHATASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3821, mi = 0.001, pvalue = 0.009, GO_POSITIVE_REGULATION_OF_TRIGLYCERIDE_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 3325, mi = 0.001, pvalue = 0.018, GO_POLYOL_CATABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 5853, mi = 0.001, pvalue = 0.021, GO_VERY_LONG_CHAIN_FATTY_ACID_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 865, mi = 0.001, pvalue = 0.021, GO_COPI_COATED_VESICLE
# Didn't pass (cutoff=0.0050): cat 3225, mi = 0.001, pvalue = 0.021, GO_PHOSPHATIDYLINOSITOL_3_KINASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3091, mi = 0.001, pvalue = 0.021, GO_OXIDOREDUCTASE_ACTIVITY_ACTING_ON_CH_OH_GROUP_OF_DONORS
# Didn't pass (cutoff=0.0050): cat 3109, mi = 0.001, pvalue = 0.019, GO_OXIDOREDUCTASE_ACTIVITY_ACTING_ON_THE_CH_OH_GROUP_OF_DONORS_NAD_OR_NADP_AS_ACCEPTOR
# Didn't pass (cutoff=0.0050): cat 1723, mi = 0.001, pvalue = 0.027, GO_INACTIVATION_OF_MAPK_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 1545, mi = 0.001, pvalue = 0.029, GO_GOLGI_TO_VACUOLE_TRANSPORT
# Didn't pass (cutoff=0.0050): cat 2767, mi = 0.001, pvalue = 0.030, GO_NEGATIVE_REGULATION_OF_TOLL_LIKE_RECEPTOR_SIGNALING_PATHWAY
# Didn't pass (cutoff=0.0050): cat 4023, mi = 0.001, pvalue = 0.033, GO_PROTEIN_PHOSPHATASE_TYPE_2A_COMPLEX
# Didn't pass (cutoff=0.0050): cat 1239, mi = 0.001, pvalue = 0.024, GO_EPIBOLY
# Didn't pass (cutoff=0.0050): cat 5868, mi = 0.001, pvalue = 0.019, GO_VIRAL_LATENCY
# Didn't pass (cutoff=0.0050): cat 1489, mi = 0.001, pvalue = 0.031, GO_GLUCOSYLTRANSFERASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 1049, mi = 0.001, pvalue = 0.031, GO_DISULFIDE_OXIDOREDUCTASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3258, mi = 0.001, pvalue = 0.038, GO_PHOSPHOLIPID_DEPHOSPHORYLATION
# Didn't pass (cutoff=0.0050): cat 11, mi = 0.001, pvalue = 0.024, GO_5_3_EXONUCLEASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3201, mi = 0.001, pvalue = 0.036, GO_PHOSPHATASE_COMPLEX
# Total number of categories evaluated = 448.
# Number of categories that passed the tests = 25
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 2, 4, 0.025511157602079
# best merge is 0, 11, 0.0280785732973895
# best merge is 1, 24, 0.0482674069810172
# best merge is 2, 3, 0.0577128535524087
# best merge is 2, 12, 0.0629545546499368
# best merge is 2, 6, 0.0796641610509358
# best merge is 2, 7, 0.127197035455499
# best merge is 1, 5, 0.135739447472175
# best merge is 0, 22, 0.17459426749547
# best merge is 1, 2, 0.191431876367012
# best merge is 0, 13, 0.192955096584292
# best merge is 1, 8, 0.255775497716702
# best merge is 14, 20, 0.260047793879526
# best merge is 1, 23, 0.328887259773629
# best merge is 16, 19, 0.34659283303849
# best merge is 10, 17, 0.415131800699739
# best merge is 18, 21, 0.463084557557279
# best merge is 0, 1, 0.523268193228559
# best merge is 10, 15, 0.711391542809042
# best merge is 0, 16, 0.774240717517063
# best merge is 10, 14, 0.871131857784171
# order classes
# 17 - 0.59225078121824
# 3 - 3.40354608577375
# 2 - 1.62529871174704
# 2 - 2.894278484733
# 0 11 22 13 1 24 5 2 4 3 12 6 7 8 23 16 19
# 9
# 10 17 15
# 14 20
# 18 21
# Done.Start drawing
# 110.21	0.00
# GO_RNA_INTERFERENCE
# GO_PURINE_NUCLEOBASE_BIOSYNTHETIC_PROCESS
# GO_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX
# GO_S100_PROTEIN_BINDING
# GO_POSITIVE_REGULATION_OF_VIRAL_PROCESS
# GO_SPLICEOSOMAL_COMPLEX
# GO_REGULATION_OF_TELOMERASE_RNA_LOCALIZATION_TO_CAJAL_BODY
# GO_REGULATION_OF_RNA_STABILITY
# GO_AMINO_ACID_ACTIVATION
# GO_REGULATION_OF_INTRINSIC_APOPTOTIC_SIGNALING_PATHWAY
# GO_NUCLEOSOMAL_DNA_BINDING
# GO_POSITIVE_REGULATION_OF_MITOTIC_NUCLEAR_DIVISION
# GO_PROTEIN_AUTOPROCESSING
# GO_RIBOSOMAL_SUBUNIT
# GO_TRANSLATION_INITIATION_FACTOR_ACTIVITY
# GO_VENTRICULAR_CARDIAC_MUSCLE_CELL_DEVELOPMENT
# GO_POLYAMINE_METABOLIC_PROCESS
# GO_BLASTOCYST_GROWTH
# GO_AMINO_ACID_TRANSMEMBRANE_TRANSPORT
# GO_RAB_GUANYL_NUCLEOTIDE_EXCHANGE_FACTOR_ACTIVITY
# GO_POTASSIUM_ION_TRANSPORT
# GO_ANCHORED_COMPONENT_OF_MEMBRANE
# GO_DNA_METHYLATION_INVOLVED_IN_GAMETE_GENERATION
# GO_POSITIVE_REGULATION_OF_AXON_EXTENSION
# GO_EMBRYONIC_SKELETAL_SYSTEM_MORPHOGENESIS
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 2, 4, 0.025511157602079
# best merge is 0, 11, 0.0280785732973895
# best merge is 1, 24, 0.0482674069810172
# best merge is 2, 3, 0.0577128535524087
# best merge is 2, 12, 0.0629545546499368
# best merge is 2, 6, 0.0796641610509358
# best merge is 2, 7, 0.127197035455499
# best merge is 1, 5, 0.135739447472175
# best merge is 0, 22, 0.17459426749547
# best merge is 1, 2, 0.191431876367012
# best merge is 0, 13, 0.192955096584292
# best merge is 1, 8, 0.255775497716702
# best merge is 14, 20, 0.260047793879526
# best merge is 1, 23, 0.328887259773629
# best merge is 16, 19, 0.34659283303849
# best merge is 10, 17, 0.415131800699739
# best merge is 18, 21, 0.463084557557279
# best merge is 0, 1, 0.523268193228559
# best merge is 10, 15, 0.711391542809042
# best merge is 0, 16, 0.774240717517063
# best merge is 10, 14, 0.871131857784171
# order classes
# 17 - 0.59225078121824
# 3 - 3.40354608577375
# 2 - 1.62529871174704
# 2 - 2.894278484733
# 0 11 22 13 1 24 5 2 4 3 12 6 7 8 23 16 19
# 9
# 10 17 15
# 14 20
# 18 21
# Done.-19.9980945467743	42	0
# -19.9923781870974	42	0.00381090645132021
# -19.9847563741947	42	0.0114327193539606
# -19.9790400145177	42	0.019054532256601
# -19.9733236548408	42	0.0228654387079212
# -19.9676072951638	42	0.0304872516105617
# -19.8361310225932	42	0.0342981580618819
# -19.4912439887488	42	0.293439796751656
# 1.36203611287542	42	0.724072225750839
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c5/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# sem --wait done
