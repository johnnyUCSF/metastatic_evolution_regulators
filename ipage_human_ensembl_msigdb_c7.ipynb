# %% [markdown]
# # This is used for running data vs human_msigdb_c7 annotations located in:
# ### /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c7

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import scipy.stats

# %% [markdown]
# ### get index of file names to loop through

# %%
# %%bash
#
# cd fc_values
# ls FC* > filelist.txt
# cd ..

# %% [markdown]
# ### get ensembl genes represented in iPAGE database

# %%
# %%bash
#
# cp /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c7/human_ensembl_msigdb_c7_index.txt human_ensembl_index.txt
# awk '{print $1}' human_ensembl_index.txt > ensembl_index.txt

# %% [markdown]
# ### make sure that genes in file match the index

# %%
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
###################REMEMBER TO SPECIFY INDEX USED IN THE IPAGE COMMAND!!!!!!!!
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#####################
#######read in data from logfc calculations
#####################
####define index file to loop through
index_file = "fc_values/filelist.txt"
####define matching ensg index
GO_index_filename = "ensembl_index.txt"
genes_with_GOs = []
with open(GO_index_filename,'r') as rf:
    for line in rf:
        gene_name = line.split('\n')[0]
        genes_with_GOs.append(gene_name)
genes_with_GOs_set = set(genes_with_GOs)
####open file and loop through each line
###
iPAGE_sh = "iPAGE_JY.sh"
cwd = os.getcwd()+"/"
os.system("rm "+iPAGE_sh)
###
with open(index_file,'r') as rf:
    for line in rf:
        #####do this to each file
        ###read in file into pandas df
        FC_file = "fc_values/"+line.split('\n')[0]
        FC_df = pd.read_csv(FC_file,sep=',',index_col=0)
        FC_df.columns = ['log2FoldChange']
        FC_df.index.names = ['Gene']
        ###filter
        FC_df = FC_df.loc[[x for x in FC_df.index if x in genes_with_GOs_set]]
        ###save
        save_file = "fc_values/filt_"+line.split('\n')[0]
        FC_df.to_csv(save_file,sep='\t',header=True)
        ###write final iPAGE command to an ipage .sh file
        iPAGE_cmd = "perl /nvme/bins/iPAGEv1.0/page.pl --expfile "+cwd+save_file+" --species=human_ensembl_msigdb_c7 --exptype=continuous --ebins=9 \n"
        with open(iPAGE_sh, "a") as myfile:
            myfile.write(iPAGE_cmd)

# %% [markdown]
# ## then run the command from this folder:
#
# nohup sh run.sh iPAGE_JY.sh &

# %%
# %%bash
#
# nohup sh run.sh iPAGE_JY.sh &
# Out:
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv --species=human_ensembl_msigdb_c7 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv --species=human_ensembl_msigdb_c7 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_3.csv --species=human_ensembl_msigdb_c7 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_4.csv --species=human_ensembl_msigdb_c7 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c7.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c7/human_ensembl_msigdb_c7.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 4872
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	4872
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 4872
# cat 2054, mi = 0.00737696, GSE2405_0H_VS_9H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_DN
# cat 2049, mi = 0.00657941, GSE2405_0H_VS_24H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_UP
# cat 3962, mi = 0.00378553, GSE41978_ID2_KO_VS_ID2_KO_AND_BIM_KO_KLRG1_LOW_EFFECTOR_CD8_TCELL_DN
# cat 1946, mi = 0.00325452, GSE22886_UNSTIM_VS_STIM_MEMORY_TCELL_DN
# cat 1689, mi = 0.00305341, GSE21927_BALBC_VS_C57BL6_MONOCYTE_TUMOR_UP
# cat 3874, mi = 0.00294428, GSE411_100MIN_VS_400MIN_IL6_STIM_MACROPHAGE_DN
# cat 676, mi = 0.00283866, GSE15930_NAIVE_VS_48H_IN_VITRO_STIM_CD8_TCELL_DN
# cat 1874, mi = 0.00265097, GSE22886_IGM_MEMORY_BCELL_VS_BLOOD_PLASMA_CELL_DN
# cat 3023, mi = 0.00257815, GSE34006_UNTREATED_VS_A2AR_AGONIST_TREATED_TREG_UP
# cat 4046, mi = 0.00254405, GSE43863_NAIVE_VS_MEMORY_LY6C_INT_CXCR5POS_CD4_TCELL_D150_LCMV_DN
# cat 1155, mi = 0.00251453, GSE17721_POLYIC_VS_PAM3CSK4_1H_BMDC_UP
# cat 2521, mi = 0.00248129, GSE27786_BCELL_VS_MONO_MAC_UP
# cat 3198, mi = 0.00248025, GSE360_L_MAJOR_VS_B_MALAYI_LOW_DOSE_MAC_DN
# cat 3296, mi = 0.00243001, GSE369_IFNG_KO_VS_WT_LIVER_DN
# cat 3412, mi = 0.00242268, GSE37416_CTRL_VS_48H_F_TULARENSIS_LVS_NEUTROPHIL_DN
#
# RESULTS
# Passed: cat 2054, mi = 0.007, pvalue = 0.000, GSE2405_0H_VS_9H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_DN
# Passed: cat 1946, mi = 0.003, pvalue = 0.000, GSE22886_UNSTIM_VS_STIM_MEMORY_TCELL_DN
# Passed: cat 1874, mi = 0.003, pvalue = 0.000, GSE22886_IGM_MEMORY_BCELL_VS_BLOOD_PLASMA_CELL_DN
# Passed: cat 1155, mi = 0.003, pvalue = 0.000, GSE17721_POLYIC_VS_PAM3CSK4_1H_BMDC_UP
# Passed: cat 2521, mi = 0.002, pvalue = 0.000, GSE27786_BCELL_VS_MONO_MAC_UP
# Passed: cat 3198, mi = 0.002, pvalue = 0.000, GSE360_L_MAJOR_VS_B_MALAYI_LOW_DOSE_MAC_DN
# Passed: cat 3296, mi = 0.002, pvalue = 0.000, GSE369_IFNG_KO_VS_WT_LIVER_DN
# Passed: cat 3412, mi = 0.002, pvalue = 0.000, GSE37416_CTRL_VS_48H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# Passed: cat 4538, mi = 0.002, pvalue = 0.000, GSE7218_IGM_VS_IGG_SIGNAL_THGOUGH_ANTIGEN_BCELL_DN
# Passed: cat 561, mi = 0.002, pvalue = 0.000, GSE14908_ATOPIC_VS_NONATOPIC_PATIENT_HDM_STIM_CD4_TCELL_UP
# Passed: cat 1379, mi = 0.002, pvalue = 0.000, GSE19825_NAIVE_VS_DAY3_EFF_CD8_TCELL_UP
# Passed: cat 3983, mi = 0.002, pvalue = 0.000, GSE42021_CD24INT_TREG_VS_CD24INT_TCONV_THYMUS_UP
# Passed: cat 3282, mi = 0.002, pvalue = 0.000, GSE36888_UNTREATED_VS_IL2_TREATED_TCELL_6H_DN
# Passed: cat 3530, mi = 0.002, pvalue = 0.000, GSE3920_UNTREATED_VS_IFNG_TREATED_ENDOTHELIAL_CELL_DN
# Passed: cat 4126, mi = 0.002, pvalue = 0.000, GSE44649_NAIVE_VS_ACTIVATED_CD8_TCELL_MIR155_KO_UP
# Passed: cat 4777, mi = 0.002, pvalue = 0.000, GSE9509_10MIN_VS_30MIN_LPS_STIM_IL10_KO_MACROPHAGE_UP
# Passed: cat 664, mi = 0.002, pvalue = 0.000, GSE15750_WT_VS_TRAF6KO_DAY10_EFF_CD8_TCELL_DN
# Passed: cat 3543, mi = 0.002, pvalue = 0.000, GSE39556_UNTREATED_VS_3H_POLYIC_INJ_MOUSE_NK_CELL_UP
# Passed: cat 2590, mi = 0.002, pvalue = 0.000, GSE27786_NKCELL_VS_ERYTHROBLAST_DN
# Passed: cat 4726, mi = 0.002, pvalue = 0.000, GSE8921_UNSTIM_0H_VS_TLR1_2_STIM_MONOCYTE_3H_DN
# Passed: cat 4524, mi = 0.002, pvalue = 0.000, GSE6674_UNSTIM_VS_ANTI_IGM_STIM_BCELL_DN
# Passed: cat 2926, mi = 0.002, pvalue = 0.000, GSE32533_WT_VS_MIR17_KO_ACT_CD4_TCELL_DN
# Passed: cat 1844, mi = 0.002, pvalue = 0.000, GSE22611_UNSTIM_VS_2H_MDP_STIM_MUTANT_NOD2_TRANSDUCED_HEK293T_CELL_DN
# Passed: cat 2825, mi = 0.002, pvalue = 0.000, GSE3039_CD4_TCELL_VS_B2_BCELL_UP
# Passed: cat 353, mi = 0.002, pvalue = 0.000, GSE13522_CTRL_VS_T_CRUZI_Y_STRAIN_INF_SKIN_IFNG_KO_UP
# Passed: cat 4440, mi = 0.002, pvalue = 0.000, GSE6090_UNSTIM_VS_DC-SIGN_STIM_DC_DN
# Passed: cat 1128, mi = 0.002, pvalue = 0.000, GSE17721_POLYIC_VS_CPG_8H_BMDC_DN
# Passed: cat 3229, mi = 0.002, pvalue = 0.000, GSE36392_TYPE_2_MYELOID_VS_MAC_IL25_TREATED_LUNG_UP
# Passed: cat 4683, mi = 0.002, pvalue = 0.000, GSE8515_CTRL_VS_IL6_4H_STIM_MAC_UP
# Passed: cat 265, mi = 0.002, pvalue = 0.000, GSE13229_IMM_VS_INTMATURE_NKCELL_UP
# Passed: cat 2041, mi = 0.002, pvalue = 0.000, GSE23984_CTRL_VS_HYPOCALEMIC_VITAMIND_ANALOG_TCELL_UP
# Passed: cat 3886, mi = 0.002, pvalue = 0.000, GSE411_WT_VS_SOCS3_KO_MACROPHAGE_DN
# Passed: cat 3221, mi = 0.002, pvalue = 0.001, GSE36392_EOSINOPHIL_VS_MAC_IL25_TREATED_LUNG_UP
# Passed: cat 765, mi = 0.002, pvalue = 0.001, GSE16450_CTRL_VS_IFNA_6H_STIM_MATURE_NEURON_CELL_LINE_UP
# Passed: cat 2177, mi = 0.002, pvalue = 0.001, GSE24972_WT_VS_IRF8_KO_SPLEEN_FOLLICULAR_BCELL_UP
# Passed: cat 1224, mi = 0.002, pvalue = 0.001, GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_0.5H_ACT_CD4_TCELL_DN
# Passed: cat 2764, mi = 0.002, pvalue = 0.001, GSE29618_PRE_VS_DAY7_POST_TIV_FLU_VACCINE_BCELL_DN
# Passed: cat 3360, mi = 0.002, pvalue = 0.001, GSE37301_LYMPHOID_PRIMED_MPP_VS_GRAN_MONO_PROGENITOR_DN
# Passed: cat 1675, mi = 0.002, pvalue = 0.002, GSE21670_UNTREATED_VS_TGFB_TREATED_CD4_TCELL_UP
# Passed: cat 4229, mi = 0.002, pvalue = 0.002, GSE46606_DAY1_VS_DAY3_CD40L_IL2_IL5_STIMULATED_BCELL_UP
# Passed: cat 3564, mi = 0.002, pvalue = 0.002, GSE39820_TGFBETA3_IL6_VS_TGFBETA3_IL6_IL23A_TREATED_CD4_TCELL_DN
# Passed: cat 3813, mi = 0.002, pvalue = 0.001, GSE40493_BCL6_KO_VS_WT_TREG_UP
# Passed: cat 544, mi = 0.002, pvalue = 0.001, GSE14769_40MIN_VS_360MIN_LPS_BMDM_DN
# Passed: cat 2623, mi = 0.002, pvalue = 0.002, GSE28237_FOLLICULAR_VS_EARLY_GC_BCELL_UP
# Passed: cat 3578, mi = 0.002, pvalue = 0.002, GSE3982_BCELL_VS_CENT_MEMORY_CD4_TCELL_DN
# Passed: cat 3312, mi = 0.001, pvalue = 0.002, GSE3720_LPS_VS_PMA_STIM_VD2_GAMMADELTA_TCELL_DN
# Passed: cat 4288, mi = 0.001, pvalue = 0.002, GSE4984_LPS_VS_VEHICLE_CTRL_TREATED_DC_DN
# Passed: cat 1825, mi = 0.001, pvalue = 0.003, GSE22601_IMMATURE_CD4_SINGLE_POSITIVE_VS_CD4_SINGLE_POSITIVE_THYMOCYTE_UP
# Passed: cat 738, mi = 0.001, pvalue = 0.003, GSE16385_ROSIGLITAZONE_IL4_VS_IFNG_TNF_STIM_MACROPHAGE_DN
# Passed: cat 4816, mi = 0.001, pvalue = 0.003, GSE9946_MATURE_STIMULATORY_VS_PROSTAGLANDINE2_TREATED_MATURE_DC_DN
# Passed: cat 38, mi = 0.001, pvalue = 0.004, GSE10240_IL17_VS_IL17_AND_IL22_STIM_PRIMARY_BRONCHIAL_EPITHELIAL_CELLS_DN
# Passed: cat 1749, mi = 0.001, pvalue = 0.002, GSE22103_UNSTIM_VS_GMCSF_AND_IFNG_STIM_NEUTROPHIL_UP
# Passed: cat 2536, mi = 0.001, pvalue = 0.004, GSE27786_CD4_TCELL_VS_NKTCELL_DN
# Passed: cat 3130, mi = 0.001, pvalue = 0.004, GSE360_CTRL_VS_L_DONOVANI_DC_DN
# Passed: cat 1510, mi = 0.001, pvalue = 0.004, GSE20715_WT_VS_TLR4_KO_6H_OZONE_LUNG_DN
# Didn't pass (cutoff=0.0050): cat 1226, mi = 0.001, pvalue = 0.005, GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_12H_ACT_CD4_TCELL_DN
# Passed: cat 3410, mi = 0.001, pvalue = 0.004, GSE37416_CTRL_VS_3H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# Passed: cat 4064, mi = 0.001, pvalue = 0.004, GSE43863_TH1_VS_LY6C_INT_CXCR5POS_MEMORY_CD4_TCELL_DN
# Passed: cat 2016, mi = 0.001, pvalue = 0.004, GSE23505_IL6_IL1_VS_IL6_IL1_TGFB_TREATED_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 2087, mi = 0.001, pvalue = 0.005, GSE24142_EARLY_THYMIC_PROGENITOR_VS_DN2_THYMOCYTE_FETAL_DN
# Didn't pass (cutoff=0.0050): cat 2273, mi = 0.001, pvalue = 0.006, GSE2585_CTEC_VS_THYMIC_DC_UP
# Didn't pass (cutoff=0.0050): cat 3475, mi = 0.001, pvalue = 0.013, GSE37605_C57BL6_VS_NOD_FOXP3_FUSION_GFP_TREG_UP
# Didn't pass (cutoff=0.0050): cat 2340, mi = 0.001, pvalue = 0.008, GSE26559_TCF1_KO_VS_WT_LIN_NEG_CELL_DN
# Didn't pass (cutoff=0.0050): cat 9, mi = 0.001, pvalue = 0.009, GSE10147_IL3_AND_HIVP17_VS_IL3_AND_CPG_STIM_PDC_UP
# Didn't pass (cutoff=0.0050): cat 4016, mi = 0.001, pvalue = 0.010, GSE42088_UNINF_VS_LEISHMANIA_INF_DC_8H_DN
# Didn't pass (cutoff=0.0050): cat 2692, mi = 0.001, pvalue = 0.012, GSE29614_CTRL_VS_DAY3_TIV_FLU_VACCINE_PBMC_DN
# Didn't pass (cutoff=0.0050): cat 3925, mi = 0.001, pvalue = 0.012, GSE41867_DAY8_VS_DAY15_LCMV_ARMSTRONG_EFFECTOR_CD8_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 2220, mi = 0.001, pvalue = 0.009, GSE25123_CTRL_VS_IL4_AND_ROSIGLITAZONE_STIM_MACROPHAGE_DN
# Didn't pass (cutoff=0.0050): cat 576, mi = 0.001, pvalue = 0.011, GSE15324_ELF4_KO_VS_WT_NAIVE_CD8_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 2169, mi = 0.001, pvalue = 0.011, GSE24814_STAT5_KO_VS_WT_PRE_BCELL_UP
# Didn't pass (cutoff=0.0050): cat 295, mi = 0.001, pvalue = 0.013, GSE13411_NAIVE_VS_MEMORY_BCELL_UP
# Didn't pass (cutoff=0.0050): cat 3342, mi = 0.001, pvalue = 0.018, GSE37301_HEMATOPOIETIC_STEM_CELL_VS_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 1564, mi = 0.001, pvalue = 0.018, GSE21063_WT_VS_NFATC1_KO_16H_ANTI_IGM_STIM_BCELL_DN
# Didn't pass (cutoff=0.0050): cat 2379, mi = 0.001, pvalue = 0.019, GSE2706_R848_VS_LPS_2H_STIM_DC_UP
# Didn't pass (cutoff=0.0050): cat 1236, mi = 0.001, pvalue = 0.020, GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_4H_ACT_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 3939, mi = 0.001, pvalue = 0.022, GSE41867_NAIVE_VS_DAY15_LCMV_CONE13_EFFECTOR_CD8_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 3924, mi = 0.001, pvalue = 0.021, GSE41867_DAY8_VS_DAY15_LCMV_ARMSTRONG_EFFECTOR_CD8_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 631, mi = 0.001, pvalue = 0.020, GSE15659_CD45RA_NEG_CD4_TCELL_VS_NONSUPPRESSIVE_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 4112, mi = 0.001, pvalue = 0.022, GSE43955_TH0_VS_TGFB_IL6_TH17_ACT_CD4_TCELL_42H_DN
# Total number of categories evaluated = 774.
# Number of categories that passed the tests = 58
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 10, 33, 0.0156765790980028
# best merge is 7, 14, 0.0333138378712703
# best merge is 1, 11, 0.0361144586840009
# best merge is 9, 51, 0.0517143038957408
# best merge is 19, 25, 0.0647680017107558
# best merge is 1, 2, 0.0741701102856818
# best merge is 16, 48, 0.076677410039631
# best merge is 27, 29, 0.0843316476905299
# best merge is 16, 49, 0.0917458653094268
# best merge is 4, 41, 0.103632912166198
# best merge is 8, 32, 0.111742853861527
# best merge is 16, 19, 0.113898047283942
# best merge is 1, 21, 0.116409701438001
# best merge is 6, 47, 0.118833956328089
# best merge is 7, 9, 0.119799464595141
# best merge is 31, 36, 0.123653064528395
# best merge is 20, 39, 0.126046188169832
# best merge is 3, 42, 0.128531897333729
# best merge is 34, 46, 0.141089690871434
# best merge is 6, 43, 0.141570839283367
# best merge is 26, 30, 0.143136466557761
# best merge is 27, 53, 0.146422242907562
# best merge is 12, 15, 0.169911010418751
# best merge is 10, 20, 0.173004032825039
# best merge is 1, 7, 0.175383162314383
# best merge is 16, 38, 0.195727354059826
# best merge is 17, 23, 0.199996712216611
# best merge is 44, 50, 0.201091914569447
# best merge is 13, 26, 0.202638574130322
# best merge is 3, 31, 0.207632325473363
# best merge is 1, 4, 0.2226731264902
# best merge is 6, 12, 0.228904155373892
# best merge is 10, 27, 0.238035990437683
# best merge is 37, 52, 0.247075299994879
# best merge is 16, 35, 0.248805870592336
# best merge is 5, 54, 0.256924828648712
# best merge is 1, 6, 0.274170451948881
# best merge is 45, 56, 0.292533129383051
# best merge is 18, 34, 0.303082748889581
# best merge is 3, 55, 0.314781131191473
# best merge is 5, 37, 0.322881559184973
# best merge is 10, 16, 0.325888985263823
# best merge is 0, 24, 0.333207594977054
# best merge is 13, 22, 0.33439950174746
# best merge is 1, 28, 0.371369089067512
# best merge is 3, 13, 0.390209791803498
# best merge is 17, 18, 0.391872438391416
# best merge is 10, 44, 0.400600598343691
# best merge is 1, 57, 0.406786095965529
# best merge is 1, 5, 0.435045149000019
# best merge is 1, 3, 0.488193039452081
# best merge is 8, 10, 0.494932221130064
# best merge is 0, 40, 0.530282240937485
# best merge is 8, 45, 0.570943478592474
# order classes
# 3 - 5.98805781166055
# 30 - 0.733154881894707
# 18 - 1.01207985541047
# 5 - 3.06099550096817
# 2 - 4.24173037605423
# 1 11 2 21 7 14 9 51 4 41 6 47 43 12 15 28 57 5 54 37 52 3 42 31 36 55 13 26 30 22
# 0 24 40
# 8 32 10 33 20 39 27 29 53 16 48 49 19 25 38 35 44 50
# 17 23 18 34 46
# 45 56
# Done.Start drawing
# 23.77	0.00
# GSE7218_IGM_VS_IGG_SIGNAL_THGOUGH_ANTIGEN_BCELL_DN
# GSE19825_NAIVE_VS_DAY3_EFF_CD8_TCELL_UP
# GSE16450_CTRL_VS_IFNA_6H_STIM_MATURE_NEURON_CELL_LINE_UP
# GSE36392_TYPE_2_MYELOID_VS_MAC_IL25_TREATED_LUNG_UP
# GSE13229_IMM_VS_INTMATURE_NKCELL_UP
# GSE3982_BCELL_VS_CENT_MEMORY_CD4_TCELL_DN
# GSE39556_UNTREATED_VS_3H_POLYIC_INJ_MOUSE_NK_CELL_UP
# GSE3039_CD4_TCELL_VS_B2_BCELL_UP
# GSE27786_NKCELL_VS_ERYTHROBLAST_DN
# GSE24972_WT_VS_IRF8_KO_SPLEEN_FOLLICULAR_BCELL_UP
# GSE4984_LPS_VS_VEHICLE_CTRL_TREATED_DC_DN
# GSE43863_TH1_VS_LY6C_INT_CXCR5POS_MEMORY_CD4_TCELL_DN
# GSE23505_IL6_IL1_VS_IL6_IL1_TGFB_TREATED_CD4_TCELL_DN
# GSE37416_CTRL_VS_3H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# GSE17721_POLYIC_VS_CPG_8H_BMDC_DN
# GSE22886_IGM_MEMORY_BCELL_VS_BLOOD_PLASMA_CELL_DN
# GSE411_WT_VS_SOCS3_KO_MACROPHAGE_DN
# GSE42021_CD24INT_TREG_VS_CD24INT_TCONV_THYMUS_UP
# GSE40493_BCL6_KO_VS_WT_TREG_UP
# GSE360_L_MAJOR_VS_B_MALAYI_LOW_DOSE_MAC_DN
# GSE29618_PRE_VS_DAY7_POST_TIV_FLU_VACCINE_BCELL_DN
# GSE3920_UNTREATED_VS_IFNG_TREATED_ENDOTHELIAL_CELL_DN
# GSE23984_CTRL_VS_HYPOCALEMIC_VITAMIND_ANALOG_TCELL_UP
# GSE22611_UNSTIM_VS_2H_MDP_STIM_MUTANT_NOD2_TRANSDUCED_HEK293T_CELL_DN
# GSE22886_UNSTIM_VS_STIM_MEMORY_TCELL_DN
# GSE20715_WT_VS_TLR4_KO_6H_OZONE_LUNG_DN
# GSE37301_LYMPHOID_PRIMED_MPP_VS_GRAN_MONO_PROGENITOR_DN
# GSE32533_WT_VS_MIR17_KO_ACT_CD4_TCELL_DN
# GSE14908_ATOPIC_VS_NONATOPIC_PATIENT_HDM_STIM_CD4_TCELL_UP
# GSE22103_UNSTIM_VS_GMCSF_AND_IFNG_STIM_NEUTROPHIL_UP
# GSE27786_BCELL_VS_MONO_MAC_UP
# GSE27786_CD4_TCELL_VS_NKTCELL_DN
# GSE17721_POLYIC_VS_PAM3CSK4_1H_BMDC_UP
# GSE14769_40MIN_VS_360MIN_LPS_BMDM_DN
# GSE37416_CTRL_VS_48H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# GSE44649_NAIVE_VS_ACTIVATED_CD8_TCELL_MIR155_KO_UP
# GSE369_IFNG_KO_VS_WT_LIVER_DN
# GSE22601_IMMATURE_CD4_SINGLE_POSITIVE_VS_CD4_SINGLE_POSITIVE_THYMOCYTE_UP
# GSE28237_FOLLICULAR_VS_EARLY_GC_BCELL_UP
# GSE36888_UNTREATED_VS_IL2_TREATED_TCELL_6H_DN
# GSE9509_10MIN_VS_30MIN_LPS_STIM_IL10_KO_MACROPHAGE_UP
# GSE8515_CTRL_VS_IL6_4H_STIM_MAC_UP
# GSE2405_0H_VS_9H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_DN
# GSE39820_TGFBETA3_IL6_VS_TGFBETA3_IL6_IL23A_TREATED_CD4_TCELL_DN
# GSE13522_CTRL_VS_T_CRUZI_Y_STRAIN_INF_SKIN_IFNG_KO_UP
# GSE3720_LPS_VS_PMA_STIM_VD2_GAMMADELTA_TCELL_DN
# GSE36392_EOSINOPHIL_VS_MAC_IL25_TREATED_LUNG_UP
# GSE6674_UNSTIM_VS_ANTI_IGM_STIM_BCELL_DN
# GSE46606_DAY1_VS_DAY3_CD40L_IL2_IL5_STIMULATED_BCELL_UP
# GSE360_CTRL_VS_L_DONOVANI_DC_DN
# GSE15750_WT_VS_TRAF6KO_DAY10_EFF_CD8_TCELL_DN
# GSE16385_ROSIGLITAZONE_IL4_VS_IFNG_TNF_STIM_MACROPHAGE_DN
# GSE9946_MATURE_STIMULATORY_VS_PROSTAGLANDINE2_TREATED_MATURE_DC_DN
# GSE8921_UNSTIM_0H_VS_TLR1_2_STIM_MONOCYTE_3H_DN
# GSE6090_UNSTIM_VS_DC-SIGN_STIM_DC_DN
# GSE21670_UNTREATED_VS_TGFB_TREATED_CD4_TCELL_UP
# GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_0.5H_ACT_CD4_TCELL_DN
# GSE10240_IL17_VS_IL17_AND_IL22_STIM_PRIMARY_BRONCHIAL_EPITHELIAL_CELLS_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 10, 33, 0.0156765790980028
# best merge is 7, 14, 0.0333138378712703
# best merge is 1, 11, 0.0361144586840009
# best merge is 9, 51, 0.0517143038957408
# best merge is 19, 25, 0.0647680017107558
# best merge is 1, 2, 0.0741701102856818
# best merge is 16, 48, 0.076677410039631
# best merge is 27, 29, 0.0843316476905299
# best merge is 16, 49, 0.0917458653094268
# best merge is 4, 41, 0.103632912166198
# best merge is 8, 32, 0.111742853861527
# best merge is 16, 19, 0.113898047283942
# best merge is 1, 21, 0.116409701438001
# best merge is 6, 47, 0.118833956328089
# best merge is 7, 9, 0.119799464595141
# best merge is 31, 36, 0.123653064528395
# best merge is 20, 39, 0.126046188169832
# best merge is 3, 42, 0.128531897333729
# best merge is 34, 46, 0.141089690871434
# best merge is 6, 43, 0.141570839283367
# best merge is 26, 30, 0.143136466557761
# best merge is 27, 53, 0.146422242907562
# best merge is 12, 15, 0.169911010418751
# best merge is 10, 20, 0.173004032825039
# best merge is 1, 7, 0.175383162314383
# best merge is 16, 38, 0.195727354059826
# best merge is 17, 23, 0.199996712216611
# best merge is 44, 50, 0.201091914569447
# best merge is 13, 26, 0.202638574130322
# best merge is 3, 31, 0.207632325473363
# best merge is 1, 4, 0.2226731264902
# best merge is 6, 12, 0.228904155373892
# best merge is 10, 27, 0.238035990437683
# best merge is 37, 52, 0.247075299994879
# best merge is 16, 35, 0.248805870592336
# best merge is 5, 54, 0.256924828648712
# best merge is 1, 6, 0.274170451948881
# best merge is 45, 56, 0.292533129383051
# best merge is 18, 34, 0.303082748889581
# best merge is 3, 55, 0.314781131191473
# best merge is 5, 37, 0.322881559184973
# best merge is 10, 16, 0.325888985263823
# best merge is 0, 24, 0.333207594977054
# best merge is 13, 22, 0.33439950174746
# best merge is 1, 28, 0.371369089067512
# best merge is 3, 13, 0.390209791803498
# best merge is 17, 18, 0.391872438391416
# best merge is 10, 44, 0.400600598343691
# best merge is 1, 57, 0.406786095965529
# best merge is 1, 5, 0.435045149000019
# best merge is 1, 3, 0.488193039452081
# best merge is 8, 10, 0.494932221130064
# best merge is 0, 40, 0.530282240937485
# best merge is 8, 45, 0.570943478592474
# order classes
# 3 - 5.98805781166055
# 30 - 0.733154881894707
# 18 - 1.01207985541047
# 5 - 3.06099550096817
# 2 - 4.24173037605423
# 1 11 2 21 7 14 9 51 4 41 6 47 43 12 15 28 57 5 54 37 52 3 42 31 36 55 13 26 30 22
# 0 24 40
# 8 32 10 33 20 39 27 29 53 16 48 49 19 25 38 35 44 50
# 17 23 18 34 46
# 45 56
# Done.-19.2932267564156	42	0
# -18.4450988641144	42	1.4135464871687
# -18.2153975599495	42	1.69625578460244
# -18.056373580143	42	1.87294909549853
# -17.8973496003366	42	2.0143037442154
# -17.7206562894405	42	2.19099705511149
# -17.51745898191	42	2.36769036600757
# -17.2082456878418	42	2.59739167017249
# 2.49305847707194	42	2.98611695414388
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c7.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c7/human_ensembl_msigdb_c7.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 4872
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	4872
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 4872
# cat 663, mi = 0.01036369, GSE15750_DAY6_VS_DAY10_TRAF6KO_EFF_CD8_TCELL_UP
# cat 661, mi = 0.01026584, GSE15750_DAY6_VS_DAY10_EFF_CD8_TCELL_UP
# cat 3439, mi = 0.00959485, GSE37532_WT_VS_PPARG_KO_VISCERAL_ADIPOSE_TISSUE_TREG_UP
# cat 2049, mi = 0.00834950, GSE2405_0H_VS_24H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_UP
# cat 1671, mi = 0.00787514, GSE21670_UNTREATED_VS_TGFB_IL6_TREATED_CD4_TCELL_UP
# cat 2409, mi = 0.00748581, GSE27241_WT_VS_RORGT_KO_TH17_POLARIZED_CD4_TCELL_UP
# cat 2841, mi = 0.00740498, GSE30962_PRIMARY_VS_SECONDARY_ACUTE_LCMV_INF_CD8_TCELL_UP
# cat 2054, mi = 0.00711624, GSE2405_0H_VS_9H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_DN
# cat 367, mi = 0.00696420, GSE13547_CTRL_VS_ANTI_IGM_STIM_BCELL_12H_UP
# cat 3502, mi = 0.00686836, GSE39110_DAY3_VS_DAY6_POST_IMMUNIZATION_CD8_TCELL_DN
# cat 3538, mi = 0.00643914, GSE39556_CD8A_DC_VS_NK_CELL_MOUSE_3H_POST_POLYIC_INJ_UP
# cat 496, mi = 0.00611400, GSE14415_NATURAL_TREG_VS_TCONV_DN
# cat 4150, mi = 0.00598769, GSE45365_HEALTHY_VS_MCMV_INFECTION_CD11B_DC_DN
# cat 363, mi = 0.00595711, GSE13547_2H_VS_12_H_ANTI_IGM_STIM_BCELL_UP
# cat 1, mi = 0.00587425, GOLDRATH_EFF_VS_MEMORY_CD8_TCELL_UP
#
# RESULTS
# Passed: cat 663, mi = 0.010, pvalue = 0.000, GSE15750_DAY6_VS_DAY10_TRAF6KO_EFF_CD8_TCELL_UP
# Passed: cat 2049, mi = 0.008, pvalue = 0.000, GSE2405_0H_VS_24H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_UP
# Passed: cat 3296, mi = 0.005, pvalue = 0.000, GSE369_IFNG_KO_VS_WT_LIVER_DN
# Passed: cat 1700, mi = 0.004, pvalue = 0.000, GSE21927_SPLEEN_C57BL6_VS_EL4_TUMOR_BALBC_MONOCYTES_DN
# Passed: cat 4741, mi = 0.004, pvalue = 0.000, GSE9006_HEALTHY_VS_TYPE_1_DIABETES_PBMC_1MONTH_POST_DX_UP
# Passed: cat 1923, mi = 0.003, pvalue = 0.000, GSE22886_NAIVE_TCELL_VS_NEUTROPHIL_UP
# Passed: cat 4603, mi = 0.003, pvalue = 0.000, GSE7509_FCGRIIB_VS_TNFA_IL1B_IL6_PGE_STIM_DC_UP
# Passed: cat 4524, mi = 0.003, pvalue = 0.000, GSE6674_UNSTIM_VS_ANTI_IGM_STIM_BCELL_DN
# Passed: cat 1787, mi = 0.003, pvalue = 0.000, GSE22432_PDC_VS_TGFB1_TREATEDCOMMON_DC_PROGENITOR_UP
# Passed: cat 4838, mi = 0.003, pvalue = 0.000, GSE9988_ANTI_TREM1_VS_CTRL_TREATED_MONOCYTES_DN
# Passed: cat 3412, mi = 0.003, pvalue = 0.000, GSE37416_CTRL_VS_48H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# Passed: cat 1411, mi = 0.003, pvalue = 0.000, GSE19888_CTRL_VS_T_CELL_MEMBRANES_ACT_MAST_CELL_UP
# Passed: cat 1836, mi = 0.003, pvalue = 0.000, GSE22611_NOD2_TRANSD_VS_CTRL_TRANSD_HEK293_MDP_STIM_2H_DN
# Passed: cat 332, mi = 0.003, pvalue = 0.000, GSE13485_DAY7_VS_DAY21_YF17D_VACCINE_PBMC_DN
# Passed: cat 846, mi = 0.003, pvalue = 0.000, GSE17580_UNINFECTED_VS_S_MANSONI_INF_TREG_DN
# Passed: cat 4778, mi = 0.003, pvalue = 0.000, GSE9509_LPS_VS_LPS_AND_IL10_STIM_IL10_KO_MACROPHAGE_10MIN_DN
# Passed: cat 1976, mi = 0.002, pvalue = 0.000, GSE23114_PERITONEAL_CAVITY_B1A_BCELL_VS_SPLEEN_BCELL_IN_SLE2C1_MOUSE_UP
# Passed: cat 1906, mi = 0.002, pvalue = 0.000, GSE22886_NAIVE_CD4_TCELL_VS_NKCELL_DN
# Passed: cat 3229, mi = 0.002, pvalue = 0.000, GSE36392_TYPE_2_MYELOID_VS_MAC_IL25_TREATED_LUNG_UP
# Passed: cat 1144, mi = 0.002, pvalue = 0.000, GSE17721_POLYIC_VS_GARDIQUIMOD_6H_BMDC_DN
# Passed: cat 4440, mi = 0.002, pvalue = 0.000, GSE6090_UNSTIM_VS_DC-SIGN_STIM_DC_DN
# Passed: cat 1455, mi = 0.002, pvalue = 0.000, GSE20198_IL12_VS_IFNA_TREATED_ACT_CD4_TCELL_UP
# Passed: cat 1279, mi = 0.002, pvalue = 0.000, GSE18791_CTRL_VS_NEWCASTLE_VIRUS_DC_2H_UP
# Passed: cat 3813, mi = 0.002, pvalue = 0.000, GSE40493_BCL6_KO_VS_WT_TREG_UP
# Passed: cat 2181, mi = 0.002, pvalue = 0.000, GSE25085_FETAL_LIVER_VS_ADULT_BM_SP4_THYMIC_IMPLANT_UP
# Passed: cat 3297, mi = 0.002, pvalue = 0.000, GSE369_IFNG_KO_VS_WT_LIVER_UP
# Passed: cat 1961, mi = 0.002, pvalue = 0.000, GSE22935_UNSTIM_VS_24H_MBOVIS_BCG_STIM_MYD88_KO_MACROPHAGE_UP
# Passed: cat 3276, mi = 0.002, pvalue = 0.000, GSE36888_UNTREATED_VS_IL2_TREATED_STAT5_AB_KNOCKIN_TCELL_6H_DN
# Passed: cat 3098, mi = 0.002, pvalue = 0.000, GSE36009_UNSTIM_VS_LPS_STIM_DC_DN
# Passed: cat 4356, mi = 0.002, pvalue = 0.000, GSE557_CIITA_KO_VS_I_AB_KO_DC_DN
# Passed: cat 664, mi = 0.002, pvalue = 0.000, GSE15750_WT_VS_TRAF6KO_DAY10_EFF_CD8_TCELL_DN
# Passed: cat 4189, mi = 0.002, pvalue = 0.000, GSE45382_UNTREATED_VS_TGFB_TREATED_MACROPHAGES_UP
# Passed: cat 1933, mi = 0.002, pvalue = 0.000, GSE22886_NEUTROPHIL_VS_DC_UP
# Passed: cat 4402, mi = 0.002, pvalue = 0.000, GSE5589_UNSTIM_VS_45MIN_LPS_AND_IL6_STIM_MACROPHAGE_DN
# Passed: cat 3270, mi = 0.002, pvalue = 0.000, GSE36888_STAT5_AB_KNOCKIN_VS_WT_TCELL_IL2_TREATED_6H_DN
# Passed: cat 4696, mi = 0.002, pvalue = 0.000, GSE8678_IL7R_LOW_VS_HIGH_EFF_CD8_TCELL_DN
# Passed: cat 1224, mi = 0.002, pvalue = 0.000, GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_0.5H_ACT_CD4_TCELL_DN
# Passed: cat 2507, mi = 0.002, pvalue = 0.000, GSE2770_UNTREATED_VS_TGFB_AND_IL12_TREATED_ACT_CD4_TCELL_6H_UP
# Passed: cat 3395, mi = 0.002, pvalue = 0.000, GSE37416_0H_VS_3H_F_TULARENSIS_LVS_NEUTROPHIL_UP
# Passed: cat 3862, mi = 0.002, pvalue = 0.000, GSE41176_UNSTIM_VS_ANTI_IGM_STIM_TAK1_KO_BCELL_6H_DN
# Passed: cat 469, mi = 0.002, pvalue = 0.000, GSE14350_TREG_VS_TEFF_UP
# Passed: cat 2710, mi = 0.002, pvalue = 0.000, GSE29617_CTRL_VS_DAY7_TIV_FLU_VACCINE_PBMC_2008_DN
# Passed: cat 1274, mi = 0.002, pvalue = 0.000, GSE18791_CTRL_VS_NEWCASTLE_VIRUS_DC_18H_DN
# Passed: cat 4825, mi = 0.002, pvalue = 0.000, GSE9960_HEALTHY_VS_GRAM_NEG_AND_POS_SEPSIS_PBMC_UP
# Passed: cat 353, mi = 0.002, pvalue = 0.000, GSE13522_CTRL_VS_T_CRUZI_Y_STRAIN_INF_SKIN_IFNG_KO_UP
# Passed: cat 1179, mi = 0.002, pvalue = 0.000, GSE17974_0.5H_VS_72H_UNTREATED_IN_VITRO_CD4_TCELL_UP
# Passed: cat 476, mi = 0.002, pvalue = 0.000, GSE14413_UNSTIM_VS_IFNB_STIM_RAW264_CELLS_DN
# Passed: cat 3404, mi = 0.002, pvalue = 0.001, GSE37416_CTRL_VS_0H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# Passed: cat 1611, mi = 0.002, pvalue = 0.000, GSE21379_WT_VS_SAP_KO_TFH_CD4_TCELL_UP
# Passed: cat 3479, mi = 0.002, pvalue = 0.000, GSE37605_C57BL6_VS_NOD_FOXP3_IRES_GFP_TREG_UP
# Passed: cat 2197, mi = 0.002, pvalue = 0.001, GSE25088_CTRL_VS_IL4_STIM_MACROPHAGE_UP
# Passed: cat 3822, mi = 0.002, pvalue = 0.001, GSE40666_STAT1_KO_VS_STAT4_KO_CD8_TCELL_WITH_IFNA_STIM_90MIN_DN
# Passed: cat 1153, mi = 0.002, pvalue = 0.000, GSE17721_POLYIC_VS_PAM3CSK4_16H_BMDC_UP
# Passed: cat 1323, mi = 0.002, pvalue = 0.000, GSE19198_1H_VS_6H_IL21_TREATED_TCELL_UP
# Passed: cat 3743, mi = 0.002, pvalue = 0.001, GSE40274_CTRL_VS_FOXP3_AND_EOS_TRANSDUCED_ACTIVATED_CD4_TCELL_UP
# Passed: cat 3901, mi = 0.002, pvalue = 0.001, GSE4142_PLASMA_CELL_VS_GC_BCELL_UP
# Passed: cat 1844, mi = 0.002, pvalue = 0.001, GSE22611_UNSTIM_VS_2H_MDP_STIM_MUTANT_NOD2_TRANSDUCED_HEK293T_CELL_DN
# Passed: cat 873, mi = 0.002, pvalue = 0.001, GSE17721_0.5H_VS_4H_LPS_BMDC_UP
# Passed: cat 3883, mi = 0.002, pvalue = 0.001, GSE411_UNSTIM_VS_400MIN_IL6_STIM_MACROPHAGE_UP
# Passed: cat 3914, mi = 0.002, pvalue = 0.002, GSE41867_DAY6_VS_DAY15_LCMV_CLONE13_EFFECTOR_CD8_TCELL_DN
# Passed: cat 1630, mi = 0.002, pvalue = 0.001, GSE21546_UNSTIM_VS_ANTI_CD3_STIM_SAP1A_KO_AND_ELK1_KO_DP_THYMOCYTES_DN
# Passed: cat 1362, mi = 0.002, pvalue = 0.001, GSE19401_UNSTIM_VS_PAM2CSK4_STIM_FOLLICULAR_DC_DN
# Passed: cat 3772, mi = 0.002, pvalue = 0.001, GSE40274_EOS_VS_FOXP3_AND_EOS_TRANSDUCED_ACTIVATED_CD4_TCELL_DN
# Passed: cat 3428, mi = 0.002, pvalue = 0.002, GSE37532_VISCERAL_ADIPOSE_TISSUE_VS_LN_DERIVED_TCONV_CD4_TCELL_DN
# Passed: cat 972, mi = 0.002, pvalue = 0.002, GSE17721_CTRL_VS_PAM3CSK4_0.5H_BMDC_DN
# Passed: cat 608, mi = 0.002, pvalue = 0.001, GSE15330_MEGAKARYOCYTE_ERYTHROID_PROGENITOR_VS_PRO_BCELL_DN
# Passed: cat 4726, mi = 0.001, pvalue = 0.002, GSE8921_UNSTIM_0H_VS_TLR1_2_STIM_MONOCYTE_3H_DN
# Passed: cat 2964, mi = 0.001, pvalue = 0.002, GSE33162_HDAC3_KO_VS_HDAC3_KO_4H_LPS_STIM_MACROPHAGE_DN
# Passed: cat 4277, mi = 0.001, pvalue = 0.002, GSE4748_CTRL_VS_LPS_STIM_DC_3H_UP
# Passed: cat 4322, mi = 0.001, pvalue = 0.002, GSE5503_LIVER_DC_VS_PLN_DC_ACTIVATED_ALLOGENIC_TCELL_DN
# Passed: cat 4003, mi = 0.001, pvalue = 0.003, GSE42021_TREG_PLN_VS_CD24LO_TREG_THYMUS_UP
# Passed: cat 2101, mi = 0.001, pvalue = 0.003, GSE24210_IL35_TREATED_VS_UNTREATED_TCONV_CD4_TCELL_UP
# Passed: cat 1350, mi = 0.001, pvalue = 0.003, GSE19374_UNINF_VS_LISTERIA_INFECTED_MACROPHAGE_DN
# Passed: cat 2770, mi = 0.001, pvalue = 0.003, GSE29618_PRE_VS_DAY7_POST_TIV_FLU_VACCINE_PDC_DN
# Passed: cat 3038, mi = 0.001, pvalue = 0.003, GSE34156_TLR1_TLR2_LIGAND_VS_NOD2_AND_TLR1_TLR2_LIGAND_6H_TREATED_MONOCYTE_DN
# Passed: cat 1226, mi = 0.001, pvalue = 0.004, GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_12H_ACT_CD4_TCELL_DN
# Passed: cat 1382, mi = 0.001, pvalue = 0.004, GSE19825_NAIVE_VS_IL2RALOW_DAY3_EFF_CD8_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 4469, mi = 0.001, pvalue = 0.005, GSE6259_DEC205_POS_DC_VS_BCELL_UP
# Passed: cat 1379, mi = 0.001, pvalue = 0.005, GSE19825_NAIVE_VS_DAY3_EFF_CD8_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 3154, mi = 0.001, pvalue = 0.005, GSE360_DC_VS_MAC_L_MAJOR_UP
# Didn't pass (cutoff=0.0050): cat 1241, mi = 0.001, pvalue = 0.006, GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_72H_ACT_CD4_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 3250, mi = 0.001, pvalue = 0.006, GSE36476_YOUNG_VS_OLD_DONOR_MEMORY_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 1931, mi = 0.001, pvalue = 0.007, GSE22886_NAIVE_VS_MEMORY_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 3198, mi = 0.001, pvalue = 0.010, GSE360_L_MAJOR_VS_B_MALAYI_LOW_DOSE_MAC_DN
# Didn't pass (cutoff=0.0050): cat 4236, mi = 0.001, pvalue = 0.015, GSE46606_IRF4HIGH_VS_IRF4MID_CD40L_IL2_IL5_DAY1_STIMULATED_BCELL_DN
# Didn't pass (cutoff=0.0050): cat 3925, mi = 0.001, pvalue = 0.025, GSE41867_DAY8_VS_DAY15_LCMV_ARMSTRONG_EFFECTOR_CD8_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 3477, mi = 0.001, pvalue = 0.027, GSE37605_C57BL6_VS_NOD_FOXP3_IRES_GFP_TCONV_UP
# Didn't pass (cutoff=0.0050): cat 2379, mi = 0.001, pvalue = 0.042, GSE2706_R848_VS_LPS_2H_STIM_DC_UP
# Didn't pass (cutoff=0.0050): cat 834, mi = 0.001, pvalue = 0.073, GSE1740_MCSF_VS_MCSF_AND_IFNG_DAY2_DERIVED_MACROPHAGE_WITH_IFNA_STIM_DN
# Didn't pass (cutoff=0.0050): cat 4807, mi = 0.001, pvalue = 0.076, GSE9946_IMMATURE_VS_LISTERIA_INF_MATURE_DC_UP
# Didn't pass (cutoff=0.0050): cat 3342, mi = 0.001, pvalue = 0.154, GSE37301_HEMATOPOIETIC_STEM_CELL_VS_CD4_TCELL_DN
# Number of categories that passed the tests = 78
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 20, 46, 0.0172394207933289
# best merge is 7, 36, 0.0204042690512856
# best merge is 12, 39, 0.028892273023163
# best merge is 15, 23, 0.0299805082636281
# best merge is 43, 51, 0.0326369094956629
# best merge is 7, 20, 0.0407838930200432
# best merge is 12, 32, 0.041698800866846
# best merge is 63, 66, 0.0475756114877037
# best merge is 10, 56, 0.0492478825275143
# best merge is 17, 38, 0.0541093412062033
# best merge is 7, 63, 0.0559835503892945
# best merge is 13, 59, 0.0574250547072872
# best merge is 15, 29, 0.0590512997202514
# best merge is 0, 16, 0.0602028091942693
# best merge is 5, 41, 0.0631557138541567
# best merge is 12, 43, 0.0686625950711157
# best merge is 24, 34, 0.0751419371807366
# best merge is 0, 25, 0.0765523525511621
# best merge is 37, 61, 0.0773777258401984
# best merge is 10, 57, 0.0788136092067522
# best merge is 7, 13, 0.0809025933363527
# best merge is 28, 65, 0.082192104412638
# best merge is 7, 77, 0.0863792495600294
# best merge is 7, 12, 0.0893032563974798
# best merge is 8, 44, 0.0995597505225467
# best merge is 3, 5, 0.112686179730837
# best merge is 4, 21, 0.113140981595118
# best merge is 10, 28, 0.1205936670731
# best merge is 45, 76, 0.121275121214825
# best merge is 0, 50, 0.12206453636528
# best merge is 2, 8, 0.131281751863085
# best merge is 33, 69, 0.142283502551115
# best merge is 53, 62, 0.142597418565072
# best merge is 48, 75, 0.142650042257084
# best merge is 9, 68, 0.144183147281486
# best merge is 47, 49, 0.147933740482296
# best merge is 7, 53, 0.156228088840571
# best merge is 0, 71, 0.157720948194261
# best merge is 17, 33, 0.167650610197739
# best merge is 10, 73, 0.171609802954724
# best merge is 26, 72, 0.17180053811367
# best merge is 15, 45, 0.174337291488912
# best merge is 1, 27, 0.177774832088072
# best merge is 7, 60, 0.179379227666938
# best merge is 18, 30, 0.189307723944333
# best merge is 10, 37, 0.19666671105201
# best merge is 18, 67, 0.219199320041883
# best merge is 3, 4, 0.234085894177809
# best merge is 10, 17, 0.236197824852083
# best merge is 9, 26, 0.237257563203884
# best merge is 22, 58, 0.268118407292515
# best merge is 0, 24, 0.278749656497631
# best merge is 6, 11, 0.282453311212221
# best merge is 7, 18, 0.291740636336794
# best merge is 10, 15, 0.29609220497464
# best merge is 9, 52, 0.30780072594304
# best merge is 31, 64, 0.314593178259428
# best merge is 2, 3, 0.323812355567144
# best merge is 54, 55, 0.334542492580875
# best merge is 7, 48, 0.373430996827266
# best merge is 9, 40, 0.407557571018142
# best merge is 0, 54, 0.411459217387994
# best merge is 10, 70, 0.411611030964674
# best merge is 2, 6, 0.418406073124882
# best merge is 7, 47, 0.426494646417074
# best merge is 2, 10, 0.453296705040227
# best merge is 1, 74, 0.521336333922396
# best merge is 7, 42, 0.529654997492589
# best merge is 14, 31, 0.532758659206025
# best merge is 2, 22, 0.541099242827924
# best merge is 2, 19, 0.60223571419766
# best merge is 0, 9, 0.665851289515947
# best merge is 14, 35, 0.70756164929513
# best merge is 2, 14, 0.733757018905351
# order classes
# 15 - 2.34152391363044
# 3 - 7.05147444405655
# 31 - 0.958507870143668
# 25 - 0.764673569031056
# 4 - 8.53806389610737
# 7 36 20 46 63 66 13 59 77 12 39 32 43 51 53 62 60 18 30 67 48 75 47 49 42
# 1 27 74
# 2 8 44 3 5 41 4 21 6 11 10 56 57 28 65 73 37 61 17 38 33 69 15 23 29 45 76 70 22 58 19
# 0 16 25 50 71 24 34 54 55 9 68 26 72 52 40
# 14 31 64 35
# Done.Start drawing
# 62.96	0.00
# GSE36392_TYPE_2_MYELOID_VS_MAC_IL25_TREATED_LUNG_UP
# GSE21379_WT_VS_SAP_KO_TFH_CD4_TCELL_UP
# GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_12H_ACT_CD4_TCELL_DN
# GSE15750_DAY6_VS_DAY10_TRAF6KO_EFF_CD8_TCELL_UP
# GSE23114_PERITONEAL_CAVITY_B1A_BCELL_VS_SPLEEN_BCELL_IN_SLE2C1_MOUSE_UP
# GSE369_IFNG_KO_VS_WT_LIVER_UP
# GSE25088_CTRL_VS_IL4_STIM_MACROPHAGE_UP
# GSE24210_IL35_TREATED_VS_UNTREATED_TCONV_CD4_TCELL_UP
# GSE25085_FETAL_LIVER_VS_ADULT_BM_SP4_THYMIC_IMPLANT_UP
# GSE36888_STAT5_AB_KNOCKIN_VS_WT_TCELL_IL2_TREATED_6H_DN
# GSE40274_CTRL_VS_FOXP3_AND_EOS_TRANSDUCED_ACTIVATED_CD4_TCELL_UP
# GSE4142_PLASMA_CELL_VS_GC_BCELL_UP
# GSE4748_CTRL_VS_LPS_STIM_DC_3H_UP
# GSE18791_CTRL_VS_NEWCASTLE_VIRUS_DC_18H_DN
# GSE22886_NAIVE_CD4_TCELL_VS_NKCELL_DN
# GSE9988_ANTI_TREM1_VS_CTRL_TREATED_MONOCYTES_DN
# GSE22935_UNSTIM_VS_24H_MBOVIS_BCG_STIM_MYD88_KO_MACROPHAGE_UP
# GSE19374_UNINF_VS_LISTERIA_INFECTED_MACROPHAGE_DN
# GSE17721_POLYIC_VS_PAM3CSK4_16H_BMDC_UP
# GSE14350_TREG_VS_TEFF_UP
# GSE42021_TREG_PLN_VS_CD24LO_TREG_THYMUS_UP
# GSE17721_POLYIC_VS_GARDIQUIMOD_6H_BMDC_DN
# GSE13522_CTRL_VS_T_CRUZI_Y_STRAIN_INF_SKIN_IFNG_KO_UP
# GSE37416_CTRL_VS_48H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# GSE2770_UNTREATED_VS_TGFB_AND_IL12_TREATED_ACT_CD4_TCELL_6H_UP
# GSE9509_LPS_VS_LPS_AND_IL10_STIM_IL10_KO_MACROPHAGE_10MIN_DN
# GSE40493_BCL6_KO_VS_WT_TREG_UP
# GSE557_CIITA_KO_VS_I_AB_KO_DC_DN
# GSE17974_0.5H_VS_72H_UNTREATED_IN_VITRO_CD4_TCELL_UP
# GSE19825_NAIVE_VS_IL2RALOW_DAY3_EFF_CD8_TCELL_DN
# GSE21927_SPLEEN_C57BL6_VS_EL4_TUMOR_BALBC_MONOCYTES_DN
# GSE7509_FCGRIIB_VS_TNFA_IL1B_IL6_PGE_STIM_DC_UP
# GSE19888_CTRL_VS_T_CELL_MEMBRANES_ACT_MAST_CELL_UP
# GSE22611_UNSTIM_VS_2H_MDP_STIM_MUTANT_NOD2_TRANSDUCED_HEK293T_CELL_DN
# GSE17721_0.5H_VS_4H_LPS_BMDC_UP
# GSE29618_PRE_VS_DAY7_POST_TIV_FLU_VACCINE_PDC_DN
# GSE37416_0H_VS_3H_F_TULARENSIS_LVS_NEUTROPHIL_UP
# GSE5589_UNSTIM_VS_45MIN_LPS_AND_IL6_STIM_MACROPHAGE_DN
# GSE5503_LIVER_DC_VS_PLN_DC_ACTIVATED_ALLOGENIC_TCELL_DN
# GSE17580_UNINFECTED_VS_S_MANSONI_INF_TREG_DN
# GSE17721_CTRL_VS_PAM3CSK4_0.5H_BMDC_DN
# GSE22432_PDC_VS_TGFB1_TREATEDCOMMON_DC_PROGENITOR_UP
# GSE22886_NAIVE_TCELL_VS_NEUTROPHIL_UP
# GSE29617_CTRL_VS_DAY7_TIV_FLU_VACCINE_PBMC_2008_DN
# GSE9006_HEALTHY_VS_TYPE_1_DIABETES_PBMC_1MONTH_POST_DX_UP
# GSE20198_IL12_VS_IFNA_TREATED_ACT_CD4_TCELL_UP
# GSE36009_UNSTIM_VS_LPS_STIM_DC_DN
# GSE15330_MEGAKARYOCYTE_ERYTHROID_PROGENITOR_VS_PRO_BCELL_DN
# GSE19401_UNSTIM_VS_PAM2CSK4_STIM_FOLLICULAR_DC_DN
# GSE369_IFNG_KO_VS_WT_LIVER_DN
# GSE45382_UNTREATED_VS_TGFB_TREATED_MACROPHAGES_UP
# GSE8678_IL7R_LOW_VS_HIGH_EFF_CD8_TCELL_DN
# GSE2405_0H_VS_24H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_UP
# GSE36888_UNTREATED_VS_IL2_TREATED_STAT5_AB_KNOCKIN_TCELL_6H_DN
# GSE34156_TLR1_TLR2_LIGAND_VS_NOD2_AND_TLR1_TLR2_LIGAND_6H_TREATED_MONOCYTE_DN
# GSE18791_CTRL_VS_NEWCASTLE_VIRUS_DC_2H_UP
# GSE411_UNSTIM_VS_400MIN_IL6_STIM_MACROPHAGE_UP
# GSE6674_UNSTIM_VS_ANTI_IGM_STIM_BCELL_DN
# GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_0.5H_ACT_CD4_TCELL_DN
# GSE6090_UNSTIM_VS_DC-SIGN_STIM_DC_DN
# GSE14413_UNSTIM_VS_IFNB_STIM_RAW264_CELLS_DN
# GSE37532_VISCERAL_ADIPOSE_TISSUE_VS_LN_DERIVED_TCONV_CD4_TCELL_DN
# GSE8921_UNSTIM_0H_VS_TLR1_2_STIM_MONOCYTE_3H_DN
# GSE13485_DAY7_VS_DAY21_YF17D_VACCINE_PBMC_DN
# GSE41867_DAY6_VS_DAY15_LCMV_CLONE13_EFFECTOR_CD8_TCELL_DN
# GSE19825_NAIVE_VS_DAY3_EFF_CD8_TCELL_UP
# GSE22611_NOD2_TRANSD_VS_CTRL_TRANSD_HEK293_MDP_STIM_2H_DN
# GSE41176_UNSTIM_VS_ANTI_IGM_STIM_TAK1_KO_BCELL_6H_DN
# GSE22886_NEUTROPHIL_VS_DC_UP
# GSE9960_HEALTHY_VS_GRAM_NEG_AND_POS_SEPSIS_PBMC_UP
# GSE40666_STAT1_KO_VS_STAT4_KO_CD8_TCELL_WITH_IFNA_STIM_90MIN_DN
# GSE19198_1H_VS_6H_IL21_TREATED_TCELL_UP
# GSE40274_EOS_VS_FOXP3_AND_EOS_TRANSDUCED_ACTIVATED_CD4_TCELL_DN
# GSE21546_UNSTIM_VS_ANTI_CD3_STIM_SAP1A_KO_AND_ELK1_KO_DP_THYMOCYTES_DN
# GSE15750_WT_VS_TRAF6KO_DAY10_EFF_CD8_TCELL_DN
# GSE33162_HDAC3_KO_VS_HDAC3_KO_4H_LPS_STIM_MACROPHAGE_DN
# GSE37416_CTRL_VS_0H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# GSE37605_C57BL6_VS_NOD_FOXP3_IRES_GFP_TREG_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 20, 46, 0.0172394207933289
# best merge is 7, 36, 0.0204042690512856
# best merge is 12, 39, 0.028892273023163
# best merge is 15, 23, 0.0299805082636281
# best merge is 43, 51, 0.0326369094956629
# best merge is 7, 20, 0.0407838930200432
# best merge is 12, 32, 0.041698800866846
# best merge is 63, 66, 0.0475756114877037
# best merge is 10, 56, 0.0492478825275143
# best merge is 17, 38, 0.0541093412062033
# best merge is 7, 63, 0.0559835503892945
# best merge is 13, 59, 0.0574250547072872
# best merge is 15, 29, 0.0590512997202514
# best merge is 0, 16, 0.0602028091942693
# best merge is 5, 41, 0.0631557138541567
# best merge is 12, 43, 0.0686625950711157
# best merge is 24, 34, 0.0751419371807366
# best merge is 0, 25, 0.0765523525511621
# best merge is 37, 61, 0.0773777258401984
# best merge is 10, 57, 0.0788136092067522
# best merge is 7, 13, 0.0809025933363527
# best merge is 28, 65, 0.082192104412638
# best merge is 7, 77, 0.0863792495600294
# best merge is 7, 12, 0.0893032563974798
# best merge is 8, 44, 0.0995597505225467
# best merge is 3, 5, 0.112686179730837
# best merge is 4, 21, 0.113140981595118
# best merge is 10, 28, 0.1205936670731
# best merge is 45, 76, 0.121275121214825
# best merge is 0, 50, 0.12206453636528
# best merge is 2, 8, 0.131281751863085
# best merge is 33, 69, 0.142283502551115
# best merge is 53, 62, 0.142597418565072
# best merge is 48, 75, 0.142650042257084
# best merge is 9, 68, 0.144183147281486
# best merge is 47, 49, 0.147933740482296
# best merge is 7, 53, 0.156228088840571
# best merge is 0, 71, 0.157720948194261
# best merge is 17, 33, 0.167650610197739
# best merge is 10, 73, 0.171609802954724
# best merge is 26, 72, 0.17180053811367
# best merge is 15, 45, 0.174337291488912
# best merge is 1, 27, 0.177774832088072
# best merge is 7, 60, 0.179379227666938
# best merge is 18, 30, 0.189307723944333
# best merge is 10, 37, 0.19666671105201
# best merge is 18, 67, 0.219199320041883
# best merge is 3, 4, 0.234085894177809
# best merge is 10, 17, 0.236197824852083
# best merge is 9, 26, 0.237257563203884
# best merge is 22, 58, 0.268118407292515
# best merge is 0, 24, 0.278749656497631
# best merge is 6, 11, 0.282453311212221
# best merge is 7, 18, 0.291740636336794
# best merge is 10, 15, 0.29609220497464
# best merge is 9, 52, 0.30780072594304
# best merge is 31, 64, 0.314593178259428
# best merge is 2, 3, 0.323812355567144
# best merge is 54, 55, 0.334542492580875
# best merge is 7, 48, 0.373430996827266
# best merge is 9, 40, 0.407557571018142
# best merge is 0, 54, 0.411459217387994
# best merge is 10, 70, 0.411611030964674
# best merge is 2, 6, 0.418406073124882
# best merge is 7, 47, 0.426494646417074
# best merge is 2, 10, 0.453296705040227
# best merge is 1, 74, 0.521336333922396
# best merge is 7, 42, 0.529654997492589
# best merge is 14, 31, 0.532758659206025
# best merge is 2, 22, 0.541099242827924
# best merge is 2, 19, 0.60223571419766
# best merge is 0, 9, 0.665851289515947
# best merge is 14, 35, 0.70756164929513
# best merge is 2, 14, 0.733757018905351
# order classes
# 15 - 2.34152391363044
# 3 - 7.05147444405655
# 31 - 0.958507870143668
# 25 - 0.764673569031056
# 4 - 8.53806389610737
# 7 36 20 46 63 66 13 59 77 12 39 32 43 51 53 62 60 18 30 67 48 75 47 49 42
# 1 27 74
# 2 8 44 3 5 41 4 21 6 11 10 56 57 28 65 73 37 61 17 38 33 69 15 23 29 45 76 70 22 58 19
# 0 16 25 50 71 24 34 54 55 9 68 26 72 52 40
# 14 31 64 35
# Done.-19.7198221092757	42	0
# -19.3562579415502	42	0.560355781448539
# -19.2195044472681	42	0.72712833545108
# -19.1227763659466	42	0.833862770012706
# -19.0360546378653	42	0.920584498094028
# -18.9459974587039	42	1.00730622617535
# -18.8359275730623	42	1.10069885641677
# -18.6558132147395	42	1.2274459974587
# 1.73046378653113	42	1.46092757306226
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_1.csv --species=human_ensembl_msigdb_c7 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_2.csv --species=human_ensembl_msigdb_c7 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c7.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c7/human_ensembl_msigdb_c7.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 4872
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	4872
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 4872
# cat 663, mi = 0.01862418, GSE15750_DAY6_VS_DAY10_TRAF6KO_EFF_CD8_TCELL_UP
# cat 661, mi = 0.01832631, GSE15750_DAY6_VS_DAY10_EFF_CD8_TCELL_UP
# cat 3538, mi = 0.01379988, GSE39556_CD8A_DC_VS_NK_CELL_MOUSE_3H_POST_POLYIC_INJ_UP
# cat 2841, mi = 0.01304401, GSE30962_PRIMARY_VS_SECONDARY_ACUTE_LCMV_INF_CD8_TCELL_UP
# cat 367, mi = 0.01264267, GSE13547_CTRL_VS_ANTI_IGM_STIM_BCELL_12H_UP
# cat 1569, mi = 0.01109379, GSE21063_WT_VS_NFATC1_KO_8H_ANTI_IGM_STIM_BCELL_UP
# cat 2147, mi = 0.01076057, GSE24634_TEFF_VS_TCONV_DAY7_IN_CULTURE_UP
# cat 2155, mi = 0.01020830, GSE24634_TREG_VS_TCONV_POST_DAY7_IL4_CONVERSION_UP
# cat 496, mi = 0.00997661, GSE14415_NATURAL_TREG_VS_TCONV_DN
# cat 3238, mi = 0.00996920, GSE36476_CTRL_VS_TSST_ACT_40H_MEMORY_CD4_TCELL_YOUNG_DN
# cat 3242, mi = 0.00995423, GSE36476_CTRL_VS_TSST_ACT_72H_MEMORY_CD4_TCELL_YOUNG_DN
# cat 2213, mi = 0.00990146, GSE25088_WT_VS_STAT6_KO_MACROPHAGE_IL4_STIM_DN
# cat 1, mi = 0.00978269, GOLDRATH_EFF_VS_MEMORY_CD8_TCELL_UP
# cat 3439, mi = 0.00942750, GSE37532_WT_VS_PPARG_KO_VISCERAL_ADIPOSE_TISSUE_TREG_UP
# cat 2409, mi = 0.00923499, GSE27241_WT_VS_RORGT_KO_TH17_POLARIZED_CD4_TCELL_UP
#
# RESULTS
# Passed: cat 663, mi = 0.019, pvalue = 0.000, GSE15750_DAY6_VS_DAY10_TRAF6KO_EFF_CD8_TCELL_UP
# Passed: cat 2054, mi = 0.006, pvalue = 0.000, GSE2405_0H_VS_9H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_DN
# Passed: cat 2153, mi = 0.005, pvalue = 0.000, GSE24634_TREG_VS_TCONV_POST_DAY5_IL4_CONVERSION_UP
# Passed: cat 3956, mi = 0.005, pvalue = 0.000, GSE41867_NAIVE_VS_EFFECTOR_CD8_TCELL_DN
# Passed: cat 1318, mi = 0.004, pvalue = 0.000, GSE18893_TCONV_VS_TREG_2H_TNF_STIM_DN
# Passed: cat 2639, mi = 0.003, pvalue = 0.000, GSE28726_ACT_CD4_TCELL_VS_ACT_VA24NEG_NKTCELL_UP
# Passed: cat 3540, mi = 0.003, pvalue = 0.000, GSE39556_UNTREATED_VS_3H_POLYIC_INJ_MOUSE_CD8A_DC_DN
# Passed: cat 1690, mi = 0.003, pvalue = 0.000, GSE21927_C26GM_VS_4T1_TUMOR_MONOCYTE_BALBC_DN
# Passed: cat 4643, mi = 0.003, pvalue = 0.000, GSE7831_1H_VS_4H_CPG_STIM_PDC_UP
# Passed: cat 3801, mi = 0.003, pvalue = 0.000, GSE40274_XBP1_VS_FOXP3_AND_XBP1_TRANSDUCED_ACTIVATED_CD4_TCELL_UP
# Passed: cat 3412, mi = 0.003, pvalue = 0.000, GSE37416_CTRL_VS_48H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# Passed: cat 1900, mi = 0.003, pvalue = 0.000, GSE22886_NAIVE_CD4_TCELL_VS_MEMORY_TCELL_DN
# Passed: cat 4190, mi = 0.003, pvalue = 0.000, GSE45739_NRAS_KO_VS_WT_ACD3_ACD28_STIM_CD4_TCELL_DN
# ...
# Didn't pass (cutoff=0.0050): cat 4456, mi = 0.001, pvalue = 0.008, GSE6259_33D1_POS_DC_VS_CD8_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 89, mi = 0.001, pvalue = 0.007, GSE11057_NAIVE_VS_MEMORY_CD4_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 1181, mi = 0.001, pvalue = 0.006, GSE17974_0H_VS_0.5H_IN_VITRO_ACT_CD4_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 3794, mi = 0.001, pvalue = 0.009, GSE40274_IRF4_VS_FOXP3_AND_IRF4_TRANSDUCED_ACTIVATED_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 1523, mi = 0.001, pvalue = 0.008, GSE20727_DNFB_ALLERGEN_VS_ROS_INH_AND_DNFB_ALLERGEN_TREATED_DC_UP
# Didn't pass (cutoff=0.0050): cat 2964, mi = 0.001, pvalue = 0.012, GSE33162_HDAC3_KO_VS_HDAC3_KO_4H_LPS_STIM_MACROPHAGE_DN
# Didn't pass (cutoff=0.0050): cat 1975, mi = 0.001, pvalue = 0.013, GSE23114_PERITONEAL_CAVITY_B1A_BCELL_VS_SPLEEN_BCELL_IN_SLE2C1_MOUSE_DN
# Didn't pass (cutoff=0.0050): cat 95, mi = 0.001, pvalue = 0.015, GSE1112_OT1_CD8AB_VS_HY_CD8AA_THYMOCYTE_RTOC_CULTURE_UP
# Didn't pass (cutoff=0.0050): cat 1964, mi = 0.001, pvalue = 0.037, GSE22935_UNSTIM_VS_48H_MBOVIS_BCG_STIM_MYD88_KO_MACROPHAGE_DN
# Didn't pass (cutoff=0.0050): cat 6, mi = 0.001, pvalue = 0.041, GSE10094_LCMV_VS_LISTERIA_IND_EFF_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 3342, mi = 0.001, pvalue = 0.059, GSE37301_HEMATOPOIETIC_STEM_CELL_VS_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 1696, mi = 0.001, pvalue = 0.064, GSE21927_HEALTHY_VS_TUMOROUS_BALBC_MOUSE_MONOCYTE_DN
# Didn't pass (cutoff=0.0050): cat 3038, mi = 0.001, pvalue = 0.059, GSE34156_TLR1_TLR2_LIGAND_VS_NOD2_AND_TLR1_TLR2_LIGAND_6H_TREATED_MONOCYTE_DN
# Didn't pass (cutoff=0.0050): cat 3798, mi = 0.001, pvalue = 0.118, GSE40274_SATB1_VS_FOXP3_AND_SATB1_TRANSDUCED_ACTIVATED_CD4_TCELL_DN
# Number of categories that passed the tests = 92
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_5.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 32, 45, 0.0113011432112657
# best merge is 30, 42, 0.0116600658769033
# best merge is 3, 82, 0.0116729478573897
# best merge is 52, 56, 0.0180538696912282
# best merge is 15, 57, 0.0198995924541108
# best merge is 7, 27, 0.0200026422111621
# best merge is 30, 75, 0.0225643612836633
# best merge is 15, 19, 0.0236353356910841
# best merge is 4, 34, 0.0254499427821397
# best merge is 12, 18, 0.0269706660992223
# best merge is 60, 83, 0.027633993759219
# best merge is 53, 55, 0.0302851573405032
# best merge is 21, 49, 0.0307533956622216
# best merge is 11, 23, 0.0312872166812603
# best merge is 52, 86, 0.0315794095612909
# best merge is 8, 84, 0.0349836096252003
# best merge is 25, 31, 0.0426598508237357
# best merge is 3, 80, 0.0440081073770152
# best merge is 32, 53, 0.0476324541079873
# best merge is 36, 48, 0.0487302646478324
# best merge is 30, 52, 0.0500733591658631
# best merge is 1, 2, 0.0512432444794806
# best merge is 10, 20, 0.0520436157299722
# best merge is 3, 44, 0.0552205756733049
# best merge is 16, 62, 0.0573486583596552
# best merge is 13, 22, 0.0584353813093604
# best merge is 11, 43, 0.0589322364289187
# best merge is 4, 59, 0.059154764271846
# best merge is 72, 81, 0.0627749771849262
# best merge is 0, 1, 0.0636294381842687
# best merge is 10, 71, 0.0658967088350791
# best merge is 32, 50, 0.0678260386663616
# best merge is 37, 74, 0.0687601363885635
# best merge is 24, 41, 0.0726155950857684
# best merge is 13, 15, 0.0773782420373225
# best merge is 5, 10, 0.0775804554045917
# best merge is 6, 90, 0.0833305294078351
# best merge is 32, 36, 0.0854879803901151
# best merge is 16, 21, 0.085751927936978
# best merge is 13, 14, 0.0870081836205392
# best merge is 8, 29, 0.0871479946616662
# best merge is 3, 13, 0.0915075753009794
# best merge is 0, 8, 0.093085754657426
# best merge is 30, 40, 0.0959830300134384
# best merge is 66, 69, 0.097428635568381
# best merge is 25, 39, 0.0977181403611022
# best merge is 24, 89, 0.101326412905691
# best merge is 11, 66, 0.104571779749093
# best merge is 4, 12, 0.106912451398671
# best merge is 37, 68, 0.1071527459785
# best merge is 30, 32, 0.108260906268224
# best merge is 64, 85, 0.110147055005209
# best merge is 67, 91, 0.110379124749422
# best merge is 0, 4, 0.118568514229624
# best merge is 17, 54, 0.120358649345319
# best merge is 11, 16, 0.125143737962215
# best merge is 24, 30, 0.128729509183149
# best merge is 63, 67, 0.136742957174517
# best merge is 6, 25, 0.139974621342873
# best merge is 3, 5, 0.148021929438301
# best merge is 24, 60, 0.157552769014036
# best merge is 7, 11, 0.158271660254095
# best merge is 28, 70, 0.165755004396392
# best merge is 64, 87, 0.166715297223137
# best merge is 46, 72, 0.168055666168045
# best merge is 6, 7, 0.170081476731848
# best merge is 3, 17, 0.18379154679846
# best merge is 0, 79, 0.19180046075712
# best merge is 24, 64, 0.195879060899099
# best merge is 6, 77, 0.217515006710768
# best merge is 9, 47, 0.221647238318932
# best merge is 24, 28, 0.228425427937207
# best merge is 3, 6, 0.232303641262801
# best merge is 46, 63, 0.235210981466499
# best merge is 0, 37, 0.242633792305471
# best merge is 61, 73, 0.253842094639654
# best merge is 3, 51, 0.280217716406251
# best merge is 0, 3, 0.285485104529585
# best merge is 24, 46, 0.34235496458577
# best merge is 0, 35, 0.345186684863207
# best merge is 33, 38, 0.413632953927899
# best merge is 24, 26, 0.464187284550508
# best merge is 0, 33, 0.489564016038216
# best merge is 0, 58, 0.516306935262327
# best merge is 24, 88, 0.55568222826065
# best merge is 0, 9, 0.589336563943616
# best merge is 0, 61, 0.652464584103173
# best merge is 0, 76, 0.749747645839447
# order classes
# 57 - 0.495154967402993
# 32 - 0.696953913174125
# 0 1 2 8 84 29 4 34 59 12 18 79 37 74 68 3 82 80 44 13 22 15 57 19 14 5 10 20 71 17 54 6 90 25 31 39 7 27 11 23 43 66 69 16 62 21 49 77 51 35 33 38 58 9 47 61 73
# 24 41 89 30 42 75 52 56 86 40 32 45 53 55 50 36 48 60 83 64 85 87 28 70 46 72 81 63 67 91 26 88
# 65
# 76
# 78
# Done.Start drawing
# 66.19	0.00
# GSE13738_RESTING_VS_TCR_ACTIVATED_CD4_TCELL_DN
# GSE29618_BCELL_VS_MDC_DN
# GSE17721_PAM3CSK4_VS_GADIQUIMOD_6H_BMDC_DN
# GSE16450_CTRL_VS_IFNA_6H_STIM_MATURE_NEURON_CELL_LINE_UP
# GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_12H_ACT_CD4_TCELL_DN
# GSE21360_SECONDARY_VS_TERTIARY_MEMORY_CD8_TCELL_UP
# GSE9006_HEALTHY_VS_TYPE_1_DIABETES_PBMC_4MONTH_POST_DX_UP
# GSE14000_TRANSLATED_RNA_VS_MRNA_DC_UP
# GSE41176_WT_VS_TAK1_KO_ANTI_IGM_STIM_BCELL_24H_UP
# GSE37301_MULTIPOTENT_PROGENITOR_VS_COMMON_LYMPHOID_PROGENITOR_DN
# GSE22611_UNSTIM_VS_2H_MDP_STIM_MUTANT_NOD2_TRANSDUCED_HEK293T_CELL_DN
# GSE46468_LUNG_INNATE_LYMPHOID_CELL_VS_SPLEEN_CD4_TCELL_DN
# GSE16385_MONOCYTE_VS_12H_IFNG_TNF_TREATED_MACROPHAGE_UP
# GSE45365_HEALTHY_VS_MCMV_INFECTION_BCELL_IFNAR_KO_UP
# GSE13547_2H_VS_12_H_ANTI_IGM_STIM_BCELL_DN
# GSE2770_IL12_AND_TGFB_ACT_VS_ACT_CD4_TCELL_6H_DN
# GSE20484_MCSG_VS_CXCL4_MONOCYTE_DERIVED_MACROPHAGE_UP
# GSE34006_UNTREATED_VS_A2AR_AGONIST_TREATED_TREG_UP
# GSE17721_POLYIC_VS_GARDIQUIMOD_8H_BMDC_DN
# GSE22935_24H_VS_48H_MBOVIS_BCG_STIM_MACROPHAGE_DN
# GSE5099_UNSTIM_VS_MCSF_TREATED_MONOCYTE_DAY7_UP
# GSE21546_ELK1_KO_VS_SAP1A_KO_AND_ELK1_KO_ANTI_CD3_STIM_DP_THYMOCYTES_UP
# GSE3920_IFNB_VS_IFNG_TREATED_ENDOTHELIAL_CELL_DN
# GSE25088_CTRL_VS_IL4_AND_ROSIGLITAZONE_STIM_MACROPHAGE_UP
# GSE22432_PDC_VS_TGFB1_TREATEDCOMMON_DC_PROGENITOR_UP
# GSE339_CD8POS_VS_CD4CD8DN_DC_IN_CULTURE_DN
# GSE36009_UNSTIM_VS_LPS_STIM_DC_DN
# GSE14908_RESTING_VS_HDM_STIM_CD4_TCELL_ATOPIC_PATIENT_UP
# GSE29617_CTRL_VS_TIV_FLU_VACCINE_PBMC_2008_DN
# GSE18791_UNSTIM_VS_NEWCATSLE_VIRUS_DC_6H_UP
# GSE15930_STIM_VS_STIM_AND_IL-12_24H_CD8_T_CELL_UP
# GSE6674_ANTI_IGM_VS_PL2_3_STIM_BCELL_DN
# GSE3982_NEUTROPHIL_VS_BASOPHIL_DN
# GSE360_DC_VS_MAC_B_MALAYI_LOW_DOSE_UP
# GSE45365_NK_CELL_VS_CD8A_DC_DN
# GSE13484_UNSTIM_VS_YF17D_VACCINE_STIM_PBMC_UP
# GSE36888_UNTREATED_VS_IL2_TREATED_TCELL_6H_DN
# GSE37416_CTRL_VS_48H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# GSE17721_0.5H_VS_4H_LPS_BMDC_UP
# GSE2770_TGFB_AND_IL4_VS_IL4_TREATED_ACT_CD4_TCELL_6H_DN
# GSE26290_WT_VS_PDK1_KO_ANTI_CD3_AND_IL2_STIM_CD8_TCELL_DN
# GSE40274_CTRL_VS_LEF1_TRANSDUCED_ACTIVATED_CD4_TCELL_DN
# GSE7852_THYMUS_VS_FAT_TCONV_UP
# GSE45837_WT_VS_GFI1_KO_PDC_DN
# GSE2770_UNTREATED_VS_TGFB_AND_IL12_TREATED_ACT_CD4_TCELL_6H_UP
# GSE7348_UNSTIM_VS_TOLERIZED_AND_LPS_STIM_MACROPHAGE_UP
# GSE29618_PRE_VS_DAY7_POST_LAIV_FLU_VACCINE_BCELL_UP
# GSE24671_CTRL_VS_SENDAI_VIRUS_INFECTED_MOUSE_SPLENOCYTES_DN
# GSE32533_WT_VS_MIR17_OVEREXPRESS_ACT_CD4_TCELL_UP
# GSE23695_CD57_POS_VS_NEG_NK_CELL_UP
# GSE41867_NAIVE_VS_DAY15_LCMV_EFFECTOR_CD8_TCELL_UP
# GSE37533_PPARG1_FOXP3_VS_PPARG2_FOXP3_TRANSDUCED_CD4_TCELL_UP
# GSE19888_CTRL_VS_T_CELL_MEMBRANES_ACT_MAST_CELL_UP
# GSE32533_WT_VS_MIR17_KO_ACT_CD4_TCELL_DN
# GSE12845_IGD_NEG_BLOOD_VS_DARKZONE_GC_TONSIL_BCELL_DN
# GSE9960_GRAM_NEG_VS_GRAM_NEG_AND_POS_SEPSIS_PBMC_DN
# GSE27786_CD4_TCELL_VS_MONO_MAC_UP
# GSE12198_LOW_IL2_STIM_NK_CELL_VS_HIGH_IL2_STIM_NK_CELL_UP
# GSE5679_PPARG_LIGAND_ROSIGLITAZONE_VS_ROSIGLITAZONE_AND_RARA_AGONIST_AM580_TREATED_DC_DN
# GSE34156_NOD2_LIGAND_VS_NOD2_AND_TLR1_TLR2_LIGAND_6H_TREATED_MONOCYTE_UP
# GSE1460_NAIVE_CD4_TCELL_CORD_BLOOD_VS_THYMIC_STROMAL_CELL_DN
# GSE21927_SPLEEN_C57BL6_VS_EL4_TUMOR_BALBC_MONOCYTES_UP
# GSE26495_PD1HIGH_VS_PD1LOW_CD8_TCELL_UP
# GSE22025_UNTREATED_VS_TGFB1_TREATED_CD4_TCELL_DN
# GSE18791_UNSTIM_VS_NEWCATSLE_VIRUS_DC_1H_UP
# GSE9946_MATURE_STIMULATORY_VS_PROSTAGLANDINE2_TREATED_MATURE_DC_DN
# GSE35543_IN_VIVO_NTREG_VS_CONVERTED_EX_ITREG_DN
# GSE13485_DAY7_VS_DAY21_YF17D_VACCINE_PBMC_DN
# GSE24210_IL35_TREATED_VS_RESTING_TREG_DN
# GSE21670_UNTREATED_VS_TGFB_TREATED_CD4_TCELL_UP
# GSE13522_WT_VS_IFNG_KO_SKIN_UP
# GSE15750_WT_VS_TRAF6KO_DAY10_EFF_CD8_TCELL_DN
# GSE22611_NOD2_TRANSD_VS_CTRL_TRANSD_HEK293_MDP_STIM_2H_DN
# GSE6259_DEC205_POS_DC_VS_BCELL_UP
# GSE41867_DAY6_VS_DAY15_LCMV_CLONE13_EFFECTOR_CD8_TCELL_DN
# GSE6090_UNSTIM_VS_DC-SIGN_STIM_DC_DN
# GSE6259_FLT3L_INDUCED_VS_WT_SPLENIC_DC_33D1_POS_DN
# GSE6681_DELETED_FOXP3_VS_WT_TREG_UP
# GSE22886_NEUTROPHIL_VS_DC_UP
# GSE23502_WT_VS_HDC_KO_MYELOID_DERIVED_SUPPRESSOR_CELL_COLON_TUMOR_DN
# GSE8921_UNSTIM_0H_VS_TLR1_2_STIM_MONOCYTE_3H_DN
# GSE22886_IL2_VS_IL15_STIM_NKCELL_UP
# GSE37532_TREG_VS_TCONV_CD4_TCELL_FROM_VISCERAL_ADIPOSE_TISSUE_UP
# GSE41867_DAY6_VS_DAY15_LCMV_CLONE13_EFFECTOR_CD8_TCELL_UP
# GSE41176_WT_VS_TAK1_KO_UNSTIM_BCELL_DN
# GSE32423_CTRL_VS_IL7_MEMORY_CD8_TCELL_UP
# GSE35543_IN_VIVO_NTREG_VS_IN_VITRO_ITREG_UP
# GSE37605_TREG_VS_TCONV_C57BL6_FOXP3_IRES_GFP_UP
# GSE2405_0H_VS_3H_A_PHAGOCYTOPHILUM_STIM_NEUTROPHIL_UP
# GSE19825_NAIVE_VS_DAY3_EFF_CD8_TCELL_UP
# GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_6H_ACT_CD4_TCELL_UP
# GSE19941_UNSTIM_VS_LPS_AND_IL10_STIM_IL10_KO_NFKBP50_KO_MACROPHAGE_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_5.csv_PAGE/filt_FC_LVM2_5.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_5.csv_PAGE/filt_FC_LVM2_5.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_5.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 32, 45, 0.0113011432112657
# best merge is 30, 42, 0.0116600658769033
# best merge is 3, 82, 0.0116729478573897
# best merge is 52, 56, 0.0180538696912282
# best merge is 15, 57, 0.0198995924541108
# best merge is 7, 27, 0.0200026422111621
# best merge is 30, 75, 0.0225643612836633
# best merge is 15, 19, 0.0236353356910841
# best merge is 4, 34, 0.0254499427821397
# best merge is 12, 18, 0.0269706660992223
# best merge is 60, 83, 0.027633993759219
# best merge is 53, 55, 0.0302851573405032
# best merge is 21, 49, 0.0307533956622216
# best merge is 11, 23, 0.0312872166812603
# best merge is 52, 86, 0.0315794095612909
# best merge is 8, 84, 0.0349836096252003
# best merge is 25, 31, 0.0426598508237357
# best merge is 3, 80, 0.0440081073770152
# best merge is 32, 53, 0.0476324541079873
# best merge is 36, 48, 0.0487302646478324
# best merge is 30, 52, 0.0500733591658631
# best merge is 1, 2, 0.0512432444794806
# best merge is 10, 20, 0.0520436157299722
# best merge is 3, 44, 0.0552205756733049
# best merge is 16, 62, 0.0573486583596552
# best merge is 13, 22, 0.0584353813093604
# best merge is 11, 43, 0.0589322364289187
# best merge is 4, 59, 0.059154764271846
# best merge is 72, 81, 0.0627749771849262
# best merge is 0, 1, 0.0636294381842687
# best merge is 10, 71, 0.0658967088350791
# best merge is 32, 50, 0.0678260386663616
# best merge is 37, 74, 0.0687601363885635
# best merge is 24, 41, 0.0726155950857684
# best merge is 13, 15, 0.0773782420373225
# best merge is 5, 10, 0.0775804554045917
# best merge is 6, 90, 0.0833305294078351
# best merge is 32, 36, 0.0854879803901151
# best merge is 16, 21, 0.085751927936978
# best merge is 13, 14, 0.0870081836205392
# best merge is 8, 29, 0.0871479946616662
# best merge is 3, 13, 0.0915075753009794
# best merge is 0, 8, 0.093085754657426
# best merge is 30, 40, 0.0959830300134384
# best merge is 66, 69, 0.097428635568381
# best merge is 25, 39, 0.0977181403611022
# best merge is 24, 89, 0.101326412905691
# best merge is 11, 66, 0.104571779749093
# best merge is 4, 12, 0.106912451398671
# best merge is 37, 68, 0.1071527459785
# best merge is 30, 32, 0.108260906268224
# best merge is 64, 85, 0.110147055005209
# best merge is 67, 91, 0.110379124749422
# best merge is 0, 4, 0.118568514229624
# best merge is 17, 54, 0.120358649345319
# best merge is 11, 16, 0.125143737962215
# best merge is 24, 30, 0.128729509183149
# best merge is 63, 67, 0.136742957174517
# best merge is 6, 25, 0.139974621342873
# best merge is 3, 5, 0.148021929438301
# best merge is 24, 60, 0.157552769014036
# best merge is 7, 11, 0.158271660254095
# best merge is 28, 70, 0.165755004396392
# best merge is 64, 87, 0.166715297223137
# best merge is 46, 72, 0.168055666168045
# best merge is 6, 7, 0.170081476731848
# best merge is 3, 17, 0.18379154679846
# best merge is 0, 79, 0.19180046075712
# best merge is 24, 64, 0.195879060899099
# best merge is 6, 77, 0.217515006710768
# best merge is 9, 47, 0.221647238318932
# best merge is 24, 28, 0.228425427937207
# best merge is 3, 6, 0.232303641262801
# best merge is 46, 63, 0.235210981466499
# best merge is 0, 37, 0.242633792305471
# best merge is 61, 73, 0.253842094639654
# best merge is 3, 51, 0.280217716406251
# best merge is 0, 3, 0.285485104529585
# best merge is 24, 46, 0.34235496458577
# best merge is 0, 35, 0.345186684863207
# best merge is 33, 38, 0.413632953927899
# best merge is 24, 26, 0.464187284550508
# best merge is 0, 33, 0.489564016038216
# best merge is 0, 58, 0.516306935262327
# best merge is 24, 88, 0.55568222826065
# best merge is 0, 9, 0.589336563943616
# best merge is 0, 61, 0.652464584103173
# best merge is 0, 76, 0.749747645839447
# order classes
# 57 - 0.495154967402993
# 32 - 0.696953913174125
# 0 1 2 8 84 29 4 34 59 12 18 79 37 74 68 3 82 80 44 13 22 15 57 19 14 5 10 20 71 17 54 6 90 25 31 39 7 27 11 23 43 66 69 16 62 21 49 77 51 35 33 38 58 9 47 61 73
# 24 41 89 30 42 75 52 56 86 40 32 45 53 55 50 36 48 60 83 64 85 87 28 70 46 72 81 63 67 91 26 88
# 65
# 76
# 78
# Done.-19.8477111346125	42	0
# -19.6224505212268	42	0.304577730775042
# -19.501888502795	42	0.450521226771416
# -19.4130533313189	42	0.545701767638616
# -19.330563529234	42	0.628191569723523
# -19.2480737271491	42	0.71068137180843
# -19.1528931862819	42	0.793171173893337
# -19.0196404290678	42	0.901042453542831
# 1.52983834416075	42	1.0596766883215
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c7/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt
# DONE
# sem --wait done
