# %% [markdown]
# # This is used for running data vs human_ensembl_encode_tf annotations located in:
# ### /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import scipy.stats

# %% [markdown]
# ### get index of file names to loop through

# %%
# %%bash
#
# cd fc_values
# ls FC* > filelist.txt
# cd ..

# %% [markdown]
# ### get ensemble genes represented in iPAGE database

# %%
# %%bash
#
# cp /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf_index.txt human_ensembl_index.txt
# awk '{print $1}' human_ensembl_index.txt > ensembl_index.txt

# %% [markdown]
# ### make sure that genes in file match the index

# %%
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
###################REMEMBER TO SPECIFY INDEX USED IN THE IPAGE COMMAND!!!!!!!!
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#####################
#######read in data from logfc calculations
#####################
####define index file to loop through
index_file = "fc_values/filelist.txt"
####define matching ensg index
GO_index_filename = "ensembl_index.txt"
genes_with_GOs = []
with open(GO_index_filename,'r') as rf:
    for line in rf:
        gene_name = line.split('\n')[0]
        genes_with_GOs.append(gene_name)
genes_with_GOs_set = set(genes_with_GOs)
####open file and loop through each line
###
iPAGE_sh = "iPAGE_JY.sh"
cwd = os.getcwd()+"/"
os.system("rm "+iPAGE_sh)
###
with open(index_file,'r') as rf:
    for line in rf:
        #####do this to each file
        ###read in file into pandas df
        FC_file = "fc_values/"+line.split('\n')[0]
        FC_df = pd.read_csv(FC_file,sep=',',index_col=0)
        FC_df.columns = ['log2FoldChange']
        FC_df.index.names = ['Gene']
        ###filter
        FC_df = FC_df.loc[[x for x in FC_df.index if x in genes_with_GOs_set]]
        ###save
        save_file = "fc_values/filt_"+line.split('\n')[0]
        FC_df.to_csv(save_file,sep='\t',header=True)
        ###write final iPAGE command to an ipage .sh file
        iPAGE_cmd = "perl /nvme/bins/iPAGEv1.0/page.pl --expfile "+cwd+save_file+" --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9 \n"
        with open(iPAGE_sh, "a") as myfile:
            myfile.write(iPAGE_cmd)

# %% [markdown]
# ## then run the command from this folder:
#
# nohup sh run.sh iPAGE_JY.sh &

# %%
# %%bash
#
# nohup sh run.sh iPAGE_JY.sh &
# Out:
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_2.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_2.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_4.csv --species=human_ensembl_encode_tf --exptype=continuous --max_p=0.1 --ebins=9
# done
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 12, mi = 0.00099702, BRF1_ChIP-seq_regulon
# cat 115, mi = 0.00075915, PPARGC1A_ChIP-seq_regulon
# cat 114, mi = 0.00073299, POU5F1_ChIP-seq_regulon
# cat 167, mi = 0.00059073, XRCC4_ChIP-seq_regulon
# cat 13, mi = 0.00048745, BRF2_ChIP-seq_regulon
# cat 9, mi = 0.00037502, BDP1_ChIP-seq_regulon
# cat 112, mi = 0.00027504, POLR3G_ChIP-seq_regulon
# cat 131, mi = 0.00019052, SMARCA4_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 12, mi = 0.001, pvalue = 0.074, BRF1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.000, pvalue = 0.936, SMARCA4_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Didn't pass: cat 19, mi = 0.000, pvalue = 1.000, CEBPD_ChIP-seq_regulon
# Didn't pass: cat 20, mi = 0.000, pvalue = 1.000, CEBPZ_ChIP-seq_regulon
# Didn't pass: cat 21, mi = 0.000, pvalue = 1.000, CHD1_ChIP-seq_regulon
# Total number of categories evaluated = 17.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 23.77	0.00
# BRF1_ChIP-seq_regulon, BRF1
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.2843920908708	42	0
# -18.4274295330248	42	1.43121581825831
# -18.2065628944047	42	1.71392511569205
# -18.0475389145982	42	1.87294909549853
# -17.8885149347918	42	2.03197307530501
# -17.7206562894405	42	2.19099705511149
# -17.51745898191	42	2.36769036600757
# -17.199411022297	42	2.59739167017249
# 2.50189314261674	42	3.00378628523349
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 115, mi = 0.00107859, PPARGC1A_ChIP-seq_regulon
# cat 112, mi = 0.00080070, POLR3G_ChIP-seq_regulon
# cat 131, mi = 0.00078613, SMARCA4_ChIP-seq_regulon
# cat 13, mi = 0.00059631, BRF2_ChIP-seq_regulon
# cat 9, mi = 0.00050579, BDP1_ChIP-seq_regulon
# cat 114, mi = 0.00049400, POU5F1_ChIP-seq_regulon
# cat 12, mi = 0.00047787, BRF1_ChIP-seq_regulon
# cat 167, mi = 0.00041578, XRCC4_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 115, mi = 0.001, pvalue = 0.049, PPARGC1A_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 112, mi = 0.001, pvalue = 0.186, POLR3G_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.001, pvalue = 0.183, SMARCA4_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 9, mi = 0.001, pvalue = 0.451, BDP1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 114, mi = 0.000, pvalue = 0.465, POU5F1_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Total number of categories evaluated = 14.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 84.94	0.00
# PPARGC1A_ChIP-seq_regulon, PPARGC1A
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.849187661879	42	0
# -19.6588179891688	42	0.301624676242053
# -19.5920649870497	42	0.380739345420297
# -19.5401459854015	42	0.435130680480339
# -19.4906993171651	42	0.484577348716741
# -19.4387803155168	42	0.534024016953143
# -19.3744996468095	42	0.588415352013186
# -19.2706616435131	42	0.662585354367789
# 1.39804567930304	42	0.796091358606075
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 115, mi = 0.00103157, PPARGC1A_ChIP-seq_regulon
# cat 9, mi = 0.00060267, BDP1_ChIP-seq_regulon
# cat 167, mi = 0.00059073, XRCC4_ChIP-seq_regulon
# cat 12, mi = 0.00052932, BRF1_ChIP-seq_regulon
# cat 112, mi = 0.00052542, POLR3G_ChIP-seq_regulon
# cat 13, mi = 0.00048745, BRF2_ChIP-seq_regulon
# cat 114, mi = 0.00048179, POU5F1_ChIP-seq_regulon
# cat 131, mi = 0.00043553, SMARCA4_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 115, mi = 0.001, pvalue = 0.071, PPARGC1A_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 9, mi = 0.001, pvalue = 0.315, BDP1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 112, mi = 0.001, pvalue = 0.502, POLR3G_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 114, mi = 0.000, pvalue = 0.486, POU5F1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.000, pvalue = 0.578, SMARCA4_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Total number of categories evaluated = 14.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 26.31	0.00
# PPARGC1A_ChIP-seq_regulon, PPARGC1A
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv_PAGE/filt_FC_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv_PAGE/filt_FC_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.521094640821	42	0
# -18.8905359179019	42	0.957810718358039
# -18.6431014823261	42	1.26111744583808
# -18.4675028506271	42	1.45267958950969
# -18.3078677309008	42	1.61231470923603
# -18.1482326111745	42	1.77194982896237
# -17.9726339794755	42	1.93158494868871
# -17.709236031927	42	2.12314709236032
# 2.22919042189282	42	2.45838084378563
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 12, mi = 0.00098849, BRF1_ChIP-seq_regulon
# cat 115, mi = 0.00096557, PPARGC1A_ChIP-seq_regulon
# cat 9, mi = 0.00079041, BDP1_ChIP-seq_regulon
# cat 112, mi = 0.00055905, POLR3G_ChIP-seq_regulon
# cat 114, mi = 0.00052770, POU5F1_ChIP-seq_regulon
# cat 13, mi = 0.00048745, BRF2_ChIP-seq_regulon
# cat 167, mi = 0.00041578, XRCC4_ChIP-seq_regulon
# cat 131, mi = 0.00032291, SMARCA4_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 12, mi = 0.001, pvalue = 0.079, BRF1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.000, pvalue = 0.777, SMARCA4_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Didn't pass: cat 19, mi = 0.000, pvalue = 1.000, CEBPD_ChIP-seq_regulon
# Didn't pass: cat 20, mi = 0.000, pvalue = 1.000, CEBPZ_ChIP-seq_regulon
# Didn't pass: cat 21, mi = 0.000, pvalue = 1.000, CHD1_ChIP-seq_regulon
# Total number of categories evaluated = 17.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 123.78	0.00
# BRF1_ChIP-seq_regulon, BRF1
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv_PAGE/filt_FC_LVM2_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv_PAGE/filt_FC_LVM2_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.876151236064	42	0
# -19.7149781871062	42	0.247697527872031
# -19.6572952011634	42	0.322346097915657
# -19.6182743577315	42	0.363063499757635
# -19.5826466311197	42	0.400387784779447
# -19.5453223460979	42	0.434318952981095
# -19.5012118274358	42	0.475036354823073
# -19.4265632573921	42	0.522539990305381
# 1.31216674745516	42	0.624333494910325
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 115, mi = 0.00103137, PPARGC1A_ChIP-seq_regulon
# cat 114, mi = 0.00091804, POU5F1_ChIP-seq_regulon
# cat 13, mi = 0.00077146, BRF2_ChIP-seq_regulon
# cat 112, mi = 0.00064889, POLR3G_ChIP-seq_regulon
# cat 167, mi = 0.00059073, XRCC4_ChIP-seq_regulon
# cat 12, mi = 0.00057624, BRF1_ChIP-seq_regulon
# cat 9, mi = 0.00054792, BDP1_ChIP-seq_regulon
# cat 131, mi = 0.00035674, SMARCA4_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 115, mi = 0.001, pvalue = 0.068, PPARGC1A_ChIP-seq_regulon
# Passed: cat 114, mi = 0.001, pvalue = 0.075, POU5F1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.000, pvalue = 0.733, SMARCA4_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Didn't pass: cat 19, mi = 0.000, pvalue = 1.000, CEBPD_ChIP-seq_regulon
# Didn't pass: cat 20, mi = 0.000, pvalue = 1.000, CEBPZ_ChIP-seq_regulon
# Didn't pass: cat 21, mi = 0.000, pvalue = 1.000, CHD1_ChIP-seq_regulon
# Total number of categories evaluated = 17.
# Number of categories that passed the tests = 2
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 62.96	0.00
# POU5F1_ChIP-seq_regulon, POU5F1
# PPARGC1A_ChIP-seq_regulon, PPARGC1A
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.7164866581957	42	0
# -19.34625158831	42	0.56702668360864
# -19.209498094028	42	0.740470139771283
# -19.1161054637865	42	0.840533672172808
# -19.0293837357052	42	0.92725540025413
# -18.9393265565438	42	1.01397712833545
# -18.8292566709022	42	1.10736975857687
# -18.6524777636595	42	1.23411689961881
# 1.73046378653113	42	1.46092757306226
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 13, mi = 0.00129673, BRF2_ChIP-seq_regulon
# cat 115, mi = 0.00114419, PPARGC1A_ChIP-seq_regulon
# cat 114, mi = 0.00098227, POU5F1_ChIP-seq_regulon
# cat 9, mi = 0.00059004, BDP1_ChIP-seq_regulon
# cat 131, mi = 0.00043403, SMARCA4_ChIP-seq_regulon
# cat 167, mi = 0.00041578, XRCC4_ChIP-seq_regulon
# cat 112, mi = 0.00031820, POLR3G_ChIP-seq_regulon
# cat 12, mi = 0.00018980, BRF1_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 13, mi = 0.001, pvalue = 0.006, BRF2_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.000, pvalue = 0.590, SMARCA4_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Didn't pass: cat 19, mi = 0.000, pvalue = 1.000, CEBPD_ChIP-seq_regulon
# Didn't pass: cat 20, mi = 0.000, pvalue = 1.000, CEBPZ_ChIP-seq_regulon
# Didn't pass: cat 21, mi = 0.000, pvalue = 1.000, CHD1_ChIP-seq_regulon
# Total number of categories evaluated = 17.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 79.76	0.00
# BRF2_ChIP-seq_regulon, BRF2
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv_PAGE/filt_FC_LVM2_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv_PAGE/filt_FC_LVM2_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.8077983951856	42	0
# -19.5339769307924	42	0.384403209628887
# -19.402331995988	42	0.547642928786359
# -19.312813440321	42	0.647693079237713
# -19.2311935807422	42	0.726680040120361
# -19.1469408224674	42	0.810932798395186
# -19.0416248746239	42	0.89518555667001
# -18.8704864593781	42	1.02156469408225
# 1.61873119358074	42	1.23746238716148
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_3.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 115, mi = 0.00135894, PPARGC1A_ChIP-seq_regulon
# cat 112, mi = 0.00066645, POLR3G_ChIP-seq_regulon
# cat 12, mi = 0.00061900, BRF1_ChIP-seq_regulon
# cat 131, mi = 0.00059849, SMARCA4_ChIP-seq_regulon
# cat 114, mi = 0.00054875, POU5F1_ChIP-seq_regulon
# cat 13, mi = 0.00048745, BRF2_ChIP-seq_regulon
# cat 167, mi = 0.00041578, XRCC4_ChIP-seq_regulon
# cat 9, mi = 0.00031480, BDP1_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 115, mi = 0.001, pvalue = 0.009, PPARGC1A_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 112, mi = 0.001, pvalue = 0.313, POLR3G_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.001, pvalue = 0.355, SMARCA4_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 114, mi = 0.001, pvalue = 0.384, POU5F1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 9, mi = 0.000, pvalue = 0.776, BDP1_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Total number of categories evaluated = 14.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 100.30	0.00
# PPARGC1A_ChIP-seq_regulon, PPARGC1A
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv_PAGE/filt_FC_LVM2_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv_PAGE/filt_FC_LVM2_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.8890329012961	42	0
# -19.7361914257228	42	0.221934197407777
# -19.6670987038883	42	0.30568295114656
# -19.6168494516451	42	0.36011964107677
# -19.5686939182453	42	0.406181455633101
# -19.5142572283151	42	0.456430707876371
# -19.4430707876371	42	0.515054835493519
# -19.3279162512463	42	0.598803589232303
# 1.37268195413758	42	0.745363908275175
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_4.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 9, mi = 0.00091724, BDP1_ChIP-seq_regulon
# cat 115, mi = 0.00079905, PPARGC1A_ChIP-seq_regulon
# cat 112, mi = 0.00065742, POLR3G_ChIP-seq_regulon
# cat 131, mi = 0.00053229, SMARCA4_ChIP-seq_regulon
# cat 13, mi = 0.00048725, BRF2_ChIP-seq_regulon
# cat 167, mi = 0.00041578, XRCC4_ChIP-seq_regulon
# cat 12, mi = 0.00038840, BRF1_ChIP-seq_regulon
# cat 114, mi = 0.00030981, POU5F1_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 9, mi = 0.001, pvalue = 0.083, BDP1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 115, mi = 0.001, pvalue = 0.188, PPARGC1A_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.001, pvalue = 0.462, SMARCA4_ChIP-seq_regulon
# Didn't pass: cat 167, mi = 0.000, pvalue = 1.000, XRCC4_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Didn't pass: cat 19, mi = 0.000, pvalue = 1.000, CEBPD_ChIP-seq_regulon
# Total number of categories evaluated = 15.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 80.82	0.00
# BDP1_ChIP-seq_regulon, BDP1
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv_PAGE/filt_FC_LVM2_5.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv_PAGE/filt_FC_LVM2_5.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.8726800296956	42	0
# -19.6855976243504	42	0.25463994060876
# -19.586859688196	42	0.374164810690423
# -19.5141054194506	42	0.452115812917595
# -19.449146250928	42	0.519673348181143
# -19.3815887156644	42	0.582034149962881
# -19.3036377134373	42	0.654788418708241
# -19.1945063103192	42	0.737936154417223
# 1.43652561247216	42	0.873051224944321
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 114, mi = 0.00151278, POU5F1_ChIP-seq_regulon
# cat 9, mi = 0.00112075, BDP1_ChIP-seq_regulon
# cat 13, mi = 0.00101272, BRF2_ChIP-seq_regulon
# cat 131, mi = 0.00088626, SMARCA4_ChIP-seq_regulon
# cat 112, mi = 0.00077501, POLR3G_ChIP-seq_regulon
# cat 12, mi = 0.00071586, BRF1_ChIP-seq_regulon
# cat 115, mi = 0.00043158, PPARGC1A_ChIP-seq_regulon
# cat 167, mi = 0.00041578, XRCC4_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 114, mi = 0.002, pvalue = 0.002, POU5F1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.001, pvalue = 0.124, SMARCA4_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 115, mi = 0.000, pvalue = 0.638, PPARGC1A_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# ...
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 115, mi = 0.00134012, PPARGC1A_ChIP-seq_regulon
# cat 114, mi = 0.00071279, POU5F1_ChIP-seq_regulon
# cat 131, mi = 0.00068757, SMARCA4_ChIP-seq_regulon
# cat 13, mi = 0.00048735, BRF2_ChIP-seq_regulon
# cat 112, mi = 0.00041597, POLR3G_ChIP-seq_regulon
# cat 167, mi = 0.00041588, XRCC4_ChIP-seq_regulon
# cat 9, mi = 0.00031470, BDP1_ChIP-seq_regulon
# cat 12, mi = 0.00018970, BRF1_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 115, mi = 0.001, pvalue = 0.010, PPARGC1A_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 114, mi = 0.001, pvalue = 0.189, POU5F1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.001, pvalue = 0.277, SMARCA4_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 112, mi = 0.000, pvalue = 0.681, POLR3G_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 9, mi = 0.000, pvalue = 0.768, BDP1_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Total number of categories evaluated = 14.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 110.21	0.00
# PPARGC1A_ChIP-seq_regulon, PPARGC1A
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.9980945467743	42	0
# -19.9923781870974	42	0.00381090645132021
# -19.9847563741947	42	0.0114327193539606
# -19.9790400145177	42	0.019054532256601
# -19.9733236548408	42	0.0228654387079212
# -19.9676072951638	42	0.0304872516105617
# -19.8285092096906	42	0.0342981580618819
# -19.4779058161691	42	0.308683422556937
# 1.3677524725524	42	0.7355049451048
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 115, mi = 0.00208459, PPARGC1A_ChIP-seq_regulon
# cat 131, mi = 0.00106709, SMARCA4_ChIP-seq_regulon
# cat 13, mi = 0.00066241, BRF2_ChIP-seq_regulon
# cat 167, mi = 0.00059093, XRCC4_ChIP-seq_regulon
# cat 9, mi = 0.00056257, BDP1_ChIP-seq_regulon
# cat 112, mi = 0.00055699, POLR3G_ChIP-seq_regulon
# cat 12, mi = 0.00026679, BRF1_ChIP-seq_regulon
# cat 114, mi = 0.00019484, POU5F1_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 115, mi = 0.002, pvalue = 0.000, PPARGC1A_ChIP-seq_regulon
# Passed: cat 131, mi = 0.001, pvalue = 0.051, SMARCA4_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 9, mi = 0.001, pvalue = 0.369, BDP1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 112, mi = 0.001, pvalue = 0.473, POLR3G_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Didn't pass: cat 19, mi = 0.000, pvalue = 1.000, CEBPD_ChIP-seq_regulon
# Didn't pass: cat 20, mi = 0.000, pvalue = 1.000, CEBPZ_ChIP-seq_regulon
# Total number of categories evaluated = 16.
# Number of categories that passed the tests = 2
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 280.55	0.00
# PPARGC1A_ChIP-seq_regulon, PPARGC1A
# SMARCA4_ChIP-seq_regulon, SMARCA4
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv_PAGE/filt_FC_P_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv_PAGE/filt_FC_P_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.9985029406523	42	0
# -19.9962573516307	42	0.00299411869541971
# -19.9940117626092	42	0.00449117804312957
# -19.9917661735876	42	0.00748529673854928
# -19.989520584566	42	0.00898235608625913
# -19.9865264658706	42	0.0119764747816788
# -19.9146676171805	42	0.0149705934770986
# -19.7537337373017	42	0.155694172161825
# 1.16841917661736	42	0.336838353234718
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_encode_tf.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_encode_tf/human_ensembl_encode_tf.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 11438... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 11438 out of 11438
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 11438	181
# Done.
# Writing internal quantized groups ...Done
# 1271 hits go_terms_num = 181
# cat 115, mi = 0.00095684, PPARGC1A_ChIP-seq_regulon
# cat 131, mi = 0.00081996, SMARCA4_ChIP-seq_regulon
# cat 167, mi = 0.00059073, XRCC4_ChIP-seq_regulon
# cat 13, mi = 0.00048755, BRF2_ChIP-seq_regulon
# cat 112, mi = 0.00040724, POLR3G_ChIP-seq_regulon
# cat 114, mi = 0.00039230, POU5F1_ChIP-seq_regulon
# cat 9, mi = 0.00037748, BDP1_ChIP-seq_regulon
# cat 12, mi = 0.00027914, BRF1_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Passed: cat 115, mi = 0.001, pvalue = 0.093, PPARGC1A_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 131, mi = 0.001, pvalue = 0.167, SMARCA4_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 112, mi = 0.000, pvalue = 0.698, POLR3G_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 114, mi = 0.000, pvalue = 0.639, POU5F1_ChIP-seq_regulon
# Didn't pass (cutoff=0.1000): cat 9, mi = 0.000, pvalue = 0.660, BDP1_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Didn't pass: cat 15, mi = 0.000, pvalue = 1.000, CBX3_ChIP-seq_regulon
# Didn't pass: cat 16, mi = 0.000, pvalue = 1.000, CBX8_ChIP-seq_regulon
# Didn't pass: cat 17, mi = 0.000, pvalue = 1.000, CCNT2_ChIP-seq_regulon
# Didn't pass: cat 18, mi = 0.000, pvalue = 1.000, CEBPB_ChIP-seq_regulon
# Total number of categories evaluated = 14.
# Number of categories that passed the tests = 1
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 15.99	0.00
# PPARGC1A_ChIP-seq_regulon, PPARGC1A
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -19.3958724202627	42	0
# -18.6341463414634	42	1.20825515947467
# -18.3846153846154	42	1.5234521575985
# -18.2007504690432	42	1.70731707317073
# -18.0168855534709	42	1.89118198874296
# -17.8330206378987	42	2.0750469043152
# -17.5966228893058	42	2.25891181988743
# -17.2157598499062	42	2.54784240150094
# 2.51031894934334	42	3.02063789868668
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_encode_tf/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# sem --wait done
