# %% [markdown]
# # This is used for running data vs human_msigdb_c2 annotations located in:
# ### /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c2

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import scipy.stats

# %% [markdown]
# ### get index of file names to loop through

# %%
# %%bash
#
# cd fc_values
# ls FC* > filelist.txt
# cd ..

# %% [markdown]
# ### get ensembl genes represented in iPAGE database

# %%
# %%bash
#
# cp /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c2/human_ensembl_msigdb_c2_index.txt human_ensembl_index.txt
# awk '{print $1}' human_ensembl_index.txt > ensembl_index.txt

# %% [markdown]
# ### make sure that genes in file match the index

# %%
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
###################REMEMBER TO SPECIFY INDEX USED IN THE IPAGE COMMAND!!!!!!!!
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#####################
#######read in data from logfc calculations
#####################
####define index file to loop through
index_file = "fc_values/filelist.txt"
####define matching ensg index
GO_index_filename = "ensembl_index.txt"
genes_with_GOs = []
with open(GO_index_filename,'r') as rf:
    for line in rf:
        gene_name = line.split('\n')[0]
        genes_with_GOs.append(gene_name)
genes_with_GOs_set = set(genes_with_GOs)
####open file and loop through each line
###
iPAGE_sh = "iPAGE_JY.sh"
cwd = os.getcwd()+"/"
os.system("rm "+iPAGE_sh)
###
with open(index_file,'r') as rf:
    for line in rf:
        #####do this to each file
        ###read in file into pandas df
        FC_file = "fc_values/"+line.split('\n')[0]
        FC_df = pd.read_csv(FC_file,sep=',',index_col=0)
        FC_df.columns = ['log2FoldChange']
        FC_df.index.names = ['Gene']
        ###filter
        FC_df = FC_df.loc[[x for x in FC_df.index if x in genes_with_GOs_set]]
        ###save
        save_file = "fc_values/filt_"+line.split('\n')[0]
        FC_df.to_csv(save_file,sep='\t',header=True)
        ###write final iPAGE command to an ipage .sh file
        iPAGE_cmd = "perl /nvme/bins/iPAGEv1.0/page.pl --expfile "+cwd+save_file+" --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9 \n"
        with open(iPAGE_sh, "a") as myfile:
            myfile.write(iPAGE_cmd)

# %% [markdown]
# ## then run the command from this folder:
#
# nohup sh run.sh iPAGE_JY.sh &

# %%
# %%bash
#
# nohup sh run.sh iPAGE_JY.sh &
# Out:
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_3.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_4.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c2.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c2/human_ensembl_msigdb_c2.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 4738
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	4738
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 4738
# cat 990, mi = 0.00961121, FISCHER_G1_S_CELL_CYCLE
# cat 3426, mi = 0.00958123, REACTOME_PEPTIDE_CHAIN_ELONGATION
# cat 3009, mi = 0.00952008, REACTOME_3_UTR_MEDIATED_TRANSLATIONAL_REGULATION
# cat 3655, mi = 0.00924229, REACTOME_TRANSLATION
# cat 1731, mi = 0.00912335, KEGG_RIBOSOME
# cat 3601, mi = 0.00808522, REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANE
# cat 3288, mi = 0.00742294, REACTOME_INFLUENZA_VIRAL_RNA_TRANSCRIPTION_AND_REPLICATION
# cat 3391, mi = 0.00739870, REACTOME_NONSENSE_MEDIATED_DECAY_ENHANCED_BY_THE_EXON_JUNCTION_COMPLEX
# cat 3287, mi = 0.00627951, REACTOME_INFLUENZA_LIFE_CYCLE
# cat 1698, mi = 0.00613831, KEGG_OXIDATIVE_PHOSPHORYLATION
# cat 182, mi = 0.00570297, BILANGES_SERUM_AND_RAPAMYCIN_SENSITIVE_GENES
# cat 4313, mi = 0.00518593, VERNELL_RETINOBLASTOMA_PATHWAY_UP
# cat 3521, mi = 0.00475595, REACTOME_RESPIRATORY_ELECTRON_TRANSPORT_ATP_SYNTHESIS_BY_CHEMIOSMOTIC_COUPLING_AND_HEAT_PRODUCTION_BY_UNCOUPLING_PROTEINS_
# cat 3807, mi = 0.00448912, SARRIO_EPITHELIAL_MESENCHYMAL_TRANSITION_UP
# cat 3626, mi = 0.00440607, REACTOME_TCA_CYCLE_AND_RESPIRATORY_ELECTRON_TRANSPORT
#
# RESULTS
# Passed: cat 990, mi = 0.010, pvalue = 0.000, FISCHER_G1_S_CELL_CYCLE
# Passed: cat 3426, mi = 0.010, pvalue = 0.000, REACTOME_PEPTIDE_CHAIN_ELONGATION
# Passed: cat 1698, mi = 0.006, pvalue = 0.000, KEGG_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 35, mi = 0.004, pvalue = 0.000, AIGNER_ZEB1_TARGETS
# Passed: cat 1739, mi = 0.004, pvalue = 0.000, KEGG_SPLICEOSOME
# Passed: cat 3428, mi = 0.003, pvalue = 0.000, REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORS
# Passed: cat 925, mi = 0.003, pvalue = 0.000, ELVIDGE_HYPOXIA_UP
# Passed: cat 1520, mi = 0.003, pvalue = 0.000, JOHNSTONE_PARVB_TARGETS_1_DN
# Passed: cat 3271, mi = 0.003, pvalue = 0.000, REACTOME_HOST_INTERACTIONS_OF_HIV_FACTORS
# Passed: cat 3865, mi = 0.003, pvalue = 0.000, SCHLOSSER_MYC_TARGETS_AND_SERUM_RESPONSE_UP
# Passed: cat 3693, mi = 0.002, pvalue = 0.000, RICKMAN_HEAD_AND_NECK_CANCER_A
# Passed: cat 2014, mi = 0.002, pvalue = 0.000, LIM_MAMMARY_LUMINAL_MATURE_DN
# Passed: cat 610, mi = 0.002, pvalue = 0.000, CERVERA_SDHB_TARGETS_1_UP
# Passed: cat 3997, mi = 0.002, pvalue = 0.000, SMID_BREAST_CANCER_LUMINAL_B_UP
# Passed: cat 512, mi = 0.002, pvalue = 0.000, BROWNE_INTERFERON_RESPONSIVE_GENES
# Passed: cat 2308, mi = 0.002, pvalue = 0.000, MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3
# Passed: cat 2084, mi = 0.002, pvalue = 0.000, LOPES_METHYLATED_IN_COLON_CANCER_DN
# Passed: cat 2499, mi = 0.002, pvalue = 0.000, NAKAYAMA_SOFT_TISSUE_TUMORS_PCA2_UP
# Passed: cat 2045, mi = 0.002, pvalue = 0.000, LIU_CDX2_TARGETS_UP
# Passed: cat 1701, mi = 0.002, pvalue = 0.000, KEGG_PANCREATIC_CANCER
# Passed: cat 703, mi = 0.002, pvalue = 0.001, CHOI_ATL_STAGE_PREDICTOR
# Passed: cat 3913, mi = 0.002, pvalue = 0.002, SENGUPTA_NASOPHARYNGEAL_CARCINOMA_WITH_LMP1_DN
# Passed: cat 3481, mi = 0.002, pvalue = 0.001, REACTOME_PYRIMIDINE_METABOLISM
# Passed: cat 412, mi = 0.002, pvalue = 0.002, BLALOCK_ALZHEIMERS_DISEASE_INCIPIENT_DN
# Passed: cat 614, mi = 0.002, pvalue = 0.003, CHANDRAN_METASTASIS_TOP50_UP
# Passed: cat 4135, mi = 0.002, pvalue = 0.001, TAVAZOIE_METASTASIS
# Passed: cat 3670, mi = 0.002, pvalue = 0.002, REACTOME_TRNA_AMINOACYLATION
# Passed: cat 2022, mi = 0.002, pvalue = 0.001, LINDGREN_BLADDER_CANCER_CLUSTER_2A_DN
# Passed: cat 3203, mi = 0.002, pvalue = 0.000, REACTOME_FGFR_LIGAND_BINDING_AND_ACTIVATION
# Passed: cat 609, mi = 0.002, pvalue = 0.001, CERVERA_SDHB_TARGETS_1_DN
# Passed: cat 2511, mi = 0.001, pvalue = 0.001, NGO_MALIGNANT_GLIOMA_1P_LOH
# Passed: cat 1903, mi = 0.001, pvalue = 0.002, KYNG_WERNER_SYNDROM_AND_NORMAL_AGING_UP
# Passed: cat 542, mi = 0.001, pvalue = 0.002, BURTON_ADIPOGENESIS_8
# Passed: cat 135, mi = 0.001, pvalue = 0.004, BEGUM_TARGETS_OF_PAX3_FOXO1_FUSION_UP
# Passed: cat 3347, mi = 0.001, pvalue = 0.001, REACTOME_METABOLISM_OF_STEROID_HORMONES_AND_VITAMINS_A_AND_D
# Passed: cat 2853, mi = 0.001, pvalue = 0.004, PID_P38_ALPHA_BETA_DOWNSTREAM_PATHWAY
# Passed: cat 1590, mi = 0.001, pvalue = 0.004, KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM
# Passed: cat 2382, mi = 0.001, pvalue = 0.003, MOREAUX_MULTIPLE_MYELOMA_BY_TACI_DN
# Didn't pass (cutoff=0.0050): cat 2037, mi = 0.001, pvalue = 0.006, LIN_MELANOMA_COPY_NUMBER_DN
# Didn't pass (cutoff=0.0050): cat 1433, mi = 0.001, pvalue = 0.006, IIZUKA_LIVER_CANCER_PROGRESSION_L0_L1_DN
# Passed: cat 2560, mi = 0.001, pvalue = 0.004, NIKOLSKY_BREAST_CANCER_8Q12_Q22_AMPLICON
# Didn't pass (cutoff=0.0050): cat 470, mi = 0.001, pvalue = 0.006, BOYLAN_MULTIPLE_MYELOMA_PCA3_DN
# Passed: cat 556, mi = 0.001, pvalue = 0.004, BYSTRYKH_HEMATOPOIESIS_STEM_CELL_AND_BRAIN_QTL_TRANS
# Didn't pass (cutoff=0.0050): cat 2007, mi = 0.001, pvalue = 0.005, LIAN_LIPA_TARGETS_6M
# Didn't pass (cutoff=0.0050): cat 3300, mi = 0.001, pvalue = 0.007, REACTOME_INTEGRIN_ALPHAIIB_BETA3_SIGNALING
# Didn't pass (cutoff=0.0050): cat 3448, mi = 0.001, pvalue = 0.006, REACTOME_PLATELET_AGGREGATION_PLUG_FORMATION
# Didn't pass (cutoff=0.0050): cat 4433, mi = 0.001, pvalue = 0.007, WENDT_COHESIN_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 3151, mi = 0.001, pvalue = 0.006, REACTOME_DEADENYLATION_OF_MRNA
# Passed: cat 3083, mi = 0.001, pvalue = 0.001, REACTOME_BASE_FREE_SUGAR_PHOSPHATE_REMOVAL_VIA_THE_SINGLE_NUCLEOTIDE_REPLACEMENT_PATHWAY
# Didn't pass (cutoff=0.0050): cat 4669, mi = 0.001, pvalue = 0.010, ZHAN_MULTIPLE_MYELOMA_MF_DN
# Didn't pass (cutoff=0.0050): cat 444, mi = 0.001, pvalue = 0.009, BOYAULT_LIVER_CANCER_SUBCLASS_G12_UP
# Didn't pass (cutoff=0.0050): cat 672, mi = 0.001, pvalue = 0.006, CHIANG_LIVER_CANCER_SUBCLASS_CTNNB1_UP
# Didn't pass (cutoff=0.0050): cat 1098, mi = 0.001, pvalue = 0.008, GAVIN_FOXP3_TARGETS_CLUSTER_P3
# Didn't pass (cutoff=0.0050): cat 1790, mi = 0.001, pvalue = 0.008, KIM_MYCN_AMPLIFICATION_TARGETS_DN
# Didn't pass (cutoff=0.0050): cat 2624, mi = 0.001, pvalue = 0.010, OUELLET_CULTURED_OVARIAN_CANCER_INVASIVE_VS_LMP_DN
# Didn't pass (cutoff=0.0050): cat 177, mi = 0.001, pvalue = 0.009, BIDUS_METASTASIS_DN
# Didn't pass (cutoff=0.0050): cat 4692, mi = 0.001, pvalue = 0.012, ZHENG_IL22_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 3893, mi = 0.001, pvalue = 0.008, SEIDEN_ONCOGENESIS_BY_MET
# Didn't pass (cutoff=0.0050): cat 2305, mi = 0.001, pvalue = 0.008, MIKKELSEN_ES_HCP_WITH_H3_UNMETHYLATED
# Passed: cat 2473, mi = 0.001, pvalue = 0.003, NAGY_PCAF_COMPONENTS_HUMAN
# Didn't pass (cutoff=0.0050): cat 1229, mi = 0.001, pvalue = 0.010, GUENTHER_GROWTH_SPHERICAL_VS_ADHERENT_UP
# Didn't pass (cutoff=0.0050): cat 3808, mi = 0.001, pvalue = 0.014, SARTIPY_BLUNTED_BY_INSULIN_RESISTANCE_DN
# Didn't pass (cutoff=0.0050): cat 1078, mi = 0.001, pvalue = 0.017, GARGALOVIC_RESPONSE_TO_OXIDIZED_PHOSPHOLIPIDS_YELLOW_UP
# Didn't pass (cutoff=0.0050): cat 1912, mi = 0.001, pvalue = 0.012, LAIHO_COLORECTAL_CANCER_SERRATED_DN
# Didn't pass (cutoff=0.0050): cat 165, mi = 0.001, pvalue = 0.022, BERNARD_PPAPDC1B_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 1284, mi = 0.001, pvalue = 0.022, HEDENFALK_BREAST_CANCER_BRACX_DN
# Didn't pass (cutoff=0.0050): cat 4280, mi = 0.001, pvalue = 0.005, VANDESLUIS_COMMD1_TARGETS_GROUP_4_DN
# Didn't pass (cutoff=0.0050): cat 2240, mi = 0.001, pvalue = 0.027, MA_PITUITARY_FETAL_VS_ADULT_DN
# Didn't pass (cutoff=0.0050): cat 476, mi = 0.001, pvalue = 0.030, BRACHAT_RESPONSE_TO_METHOTREXATE_UP
# Didn't pass (cutoff=0.0050): cat 2267, mi = 0.001, pvalue = 0.032, MCDOWELL_ACUTE_LUNG_INJURY_DN
# Didn't pass (cutoff=0.0050): cat 4045, mi = 0.001, pvalue = 0.037, STEARMAN_TUMOR_FIELD_EFFECT_UP
# Didn't pass (cutoff=0.0050): cat 1151, mi = 0.001, pvalue = 0.027, GINESTIER_BREAST_CANCER_ZNF217_AMPLIFIED_UP
# Didn't pass (cutoff=0.0050): cat 4635, mi = 0.001, pvalue = 0.026, ZHANG_BREAST_CANCER_PROGENITORS_DN
# Didn't pass (cutoff=0.0050): cat 977, mi = 0.001, pvalue = 0.028, FIGUEROA_AML_METHYLATION_CLUSTER_6_UP
# Didn't pass (cutoff=0.0050): cat 2328, mi = 0.001, pvalue = 0.037, MIKKELSEN_MEF_LCP_WITH_H3K27ME3
# Didn't pass (cutoff=0.0050): cat 1998, mi = 0.001, pvalue = 0.035, LIANG_HEMATOPOIESIS_STEM_CELL_NUMBER_LARGE_VS_TINY_DN
# Didn't pass (cutoff=0.0050): cat 4622, mi = 0.001, pvalue = 0.038, ZEMBUTSU_SENSITIVITY_TO_CYCLOPHOSPHAMIDE
# Didn't pass (cutoff=0.0050): cat 1655, mi = 0.001, pvalue = 0.037, KEGG_GLYOXYLATE_AND_DICARBOXYLATE_METABOLISM
# Didn't pass (cutoff=0.0050): cat 441, mi = 0.001, pvalue = 0.043, BOYAULT_LIVER_CANCER_SUBCLASS_G123_DN
# Didn't pass (cutoff=0.0050): cat 3405, mi = 0.001, pvalue = 0.034, REACTOME_N_GLYCAN_TRIMMING_IN_THE_ER_AND_CALNEXIN_CALRETICULIN_CYCLE
# Total number of categories evaluated = 644.
# Number of categories that passed the tests = 42
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 3, 28, 0.0232090943349479
# best merge is 0, 16, 0.0357463840735578
# best merge is 6, 33, 0.04971963806823
# best merge is 3, 18, 0.0520849737043718
# best merge is 5, 15, 0.0588291543290593
# best merge is 0, 34, 0.0812641624693463
# best merge is 3, 13, 0.0875687867570946
# best merge is 24, 30, 0.091105354679784
# best merge is 3, 5, 0.0997308435843861
# best merge is 10, 29, 0.102966736891062
# best merge is 0, 6, 0.134534077692827
# best merge is 3, 17, 0.145038230431286
# best merge is 20, 39, 0.149790126186971
# best merge is 10, 11, 0.165688407136819
# best merge is 0, 7, 0.170610588759696
# best merge is 1, 2, 0.180508040212693
# best merge is 4, 37, 0.182492593784562
# best merge is 9, 23, 0.18437271152311
# best merge is 27, 32, 0.216417965811093
# best merge is 3, 21, 0.228892046054751
# best merge is 0, 10, 0.269148918637744
# best merge is 22, 27, 0.270653230237715
# best merge is 4, 9, 0.317470514412328
# best merge is 1, 38, 0.356199502167642
# best merge is 12, 14, 0.377326503894346
# best merge is 19, 25, 0.380418329466067
# best merge is 26, 35, 0.411653207972463
# best merge is 31, 41, 0.417466822834199
# best merge is 0, 12, 0.441825435019672
# best merge is 20, 31, 0.456074129431214
# best merge is 4, 8, 0.461738145029562
# best merge is 1, 24, 0.504549881060731
# best merge is 19, 36, 0.518929600331804
# best merge is 4, 20, 0.567544068498255
# best merge is 19, 22, 0.575398350751549
# best merge is 4, 26, 0.669989377079904
# best merge is 0, 19, 0.798552537557415
# best merge is 1, 4, 0.804660465337129
# order classes
# 17 - 1.29216919207642
# 5 - 2.69560145271792
# 8 - 0.6101869938265
# 11 - 1.87422849670665
# 3 28 18 13 5 15 17 21
# 1 2 38 24 30
# 0 16 34 6 33 7 10 29 11 12 14 19 25 36 22 27 32
# 4 37 9 23 8 20 39 31 41 26 35
# 40
# Done.Start drawing
# 23.77	0.00
# FISCHER_G1_S_CELL_CYCLE
# LOPES_METHYLATED_IN_COLON_CANCER_DN
# REACTOME_METABOLISM_OF_STEROID_HORMONES_AND_VITAMINS_A_AND_D
# ELVIDGE_HYPOXIA_UP
# BEGUM_TARGETS_OF_PAX3_FOXO1_FUSION_UP
# JOHNSTONE_PARVB_TARGETS_1_DN
# RICKMAN_HEAD_AND_NECK_CANCER_A
# CERVERA_SDHB_TARGETS_1_DN
# LIM_MAMMARY_LUMINAL_MATURE_DN
# CERVERA_SDHB_TARGETS_1_UP
# BROWNE_INTERFERON_RESPONSIVE_GENES
# KEGG_PANCREATIC_CANCER
# TAVAZOIE_METASTASIS
# KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM
# LINDGREN_BLADDER_CANCER_CLUSTER_2A_DN
# BURTON_ADIPOGENESIS_8
# REACTOME_PYRIMIDINE_METABOLISM
# REACTOME_BASE_FREE_SUGAR_PHOSPHATE_REMOVAL_VIA_THE_SINGLE_NUCLEOTIDE_REPLACEMENT_PATHWAY
# CHANDRAN_METASTASIS_TOP50_UP
# NGO_MALIGNANT_GLIOMA_1P_LOH
# BYSTRYKH_HEMATOPOIESIS_STEM_CELL_AND_BRAIN_QTL_TRANS
# REACTOME_TRNA_AMINOACYLATION
# PID_P38_ALPHA_BETA_DOWNSTREAM_PATHWAY
# KEGG_SPLICEOSOME
# KYNG_WERNER_SYNDROM_AND_NORMAL_AGING_UP
# SCHLOSSER_MYC_TARGETS_AND_SERUM_RESPONSE_UP
# REACTOME_HOST_INTERACTIONS_OF_HIV_FACTORS
# NAGY_PCAF_COMPONENTS_HUMAN
# REACTOME_PEPTIDE_CHAIN_ELONGATION
# KEGG_OXIDATIVE_PHOSPHORYLATION
# MOREAUX_MULTIPLE_MYELOMA_BY_TACI_DN
# BLALOCK_ALZHEIMERS_DISEASE_INCIPIENT_DN
# CHOI_ATL_STAGE_PREDICTOR
# NIKOLSKY_BREAST_CANCER_8Q12_Q22_AMPLICON
# AIGNER_ZEB1_TARGETS
# REACTOME_FGFR_LIGAND_BINDING_AND_ACTIVATION
# LIU_CDX2_TARGETS_UP
# SMID_BREAST_CANCER_LUMINAL_B_UP
# REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORS
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3
# NAKAYAMA_SOFT_TISSUE_TUMORS_PCA2_UP
# SENGUPTA_NASOPHARYNGEAL_CARCINOMA_WITH_LMP1_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 3, 28, 0.0232090943349479
# best merge is 0, 16, 0.0357463840735578
# best merge is 6, 33, 0.04971963806823
# best merge is 3, 18, 0.0520849737043718
# best merge is 5, 15, 0.0588291543290593
# best merge is 0, 34, 0.0812641624693463
# best merge is 3, 13, 0.0875687867570946
# best merge is 24, 30, 0.091105354679784
# best merge is 3, 5, 0.0997308435843861
# best merge is 10, 29, 0.102966736891062
# best merge is 0, 6, 0.134534077692827
# best merge is 3, 17, 0.145038230431286
# best merge is 20, 39, 0.149790126186971
# best merge is 10, 11, 0.165688407136819
# best merge is 0, 7, 0.170610588759696
# best merge is 1, 2, 0.180508040212693
# best merge is 4, 37, 0.182492593784562
# best merge is 9, 23, 0.18437271152311
# best merge is 27, 32, 0.216417965811093
# best merge is 3, 21, 0.228892046054751
# best merge is 0, 10, 0.269148918637744
# best merge is 22, 27, 0.270653230237715
# best merge is 4, 9, 0.317470514412328
# best merge is 1, 38, 0.356199502167642
# best merge is 12, 14, 0.377326503894346
# best merge is 19, 25, 0.380418329466067
# best merge is 26, 35, 0.411653207972463
# best merge is 31, 41, 0.417466822834199
# best merge is 0, 12, 0.441825435019672
# best merge is 20, 31, 0.456074129431214
# best merge is 4, 8, 0.461738145029562
# best merge is 1, 24, 0.504549881060731
# best merge is 19, 36, 0.518929600331804
# best merge is 4, 20, 0.567544068498255
# best merge is 19, 22, 0.575398350751549
# best merge is 4, 26, 0.669989377079904
# best merge is 0, 19, 0.798552537557415
# best merge is 1, 4, 0.804660465337129
# order classes
# 17 - 1.29216919207642
# 5 - 2.69560145271792
# 8 - 0.6101869938265
# 11 - 1.87422849670665
# 3 28 18 13 5 15 17 21
# 1 2 38 24 30
# 0 16 34 6 33 7 10 29 11 12 14 19 25 36 22 27 32
# 4 37 9 23 8 20 39 31 41 26 35
# 40
# Done.-19.2932267564156	42	0
# -18.4450988641144	42	1.4135464871687
# -18.2153975599495	42	1.69625578460244
# -18.056373580143	42	1.87294909549853
# -17.8973496003366	42	2.0143037442154
# -17.7206562894405	42	2.19099705511149
# -17.51745898191	42	2.36769036600757
# -17.2082456878418	42	2.59739167017249
# 2.49305847707194	42	2.98611695414388
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM2_1.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM2_2.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM2_3.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM2_4.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c2.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c2/human_ensembl_msigdb_c2.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 4738
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	4738
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 4738
# cat 4455, mi = 0.01769397, WHITFIELD_CELL_CYCLE_G2
# cat 3426, mi = 0.01230166, REACTOME_PEPTIDE_CHAIN_ELONGATION
# cat 1731, mi = 0.01144138, KEGG_RIBOSOME
# cat 3009, mi = 0.01115946, REACTOME_3_UTR_MEDIATED_TRANSLATIONAL_REGULATION
# cat 3655, mi = 0.01102252, REACTOME_TRANSLATION
# cat 3288, mi = 0.01049426, REACTOME_INFLUENZA_VIRAL_RNA_TRANSCRIPTION_AND_REPLICATION
# cat 3753, mi = 0.01047032, ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER
# cat 3601, mi = 0.01042370, REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANE
# cat 620, mi = 0.00885973, CHANG_CYCLING_GENES
# cat 1698, mi = 0.00880956, KEGG_OXIDATIVE_PHOSPHORYLATION
# cat 3391, mi = 0.00857588, REACTOME_NONSENSE_MEDIATED_DECAY_ENHANCED_BY_THE_EXON_JUNCTION_COMPLEX
# cat 4022, mi = 0.00856639, SOTIRIOU_BREAST_CANCER_GRADE_1_VS_3_UP
# cat 4701, mi = 0.00846717, ZHOU_CELL_CYCLE_GENES_IN_IR_RESPONSE_24HR
# cat 3521, mi = 0.00756199, REACTOME_RESPIRATORY_ELECTRON_TRANSPORT_ATP_SYNTHESIS_BY_CHEMIOSMOTIC_COUPLING_AND_HEAT_PRODUCTION_BY_UNCOUPLING_PROTEINS_
# cat 1946, mi = 0.00739993, LEE_EARLY_T_LYMPHOCYTE_UP
#
# RESULTS
# Passed: cat 4455, mi = 0.018, pvalue = 0.000, WHITFIELD_CELL_CYCLE_G2
# Passed: cat 3426, mi = 0.012, pvalue = 0.000, REACTOME_PEPTIDE_CHAIN_ELONGATION
# Passed: cat 1698, mi = 0.009, pvalue = 0.000, KEGG_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 3358, mi = 0.006, pvalue = 0.000, REACTOME_MITOTIC_PROMETAPHASE
# Passed: cat 1739, mi = 0.005, pvalue = 0.000, KEGG_SPLICEOSOME
# Passed: cat 627, mi = 0.004, pvalue = 0.000, CHARAFE_BREAST_CANCER_BASAL_VS_MESENCHYMAL_UP
# Passed: cat 3866, mi = 0.004, pvalue = 0.000, SCHLOSSER_MYC_TARGETS_REPRESSED_BY_SERUM
# Passed: cat 3428, mi = 0.004, pvalue = 0.000, REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORS
# Passed: cat 4458, mi = 0.004, pvalue = 0.000, WHITFIELD_CELL_CYCLE_M_G1
# Passed: cat 4014, mi = 0.004, pvalue = 0.000, SMIRNOV_RESPONSE_TO_IR_6HR_DN
# Passed: cat 4454, mi = 0.003, pvalue = 0.000, WHITFIELD_CELL_CYCLE_G1_S
# Passed: cat 1797, mi = 0.003, pvalue = 0.000, KIM_RESPONSE_TO_TSA_AND_DECITABINE_UP
# Passed: cat 2017, mi = 0.003, pvalue = 0.000, LIM_MAMMARY_LUMINAL_PROGENITOR_UP
# Passed: cat 2498, mi = 0.003, pvalue = 0.000, NAKAYAMA_SOFT_TISSUE_TUMORS_PCA2_DN
# Passed: cat 3693, mi = 0.002, pvalue = 0.000, RICKMAN_HEAD_AND_NECK_CANCER_A
# Passed: cat 1757, mi = 0.002, pvalue = 0.000, KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS
# Passed: cat 4690, mi = 0.002, pvalue = 0.000, ZHENG_GLIOBLASTOMA_PLASTICITY_DN
# Passed: cat 1790, mi = 0.002, pvalue = 0.000, KIM_MYCN_AMPLIFICATION_TARGETS_DN
# Passed: cat 4579, mi = 0.002, pvalue = 0.000, YAO_TEMPORAL_RESPONSE_TO_PROGESTERONE_CLUSTER_10
# Passed: cat 1461, mi = 0.002, pvalue = 0.000, IVANOVA_HEMATOPOIESIS_INTERMEDIATE_PROGENITOR
# Passed: cat 2290, mi = 0.002, pvalue = 0.000, MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3
# Passed: cat 3458, mi = 0.002, pvalue = 0.000, REACTOME_POTASSIUM_CHANNELS
# Passed: cat 2028, mi = 0.002, pvalue = 0.000, LINDGREN_BLADDER_CANCER_WITH_LOH_IN_CHR9Q
# Passed: cat 4370, mi = 0.002, pvalue = 0.000, WANG_LSD1_TARGETS_DN
# Passed: cat 819, mi = 0.002, pvalue = 0.000, DAZARD_RESPONSE_TO_UV_SCC_DN
# Passed: cat 437, mi = 0.002, pvalue = 0.000, BOSCO_TH1_CYTOTOXIC_MODULE
# Passed: cat 3818, mi = 0.002, pvalue = 0.000, SASSON_RESPONSE_TO_FORSKOLIN_DN
# Passed: cat 2618, mi = 0.002, pvalue = 0.000, OSADA_ASCL1_TARGETS_UP
# Passed: cat 1871, mi = 0.002, pvalue = 0.000, KUNINGER_IGF1_VS_PDGFB_TARGETS_UP
# Passed: cat 1800, mi = 0.002, pvalue = 0.000, KIM_WT1_TARGETS_12HR_UP
# Passed: cat 2572, mi = 0.002, pvalue = 0.000, NOUZOVA_TRETINOIN_AND_H4_ACETYLATION
# Passed: cat 4080, mi = 0.002, pvalue = 0.001, ST_P38_MAPK_PATHWAY
# Passed: cat 766, mi = 0.002, pvalue = 0.001, DACOSTA_ERCC3_ALLELE_XPCS_VS_TTD_DN
# Passed: cat 2893, mi = 0.002, pvalue = 0.001, PID_SYNDECAN_2_PATHWAY
# Passed: cat 1759, mi = 0.002, pvalue = 0.001, KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION
# Passed: cat 1719, mi = 0.002, pvalue = 0.001, KEGG_PROTEASOME
# Passed: cat 2007, mi = 0.002, pvalue = 0.001, LIAN_LIPA_TARGETS_6M
# Passed: cat 3120, mi = 0.002, pvalue = 0.001, REACTOME_CIRCADIAN_REPRESSION_OF_EXPRESSION_BY_REV_ERBA
# Passed: cat 3697, mi = 0.002, pvalue = 0.000, RICKMAN_HEAD_AND_NECK_CANCER_E
# Passed: cat 2569, mi = 0.002, pvalue = 0.001, NOUSHMEHR_GBM_SILENCED_BY_METHYLATION
# Passed: cat 3018, mi = 0.002, pvalue = 0.000, REACTOME_ACTIVATED_POINT_MUTANTS_OF_FGFR2
# Passed: cat 3915, mi = 0.002, pvalue = 0.002, SERVITJA_ISLET_HNF1A_TARGETS_DN
# Passed: cat 1263, mi = 0.002, pvalue = 0.002, HANN_RESISTANCE_TO_BCL2_INHIBITOR_DN
# Passed: cat 3836, mi = 0.002, pvalue = 0.002, SCHAEFFER_PROSTATE_DEVELOPMENT_12HR_DN
# Passed: cat 1222, mi = 0.001, pvalue = 0.003, GROSS_HYPOXIA_VIA_HIF1A_UP
# Passed: cat 2320, mi = 0.001, pvalue = 0.003, MIKKELSEN_MCV6_ICP_WITH_H3K27ME3
# Passed: cat 4044, mi = 0.001, pvalue = 0.003, STEARMAN_LUNG_CANCER_EARLY_VS_LATE_UP
# Passed: cat 2511, mi = 0.001, pvalue = 0.003, NGO_MALIGNANT_GLIOMA_1P_LOH
# Didn't pass (cutoff=0.0050): cat 2281, mi = 0.001, pvalue = 0.006, MEISSNER_BRAIN_HCP_WITH_H3K4ME2_AND_H3K27ME3
# Didn't pass (cutoff=0.0050): cat 3354, mi = 0.001, pvalue = 0.005, REACTOME_MITOCHONDRIAL_TRNA_AMINOACYLATION
# Didn't pass (cutoff=0.0050): cat 1429, mi = 0.001, pvalue = 0.006, IIZUKA_LIVER_CANCER_PROGRESSION_G1_G2_DN
# Passed: cat 1714, mi = 0.001, pvalue = 0.005, KEGG_PRIMARY_IMMUNODEFICIENCY
# Passed: cat 144, mi = 0.001, pvalue = 0.004, BENPORATH_ES_CORE_NINE_CORRELATED
# Passed: cat 2240, mi = 0.001, pvalue = 0.004, MA_PITUITARY_FETAL_VS_ADULT_DN
# Didn't pass (cutoff=0.0050): cat 555, mi = 0.001, pvalue = 0.007, BYSTRYKH_HEMATOPOIESIS_STEM_CELL_AND_BRAIN_QTL_CIS
# Didn't pass (cutoff=0.0050): cat 1206, mi = 0.001, pvalue = 0.005, GREENBAUM_E2A_TARGETS_DN
# Didn't pass (cutoff=0.0050): cat 1927, mi = 0.001, pvalue = 0.007, LASTOWSKA_NEUROBLASTOMA_COPY_NUMBER_UP
# Didn't pass (cutoff=0.0050): cat 4535, mi = 0.001, pvalue = 0.007, XU_HGF_TARGETS_REPRESSED_BY_AKT1_DN
# Didn't pass (cutoff=0.0050): cat 2583, mi = 0.001, pvalue = 0.009, ODONNELL_METASTASIS_UP
# Didn't pass (cutoff=0.0050): cat 2561, mi = 0.001, pvalue = 0.007, NIKOLSKY_BREAST_CANCER_8Q23_Q24_AMPLICON
# Didn't pass (cutoff=0.0050): cat 2142, mi = 0.001, pvalue = 0.008, MAINA_VHL_TARGETS_DN
# Didn't pass (cutoff=0.0050): cat 934, mi = 0.001, pvalue = 0.012, EPPERT_LSC_R
# Didn't pass (cutoff=0.0050): cat 2389, mi = 0.001, pvalue = 0.012, MORI_IMMATURE_B_LYMPHOCYTE_UP
# Didn't pass (cutoff=0.0050): cat 4672, mi = 0.001, pvalue = 0.014, ZHAN_MULTIPLE_MYELOMA_MS_UP
# Didn't pass (cutoff=0.0050): cat 2927, mi = 0.001, pvalue = 0.012, PLASARI_TGFB1_SIGNALING_VIA_NFIC_10HR_UP
# Didn't pass (cutoff=0.0050): cat 3580, mi = 0.001, pvalue = 0.015, REACTOME_SIGNALING_BY_ROBO_RECEPTOR
# Didn't pass (cutoff=0.0050): cat 2328, mi = 0.001, pvalue = 0.011, MIKKELSEN_MEF_LCP_WITH_H3K27ME3
# Passed: cat 1158, mi = 0.001, pvalue = 0.003, GOERING_BLOOD_HDL_CHOLESTEROL_QTL_TRANS
# Didn't pass (cutoff=0.0050): cat 1852, mi = 0.001, pvalue = 0.015, KRASNOSELSKAYA_ILF3_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 1896, mi = 0.001, pvalue = 0.019, KYNG_NORMAL_AGING_DN
# Didn't pass (cutoff=0.0050): cat 3457, mi = 0.001, pvalue = 0.012, REACTOME_POST_TRANSLATIONAL_PROTEIN_MODIFICATION
# Didn't pass (cutoff=0.0050): cat 3074, mi = 0.001, pvalue = 0.014, REACTOME_ASPARAGINE_N_LINKED_GLYCOSYLATION
# Didn't pass (cutoff=0.0050): cat 2474, mi = 0.001, pvalue = 0.016, NAGY_STAGA_COMPONENTS_HUMAN
# Didn't pass (cutoff=0.0050): cat 971, mi = 0.001, pvalue = 0.014, FIGUEROA_AML_METHYLATION_CLUSTER_3_UP
# Didn't pass (cutoff=0.0050): cat 2086, mi = 0.001, pvalue = 0.011, LOPEZ_EPITHELIOID_MESOTHELIOMA
# Didn't pass (cutoff=0.0050): cat 4082, mi = 0.001, pvalue = 0.022, ST_PHOSPHOINOSITIDE_3_KINASE_PATHWAY
# Didn't pass (cutoff=0.0050): cat 714, mi = 0.001, pvalue = 0.021, CLASPER_LYMPHATIC_VESSELS_DURING_METASTASIS_UP
# Didn't pass (cutoff=0.0050): cat 1658, mi = 0.001, pvalue = 0.024, KEGG_HEDGEHOG_SIGNALING_PATHWAY
# Didn't pass (cutoff=0.0050): cat 1485, mi = 0.001, pvalue = 0.028, JAERVINEN_AMPLIFIED_IN_LARYNGEAL_CANCER
# Didn't pass (cutoff=0.0050): cat 2305, mi = 0.001, pvalue = 0.026, MIKKELSEN_ES_HCP_WITH_H3_UNMETHYLATED
# Didn't pass (cutoff=0.0050): cat 2246, mi = 0.001, pvalue = 0.021, MCBRYAN_PUBERTAL_BREAST_5_6WK_DN
# Didn't pass (cutoff=0.0050): cat 480, mi = 0.001, pvalue = 0.029, BREDEMEYER_RAG_SIGNALING_VIA_ATM_NOT_VIA_NFKB_UP
# Didn't pass (cutoff=0.0050): cat 2402, mi = 0.001, pvalue = 0.027, MOSERLE_IFNA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 2884, mi = 0.001, pvalue = 0.026, PID_S1P_META_PATHWAY
# Didn't pass (cutoff=0.0050): cat 4621, mi = 0.001, pvalue = 0.030, ZEMBUTSU_SENSITIVITY_TO_CISPLATIN
# Didn't pass (cutoff=0.0050): cat 4032, mi = 0.001, pvalue = 0.033, STAMBOLSKY_RESPONSE_TO_VITAMIN_D3_DN
# Didn't pass (cutoff=0.0050): cat 2318, mi = 0.001, pvalue = 0.035, MIKKELSEN_IPS_WITH_HCP_H3K27ME3
# Didn't pass (cutoff=0.0050): cat 4673, mi = 0.001, pvalue = 0.035, ZHAN_MULTIPLE_MYELOMA_PR_DN
# Total number of categories evaluated = 747.
# Number of categories that passed the tests = 52
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 5, 40, 0.0142138321107026
# best merge is 12, 13, 0.0142479591957737
# best merge is 0, 9, 0.0251943374174773
# best merge is 12, 41, 0.0315733151259245
# best merge is 7, 27, 0.0403689734112179
# best merge is 5, 7, 0.0447807462397873
# best merge is 20, 21, 0.0547614463478617
# best merge is 0, 25, 0.0562029899275018
# best merge is 48, 51, 0.0597929701088616
# best merge is 5, 12, 0.0664380990389524
# best merge is 11, 20, 0.0912589514659965
# best merge is 5, 14, 0.0944966994126158
# best merge is 10, 34, 0.0956590294347814
# best merge is 2, 19, 0.104595067795118
# best merge is 5, 38, 0.10943792707712
# best merge is 0, 3, 0.118060497298586
# best merge is 17, 29, 0.131732901768795
# best merge is 4, 18, 0.13197203377703
# best merge is 36, 42, 0.14090142037576
# best merge is 5, 11, 0.145592911799322
# best merge is 6, 35, 0.154783944340209
# best merge is 0, 48, 0.158365908122803
# best merge is 24, 49, 0.172703747882494
# best merge is 5, 36, 0.177250486692468
# best merge is 2, 47, 0.187790162234411
# best merge is 0, 17, 0.204145311403727
# best merge is 8, 26, 0.213545142078097
# best merge is 31, 37, 0.223790994951461
# best merge is 22, 44, 0.232330361506812
# best merge is 30, 31, 0.239865643334461
# best merge is 16, 28, 0.240954562854306
# best merge is 4, 6, 0.257126924984993
# best merge is 1, 2, 0.258963430158358
# best merge is 16, 43, 0.274766044903084
# best merge is 5, 45, 0.298472239292903
# best merge is 5, 23, 0.304971574979547
# best merge is 32, 39, 0.311609155860148
# best merge is 15, 50, 0.322538431692207
# best merge is 4, 22, 0.362706806530284
# best merge is 24, 30, 0.371079445842094
# best merge is 5, 32, 0.384762196303516
# best merge is 0, 8, 0.405038041941648
# best merge is 5, 16, 0.506260859585267
# best merge is 1, 10, 0.581655782042036
# best merge is 24, 46, 0.64469703850459
# best merge is 4, 15, 0.701343514420619
# best merge is 5, 33, 0.806367286981147
# best merge is 0, 24, 0.83683826244937
# order classes
# 10 - 1.15378977958582
# 6 - 2.891763799653
# 8 - 2.67879403523589
# 22 - 0.758395283972137
# 6 - 3.04594232081552
# 5 40 7 27 12 13 41 14 38 11 20 21 36 42 45 23 32 39 16 28 43 33
# 1 2 19 47 10 34
# 4 18 6 35 22 44 15 50
# 0 9 25 3 48 51 17 29 8 26
# 24 49 30 31 37 46
# Done.Start drawing
# 62.96	0.00
# ZHENG_GLIOBLASTOMA_PLASTICITY_DN
# WHITFIELD_CELL_CYCLE_G2
# SMIRNOV_RESPONSE_TO_IR_6HR_DN
# BOSCO_TH1_CYTOTOXIC_MODULE
# REACTOME_MITOTIC_PROMETAPHASE
# KEGG_PRIMARY_IMMUNODEFICIENCY
# GOERING_BLOOD_HDL_CHOLESTEROL_QTL_TRANS
# KIM_MYCN_AMPLIFICATION_TARGETS_DN
# KIM_WT1_TARGETS_12HR_UP
# WHITFIELD_CELL_CYCLE_M_G1
# SASSON_RESPONSE_TO_FORSKOLIN_DN
# DAZARD_RESPONSE_TO_UV_SCC_DN
# BENPORATH_ES_CORE_NINE_CORRELATED
# NOUZOVA_TRETINOIN_AND_H4_ACETYLATION
# ST_P38_MAPK_PATHWAY
# REACTOME_CIRCADIAN_REPRESSION_OF_EXPRESSION_BY_REV_ERBA
# PID_SYNDECAN_2_PATHWAY
# KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS
# MA_PITUITARY_FETAL_VS_ADULT_DN
# SCHLOSSER_MYC_TARGETS_REPRESSED_BY_SERUM
# LINDGREN_BLADDER_CANCER_WITH_LOH_IN_CHR9Q
# KEGG_SPLICEOSOME
# YAO_TEMPORAL_RESPONSE_TO_PROGESTERONE_CLUSTER_10
# GROSS_HYPOXIA_VIA_HIF1A_UP
# STEARMAN_LUNG_CANCER_EARLY_VS_LATE_UP
# REACTOME_PEPTIDE_CHAIN_ELONGATION
# KEGG_OXIDATIVE_PHOSPHORYLATION
# IVANOVA_HEMATOPOIESIS_INTERMEDIATE_PROGENITOR
# NGO_MALIGNANT_GLIOMA_1P_LOH
# KEGG_PROTEASOME
# WHITFIELD_CELL_CYCLE_G1_S
# KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION
# CHARAFE_BREAST_CANCER_BASAL_VS_MESENCHYMAL_UP
# REACTOME_ACTIVATED_POINT_MUTANTS_OF_FGFR2
# REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORS
# OSADA_ASCL1_TARGETS_UP
# LIM_MAMMARY_LUMINAL_PROGENITOR_UP
# NAKAYAMA_SOFT_TISSUE_TUMORS_PCA2_DN
# SERVITJA_ISLET_HNF1A_TARGETS_DN
# RICKMAN_HEAD_AND_NECK_CANCER_A
# RICKMAN_HEAD_AND_NECK_CANCER_E
# KIM_RESPONSE_TO_TSA_AND_DECITABINE_UP
# MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3
# REACTOME_POTASSIUM_CHANNELS
# LIAN_LIPA_TARGETS_6M
# HANN_RESISTANCE_TO_BCL2_INHIBITOR_DN
# MIKKELSEN_MCV6_ICP_WITH_H3K27ME3
# WANG_LSD1_TARGETS_DN
# DACOSTA_ERCC3_ALLELE_XPCS_VS_TTD_DN
# NOUSHMEHR_GBM_SILENCED_BY_METHYLATION
# KUNINGER_IGF1_VS_PDGFB_TARGETS_UP
# SCHAEFFER_PROSTATE_DEVELOPMENT_12HR_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 5, 40, 0.0142138321107026
# best merge is 12, 13, 0.0142479591957737
# best merge is 0, 9, 0.0251943374174773
# best merge is 12, 41, 0.0315733151259245
# best merge is 7, 27, 0.0403689734112179
# best merge is 5, 7, 0.0447807462397873
# best merge is 20, 21, 0.0547614463478617
# best merge is 0, 25, 0.0562029899275018
# best merge is 48, 51, 0.0597929701088616
# best merge is 5, 12, 0.0664380990389524
# best merge is 11, 20, 0.0912589514659965
# best merge is 5, 14, 0.0944966994126158
# best merge is 10, 34, 0.0956590294347814
# best merge is 2, 19, 0.104595067795118
# best merge is 5, 38, 0.10943792707712
# best merge is 0, 3, 0.118060497298586
# best merge is 17, 29, 0.131732901768795
# best merge is 4, 18, 0.13197203377703
# best merge is 36, 42, 0.14090142037576
# best merge is 5, 11, 0.145592911799322
# best merge is 6, 35, 0.154783944340209
# best merge is 0, 48, 0.158365908122803
# best merge is 24, 49, 0.172703747882494
# best merge is 5, 36, 0.177250486692468
# best merge is 2, 47, 0.187790162234411
# best merge is 0, 17, 0.204145311403727
# best merge is 8, 26, 0.213545142078097
# best merge is 31, 37, 0.223790994951461
# best merge is 22, 44, 0.232330361506812
# best merge is 30, 31, 0.239865643334461
# best merge is 16, 28, 0.240954562854306
# best merge is 4, 6, 0.257126924984993
# best merge is 1, 2, 0.258963430158358
# best merge is 16, 43, 0.274766044903084
# best merge is 5, 45, 0.298472239292903
# best merge is 5, 23, 0.304971574979547
# best merge is 32, 39, 0.311609155860148
# best merge is 15, 50, 0.322538431692207
# best merge is 4, 22, 0.362706806530284
# best merge is 24, 30, 0.371079445842094
# best merge is 5, 32, 0.384762196303516
# best merge is 0, 8, 0.405038041941648
# best merge is 5, 16, 0.506260859585267
# best merge is 1, 10, 0.581655782042036
# best merge is 24, 46, 0.64469703850459
# best merge is 4, 15, 0.701343514420619
# best merge is 5, 33, 0.806367286981147
# best merge is 0, 24, 0.83683826244937
# order classes
# 10 - 1.15378977958582
# 6 - 2.891763799653
# 8 - 2.67879403523589
# 22 - 0.758395283972137
# 6 - 3.04594232081552
# 5 40 7 27 12 13 41 14 38 11 20 21 36 42 45 23 32 39 16 28 43 33
# 1 2 19 47 10 34
# 4 18 6 35 22 44 15 50
# 0 9 25 3 48 51 17 29 8 26
# 24 49 30 31 37 46
# Done.-19.7198221092757	42	0
# -19.3562579415502	42	0.560355781448539
# -19.2195044472681	42	0.72712833545108
# -19.1227763659466	42	0.833862770012706
# -19.0360546378653	42	0.920584498094028
# -18.9459974587039	42	1.00730622617535
# -18.8359275730623	42	1.10069885641677
# -18.6558132147395	42	1.2274459974587
# 1.73046378653113	42	1.46092757306226
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM2_5.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_1.csv --species=human_ensembl_msigdb_c2 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c2.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c2/human_ensembl_msigdb_c2.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 4738
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	4738
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 4738
# cat 3753, mi = 0.02119215, ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER
# cat 4022, mi = 0.01754921, SOTIRIOU_BREAST_CANCER_GRADE_1_VS_3_UP
# cat 620, mi = 0.01660634, CHANG_CYCLING_GENES
# cat 1192, mi = 0.01379516, GRAHAM_CML_DIVIDING_VS_NORMAL_QUIESCENT_UP
# cat 4701, mi = 0.01329269, ZHOU_CELL_CYCLE_GENES_IN_IR_RESPONSE_24HR
# cat 1833, mi = 0.01326058, KONG_E2F3_TARGETS
# cat 752, mi = 0.01230614, CROONQUIST_IL6_DEPRIVATION_DN
# cat 4449, mi = 0.01192729, WHITEFORD_PEDIATRIC_CANCER_MARKERS
# cat 1548, mi = 0.01144660, KANG_DOXORUBICIN_RESISTANCE_UP
# cat 1199, mi = 0.01117554, GRAHAM_NORMAL_QUIESCENT_VS_NORMAL_DIVIDING_DN
# cat 1336, mi = 0.01100528, HOFFMANN_LARGE_TO_SMALL_PRE_BII_LYMPHOCYTE_UP
# cat 1029, mi = 0.01093985, FUJII_YBX1_TARGETS_DN
# cat 1946, mi = 0.01071807, LEE_EARLY_T_LYMPHOCYTE_UP
# cat 754, mi = 0.01049319, CROONQUIST_NRAS_SIGNALING_DN
# cat 537, mi = 0.01041137, BURTON_ADIPOGENESIS_3
#
# RESULTS
# Passed: cat 3753, mi = 0.021, pvalue = 0.000, ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER
# Passed: cat 3426, mi = 0.009, pvalue = 0.000, REACTOME_PEPTIDE_CHAIN_ELONGATION
# Passed: cat 925, mi = 0.004, pvalue = 0.000, ELVIDGE_HYPOXIA_UP
# Passed: cat 1698, mi = 0.004, pvalue = 0.000, KEGG_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 3363, mi = 0.004, pvalue = 0.000, REACTOME_MRNA_PROCESSING
# Passed: cat 3333, mi = 0.003, pvalue = 0.000, REACTOME_MEIOTIC_RECOMBINATION
# Passed: cat 3508, mi = 0.003, pvalue = 0.000, REACTOME_REGULATION_OF_MRNA_STABILITY_BY_PROTEINS_THAT_BIND_AU_RICH_ELEMENTS
# Passed: cat 627, mi = 0.003, pvalue = 0.000, CHARAFE_BREAST_CANCER_BASAL_VS_MESENCHYMAL_UP
# Passed: cat 4119, mi = 0.003, pvalue = 0.000, TAKEDA_TARGETS_OF_NUP98_HOXA9_FUSION_10D_UP
# Passed: cat 2585, mi = 0.002, pvalue = 0.000, ODONNELL_TARGETS_OF_MYC_AND_TFRC_UP
# Passed: cat 1779, mi = 0.002, pvalue = 0.000, KIM_BIPOLAR_DISORDER_OLIGODENDROCYTE_DENSITY_CORR_DN
# Passed: cat 2975, mi = 0.002, pvalue = 0.000, RADMACHER_AML_PROGNOSIS
# Passed: cat 924, mi = 0.002, pvalue = 0.000, ELVIDGE_HYPOXIA_DN
# Passed: cat 1665, mi = 0.002, pvalue = 0.000, KEGG_INSULIN_SIGNALING_PATHWAY
# Passed: cat 738, mi = 0.002, pvalue = 0.000, COULOUARN_TEMPORAL_TGFB1_SIGNATURE_UP
# Passed: cat 2979, mi = 0.002, pvalue = 0.000, RAHMAN_TP53_TARGETS_PHOSPHORYLATED
# Passed: cat 1627, mi = 0.002, pvalue = 0.000, KEGG_ECM_RECEPTOR_INTERACTION
# Passed: cat 1913, mi = 0.002, pvalue = 0.000, LAIHO_COLORECTAL_CANCER_SERRATED_UP
# Passed: cat 1251, mi = 0.002, pvalue = 0.000, HAHTOLA_MYCOSIS_FUNGOIDES_CD4_DN
# Passed: cat 2316, mi = 0.002, pvalue = 0.000, MIKKELSEN_IPS_LCP_WITH_H3K4ME3
# Passed: cat 4569, mi = 0.002, pvalue = 0.000, YANG_BREAST_CANCER_ESR1_UP
# Passed: cat 135, mi = 0.002, pvalue = 0.000, BEGUM_TARGETS_OF_PAX3_FOXO1_FUSION_UP
# Passed: cat 4311, mi = 0.002, pvalue = 0.001, VERHAAK_GLIOBLASTOMA_PRONEURAL
# Passed: cat 4490, mi = 0.002, pvalue = 0.001, WONG_ENDMETRIUM_CANCER_DN
# Passed: cat 2364, mi = 0.002, pvalue = 0.001, MOLENAAR_TARGETS_OF_CCND1_AND_CDK4_UP
# Passed: cat 1151, mi = 0.002, pvalue = 0.001, GINESTIER_BREAST_CANCER_ZNF217_AMPLIFIED_UP
# Passed: cat 609, mi = 0.002, pvalue = 0.001, CERVERA_SDHB_TARGETS_1_DN
# Passed: cat 177, mi = 0.002, pvalue = 0.001, BIDUS_METASTASIS_DN
# Passed: cat 2027, mi = 0.002, pvalue = 0.001, LINDGREN_BLADDER_CANCER_HIGH_RECURRENCE
# Passed: cat 2942, mi = 0.002, pvalue = 0.001, POS_HISTAMINE_RESPONSE_NETWORK
# Passed: cat 2550, mi = 0.002, pvalue = 0.003, NIKOLSKY_BREAST_CANCER_20Q11_AMPLICON
# Passed: cat 3336, mi = 0.002, pvalue = 0.002, REACTOME_MEMBRANE_TRAFFICKING
# Passed: cat 4140, mi = 0.002, pvalue = 0.002, TCGA_GLIOBLASTOMA_COPY_NUMBER_UP
# Passed: cat 4729, mi = 0.001, pvalue = 0.004, ZWANG_CLASS_2_TRANSIENTLY_INDUCED_BY_EGF
# Passed: cat 4033, mi = 0.001, pvalue = 0.004, STAMBOLSKY_RESPONSE_TO_VITAMIN_D3_UP
# Passed: cat 542, mi = 0.001, pvalue = 0.004, BURTON_ADIPOGENESIS_8
# Passed: cat 3917, mi = 0.001, pvalue = 0.004, SERVITJA_LIVER_HNF1A_TARGETS_DN
# Passed: cat 3068, mi = 0.001, pvalue = 0.001, REACTOME_APOPTOSIS_INDUCED_DNA_FRAGMENTATION
# Didn't pass (cutoff=0.0050): cat 2290, mi = 0.001, pvalue = 0.006, MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3
# Didn't pass (cutoff=0.0050): cat 2037, mi = 0.001, pvalue = 0.009, LIN_MELANOMA_COPY_NUMBER_DN
# Didn't pass (cutoff=0.0050): cat 2281, mi = 0.001, pvalue = 0.009, MEISSNER_BRAIN_HCP_WITH_H3K4ME2_AND_H3K27ME3
# Didn't pass (cutoff=0.0050): cat 3863, mi = 0.001, pvalue = 0.009, SCHLOSSER_MYC_AND_SERUM_RESPONSE_SYNERGY
# Didn't pass (cutoff=0.0050): cat 2763, mi = 0.001, pvalue = 0.008, PID_DNA_PK_PATHWAY
# Didn't pass (cutoff=0.0050): cat 4622, mi = 0.001, pvalue = 0.009, ZEMBUTSU_SENSITIVITY_TO_CYCLOPHOSPHAMIDE
# Didn't pass (cutoff=0.0050): cat 3897, mi = 0.001, pvalue = 0.009, SEKI_INFLAMMATORY_RESPONSE_LPS_DN
# Didn't pass (cutoff=0.0050): cat 1714, mi = 0.001, pvalue = 0.013, KEGG_PRIMARY_IMMUNODEFICIENCY
# Didn't pass (cutoff=0.0050): cat 773, mi = 0.001, pvalue = 0.014, DACOSTA_UV_RESPONSE_VIA_ERCC3_TTD_DN
# Didn't pass (cutoff=0.0050): cat 3344, mi = 0.001, pvalue = 0.009, REACTOME_METABOLISM_OF_PORPHYRINS
# Passed: cat 71, mi = 0.001, pvalue = 0.003, AMUNDSON_GAMMA_RADIATION_RESISTANCE
# Didn't pass (cutoff=0.0050): cat 1061, mi = 0.001, pvalue = 0.009, GARGALOVIC_RESPONSE_TO_OXIDIZED_PHOSPHOLIPIDS_BLACK_DN
# Didn't pass (cutoff=0.0050): cat 3203, mi = 0.001, pvalue = 0.009, REACTOME_FGFR_LIGAND_BINDING_AND_ACTIVATION
# Didn't pass (cutoff=0.0050): cat 4606, mi = 0.001, pvalue = 0.017, YORDY_RECIPROCAL_REGULATION_BY_ETS1_AND_SP100_DN
# Didn't pass (cutoff=0.0050): cat 3398, mi = 0.001, pvalue = 0.021, REACTOME_NUCLEAR_RECEPTOR_TRANSCRIPTION_PATHWAY
# Didn't pass (cutoff=0.0050): cat 617, mi = 0.001, pvalue = 0.021, CHANGOLKAR_H2AFY_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 137, mi = 0.001, pvalue = 0.023, BEIER_GLIOMA_STEM_CELL_UP
# Didn't pass (cutoff=0.0050): cat 374, mi = 0.001, pvalue = 0.024, BIOCARTA_RHO_PATHWAY
# Didn't pass (cutoff=0.0050): cat 676, mi = 0.001, pvalue = 0.025, CHIANG_LIVER_CANCER_SUBCLASS_POLYSOMY7_UP
# Passed: cat 2322, mi = 0.001, pvalue = 0.005, MIKKELSEN_MCV6_LCP_WITH_H3K27ME3
# Didn't pass (cutoff=0.0050): cat 2664, mi = 0.001, pvalue = 0.027, PARK_TRETINOIN_RESPONSE_AND_PML_RARA_FUSION
# Didn't pass (cutoff=0.0050): cat 125, mi = 0.001, pvalue = 0.025, BASSO_CD40_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 3891, mi = 0.001, pvalue = 0.031, SCIBETTA_KDM5B_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 1674, mi = 0.001, pvalue = 0.029, KEGG_LYSINE_DEGRADATION
# Didn't pass (cutoff=0.0050): cat 457, mi = 0.001, pvalue = 0.009, BOYERINAS_ONCOFETAL_TARGETS_OF_LET7A1
# Didn't pass (cutoff=0.0050): cat 4610, mi = 0.001, pvalue = 0.034, YOSHIOKA_LIVER_CANCER_EARLY_RECURRENCE_DN
# Didn't pass (cutoff=0.0050): cat 2320, mi = 0.001, pvalue = 0.039, MIKKELSEN_MCV6_ICP_WITH_H3K27ME3
# Didn't pass (cutoff=0.0050): cat 4280, mi = 0.001, pvalue = 0.019, VANDESLUIS_COMMD1_TARGETS_GROUP_4_DN
# Didn't pass (cutoff=0.0050): cat 4437, mi = 0.001, pvalue = 0.040, WENG_POR_TARGETS_LIVER_DN
# Didn't pass (cutoff=0.0050): cat 1783, mi = 0.001, pvalue = 0.034, KIM_GERMINAL_CENTER_T_HELPER_UP
# Didn't pass (cutoff=0.0050): cat 1158, mi = 0.001, pvalue = 0.022, GOERING_BLOOD_HDL_CHOLESTEROL_QTL_TRANS
# Didn't pass (cutoff=0.0050): cat 3995, mi = 0.001, pvalue = 0.046, SMID_BREAST_CANCER_LUMINAL_A_UP
# Didn't pass (cutoff=0.0050): cat 2069, mi = 0.001, pvalue = 0.048, LI_CYTIDINE_ANALOGS_CYCTOTOXICITY
# Didn't pass (cutoff=0.0050): cat 3048, mi = 0.001, pvalue = 0.036, REACTOME_ALPHA_LINOLENIC_ACID_ALA_METABOLISM
# Didn't pass (cutoff=0.0050): cat 3670, mi = 0.001, pvalue = 0.053, REACTOME_TRNA_AMINOACYLATION
# Didn't pass (cutoff=0.0050): cat 197, mi = 0.001, pvalue = 0.064, BIOCARTA_ACTINY_PATHWAY
# Didn't pass (cutoff=0.0050): cat 4122, mi = 0.001, pvalue = 0.059, TAKEDA_TARGETS_OF_NUP98_HOXA9_FUSION_3D_DN
# Didn't pass (cutoff=0.0050): cat 1004, mi = 0.001, pvalue = 0.053, FONTAINE_PAPILLARY_THYROID_CARCINOMA_DN
# Didn't pass (cutoff=0.0050): cat 298, mi = 0.001, pvalue = 0.042, BIOCARTA_IL10_PATHWAY
# Didn't pass (cutoff=0.0050): cat 70, mi = 0.001, pvalue = 0.062, AMUNDSON_DNA_DAMAGE_RESPONSE_TP53
# Total number of categories evaluated = 1051.
# Number of categories that passed the tests = 40
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 37, 0.018580941751826
# best merge is 1, 15, 0.0218481125283241
# best merge is 7, 38, 0.0320644449268931
# best merge is 0, 7, 0.041850987303248
# best merge is 2, 16, 0.0441414886164007
# best merge is 0, 5, 0.0540920069736461
# best merge is 9, 20, 0.0707985677787797
# best merge is 21, 26, 0.0721592242242991
# best merge is 2, 23, 0.0766065315517066
# best merge is 3, 4, 0.0776326231163554
# best merge is 2, 21, 0.0832900876973719
# best merge is 0, 10, 0.110306306574215
# best merge is 3, 12, 0.128152084843158
# best merge is 19, 39, 0.131196391415309
# best merge is 14, 28, 0.135814161176949
# best merge is 2, 8, 0.14658167374473
# best merge is 2, 19, 0.152673371869695
# best merge is 11, 27, 0.177217843415338
# best merge is 2, 9, 0.194225849221101
# best merge is 3, 6, 0.200326357044503
# best merge is 25, 35, 0.229801410893648
# best merge is 24, 32, 0.245963213095643
# best merge is 2, 11, 0.263346917585204
# best merge is 14, 30, 0.274654763259025
# best merge is 13, 31, 0.300322312005125
# best merge is 2, 33, 0.316219309663572
# best merge is 22, 34, 0.323072455724089
# best merge is 13, 18, 0.33072389765241
# best merge is 2, 14, 0.378367307727663
# best merge is 17, 24, 0.379553692703322
# best merge is 1, 3, 0.413816015667908
# best merge is 0, 36, 0.456739143659958
# best merge is 17, 25, 0.505870175399614
# best merge is 2, 17, 0.63675377434366
# best merge is 0, 22, 0.647663912337609
# best merge is 1, 13, 0.656825389309631
# order classes
# 9 - 1.43942397663295
# 6 - 1.5804785562251
# 21 - 0.747517402349315
# 3 - 2.84968920684428
# 2 16 23 21 26 8 19 39 9 20 11 27 33 14 28 30 17 24 32 25 35
# 1 15 3 4 12 6
# 0 37 7 38 5 10 36 22 34
# 13 31 18
# 29
# Done.Start drawing
# 84.94	0.00
# ELVIDGE_HYPOXIA_UP
# KEGG_ECM_RECEPTOR_INTERACTION
# WONG_ENDMETRIUM_CANCER_DN
# ...
# best merge is 5, 11, 0.124002386093048
# best merge is 18, 29, 0.134723428517318
# best merge is 2, 5, 0.178580655150267
# best merge is 0, 9, 0.18179471798062
# best merge is 17, 22, 0.212829957449891
# best merge is 20, 27, 0.24295520008958
# best merge is 25, 28, 0.341011976413027
# best merge is 2, 26, 0.35361447105361
# best merge is 20, 21, 0.353917464599514
# best merge is 0, 17, 0.462971752506896
# best merge is 2, 20, 0.477591179625364
# best merge is 0, 2, 0.486417770145339
# best merge is 24, 30, 0.655587876620376
# best merge is 23, 25, 0.765310232229712
# best merge is 23, 31, 0.855908934283396
# order classes
# 24 - 0.430154594465259
# 2 - 1.07778742813854
# 3 - 4.43646208206803
# 2 - 5.244703012963
# 0 13 1 9 17 22 2 4 14 16 19 3 10 12 6 7 8 15 5 11 26 20 27 21
# 18 29
# 23 25 28
# 24 30
# 31
# Done.-19.9980945467743	42	0
# -19.9923781870974	42	0.00381090645132021
# -19.9847563741947	42	0.0114327193539606
# -19.9790400145177	42	0.019054532256601
# -19.9733236548408	42	0.0228654387079212
# -19.9676072951638	42	0.0304872516105617
# -19.8361310225932	42	0.0342981580618819
# -19.4912439887488	42	0.293439796751656
# 1.36203611287542	42	0.724072225750839
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c2.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c2/human_ensembl_msigdb_c2.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 4738
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	4738
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 4738
# cat 3753, mi = 0.02527434, ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER
# cat 4022, mi = 0.02345621, SOTIRIOU_BREAST_CANCER_GRADE_1_VS_3_UP
# cat 620, mi = 0.02127419, CHANG_CYCLING_GENES
# cat 4701, mi = 0.01984485, ZHOU_CELL_CYCLE_GENES_IN_IR_RESPONSE_24HR
# cat 1192, mi = 0.01786808, GRAHAM_CML_DIVIDING_VS_NORMAL_QUIESCENT_UP
# cat 1029, mi = 0.01671433, FUJII_YBX1_TARGETS_DN
# cat 3807, mi = 0.01668631, SARRIO_EPITHELIAL_MESENCHYMAL_TRANSITION_UP
# cat 752, mi = 0.01650818, CROONQUIST_IL6_DEPRIVATION_DN
# cat 4703, mi = 0.01606405, ZHOU_CELL_CYCLE_GENES_IN_IR_RESPONSE_6HR
# cat 4449, mi = 0.01587644, WHITEFORD_PEDIATRIC_CANCER_MARKERS
# cat 1833, mi = 0.01564568, KONG_E2F3_TARGETS
# cat 1336, mi = 0.01497626, HOFFMANN_LARGE_TO_SMALL_PRE_BII_LYMPHOCYTE_UP
# cat 1199, mi = 0.01396392, GRAHAM_NORMAL_QUIESCENT_VS_NORMAL_DIVIDING_DN
# cat 2959, mi = 0.01393946, PUJANA_XPRSS_INT_NETWORK
# cat 754, mi = 0.01376482, CROONQUIST_NRAS_SIGNALING_DN
#
# RESULTS
# Passed: cat 3753, mi = 0.025, pvalue = 0.000, ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER
# Passed: cat 3601, mi = 0.007, pvalue = 0.000, REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANE
# Passed: cat 3466, mi = 0.006, pvalue = 0.000, REACTOME_PROCESSING_OF_CAPPED_INTRON_CONTAINING_PRE_MRNA
# Passed: cat 3772, mi = 0.005, pvalue = 0.000, RUIZ_TNC_TARGETS_UP
# Passed: cat 2784, mi = 0.005, pvalue = 0.000, PID_FANCONI_PATHWAY
# Passed: cat 924, mi = 0.005, pvalue = 0.000, ELVIDGE_HYPOXIA_DN
# Passed: cat 1698, mi = 0.003, pvalue = 0.000, KEGG_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 1744, mi = 0.003, pvalue = 0.000, KEGG_SYSTEMIC_LUPUS_ERYTHEMATOSUS
# Passed: cat 2349, mi = 0.003, pvalue = 0.000, MISSIAGLIA_REGULATED_BY_METHYLATION_UP
# Passed: cat 1060, mi = 0.003, pvalue = 0.000, GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP
# Passed: cat 861, mi = 0.002, pvalue = 0.000, DING_LUNG_CANCER_EXPRESSION_BY_COPY_NUMBER
# Passed: cat 2323, mi = 0.002, pvalue = 0.000, MIKKELSEN_MCV6_LCP_WITH_H3K4ME3
# Passed: cat 3508, mi = 0.002, pvalue = 0.000, REACTOME_REGULATION_OF_MRNA_STABILITY_BY_PROTEINS_THAT_BIND_AU_RICH_ELEMENTS
# Passed: cat 1951, mi = 0.002, pvalue = 0.000, LEE_LIVER_CANCER_CIPROFIBRATE_DN
# Passed: cat 175, mi = 0.002, pvalue = 0.000, BHAT_ESR1_TARGETS_VIA_AKT1_DN
# Passed: cat 757, mi = 0.002, pvalue = 0.000, CROONQUIST_NRAS_VS_STROMAL_STIMULATION_UP
# Passed: cat 3867, mi = 0.002, pvalue = 0.000, SCHLOSSER_SERUM_RESPONSE_AUGMENTED_BY_MYC
# Passed: cat 1260, mi = 0.002, pvalue = 0.000, HALMOS_CEBPA_TARGETS_UP
# Passed: cat 4204, mi = 0.002, pvalue = 0.000, TOOKER_GEMCITABINE_RESISTANCE_DN
# Passed: cat 2308, mi = 0.002, pvalue = 0.001, MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3
# Passed: cat 177, mi = 0.002, pvalue = 0.001, BIDUS_METASTASIS_DN
# Passed: cat 4621, mi = 0.002, pvalue = 0.001, ZEMBUTSU_SENSITIVITY_TO_CISPLATIN
# Passed: cat 1603, mi = 0.002, pvalue = 0.001, KEGG_BASE_EXCISION_REPAIR
# Passed: cat 1438, mi = 0.002, pvalue = 0.001, IKEDA_MIR133_TARGETS_UP
# Passed: cat 137, mi = 0.002, pvalue = 0.002, BEIER_GLIOMA_STEM_CELL_UP
# Passed: cat 4481, mi = 0.002, pvalue = 0.001, WINNEPENNINCKX_MELANOMA_METASTASIS_DN
# Passed: cat 4433, mi = 0.002, pvalue = 0.001, WENDT_COHESIN_TARGETS_UP
# Passed: cat 3864, mi = 0.002, pvalue = 0.001, SCHLOSSER_MYC_TARGETS_AND_SERUM_RESPONSE_DN
# Passed: cat 2783, mi = 0.002, pvalue = 0.001, PID_FAK_PATHWAY
# Passed: cat 1068, mi = 0.002, pvalue = 0.000, GARGALOVIC_RESPONSE_TO_OXIDIZED_PHOSPHOLIPIDS_GREY_UP
# Passed: cat 785, mi = 0.002, pvalue = 0.002, DANG_MYC_TARGETS_DN
# Passed: cat 4002, mi = 0.002, pvalue = 0.003, SMID_BREAST_CANCER_RELAPSE_IN_BRAIN_DN
# Passed: cat 1708, mi = 0.001, pvalue = 0.003, KEGG_PEROXISOME
# Passed: cat 722, mi = 0.001, pvalue = 0.003, COLDREN_GEFITINIB_RESISTANCE_UP
# Passed: cat 4213, mi = 0.001, pvalue = 0.003, TRAYNOR_RETT_SYNDROM_DN
# Passed: cat 4332, mi = 0.001, pvalue = 0.003, VISALA_RESPONSE_TO_HEAT_SHOCK_AND_AGING_UP
# Passed: cat 2474, mi = 0.001, pvalue = 0.005, NAGY_STAGA_COMPONENTS_HUMAN
# Passed: cat 2531, mi = 0.001, pvalue = 0.001, NIELSEN_SYNOVIAL_SARCOMA_DN
# Didn't pass (cutoff=0.0050): cat 2441, mi = 0.001, pvalue = 0.005, MYLLYKANGAS_AMPLIFICATION_HOT_SPOT_23
# Didn't pass (cutoff=0.0050): cat 1488, mi = 0.001, pvalue = 0.007, JAZAERI_BREAST_CANCER_BRCA1_VS_BRCA2_UP
# Didn't pass (cutoff=0.0050): cat 1331, mi = 0.001, pvalue = 0.006, HOELZEL_NF1_TARGETS_DN
# Didn't pass (cutoff=0.0050): cat 2328, mi = 0.001, pvalue = 0.006, MIKKELSEN_MEF_LCP_WITH_H3K27ME3
# Passed: cat 89, mi = 0.001, pvalue = 0.004, AZARE_NEOPLASTIC_TRANSFORMATION_BY_STAT3_UP
# Didn't pass (cutoff=0.0050): cat 4504, mi = 0.001, pvalue = 0.006, WORSCHECH_TUMOR_REJECTION_UP
# Didn't pass (cutoff=0.0050): cat 460, mi = 0.001, pvalue = 0.009, BOYLAN_MULTIPLE_MYELOMA_C_DN
# Didn't pass (cutoff=0.0050): cat 2749, mi = 0.001, pvalue = 0.011, PID_BMP_PATHWAY
# Didn't pass (cutoff=0.0050): cat 3741, mi = 0.001, pvalue = 0.008, ROME_INSULIN_TARGETS_IN_MUSCLE_DN
# Passed: cat 1544, mi = 0.001, pvalue = 0.003, KANG_AR_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 4428, mi = 0.001, pvalue = 0.010, WEI_MIR34A_TARGETS
# Didn't pass (cutoff=0.0050): cat 979, mi = 0.001, pvalue = 0.014, FIGUEROA_AML_METHYLATION_CLUSTER_7_UP
# Didn't pass (cutoff=0.0050): cat 1264, mi = 0.001, pvalue = 0.020, HANN_RESISTANCE_TO_BCL2_INHIBITOR_UP
# Didn't pass (cutoff=0.0050): cat 3349, mi = 0.001, pvalue = 0.017, REACTOME_METAL_ION_SLC_TRANSPORTERS
# Didn't pass (cutoff=0.0050): cat 4594, mi = 0.001, pvalue = 0.019, YAO_TEMPORAL_RESPONSE_TO_PROGESTERONE_CLUSTER_9
# Didn't pass (cutoff=0.0050): cat 2545, mi = 0.001, pvalue = 0.021, NIKOLSKY_BREAST_CANCER_19Q13.1_AMPLICON
# Didn't pass (cutoff=0.0050): cat 1790, mi = 0.001, pvalue = 0.018, KIM_MYCN_AMPLIFICATION_TARGETS_DN
# Didn't pass (cutoff=0.0050): cat 477, mi = 0.001, pvalue = 0.029, BREDEMEYER_RAG_SIGNALING_NOT_VIA_ATM_DN
# Didn't pass (cutoff=0.0050): cat 4734, mi = 0.001, pvalue = 0.026, ZWANG_EGF_PERSISTENTLY_DN
# Didn't pass (cutoff=0.0050): cat 2514, mi = 0.001, pvalue = 0.035, NICK_RESPONSE_TO_PROC_TREATMENT_DN
# Didn't pass (cutoff=0.0050): cat 2653, mi = 0.001, pvalue = 0.035, PARENT_MTOR_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 2394, mi = 0.001, pvalue = 0.035, MORI_PLASMA_CELL_DN
# Didn't pass (cutoff=0.0050): cat 2312, mi = 0.001, pvalue = 0.035, MIKKELSEN_IPS_HCP_WITH_H3_UNMETHYLATED
# Didn't pass (cutoff=0.0050): cat 3718, mi = 0.001, pvalue = 0.034, RIZ_ERYTHROID_DIFFERENTIATION_APOBEC2
# Didn't pass (cutoff=0.0050): cat 4637, mi = 0.001, pvalue = 0.037, ZHANG_GATA6_TARGETS_DN
# Didn't pass (cutoff=0.0050): cat 1022, mi = 0.001, pvalue = 0.039, FRASOR_RESPONSE_TO_SERM_OR_FULVESTRANT_UP
# Didn't pass (cutoff=0.0050): cat 3612, mi = 0.001, pvalue = 0.036, REACTOME_SYNTHESIS_OF_PC
# Didn't pass (cutoff=0.0050): cat 4435, mi = 0.001, pvalue = 0.047, WENG_POR_TARGETS_GLOBAL_DN
# Didn't pass (cutoff=0.0050): cat 3482, mi = 0.001, pvalue = 0.043, REACTOME_PYRUVATE_METABOLISM
# Didn't pass (cutoff=0.0050): cat 2625, mi = 0.001, pvalue = 0.034, OUELLET_CULTURED_OVARIAN_CANCER_INVASIVE_VS_LMP_UP
# Total number of categories evaluated = 757.
# Number of categories that passed the tests = 40
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 4, 0.00208561030453358
# best merge is 3, 11, 0.022592985275857
# best merge is 2, 5, 0.04135927960699
# best merge is 6, 10, 0.0486551481197323
# best merge is 3, 15, 0.0490924284371373
# best merge is 3, 8, 0.0646843160956174
# best merge is 0, 22, 0.0767492226052454
# best merge is 3, 9, 0.0881161749543284
# best merge is 12, 18, 0.0964077797211415
# best merge is 0, 7, 0.0985297590880269
# best merge is 2, 27, 0.102848482547805
# best merge is 17, 21, 0.102985491187527
# best merge is 3, 14, 0.106349737575868
# best merge is 3, 20, 0.117256822392232
# best merge is 3, 25, 0.144219208387975
# best merge is 19, 37, 0.144852522915388
# best merge is 6, 12, 0.153667757439016
# best merge is 17, 29, 0.181810534189403
# best merge is 13, 24, 0.202874389774926
# best merge is 26, 35, 0.205410645560708
# best merge is 1, 34, 0.223080973704767
# best merge is 6, 16, 0.242453975526993
# best merge is 6, 28, 0.249820290805234
# best merge is 17, 38, 0.25642025222055
# best merge is 19, 31, 0.267557821164011
# best merge is 3, 17, 0.314425322694601
# best merge is 33, 36, 0.349287942823405
# best merge is 3, 19, 0.465127907897647
# best merge is 26, 30, 0.490028873009325
# best merge is 2, 6, 0.499676998109957
# best merge is 0, 13, 0.509206068222175
# best merge is 26, 32, 0.533192112325452
# best merge is 2, 33, 0.675924117845443
# best merge is 1, 23, 0.730245212886539
# best merge is 3, 26, 0.81522929084135
# best merge is 0, 39, 0.870953471377469
# order classes
# 6 - 1.75099861790053
# 3 - 4.98835970215658
# 11 - 1.48675074911821
# 19 - 0.971954771742277
# 3 11 15 8 9 14 20 25 17 21 29 38 19 37 31 26 35 30 32
# 1 34 23
# 2 5 27 6 10 12 18 16 28 33 36
# 0 4 22 7 13 24
# 39
# Done.Start drawing
# 11.42	0.00
# RUIZ_TNC_TARGETS_UP
# MIKKELSEN_MCV6_LCP_WITH_H3K4ME3
# CROONQUIST_NRAS_VS_STROMAL_STIMULATION_UP
# MISSIAGLIA_REGULATED_BY_METHYLATION_UP
# GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP
# BHAT_ESR1_TARGETS_VIA_AKT1_DN
# BIDUS_METASTASIS_DN
# WINNEPENNINCKX_MELANOMA_METASTASIS_DN
# HALMOS_CEBPA_TARGETS_UP
# ZEMBUTSU_SENSITIVITY_TO_CISPLATIN
# GARGALOVIC_RESPONSE_TO_OXIDIZED_PHOSPHOLIPIDS_GREY_UP
# AZARE_NEOPLASTIC_TRANSFORMATION_BY_STAT3_UP
# LEE_LIVER_CANCER_CIPROFIBRATE_DN
# BEIER_GLIOMA_STEM_CELL_UP
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3
# NIELSEN_SYNOVIAL_SARCOMA_DN
# SMID_BREAST_CANCER_RELAPSE_IN_BRAIN_DN
# WENDT_COHESIN_TARGETS_UP
# VISALA_RESPONSE_TO_HEAT_SHOCK_AND_AGING_UP
# DANG_MYC_TARGETS_DN
# KEGG_PEROXISOME
# IKEDA_MIR133_TARGETS_UP
# REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANE
# TRAYNOR_RETT_SYNDROM_DN
# NAGY_STAGA_COMPONENTS_HUMAN
# KEGG_OXIDATIVE_PHOSPHORYLATION
# DING_LUNG_CANCER_EXPRESSION_BY_COPY_NUMBER
# TOOKER_GEMCITABINE_RESISTANCE_DN
# SCHLOSSER_SERUM_RESPONSE_AUGMENTED_BY_MYC
# PID_FAK_PATHWAY
# REACTOME_PROCESSING_OF_CAPPED_INTRON_CONTAINING_PRE_MRNA
# ELVIDGE_HYPOXIA_DN
# SCHLOSSER_MYC_TARGETS_AND_SERUM_RESPONSE_DN
# REACTOME_REGULATION_OF_MRNA_STABILITY_BY_PROTEINS_THAT_BIND_AU_RICH_ELEMENTS
# COLDREN_GEFITINIB_RESISTANCE_UP
# KANG_AR_TARGETS_UP
# ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER
# PID_FANCONI_PATHWAY
# KEGG_BASE_EXCISION_REPAIR
# KEGG_SYSTEMIC_LUPUS_ERYTHEMATOSUS
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 4, 0.00208561030453358
# best merge is 3, 11, 0.022592985275857
# best merge is 2, 5, 0.04135927960699
# best merge is 6, 10, 0.0486551481197323
# best merge is 3, 15, 0.0490924284371373
# best merge is 3, 8, 0.0646843160956174
# best merge is 0, 22, 0.0767492226052454
# best merge is 3, 9, 0.0881161749543284
# best merge is 12, 18, 0.0964077797211415
# best merge is 0, 7, 0.0985297590880269
# best merge is 2, 27, 0.102848482547805
# best merge is 17, 21, 0.102985491187527
# best merge is 3, 14, 0.106349737575868
# best merge is 3, 20, 0.117256822392232
# best merge is 3, 25, 0.144219208387975
# best merge is 19, 37, 0.144852522915388
# best merge is 6, 12, 0.153667757439016
# best merge is 17, 29, 0.181810534189403
# best merge is 13, 24, 0.202874389774926
# best merge is 26, 35, 0.205410645560708
# best merge is 1, 34, 0.223080973704767
# best merge is 6, 16, 0.242453975526993
# best merge is 6, 28, 0.249820290805234
# best merge is 17, 38, 0.25642025222055
# best merge is 19, 31, 0.267557821164011
# best merge is 3, 17, 0.314425322694601
# best merge is 33, 36, 0.349287942823405
# best merge is 3, 19, 0.465127907897647
# best merge is 26, 30, 0.490028873009325
# best merge is 2, 6, 0.499676998109957
# best merge is 0, 13, 0.509206068222175
# best merge is 26, 32, 0.533192112325452
# best merge is 2, 33, 0.675924117845443
# best merge is 1, 23, 0.730245212886539
# best merge is 3, 26, 0.81522929084135
# best merge is 0, 39, 0.870953471377469
# order classes
# 6 - 1.75099861790053
# 3 - 4.98835970215658
# 11 - 1.48675074911821
# 19 - 0.971954771742277
# 3 11 15 8 9 14 20 25 17 21 29 38 19 37 31 26 35 30 32
# 1 34 23
# 2 5 27 6 10 12 18 16 28 33 36
# 0 4 22 7 13 24
# 39
# Done.-19.1725043782837	42	0
# -18.1059544658494	42	1.65499124343257
# -17.7381786339755	42	2.13309982486865
# -17.4807355516637	42	2.39054290718039
# -17.223292469352	42	2.64798598949212
# -16.9658493870403	42	2.90542907180385
# -16.6348511383538	42	3.16287215411559
# -16.0831873905429	42	3.56742556917688
# 3.13309982486865	42	4.2661996497373
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c2/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# sem --wait done
