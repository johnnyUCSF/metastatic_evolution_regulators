# %% [markdown]
# # This is used for running data vs human_msigdb_c6 annotations located in:
# ### /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import scipy.stats

# %% [markdown]
# ### get index of file names to loop through

# %%
# %%bash
#
# cd fc_values
# ls FC* > filelist.txt
# cd ..

# %% [markdown]
# ### get ensembl genes represented in iPAGE database

# %%
# %%bash
#
# cp /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6_index.txt human_ensembl_index.txt
# awk '{print $1}' human_ensembl_index.txt > ensembl_index.txt

# %% [markdown]
# ### make sure that genes in file match the index

# %%
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
###################REMEMBER TO SPECIFY INDEX USED IN THE IPAGE COMMAND!!!!!!!!
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#####################
#######read in data from logfc calculations
#####################
####define index file to loop through
index_file = "fc_values/filelist.txt"
####define matching ensg index
GO_index_filename = "ensembl_index.txt"
genes_with_GOs = []
with open(GO_index_filename,'r') as rf:
    for line in rf:
        gene_name = line.split('\n')[0]
        genes_with_GOs.append(gene_name)
genes_with_GOs_set = set(genes_with_GOs)
####open file and loop through each line
###
iPAGE_sh = "iPAGE_JY.sh"
cwd = os.getcwd()+"/"
os.system("rm "+iPAGE_sh)
###
with open(index_file,'r') as rf:
    for line in rf:
        #####do this to each file
        ###read in file into pandas df
        FC_file = "fc_values/"+line.split('\n')[0]
        FC_df = pd.read_csv(FC_file,sep=',',index_col=0)
        FC_df.columns = ['log2FoldChange']
        FC_df.index.names = ['Gene']
        ###filter
        FC_df = FC_df.loc[[x for x in FC_df.index if x in genes_with_GOs_set]]
        ###save
        save_file = "fc_values/filt_"+line.split('\n')[0]
        FC_df.to_csv(save_file,sep='\t',header=True)
        ###write final iPAGE command to an ipage .sh file
        iPAGE_cmd = "perl /nvme/bins/iPAGEv1.0/page.pl --expfile "+cwd+save_file+" --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9 \n"
        with open(iPAGE_sh, "a") as myfile:
            myfile.write(iPAGE_cmd)

# %% [markdown]
# ## then run the command from this folder:
#
# nohup sh run.sh iPAGE_JY.sh &

# %%
# %%bash
#
# nohup sh run.sh iPAGE_JY.sh &
# Out:
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 157, mi = 0.00315193, RB_P107_DN.V1_UP
# cat 73, mi = 0.00295861, HOXA9_DN.V1_DN
# cat 100, mi = 0.00276395, KRAS.KIDNEY_UP.V1_UP
# cat 108, mi = 0.00267493, LEF1_UP.V1_UP
# cat 86, mi = 0.00265578, KRAS.300_UP.V1_UP
# cat 102, mi = 0.00260756, KRAS.LUNG.BREAST_UP.V1_UP
# cat 21, mi = 0.00258864, BMI1_DN_MEL18_DN.V1_UP
# cat 46, mi = 0.00243240, DCA_UP.V1_UP
# cat 96, mi = 0.00232758, KRAS.BREAST_UP.V1_UP
# cat 26, mi = 0.00225891, CAHOY_NEURONAL
# cat 60, mi = 0.00224383, ESC_J1_UP_LATE.V1_UP
# cat 114, mi = 0.00223520, MEL18_DN.V1_UP
# cat 6, mi = 0.00200923, ATF2_S_UP.V1_DN
# cat 127, mi = 0.00196640, P53_DN.V1_UP
# cat 48, mi = 0.00194425, E2F1_UP.V1_UP
#
# RESULTS
# Passed: cat 157, mi = 0.003, pvalue = 0.000, RB_P107_DN.V1_UP
# Passed: cat 100, mi = 0.003, pvalue = 0.000, KRAS.KIDNEY_UP.V1_UP
# Passed: cat 102, mi = 0.003, pvalue = 0.000, KRAS.LUNG.BREAST_UP.V1_UP
# Passed: cat 60, mi = 0.002, pvalue = 0.000, ESC_J1_UP_LATE.V1_UP
# Passed: cat 146, mi = 0.002, pvalue = 0.000, PTEN_DN.V1_DN
# Passed: cat 51, mi = 0.002, pvalue = 0.001, EGFR_UP.V1_DN
# Passed: cat 160, mi = 0.002, pvalue = 0.002, RELA_DN.V1_DN
# Passed: cat 136, mi = 0.002, pvalue = 0.003, PKCA_DN.V1_DN
# Passed: cat 112, mi = 0.001, pvalue = 0.002, MEK_UP.V1_UP
# Passed: cat 186, mi = 0.001, pvalue = 0.004, WNT_UP.V1_UP
# Passed: cat 29, mi = 0.001, pvalue = 0.004, CAMP_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 137, mi = 0.001, pvalue = 0.006, PKCA_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 147, mi = 0.001, pvalue = 0.007, PTEN_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 69, mi = 0.001, pvalue = 0.009, GLI1_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 85, mi = 0.001, pvalue = 0.012, KRAS.300_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 145, mi = 0.001, pvalue = 0.033, PRC2_SUZ12_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 35, mi = 0.001, pvalue = 0.039, CSR_EARLY_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 188, mi = 0.001, pvalue = 0.055, YAP1_UP
# Didn't pass (cutoff=0.0050): cat 12, mi = 0.001, pvalue = 0.108, BCAT.100_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 164, mi = 0.001, pvalue = 0.097, SINGH_KRAS_DEPENDENCY_SIGNATURE_
# Didn't pass (cutoff=0.0050): cat 87, mi = 0.001, pvalue = 0.227, KRAS.50_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 170, mi = 0.001, pvalue = 0.138, SRC_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 14, mi = 0.001, pvalue = 0.224, BCAT_BILD_ET_AL_DN
# Didn't pass (cutoff=0.0050): cat 16, mi = 0.001, pvalue = 0.242, BCAT_GDS748_DN
# Didn't pass (cutoff=0.0050): cat 15, mi = 0.001, pvalue = 0.269, BCAT_BILD_ET_AL_UP
# Didn't pass (cutoff=0.0050): cat 133, mi = 0.000, pvalue = 0.494, PDGF_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 179, mi = 0.000, pvalue = 0.682, TBK1.DN.48HRS_DN
# Didn't pass: cat 89, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_DN
# Didn't pass: cat 90, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_UP
# Didn't pass: cat 91, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_DN
# Didn't pass: cat 92, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_UP
# Total number of categories evaluated = 170.
# Number of categories that passed the tests = 11
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 2, 6, 0.0704595512658449
# best merge is 1, 8, 0.104741657947894
# best merge is 4, 7, 0.157762988569799
# best merge is 1, 2, 0.195343529247353
# best merge is 4, 5, 0.19752666680688
# best merge is 1, 3, 0.243447727315615
# best merge is 0, 4, 0.298561182392196
# order classes
# 5 - 0.339744457441948
# 3 - 0.450442929186604
# 1 8 2 6 3
# 0
# 4 7 5
# 9
# 10
# Done.Start drawing
# 23.77	0.00
# MEK_UP.V1_UP
# RB_P107_DN.V1_UP
# PTEN_DN.V1_DN
# PKCA_DN.V1_DN
# EGFR_UP.V1_DN
# CAMP_UP.V1_UP
# KRAS.KIDNEY_UP.V1_UP
# KRAS.LUNG.BREAST_UP.V1_UP
# RELA_DN.V1_DN
# ESC_J1_UP_LATE.V1_UP
# WNT_UP.V1_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 2, 6, 0.0704595512658449
# best merge is 1, 8, 0.104741657947894
# best merge is 4, 7, 0.157762988569799
# best merge is 1, 2, 0.195343529247353
# best merge is 4, 5, 0.19752666680688
# best merge is 1, 3, 0.243447727315615
# best merge is 0, 4, 0.298561182392196
# order classes
# 5 - 0.339744457441948
# 3 - 0.450442929186604
# 1 8 2 6 3
# 0
# 4 7 5
# 9
# 10
# Done.-19.2932267564156	42	0
# -18.4450988641144	42	1.4135464871687
# -18.2153975599495	42	1.69625578460244
# -18.056373580143	42	1.87294909549853
# -17.8973496003366	42	2.0143037442154
# -17.7206562894405	42	2.19099705511149
# -17.51745898191	42	2.36769036600757
# -17.2082456878418	42	2.59739167017249
# 2.49305847707194	42	2.98611695414388
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 102, mi = 0.00371761, KRAS.LUNG.BREAST_UP.V1_UP
# cat 30, mi = 0.00297067, CORDENONSI_YAP_CONSERVED_SIGNATURE
# cat 86, mi = 0.00278986, KRAS.300_UP.V1_UP
# cat 96, mi = 0.00277467, KRAS.BREAST_UP.V1_UP
# cat 127, mi = 0.00263525, P53_DN.V1_UP
# cat 99, mi = 0.00258838, KRAS.KIDNEY_UP.V1_DN
# cat 50, mi = 0.00253034, E2F3_UP.V1_UP
# cat 120, mi = 0.00247824, MYC_UP.V1_UP
# cat 82, mi = 0.00244092, JAK2_DN.V1_UP
# cat 108, mi = 0.00242111, LEF1_UP.V1_UP
# cat 26, mi = 0.00236075, CAHOY_NEURONAL
# cat 183, mi = 0.00232235, VEGF_A_UP.V1_DN
# cat 79, mi = 0.00225380, IL2_UP.V1_DN
# cat 104, mi = 0.00212378, KRAS.LUNG_UP.V1_UP
# cat 106, mi = 0.00208260, KRAS.PROSTATE_UP.V1_UP
#
# RESULTS
# Passed: cat 102, mi = 0.004, pvalue = 0.000, KRAS.LUNG.BREAST_UP.V1_UP
# Passed: cat 30, mi = 0.003, pvalue = 0.000, CORDENONSI_YAP_CONSERVED_SIGNATURE
# Passed: cat 50, mi = 0.003, pvalue = 0.000, E2F3_UP.V1_UP
# Passed: cat 82, mi = 0.002, pvalue = 0.000, JAK2_DN.V1_UP
# Passed: cat 108, mi = 0.002, pvalue = 0.000, LEF1_UP.V1_UP
# Passed: cat 26, mi = 0.002, pvalue = 0.000, CAHOY_NEURONAL
# Passed: cat 183, mi = 0.002, pvalue = 0.000, VEGF_A_UP.V1_DN
# Passed: cat 79, mi = 0.002, pvalue = 0.000, IL2_UP.V1_DN
# Passed: cat 78, mi = 0.002, pvalue = 0.000, IL21_UP.V1_UP
# Passed: cat 164, mi = 0.002, pvalue = 0.000, SINGH_KRAS_DEPENDENCY_SIGNATURE_
# Passed: cat 105, mi = 0.002, pvalue = 0.001, KRAS.PROSTATE_UP.V1_DN
# Passed: cat 151, mi = 0.002, pvalue = 0.001, RAF_UP.V1_UP
# Passed: cat 136, mi = 0.002, pvalue = 0.002, PKCA_DN.V1_DN
# Passed: cat 41, mi = 0.001, pvalue = 0.002, CYCLIN_D1_KE_.V1_DN
# Didn't pass (cutoff=0.0050): cat 166, mi = 0.001, pvalue = 0.006, SIRNA_EIF4GI_UP
# Didn't pass (cutoff=0.0050): cat 40, mi = 0.001, pvalue = 0.005, CTIP_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 66, mi = 0.001, pvalue = 0.021, GCNP_SHH_UP_EARLY.V1_UP
# Didn't pass (cutoff=0.0050): cat 62, mi = 0.001, pvalue = 0.049, ESC_V6.5_UP_EARLY.V1_UP
# Didn't pass (cutoff=0.0050): cat 54, mi = 0.001, pvalue = 0.054, EIF4E_UP
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.001, pvalue = 0.060, CSR_LATE_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 159, mi = 0.001, pvalue = 0.069, RB_P130_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 81, mi = 0.001, pvalue = 0.088, JAK2_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 16, mi = 0.000, pvalue = 0.653, BCAT_GDS748_DN
# Didn't pass (cutoff=0.0050): cat 188, mi = 0.000, pvalue = 0.686, YAP1_UP
# Didn't pass: cat 89, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_DN
# Didn't pass: cat 90, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_UP
# Didn't pass: cat 91, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_DN
# Didn't pass: cat 92, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_UP
# Didn't pass: cat 121, mi = 0.000, pvalue = 1.000, NFE2L2.V2
# Didn't pass: cat 171, mi = 0.000, pvalue = 1.000, STK33_DN
# Didn't pass: cat 172, mi = 0.000, pvalue = 1.000, STK33_NOMO_DN
# Didn't pass: cat 173, mi = 0.000, pvalue = 1.000, STK33_NOMO_UP
# Didn't pass: cat 174, mi = 0.000, pvalue = 1.000, STK33_SKM_DN
# Didn't pass: cat 175, mi = 0.000, pvalue = 1.000, STK33_SKM_UP
# Total number of categories evaluated = 176.
# Number of categories that passed the tests = 14
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 5, 0.0397062133017567
# best merge is 8, 9, 0.0738441639640562
# best merge is 0, 2, 0.0813159506421545
# best merge is 7, 12, 0.0851182393182212
# best merge is 0, 10, 0.0893322904213463
# best merge is 1, 6, 0.0983745629821988
# best merge is 0, 8, 0.129309804724733
# best merge is 3, 4, 0.148474711396084
# best merge is 3, 7, 0.187532868685188
# best merge is 3, 11, 0.205325637788487
# order classes
# 6 - 0.204640798394151
# 2 - 0.344310970437696
# 4 - 0.430379436136588
# 0 5 2 10 8 9
# 1 6
# 3 4 7 12
# 11
# 13
# Done.Start drawing
# 62.96	0.00
# CORDENONSI_YAP_CONSERVED_SIGNATURE
# VEGF_A_UP.V1_DN
# LEF1_UP.V1_UP
# PKCA_DN.V1_DN
# RAF_UP.V1_UP
# KRAS.LUNG.BREAST_UP.V1_UP
# CAHOY_NEURONAL
# E2F3_UP.V1_UP
# KRAS.PROSTATE_UP.V1_DN
# IL21_UP.V1_UP
# SINGH_KRAS_DEPENDENCY_SIGNATURE_
# JAK2_DN.V1_UP
# IL2_UP.V1_DN
# CYCLIN_D1_KE_.V1_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 5, 0.0397062133017567
# best merge is 8, 9, 0.0738441639640562
# best merge is 0, 2, 0.0813159506421545
# best merge is 7, 12, 0.0851182393182212
# best merge is 0, 10, 0.0893322904213463
# best merge is 1, 6, 0.0983745629821988
# best merge is 0, 8, 0.129309804724733
# best merge is 3, 4, 0.148474711396084
# best merge is 3, 7, 0.187532868685188
# best merge is 3, 11, 0.205325637788487
# order classes
# 6 - 0.204640798394151
# 2 - 0.344310970437696
# 4 - 0.430379436136588
# 0 5 2 10 8 9
# 1 6
# 3 4 7 12
# 11
# 13
# Done.-19.7198221092757	42	0
# -19.3562579415502	42	0.560355781448539
# -19.2195044472681	42	0.72712833545108
# -19.1227763659466	42	0.833862770012706
# -19.0360546378653	42	0.920584498094028
# -18.9459974587039	42	1.00730622617535
# -18.8359275730623	42	1.10069885641677
# -18.6558132147395	42	1.2274459974587
# 1.73046378653113	42	1.46092757306226
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 157, mi = 0.00490930, RB_P107_DN.V1_UP
# cat 143, mi = 0.00444803, PRC2_EZH2_UP.V1_UP
# cat 38, mi = 0.00317394, CSR_LATE_UP.V1_UP
# cat 100, mi = 0.00317317, KRAS.KIDNEY_UP.V1_UP
# cat 50, mi = 0.00303629, E2F3_UP.V1_UP
# cat 162, mi = 0.00290850, RPS14_DN.V1_DN
# cat 159, mi = 0.00274262, RB_P130_DN.V1_UP
# cat 86, mi = 0.00262925, KRAS.300_UP.V1_UP
# cat 107, mi = 0.00244873, LEF1_UP.V1_DN
# cat 21, mi = 0.00228699, BMI1_DN_MEL18_DN.V1_UP
# cat 37, mi = 0.00228501, CSR_LATE_UP.V1_DN
# cat 75, mi = 0.00227812, IL15_UP.V1_DN
# cat 127, mi = 0.00225316, P53_DN.V1_UP
# cat 108, mi = 0.00219253, LEF1_UP.V1_UP
# cat 126, mi = 0.00216552, P53_DN.V1_DN
#
# RESULTS
# Passed: cat 157, mi = 0.005, pvalue = 0.000, RB_P107_DN.V1_UP
# Passed: cat 143, mi = 0.004, pvalue = 0.000, PRC2_EZH2_UP.V1_UP
# Passed: cat 100, mi = 0.003, pvalue = 0.000, KRAS.KIDNEY_UP.V1_UP
# Passed: cat 159, mi = 0.003, pvalue = 0.000, RB_P130_DN.V1_UP
# Passed: cat 21, mi = 0.002, pvalue = 0.000, BMI1_DN_MEL18_DN.V1_UP
# Passed: cat 37, mi = 0.002, pvalue = 0.000, CSR_LATE_UP.V1_DN
# Passed: cat 75, mi = 0.002, pvalue = 0.000, IL15_UP.V1_DN
# Passed: cat 146, mi = 0.002, pvalue = 0.000, PTEN_DN.V1_DN
# Passed: cat 137, mi = 0.002, pvalue = 0.000, PKCA_DN.V1_UP
# Passed: cat 30, mi = 0.002, pvalue = 0.000, CORDENONSI_YAP_CONSERVED_SIGNATURE
# Passed: cat 82, mi = 0.002, pvalue = 0.000, JAK2_DN.V1_UP
# Passed: cat 158, mi = 0.002, pvalue = 0.000, RB_P130_DN.V1_DN
# Passed: cat 101, mi = 0.002, pvalue = 0.001, KRAS.LUNG.BREAST_UP.V1_DN
# Passed: cat 25, mi = 0.001, pvalue = 0.003, CAHOY_ASTROGLIAL
# Passed: cat 29, mi = 0.001, pvalue = 0.004, CAMP_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 170, mi = 0.001, pvalue = 0.008, SRC_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 185, mi = 0.001, pvalue = 0.016, WNT_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 135, mi = 0.001, pvalue = 0.019, PIGF_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 129, mi = 0.001, pvalue = 0.078, P53_DN.V2_UP
# Didn't pass (cutoff=0.0050): cat 166, mi = 0.001, pvalue = 0.072, SIRNA_EIF4GI_UP
# Didn't pass (cutoff=0.0050): cat 10, mi = 0.001, pvalue = 0.143, ATM_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 64, mi = 0.001, pvalue = 0.134, ESC_V6.5_UP_LATE.V1_UP
# Didn't pass (cutoff=0.0050): cat 33, mi = 0.001, pvalue = 0.166, CRX_NRL_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 120, mi = 0.001, pvalue = 0.174, MYC_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 81, mi = 0.001, pvalue = 0.316, JAK2_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 69, mi = 0.000, pvalue = 0.603, GLI1_UP.V1_DN
# Didn't pass: cat 89, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_DN
# Didn't pass: cat 90, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_UP
# Didn't pass: cat 91, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_DN
# Didn't pass: cat 92, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_UP
# Didn't pass: cat 121, mi = 0.000, pvalue = 1.000, NFE2L2.V2
# Didn't pass: cat 171, mi = 0.000, pvalue = 1.000, STK33_DN
# Didn't pass: cat 172, mi = 0.000, pvalue = 1.000, STK33_NOMO_DN
# Didn't pass: cat 173, mi = 0.000, pvalue = 1.000, STK33_NOMO_UP
# Didn't pass: cat 174, mi = 0.000, pvalue = 1.000, STK33_SKM_DN
# Total number of categories evaluated = 175.
# Number of categories that passed the tests = 15
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 6, 7, 0.0344745072653626
# best merge is 0, 1, 0.0380156741769754
# best merge is 6, 9, 0.0480330478678776
# best merge is 4, 10, 0.0751630167205578
# best merge is 4, 6, 0.138340658654408
# best merge is 0, 3, 0.167526702716793
# best merge is 2, 4, 0.183267157844805
# best merge is 2, 12, 0.249064087184627
# best merge is 2, 8, 0.317812705145878
# best merge is 11, 13, 0.359959873120458
# best merge is 0, 2, 0.579000008184961
# order classes
# 3 - 0.41452119956729
# 8 - 0.332294344921937
# 2 - 1.34984952420172
# 2 4 10 6 7 9 12 8
# 0 1 3
# 5
# 11 13
# 14
# Done.Start drawing
# 84.94	0.00
# BMI1_DN_MEL18_DN.V1_UP
# JAK2_DN.V1_UP
# IL15_UP.V1_DN
# PTEN_DN.V1_DN
# CORDENONSI_YAP_CONSERVED_SIGNATURE
# KRAS.LUNG.BREAST_UP.V1_DN
# CAHOY_ASTROGLIAL
# CSR_LATE_UP.V1_DN
# RB_P130_DN.V1_DN
# CAMP_UP.V1_UP
# KRAS.KIDNEY_UP.V1_UP
# PKCA_DN.V1_UP
# RB_P107_DN.V1_UP
# PRC2_EZH2_UP.V1_UP
# RB_P130_DN.V1_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 6, 7, 0.0344745072653626
# best merge is 0, 1, 0.0380156741769754
# best merge is 6, 9, 0.0480330478678776
# best merge is 4, 10, 0.0751630167205578
# best merge is 4, 6, 0.138340658654408
# best merge is 0, 3, 0.167526702716793
# best merge is 2, 4, 0.183267157844805
# best merge is 2, 12, 0.249064087184627
# best merge is 2, 8, 0.317812705145878
# best merge is 11, 13, 0.359959873120458
# best merge is 0, 2, 0.579000008184961
# order classes
# 3 - 0.41452119956729
# 8 - 0.332294344921937
# 2 - 1.34984952420172
# 2 4 10 6 7 9 12 8
# 0 1 3
# 5
# 11 13
# 14
# Done.-19.849187661879	42	0
# -19.6588179891688	42	0.301624676242053
# -19.5920649870497	42	0.380739345420297
# -19.5401459854015	42	0.435130680480339
# -19.4931716505769	42	0.484577348716741
# -19.4437249823405	42	0.529079350129503
# -19.3769719802213	42	0.583470685189545
# -19.2706616435131	42	0.662585354367789
# 1.39804567930304	42	0.796091358606075
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 30, mi = 0.00355253, CORDENONSI_YAP_CONSERVED_SIGNATURE
# cat 50, mi = 0.00342537, E2F3_UP.V1_UP
# cat 108, mi = 0.00314305, LEF1_UP.V1_UP
# cat 96, mi = 0.00278951, KRAS.BREAST_UP.V1_UP
# cat 102, mi = 0.00268136, KRAS.LUNG.BREAST_UP.V1_UP
# cat 100, mi = 0.00268097, KRAS.KIDNEY_UP.V1_UP
# cat 21, mi = 0.00266327, BMI1_DN_MEL18_DN.V1_UP
# cat 36, mi = 0.00250384, CSR_EARLY_UP.V1_UP
# cat 137, mi = 0.00249013, PKCA_DN.V1_UP
# cat 82, mi = 0.00241125, JAK2_DN.V1_UP
# cat 104, mi = 0.00226126, KRAS.LUNG_UP.V1_UP
# cat 77, mi = 0.00218496, IL21_UP.V1_DN
# cat 107, mi = 0.00213915, LEF1_UP.V1_DN
# cat 101, mi = 0.00208835, KRAS.LUNG.BREAST_UP.V1_DN
# cat 40, mi = 0.00208403, CTIP_DN.V1_UP
#
# RESULTS
# Passed: cat 30, mi = 0.004, pvalue = 0.000, CORDENONSI_YAP_CONSERVED_SIGNATURE
# Passed: cat 50, mi = 0.003, pvalue = 0.000, E2F3_UP.V1_UP
# Passed: cat 108, mi = 0.003, pvalue = 0.000, LEF1_UP.V1_UP
# Passed: cat 96, mi = 0.003, pvalue = 0.000, KRAS.BREAST_UP.V1_UP
# Passed: cat 36, mi = 0.003, pvalue = 0.000, CSR_EARLY_UP.V1_UP
# Passed: cat 82, mi = 0.002, pvalue = 0.000, JAK2_DN.V1_UP
# Passed: cat 77, mi = 0.002, pvalue = 0.000, IL21_UP.V1_DN
# Passed: cat 107, mi = 0.002, pvalue = 0.000, LEF1_UP.V1_DN
# Passed: cat 40, mi = 0.002, pvalue = 0.000, CTIP_DN.V1_UP
# Passed: cat 78, mi = 0.002, pvalue = 0.000, IL21_UP.V1_UP
# Passed: cat 135, mi = 0.002, pvalue = 0.000, PIGF_UP.V1_UP
# Passed: cat 94, mi = 0.002, pvalue = 0.002, KRAS.AMP.LUNG_UP.V1_UP
# Passed: cat 158, mi = 0.002, pvalue = 0.002, RB_P130_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 164, mi = 0.001, pvalue = 0.009, SINGH_KRAS_DEPENDENCY_SIGNATURE_
# Didn't pass (cutoff=0.0050): cat 166, mi = 0.001, pvalue = 0.012, SIRNA_EIF4GI_UP
# Didn't pass (cutoff=0.0050): cat 186, mi = 0.001, pvalue = 0.019, WNT_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 159, mi = 0.001, pvalue = 0.029, RB_P130_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 35, mi = 0.001, pvalue = 0.054, CSR_EARLY_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 1, mi = 0.001, pvalue = 0.071, AKT_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 42, mi = 0.001, pvalue = 0.083, CYCLIN_D1_KE_.V1_UP
# Didn't pass (cutoff=0.0050): cat 68, mi = 0.001, pvalue = 0.096, GCNP_SHH_UP_LATE.V1_UP
# Didn't pass (cutoff=0.0050): cat 131, mi = 0.001, pvalue = 0.127, PDGF_ERK_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 179, mi = 0.001, pvalue = 0.341, TBK1.DN.48HRS_DN
# Didn't pass (cutoff=0.0050): cat 69, mi = 0.000, pvalue = 0.677, GLI1_UP.V1_DN
# Didn't pass: cat 89, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_DN
# Didn't pass: cat 90, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_UP
# Didn't pass: cat 91, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_DN
# Didn't pass: cat 92, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_UP
# Didn't pass: cat 121, mi = 0.000, pvalue = 1.000, NFE2L2.V2
# Didn't pass: cat 171, mi = 0.000, pvalue = 1.000, STK33_DN
# Didn't pass: cat 172, mi = 0.000, pvalue = 1.000, STK33_NOMO_DN
# Didn't pass: cat 173, mi = 0.000, pvalue = 1.000, STK33_NOMO_UP
# Didn't pass: cat 174, mi = 0.000, pvalue = 1.000, STK33_SKM_DN
# Total number of categories evaluated = 175.
# Number of categories that passed the tests = 13
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 3, 7, 0.0339428726887496
# best merge is 6, 8, 0.0447226164070905
# best merge is 3, 9, 0.0747358339417612
# best merge is 0, 2, 0.089087912069554
# best merge is 3, 6, 0.0973326310917161
# best merge is 1, 3, 0.101708890379258
# best merge is 4, 12, 0.14909640407335
# best merge is 1, 11, 0.150285958191277
# best merge is 1, 5, 0.273955264928581
# order classes
# 2 - 0.289535714226051
# 7 - 0.168461287926862
# 2 - 0.484563313238389
# 1 3 7 9 6 8 11
# 0 2
# 4 12
# 5
# 10
# Done.Start drawing
# 26.31	0.00
# CORDENONSI_YAP_CONSERVED_SIGNATURE
# LEF1_UP.V1_UP
# CSR_EARLY_UP.V1_UP
# RB_P130_DN.V1_DN
# PIGF_UP.V1_UP
# E2F3_UP.V1_UP
# KRAS.BREAST_UP.V1_UP
# LEF1_UP.V1_DN
# IL21_UP.V1_UP
# IL21_UP.V1_DN
# CTIP_DN.V1_UP
# KRAS.AMP.LUNG_UP.V1_UP
# JAK2_DN.V1_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv_PAGE/filt_FC_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv_PAGE/filt_FC_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 3, 7, 0.0339428726887496
# best merge is 6, 8, 0.0447226164070905
# best merge is 3, 9, 0.0747358339417612
# best merge is 0, 2, 0.089087912069554
# best merge is 3, 6, 0.0973326310917161
# best merge is 1, 3, 0.101708890379258
# best merge is 4, 12, 0.14909640407335
# best merge is 1, 11, 0.150285958191277
# best merge is 1, 5, 0.273955264928581
# order classes
# 2 - 0.289535714226051
# 7 - 0.168461287926862
# 2 - 0.484563313238389
# 1 3 7 9 6 8 11
# 0 2
# 4 12
# 5
# 10
# Done.-19.5290763968073	42	0
# -18.9064994298746	42	0.941847206385405
# -18.6590649942987	42	1.24515393386545
# -18.4754846066135	42	1.43671607753706
# -18.3158494868871	42	1.61231470923603
# -18.1641961231471	42	1.75598631698974
# -17.9806157354618	42	1.91562143671608
# -17.709236031927	42	2.12314709236032
# 2.22919042189282	42	2.45838084378563
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_3.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 108, mi = 0.00461702, LEF1_UP.V1_UP
# cat 127, mi = 0.00391918, P53_DN.V1_UP
# cat 96, mi = 0.00350198, KRAS.BREAST_UP.V1_UP
# cat 102, mi = 0.00299807, KRAS.LUNG.BREAST_UP.V1_UP
# cat 86, mi = 0.00294437, KRAS.300_UP.V1_UP
# cat 126, mi = 0.00282807, P53_DN.V1_DN
# cat 144, mi = 0.00265056, PRC2_SUZ12_UP.V1_DN
# cat 107, mi = 0.00264757, LEF1_UP.V1_DN
# cat 105, mi = 0.00262897, KRAS.PROSTATE_UP.V1_DN
# cat 26, mi = 0.00248621, CAHOY_NEURONAL
# cat 147, mi = 0.00242479, PTEN_DN.V1_UP
# cat 100, mi = 0.00237654, KRAS.KIDNEY_UP.V1_UP
# cat 112, mi = 0.00234891, MEK_UP.V1_UP
# cat 37, mi = 0.00234506, CSR_LATE_UP.V1_DN
# cat 30, mi = 0.00227517, CORDENONSI_YAP_CONSERVED_SIGNATURE
#
# RESULTS
# Passed: cat 108, mi = 0.005, pvalue = 0.000, LEF1_UP.V1_UP
# Passed: cat 127, mi = 0.004, pvalue = 0.000, P53_DN.V1_UP
# Passed: cat 96, mi = 0.004, pvalue = 0.000, KRAS.BREAST_UP.V1_UP
# Passed: cat 107, mi = 0.003, pvalue = 0.000, LEF1_UP.V1_DN
# Passed: cat 105, mi = 0.003, pvalue = 0.000, KRAS.PROSTATE_UP.V1_DN
# Passed: cat 26, mi = 0.002, pvalue = 0.000, CAHOY_NEURONAL
# Passed: cat 37, mi = 0.002, pvalue = 0.000, CSR_LATE_UP.V1_DN
# Passed: cat 186, mi = 0.002, pvalue = 0.000, WNT_UP.V1_UP
# Passed: cat 84, mi = 0.002, pvalue = 0.000, JNK_DN.V1_UP
# Passed: cat 36, mi = 0.002, pvalue = 0.000, CSR_EARLY_UP.V1_UP
# Passed: cat 48, mi = 0.002, pvalue = 0.000, E2F1_UP.V1_UP
# Passed: cat 82, mi = 0.002, pvalue = 0.001, JAK2_DN.V1_UP
# Passed: cat 29, mi = 0.002, pvalue = 0.000, CAMP_UP.V1_UP
# Passed: cat 27, mi = 0.002, pvalue = 0.002, CAHOY_OLIGODENDROCUTIC
# Passed: cat 164, mi = 0.001, pvalue = 0.002, SINGH_KRAS_DEPENDENCY_SIGNATURE_
# Passed: cat 135, mi = 0.001, pvalue = 0.003, PIGF_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 139, mi = 0.001, pvalue = 0.008, PRC1_BMI_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 75, mi = 0.001, pvalue = 0.019, IL15_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 119, mi = 0.001, pvalue = 0.024, MYC_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 16, mi = 0.001, pvalue = 0.074, BCAT_GDS748_DN
# Didn't pass (cutoff=0.0050): cat 165, mi = 0.001, pvalue = 0.086, SIRNA_EIF4GI_DN
# Didn't pass (cutoff=0.0050): cat 17, mi = 0.001, pvalue = 0.281, BCAT_GDS748_UP
# Didn't pass (cutoff=0.0050): cat 69, mi = 0.001, pvalue = 0.415, GLI1_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 24, mi = 0.001, pvalue = 0.386, CAHOY_ASTROCYTIC
# Didn't pass (cutoff=0.0050): cat 188, mi = 0.000, pvalue = 0.503, YAP1_UP
# Didn't pass: cat 89, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_DN
# Didn't pass: cat 90, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_UP
# Didn't pass: cat 91, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_DN
# Didn't pass: cat 92, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_UP
# Didn't pass: cat 121, mi = 0.000, pvalue = 1.000, NFE2L2.V2
# Didn't pass: cat 171, mi = 0.000, pvalue = 1.000, STK33_DN
# Didn't pass: cat 172, mi = 0.000, pvalue = 1.000, STK33_NOMO_DN
# Didn't pass: cat 173, mi = 0.000, pvalue = 1.000, STK33_NOMO_UP
# Didn't pass: cat 174, mi = 0.000, pvalue = 1.000, STK33_SKM_DN
# Didn't pass: cat 175, mi = 0.000, pvalue = 1.000, STK33_SKM_UP
# Didn't pass: cat 176, mi = 0.000, pvalue = 1.000, STK33_UP
# Total number of categories evaluated = 177.
# Number of categories that passed the tests = 16
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 2, 5, 0.0311976325066279
# best merge is 1, 3, 0.0818160975913228
# best merge is 2, 14, 0.0866643969772886
# best merge is 0, 6, 0.125316752486166
# best merge is 0, 8, 0.156109755825041
# best merge is 12, 15, 0.156487207079626
# best merge is 2, 7, 0.168233658123948
# best merge is 1, 2, 0.173083705430741
# best merge is 1, 11, 0.239547404047051
# best merge is 1, 4, 0.278677192929968
# best merge is 0, 1, 0.53828069729998
# best merge is 10, 13, 0.557955042569039
# order classes
# 11 - 0.454876295501082
# 2 - 0.625948828318503
# 0 6 8 1 3 2 5 14 7 11 4
# 9
# 10
# 12 15
# 13
# Done.Start drawing
# 70.09	0.00
# LEF1_UP.V1_UP
# CSR_LATE_UP.V1_DN
# JNK_DN.V1_UP
# CSR_EARLY_UP.V1_UP
# E2F1_UP.V1_UP
# CAMP_UP.V1_UP
# PIGF_UP.V1_UP
# P53_DN.V1_UP
# LEF1_UP.V1_DN
# KRAS.BREAST_UP.V1_UP
# CAHOY_NEURONAL
# SINGH_KRAS_DEPENDENCY_SIGNATURE_
# WNT_UP.V1_UP
# JAK2_DN.V1_UP
# KRAS.PROSTATE_UP.V1_DN
# CAHOY_OLIGODENDROCUTIC
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv_PAGE/filt_FC_LVM2_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv_PAGE/filt_FC_LVM2_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 2, 5, 0.0311976325066279
# best merge is 1, 3, 0.0818160975913228
# best merge is 2, 14, 0.0866643969772886
# best merge is 0, 6, 0.125316752486166
# best merge is 0, 8, 0.156109755825041
# best merge is 12, 15, 0.156487207079626
# best merge is 2, 7, 0.168233658123948
# best merge is 1, 2, 0.173083705430741
# best merge is 1, 11, 0.239547404047051
# best merge is 1, 4, 0.278677192929968
# best merge is 0, 1, 0.53828069729998
# best merge is 10, 13, 0.557955042569039
# order classes
# 11 - 0.454876295501082
# 2 - 0.625948828318503
# 0 6 8 1 3 2 5 14 7 11 4
# 9
# 10
# 12 15
# 13
# Done.-19.784277357683	42	0
# -19.5056356113568	42	0.431445284634042
# -19.4037665858182	42	0.557283492652304
# -19.3318590383792	42	0.635183335711228
# -19.2689399343701	42	0.701098587530318
# -19.203024682551	42	0.761021543729491
# -19.1221286916821	42	0.832929091168498
# -18.9902981880439	42	0.922813525467256
# 1.54829504922243	42	1.09659009844486
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 102, mi = 0.00389917, KRAS.LUNG.BREAST_UP.V1_UP
# cat 96, mi = 0.00381153, KRAS.BREAST_UP.V1_UP
# cat 26, mi = 0.00362337, CAHOY_NEURONAL
# cat 86, mi = 0.00336032, KRAS.300_UP.V1_UP
# cat 127, mi = 0.00330014, P53_DN.V1_UP
# cat 78, mi = 0.00299947, IL21_UP.V1_UP
# cat 167, mi = 0.00254462, SNF5_DN.V1_DN
# cat 108, mi = 0.00252478, LEF1_UP.V1_UP
# cat 100, mi = 0.00240055, KRAS.KIDNEY_UP.V1_UP
# cat 99, mi = 0.00224882, KRAS.KIDNEY_UP.V1_DN
# cat 48, mi = 0.00223542, E2F1_UP.V1_UP
# cat 13, mi = 0.00223503, BCAT.100_UP.V1_UP
# cat 30, mi = 0.00217806, CORDENONSI_YAP_CONSERVED_SIGNATURE
# cat 38, mi = 0.00214812, CSR_LATE_UP.V1_UP
# cat 73, mi = 0.00203216, HOXA9_DN.V1_DN
#
# RESULTS
# Passed: cat 102, mi = 0.004, pvalue = 0.000, KRAS.LUNG.BREAST_UP.V1_UP
# Passed: cat 26, mi = 0.004, pvalue = 0.000, CAHOY_NEURONAL
# Passed: cat 127, mi = 0.003, pvalue = 0.000, P53_DN.V1_UP
# Passed: cat 78, mi = 0.003, pvalue = 0.000, IL21_UP.V1_UP
# Passed: cat 167, mi = 0.003, pvalue = 0.000, SNF5_DN.V1_DN
# Passed: cat 48, mi = 0.002, pvalue = 0.000, E2F1_UP.V1_UP
# Passed: cat 38, mi = 0.002, pvalue = 0.000, CSR_LATE_UP.V1_UP
# Passed: cat 73, mi = 0.002, pvalue = 0.000, HOXA9_DN.V1_DN
# Passed: cat 11, mi = 0.002, pvalue = 0.000, ATM_DN.V1_UP
# Passed: cat 82, mi = 0.002, pvalue = 0.000, JAK2_DN.V1_UP
# Passed: cat 105, mi = 0.002, pvalue = 0.000, KRAS.PROSTATE_UP.V1_DN
# Passed: cat 166, mi = 0.002, pvalue = 0.001, SIRNA_EIF4GI_UP
# Passed: cat 137, mi = 0.002, pvalue = 0.001, PKCA_DN.V1_UP
# Passed: cat 164, mi = 0.002, pvalue = 0.001, SINGH_KRAS_DEPENDENCY_SIGNATURE_
# Passed: cat 58, mi = 0.002, pvalue = 0.001, ESC_J1_UP_EARLY.V1_UP
# Passed: cat 186, mi = 0.002, pvalue = 0.001, WNT_UP.V1_UP
# Passed: cat 169, mi = 0.002, pvalue = 0.002, SRC_UP.V1_DN
# Passed: cat 3, mi = 0.002, pvalue = 0.002, AKT_UP_MTOR_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 79, mi = 0.001, pvalue = 0.008, IL2_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 115, mi = 0.001, pvalue = 0.008, MTOR_UP.N4.V1_DN
# Didn't pass (cutoff=0.0050): cat 69, mi = 0.001, pvalue = 0.059, GLI1_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 54, mi = 0.001, pvalue = 0.043, EIF4E_UP
# Didn't pass (cutoff=0.0050): cat 141, mi = 0.001, pvalue = 0.044, PRC2_EED_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 12, mi = 0.001, pvalue = 0.065, BCAT.100_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 133, mi = 0.001, pvalue = 0.093, PDGF_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 158, mi = 0.000, pvalue = 0.571, RB_P130_DN.V1_DN
# Didn't pass: cat 89, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_DN
# Didn't pass: cat 90, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_UP
# Didn't pass: cat 91, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_DN
# Didn't pass: cat 92, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_UP
# Didn't pass: cat 121, mi = 0.000, pvalue = 1.000, NFE2L2.V2
# Didn't pass: cat 171, mi = 0.000, pvalue = 1.000, STK33_DN
# Didn't pass: cat 172, mi = 0.000, pvalue = 1.000, STK33_NOMO_DN
# Didn't pass: cat 173, mi = 0.000, pvalue = 1.000, STK33_NOMO_UP
# Didn't pass: cat 174, mi = 0.000, pvalue = 1.000, STK33_SKM_DN
# Didn't pass: cat 175, mi = 0.000, pvalue = 1.000, STK33_SKM_UP
# Didn't pass: cat 176, mi = 0.000, pvalue = 1.000, STK33_UP
# Didn't pass: cat 177, mi = 0.000, pvalue = 1.000, TBK1.DF_DN
# Total number of categories evaluated = 178.
# Number of categories that passed the tests = 18
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 1, 0.0349387060966658
# best merge is 0, 2, 0.0521366426977247
# best merge is 5, 6, 0.0775857372534496
# best merge is 4, 10, 0.0925645282055061
# best merge is 0, 13, 0.103656216135144
# best merge is 3, 12, 0.138729914195406
# best merge is 0, 4, 0.159801646800685
# best merge is 15, 16, 0.167221455073516
# best merge is 0, 8, 0.172535220054668
# best merge is 9, 15, 0.195561000277211
# best merge is 0, 3, 0.207081833896088
# best merge is 14, 17, 0.207600065947134
# best merge is 5, 7, 0.262074904998062
# best merge is 0, 9, 0.298012688626501
# order classes
# 9 - 0.291073839584058
# 3 - 0.802314062999431
# 3 - 0.744457940837251
# 2 - 0.934200296762104
# 0 1 2 13 4 10 8 3 12
# 5 6 7
# 9 15 16
# 11
# 14 17
# Done.Start drawing
# 101.03	0.00
# E2F1_UP.V1_UP
# CSR_LATE_UP.V1_UP
# HOXA9_DN.V1_DN
# SRC_UP.V1_DN
# SIRNA_EIF4GI_UP
# KRAS.LUNG.BREAST_UP.V1_UP
# CAHOY_NEURONAL
# P53_DN.V1_UP
# SINGH_KRAS_DEPENDENCY_SIGNATURE_
# SNF5_DN.V1_DN
# KRAS.PROSTATE_UP.V1_DN
# ATM_DN.V1_UP
# IL21_UP.V1_UP
# PKCA_DN.V1_UP
# JAK2_DN.V1_UP
# WNT_UP.V1_UP
# ESC_J1_UP_EARLY.V1_UP
# AKT_UP_MTOR_DN.V1_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv_PAGE/filt_FC_LVM2_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv_PAGE/filt_FC_LVM2_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 1, 0.0349387060966658
# best merge is 0, 2, 0.0521366426977247
# best merge is 5, 6, 0.0775857372534496
# best merge is 4, 10, 0.0925645282055061
# best merge is 0, 13, 0.103656216135144
# best merge is 3, 12, 0.138729914195406
# best merge is 0, 4, 0.159801646800685
# best merge is 15, 16, 0.167221455073516
# best merge is 0, 8, 0.172535220054668
# best merge is 9, 15, 0.195561000277211
# best merge is 0, 3, 0.207081833896088
# best merge is 14, 17, 0.207600065947134
# best merge is 5, 7, 0.262074904998062
# best merge is 0, 9, 0.298012688626501
# order classes
# 9 - 0.291073839584058
# 3 - 0.802314062999431
# 3 - 0.744457940837251
# 2 - 0.934200296762104
# 0 1 2 13 4 10 8 3 12
# 5 6 7
# 9 15 16
# 11
# 14 17
# Done.-19.8544986637632	42	0
# -19.6570325645848	42	0.291002672473523
# -19.5759675343957	42	0.394932198356924
# -19.5219241809364	42	0.453132732851628
# -19.4720380085123	42	0.503018905275661
# -19.417994655053	42	0.552905077699693
# -19.3514797584876	42	0.611105612194398
# -19.2454716420865	42	0.685934870830446
# 1.41156092249827	42	0.823121844996536
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_2.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_4.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_LVM2_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 30, mi = 0.00364248, CORDENONSI_YAP_CONSERVED_SIGNATURE
# cat 102, mi = 0.00331661, KRAS.LUNG.BREAST_UP.V1_UP
# cat 96, mi = 0.00326663, KRAS.BREAST_UP.V1_UP
# cat 183, mi = 0.00298534, VEGF_A_UP.V1_DN
# cat 120, mi = 0.00297453, MYC_UP.V1_UP
# cat 26, mi = 0.00288842, CAHOY_NEURONAL
# cat 86, mi = 0.00282530, KRAS.300_UP.V1_UP
# cat 108, mi = 0.00271769, LEF1_UP.V1_UP
# cat 104, mi = 0.00253566, KRAS.LUNG_UP.V1_UP
# cat 21, mi = 0.00246810, BMI1_DN_MEL18_DN.V1_UP
# cat 50, mi = 0.00241584, E2F3_UP.V1_UP
# cat 64, mi = 0.00223017, ESC_V6.5_UP_LATE.V1_UP
# cat 127, mi = 0.00222430, P53_DN.V1_UP
# ...
# RB_P107_DN.V1_UP
# P53_DN.V2_DN
# CAMP_UP.V1_UP
# MYC_UP.V1_UP
# IL21_UP.V1_UP
# KRAS.300_UP.V1_DN
# CAHOY_NEURONAL
# KRAS.BREAST_UP.V1_UP
# PKCA_DN.V1_UP
# IL15_UP.V1_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_2.csv_PAGE/filt_FC_P_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_2.csv_PAGE/filt_FC_P_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 6, 10, 0.02350654023237
# best merge is 4, 8, 0.085581919848409
# best merge is 3, 6, 0.13722207559154
# best merge is 5, 7, 0.144531904797778
# best merge is 1, 2, 0.145733683916453
# best merge is 1, 3, 0.204360616960497
# best merge is 1, 9, 0.270461707412182
# best merge is 5, 12, 0.326339736841585
# best merge is 0, 1, 0.461587821027129
# order classes
# 6 - 0.363778110963198
# 2 - 0.278141239507329
# 3 - 0.7676850311298
# 4 8
# 1 2 3 6 10 9
# 0
# 5 7 12
# 11
# Done.-16.8638941398866	42	0
# -13.2117202268431	42	6.27221172022684
# -12.3780718336484	42	7.30434782608696
# -11.8223062381853	42	7.93950850661626
# -11.3856332703214	42	8.41587901701323
# -10.9092627599244	42	8.81285444234405
# -10.3137996219282	42	9.36862003780718
# -9.44045368620038	42	10.0037807183365
# 6.55765595463138	42	11.1153119092628
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv --species=human_ensembl_msigdb_c6 --exptype=continuous --ebins=9
# done
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 157, mi = 0.00922043, RB_P107_DN.V1_UP
# cat 38, mi = 0.00769883, CSR_LATE_UP.V1_UP
# cat 143, mi = 0.00540645, PRC2_EZH2_UP.V1_UP
# cat 48, mi = 0.00471631, E2F1_UP.V1_UP
# cat 162, mi = 0.00378741, RPS14_DN.V1_DN
# cat 50, mi = 0.00312479, E2F3_UP.V1_UP
# cat 107, mi = 0.00291154, LEF1_UP.V1_DN
# cat 68, mi = 0.00286331, GCNP_SHH_UP_LATE.V1_UP
# cat 147, mi = 0.00282915, PTEN_DN.V1_UP
# cat 79, mi = 0.00273443, IL2_UP.V1_DN
# cat 163, mi = 0.00272555, RPS14_DN.V1_UP
# cat 102, mi = 0.00250388, KRAS.LUNG.BREAST_UP.V1_UP
# cat 140, mi = 0.00232518, PRC2_EED_UP.V1_DN
# cat 115, mi = 0.00229306, MTOR_UP.N4.V1_DN
# cat 98, mi = 0.00228434, KRAS.DF.V1_UP
#
# RESULTS
# Passed: cat 157, mi = 0.009, pvalue = 0.000, RB_P107_DN.V1_UP
# Passed: cat 38, mi = 0.008, pvalue = 0.000, CSR_LATE_UP.V1_UP
# Passed: cat 143, mi = 0.005, pvalue = 0.000, PRC2_EZH2_UP.V1_UP
# Passed: cat 107, mi = 0.003, pvalue = 0.000, LEF1_UP.V1_DN
# Passed: cat 147, mi = 0.003, pvalue = 0.000, PTEN_DN.V1_UP
# Passed: cat 79, mi = 0.003, pvalue = 0.000, IL2_UP.V1_DN
# Passed: cat 163, mi = 0.003, pvalue = 0.000, RPS14_DN.V1_UP
# Passed: cat 160, mi = 0.002, pvalue = 0.000, RELA_DN.V1_DN
# Passed: cat 58, mi = 0.002, pvalue = 0.001, ESC_J1_UP_EARLY.V1_UP
# Passed: cat 78, mi = 0.002, pvalue = 0.001, IL21_UP.V1_UP
# Passed: cat 135, mi = 0.002, pvalue = 0.001, PIGF_UP.V1_UP
# Passed: cat 105, mi = 0.001, pvalue = 0.002, KRAS.PROSTATE_UP.V1_DN
# Passed: cat 49, mi = 0.001, pvalue = 0.003, E2F3_UP.V1_DN
# Passed: cat 170, mi = 0.001, pvalue = 0.004, SRC_UP.V1_UP
# Passed: cat 0, mi = 0.001, pvalue = 0.004, AKT_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 158, mi = 0.001, pvalue = 0.018, RB_P130_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 179, mi = 0.001, pvalue = 0.023, TBK1.DN.48HRS_DN
# Didn't pass (cutoff=0.0050): cat 166, mi = 0.001, pvalue = 0.029, SIRNA_EIF4GI_UP
# Didn't pass (cutoff=0.0050): cat 129, mi = 0.001, pvalue = 0.044, P53_DN.V2_UP
# Didn't pass (cutoff=0.0050): cat 54, mi = 0.001, pvalue = 0.037, EIF4E_UP
# Didn't pass (cutoff=0.0050): cat 133, mi = 0.001, pvalue = 0.042, PDGF_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 33, mi = 0.001, pvalue = 0.140, CRX_NRL_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 131, mi = 0.001, pvalue = 0.180, PDGF_ERK_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 69, mi = 0.001, pvalue = 0.376, GLI1_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 24, mi = 0.001, pvalue = 0.318, CAHOY_ASTROCYTIC
# Didn't pass: cat 89, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_DN
# Didn't pass: cat 90, mi = 0.000, pvalue = 1.000, KRAS.600.LUNG.BREAST_UP.V1_UP
# Didn't pass: cat 91, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_DN
# Didn't pass: cat 92, mi = 0.000, pvalue = 1.000, KRAS.600_UP.V1_UP
# Didn't pass: cat 121, mi = 0.000, pvalue = 1.000, NFE2L2.V2
# Didn't pass: cat 171, mi = 0.000, pvalue = 1.000, STK33_DN
# Didn't pass: cat 172, mi = 0.000, pvalue = 1.000, STK33_NOMO_DN
# Didn't pass: cat 173, mi = 0.000, pvalue = 1.000, STK33_NOMO_UP
# Didn't pass: cat 174, mi = 0.000, pvalue = 1.000, STK33_SKM_DN
# Didn't pass: cat 175, mi = 0.000, pvalue = 1.000, STK33_SKM_UP
# Total number of categories evaluated = 176.
# Number of categories that passed the tests = 15
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 2, 0.0157568761596892
# best merge is 4, 5, 0.0188192529139801
# best merge is 0, 1, 0.0242016979313675
# best merge is 3, 7, 0.0763885796266458
# best merge is 3, 4, 0.103605302912938
# best merge is 3, 9, 0.178714621839014
# best merge is 6, 8, 0.250088956374544
# best merge is 3, 11, 0.33546559143648
# best merge is 6, 14, 0.423702106849584
# best merge is 3, 12, 0.502342680620733
# best merge is 0, 13, 0.613075624255809
# order classes
# 3 - 0.0712891911360269
# 7 - 0.517423169602498
# 3 - 1.21943685563746
# 0 2 1
# 3 7 4 5 9 11 12
# 6 8 14
# 10
# 13
# Done.Start drawing
# 11.42	0.00
# LEF1_UP.V1_DN
# RELA_DN.V1_DN
# PTEN_DN.V1_UP
# IL2_UP.V1_DN
# IL21_UP.V1_UP
# KRAS.PROSTATE_UP.V1_DN
# E2F3_UP.V1_DN
# RPS14_DN.V1_UP
# ESC_J1_UP_EARLY.V1_UP
# AKT_UP.V1_DN
# PIGF_UP.V1_UP
# SRC_UP.V1_UP
# RB_P107_DN.V1_UP
# PRC2_EZH2_UP.V1_UP
# CSR_LATE_UP.V1_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 2, 0.0157568761596892
# best merge is 4, 5, 0.0188192529139801
# best merge is 0, 1, 0.0242016979313675
# best merge is 3, 7, 0.0763885796266458
# best merge is 3, 4, 0.103605302912938
# best merge is 3, 9, 0.178714621839014
# best merge is 6, 8, 0.250088956374544
# best merge is 3, 11, 0.33546559143648
# best merge is 6, 14, 0.423702106849584
# best merge is 3, 12, 0.502342680620733
# best merge is 0, 13, 0.613075624255809
# order classes
# 3 - 0.0712891911360269
# 7 - 0.517423169602498
# 3 - 1.21943685563746
# 0 2 1
# 3 7 4 5 9 11 12
# 6 8 14
# 10
# 13
# Done.-19.1725043782837	42	0
# -18.1059544658494	42	1.65499124343257
# -17.7381786339755	42	2.13309982486865
# -17.4807355516637	42	2.39054290718039
# -17.223292469352	42	2.64798598949212
# -16.9658493870403	42	2.90542907180385
# -16.6348511383538	42	3.16287215411559
# -16.0831873905429	42	3.56742556917688
# 3.13309982486865	42	4.2661996497373
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_c6.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_c6/human_ensembl_msigdb_c6.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	189
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 189
# cat 140, mi = 0.00238057, PRC2_EED_UP.V1_DN
# cat 138, mi = 0.00222673, PRC1_BMI_UP.V1_DN
# cat 107, mi = 0.00198468, LEF1_UP.V1_DN
# cat 4, mi = 0.00192033, ALK_DN.V1_DN
# cat 83, mi = 0.00187589, JNK_DN.V1_DN
# cat 166, mi = 0.00176551, SIRNA_EIF4GI_UP
# cat 40, mi = 0.00157932, CTIP_DN.V1_UP
# cat 79, mi = 0.00154878, IL2_UP.V1_DN
# cat 75, mi = 0.00150931, IL15_UP.V1_DN
# cat 94, mi = 0.00147818, KRAS.AMP.LUNG_UP.V1_UP
# cat 50, mi = 0.00145380, E2F3_UP.V1_UP
# cat 184, mi = 0.00141693, VEGF_A_UP.V1_UP
# cat 169, mi = 0.00132585, SRC_UP.V1_DN
# cat 139, mi = 0.00131249, PRC1_BMI_UP.V1_UP
# cat 78, mi = 0.00128816, IL21_UP.V1_UP
#
# RESULTS
# Passed: cat 140, mi = 0.002, pvalue = 0.000, PRC2_EED_UP.V1_DN
# Passed: cat 138, mi = 0.002, pvalue = 0.000, PRC1_BMI_UP.V1_DN
# Passed: cat 107, mi = 0.002, pvalue = 0.000, LEF1_UP.V1_DN
# Passed: cat 166, mi = 0.002, pvalue = 0.000, SIRNA_EIF4GI_UP
# Passed: cat 40, mi = 0.002, pvalue = 0.002, CTIP_DN.V1_UP
# Passed: cat 75, mi = 0.002, pvalue = 0.001, IL15_UP.V1_DN
# Passed: cat 94, mi = 0.001, pvalue = 0.003, KRAS.AMP.LUNG_UP.V1_UP
# Passed: cat 50, mi = 0.001, pvalue = 0.003, E2F3_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 169, mi = 0.001, pvalue = 0.006, SRC_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 156, mi = 0.001, pvalue = 0.009, RB_P107_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 38, mi = 0.001, pvalue = 0.008, CSR_LATE_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 82, mi = 0.001, pvalue = 0.015, JAK2_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 137, mi = 0.001, pvalue = 0.023, PKCA_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 85, mi = 0.001, pvalue = 0.082, KRAS.300_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 187, mi = 0.001, pvalue = 0.125, YAP1_DN
# Didn't pass (cutoff=0.0050): cat 32, mi = 0.001, pvalue = 0.090, CRX_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 54, mi = 0.001, pvalue = 0.142, EIF4E_UP
# Didn't pass (cutoff=0.0050): cat 25, mi = 0.001, pvalue = 0.196, CAHOY_ASTROGLIAL
# Didn't pass (cutoff=0.0050): cat 164, mi = 0.001, pvalue = 0.353, SINGH_KRAS_DEPENDENCY_SIGNATURE_
# Didn't pass (cutoff=0.0050): cat 34, mi = 0.001, pvalue = 0.246, CRX_NRL_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 97, mi = 0.001, pvalue = 0.238, KRAS.DF.V1_DN
# Didn't pass (cutoff=0.0050): cat 42, mi = 0.001, pvalue = 0.241, CYCLIN_D1_KE_.V1_UP
# Didn't pass (cutoff=0.0050): cat 131, mi = 0.001, pvalue = 0.255, PDGF_ERK_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 168, mi = 0.001, pvalue = 0.261, SNF5_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 24, mi = 0.001, pvalue = 0.302, CAHOY_ASTROCYTIC
# Didn't pass (cutoff=0.0050): cat 124, mi = 0.001, pvalue = 0.314, NRL_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 122, mi = 0.001, pvalue = 0.338, NOTCH_DN.V1_DN
# Didn't pass (cutoff=0.0050): cat 44, mi = 0.001, pvalue = 0.345, CYCLIN_D1_UP.V1_UP
# Total number of categories evaluated = 94.
# Number of categories that passed the tests = 8
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 1, 2, 0.0857699009251283
# best merge is 5, 7, 0.230379445544389
# best merge is 1, 4, 0.249100422811788
# best merge is 0, 5, 0.320340787737368
# order classes
# 3 - 0.346056738695528
# 2 - 0.460758891088777
# 1 2 4
# 0
# 3
# 5 7
# 6
# Done.Start drawing
# 110.21	0.00
# SIRNA_EIF4GI_UP
# E2F3_UP.V1_UP
# PRC2_EED_UP.V1_DN
# IL15_UP.V1_DN
# PRC1_BMI_UP.V1_DN
# KRAS.AMP.LUNG_UP.V1_UP
# LEF1_UP.V1_DN
# CTIP_DN.V1_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 1, 2, 0.0857699009251283
# best merge is 5, 7, 0.230379445544389
# best merge is 1, 4, 0.249100422811788
# best merge is 0, 5, 0.320340787737368
# order classes
# 3 - 0.346056738695528
# 2 - 0.460758891088777
# 1 2 4
# 0
# 3
# 5 7
# 6
# Done.-19.9980945467743	42	0
# -19.9923781870974	42	0.00381090645132021
# -19.9847563741947	42	0.0114327193539606
# -19.9790400145177	42	0.019054532256601
# -19.9733236548408	42	0.0228654387079212
# -19.9676072951638	42	0.0304872516105617
# -19.8361310225932	42	0.0342981580618819
# -19.4912439887488	42	0.293439796751656
# 1.36203611287542	42	0.724072225750839
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_c6/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# sem --wait done
