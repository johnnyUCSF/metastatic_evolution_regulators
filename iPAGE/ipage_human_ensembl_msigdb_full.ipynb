# %% [markdown]
# # This is used for running data vs human_msigdb_full annotations located in:
# ### /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_full

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import scipy.stats

# %% [markdown]
# ### get index of file names to loop through

# %%
# %%bash
#
# cd fc_values
# ls FC* > filelist.txt
# cd ..

# %% [markdown]
# ### get ensembl genes represented in iPAGE database

# %%
# %%bash
#
# cp /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_full/human_ensembl_msigdb_full_index.txt human_ensembl_index.txt
# awk '{print $1}' human_ensembl_index.txt > ensembl_index.txt

# %% [markdown]
# ### make sure that genes in file match the index

# %%
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
###################REMEMBER TO SPECIFY INDEX USED IN THE IPAGE COMMAND!!!!!!!!
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#####################
#######read in data from logfc calculations
#####################
####define index file to loop through
index_file = "fc_values/filelist.txt"
####define matching ensg index
GO_index_filename = "ensembl_index.txt"
genes_with_GOs = []
with open(GO_index_filename,'r') as rf:
    for line in rf:
        gene_name = line.split('\n')[0]
        genes_with_GOs.append(gene_name)
genes_with_GOs_set = set(genes_with_GOs)
####open file and loop through each line
###
iPAGE_sh = "iPAGE_JY.sh"
cwd = os.getcwd()+"/"
os.system("rm "+iPAGE_sh)
###
with open(index_file,'r') as rf:
    for line in rf:
        #####do this to each file
        ###read in file into pandas df
        FC_file = "fc_values/"+line.split('\n')[0]
        FC_df = pd.read_csv(FC_file,sep=',',index_col=0)
        FC_df.columns = ['log2FoldChange']
        FC_df.index.names = ['Gene']
        ###filter
        FC_df = FC_df.loc[[x for x in FC_df.index if x in genes_with_GOs_set]]
        ###save
        save_file = "fc_values/filt_"+line.split('\n')[0]
        FC_df.to_csv(save_file,sep='\t',header=True)
        ###write final iPAGE command to an ipage .sh file
        iPAGE_cmd = "perl /nvme/bins/iPAGEv1.0/page.pl --expfile "+cwd+save_file+" --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9 \n"
        with open(iPAGE_sh, "a") as myfile:
            myfile.write(iPAGE_cmd)

# %% [markdown]
# ## then run the command from this folder:
#
# nohup sh run.sh iPAGE_JY.sh &

# %%
# %%bash
#
# nohup sh run.sh iPAGE_JY.sh &
# Out:
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_2.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_3.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_4.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_full.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_full/human_ensembl_msigdb_full.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 17786
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	17786
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 17786
# cat 14627, mi = 0.01125916, MORF_NPM1
# cat 14520, mi = 0.00973429, MORF_ACTG1
# cat 1375, mi = 0.00961121, FISCHER_G1_S_CELL_CYCLE
# cat 15897, mi = 0.00958123, REACTOME_PEPTIDE_CHAIN_ELONGATION
# cat 15480, mi = 0.00952008, REACTOME_3_UTR_MEDIATED_TRANSLATIONAL_REGULATION
# cat 16126, mi = 0.00924229, REACTOME_TRANSLATION
# cat 13373, mi = 0.00912335, KEGG_RIBOSOME
# cat 7604, mi = 0.00908166, GO_TRANSLATIONAL_INITIATION
# cat 14625, mi = 0.00880374, MORF_NME2
# cat 1759, mi = 0.00879342, GNF2_EIF3S6
# cat 14700, mi = 0.00820652, MORF_TPT1
# cat 16072, mi = 0.00808522, REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANE
# cat 2843, mi = 0.00768792, GO_CYTOSOLIC_RIBOSOME
# cat 1629, mi = 0.00765990, GCM_TPT1
# cat 3178, mi = 0.00753814, GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
#
# RESULTS
# Passed: cat 14627, mi = 0.011, pvalue = 0.000, MORF_NPM1
# Passed: cat 1375, mi = 0.010, pvalue = 0.000, FISCHER_G1_S_CELL_CYCLE
# Passed: cat 13340, mi = 0.006, pvalue = 0.000, KEGG_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 14659, mi = 0.004, pvalue = 0.000, MORF_RAB1A
# Passed: cat 7385, mi = 0.004, pvalue = 0.000, GO_SPLICEOSOMAL_COMPLEX
# Passed: cat 105, mi = 0.004, pvalue = 0.000, AIGNER_ZEB1_TARGETS
# Passed: cat 17506, mi = 0.004, pvalue = 0.000, chr13q14
# Passed: cat 4110, mi = 0.004, pvalue = 0.000, GO_MITOCHONDRIAL_TRANSLATION
# Passed: cat 14246, mi = 0.004, pvalue = 0.000, MODULE_297
# Passed: cat 17504, mi = 0.003, pvalue = 0.000, chr13q12
# Passed: cat 3556, mi = 0.003, pvalue = 0.000, GO_HORMONE_ACTIVITY
# Passed: cat 17555, mi = 0.003, pvalue = 0.000, chr17q25
# Passed: cat 1595, mi = 0.003, pvalue = 0.000, GCM_MLL
# Passed: cat 13149, mi = 0.003, pvalue = 0.000, JOHNSTONE_PARVB_TARGETS_1_DN
# Passed: cat 11731, mi = 0.003, pvalue = 0.000, GSE411_100MIN_VS_400MIN_IL6_STIM_MACROPHAGE_DN
# Passed: cat 14955, mi = 0.003, pvalue = 0.000, NRSF_01
# Passed: cat 16014, mi = 0.003, pvalue = 0.000, REACTOME_SCFSKP2_MEDIATED_DEGRADATION_OF_P27_P21
# Passed: cat 9731, mi = 0.003, pvalue = 0.000, GSE22886_IGM_MEMORY_BCELL_VS_BLOOD_PLASMA_CELL_DN
# Passed: cat 17510, mi = 0.003, pvalue = 0.000, chr13q32
# Passed: cat 17512, mi = 0.003, pvalue = 0.000, chr13q34
# Passed: cat 9012, mi = 0.003, pvalue = 0.000, GSE17721_POLYIC_VS_PAM3CSK4_1H_BMDC_UP
# Passed: cat 16979, mi = 0.003, pvalue = 0.000, VECCHI_GASTRIC_CANCER_ADVANCED_VS_EARLY_UP
# Passed: cat 10378, mi = 0.002, pvalue = 0.000, GSE27786_BCELL_VS_MONO_MAC_UP
# Passed: cat 17769, mi = 0.002, pvalue = 0.000, chrxp11
# Passed: cat 1141, mi = 0.002, pvalue = 0.000, DCA_UP.V1_UP
# Passed: cat 12395, mi = 0.002, pvalue = 0.000, GSE7218_IGM_VS_IGG_SIGNAL_THGOUGH_ANTIGEN_BCELL_DN
# Passed: cat 8418, mi = 0.002, pvalue = 0.000, GSE14908_ATOPIC_VS_NONATOPIC_PATIENT_HDM_STIM_CD4_TCELL_UP
# Passed: cat 13505, mi = 0.002, pvalue = 0.000, KRAS.BREAST_UP.V1_UP
# Passed: cat 9236, mi = 0.002, pvalue = 0.000, GSE19825_NAIVE_VS_DAY3_EFF_CD8_TCELL_UP
# Passed: cat 16171, mi = 0.002, pvalue = 0.000, RICKMAN_HEAD_AND_NECK_CANCER_A
# Passed: cat 767, mi = 0.002, pvalue = 0.000, CAHOY_NEURONAL
# Passed: cat 850, mi = 0.002, pvalue = 0.000, CERVERA_SDHB_TARGETS_1_UP
# Passed: cat 11387, mi = 0.002, pvalue = 0.000, GSE3920_UNTREATED_VS_IFNG_TREATED_ENDOTHELIAL_CELL_DN
# Passed: cat 12634, mi = 0.002, pvalue = 0.000, GSE9509_10MIN_VS_30MIN_LPS_STIM_IL10_KO_MACROPHAGE_UP
# Passed: cat 8521, mi = 0.002, pvalue = 0.000, GSE15750_WT_VS_TRAF6KO_DAY10_EFF_CD8_TCELL_DN
# Passed: cat 4959, mi = 0.002, pvalue = 0.000, GO_OUTER_MEMBRANE
# Passed: cat 2422, mi = 0.002, pvalue = 0.000, GO_CELLULAR_RESPONSE_TO_AMINO_ACID_STARVATION
# Passed: cat 817, mi = 0.002, pvalue = 0.000, CCAWWNAAGG_SRF_Q4
# Passed: cat 13760, mi = 0.002, pvalue = 0.000, LOPES_METHYLATED_IN_COLON_CANCER_DN
# Passed: cat 10447, mi = 0.002, pvalue = 0.000, GSE27786_NKCELL_VS_ERYTHROBLAST_DN
# Passed: cat 12583, mi = 0.002, pvalue = 0.000, GSE8921_UNSTIM_0H_VS_TLR1_2_STIM_MONOCYTE_3H_DN
# Passed: cat 12381, mi = 0.002, pvalue = 0.000, GSE6674_UNSTIM_VS_ANTI_IGM_STIM_BCELL_DN
# Passed: cat 9059, mi = 0.002, pvalue = 0.000, GSE17974_2.5H_VS_72H_IL4_AND_ANTI_IL12_ACT_CD4_TCELL_DN
# Passed: cat 10477, mi = 0.002, pvalue = 0.000, GSE28237_EARLY_VS_LATE_GC_BCELL_DN
# Passed: cat 10783, mi = 0.002, pvalue = 0.000, GSE32533_WT_VS_MIR17_KO_ACT_CD4_TCELL_DN
# Passed: cat 9701, mi = 0.002, pvalue = 0.000, GSE22611_UNSTIM_VS_2H_MDP_STIM_MUTANT_NOD2_TRANSDUCED_HEK293T_CELL_DN
# Passed: cat 17734, mi = 0.002, pvalue = 0.000, chr7q31
# Passed: cat 11681, mi = 0.002, pvalue = 0.000, GSE40666_UNTREATED_VS_IFNA_STIM_CD8_TCELL_90MIN_DN
# Passed: cat 16228, mi = 0.002, pvalue = 0.000, RORIE_TARGETS_OF_EWSR1_FLI1_FUSION_DN
# Passed: cat 13069, mi = 0.002, pvalue = 0.001, INGRAM_SHH_TARGETS_UP
# Passed: cat 1038, mi = 0.002, pvalue = 0.000, CSR_LATE_UP.V1_DN
# Passed: cat 8210, mi = 0.002, pvalue = 0.000, GSE13522_CTRL_VS_T_CRUZI_Y_STRAIN_INF_SKIN_IFNG_KO_UP
# Passed: cat 11138, mi = 0.002, pvalue = 0.000, GSE36888_UNTREATED_VS_IL2_TREATED_TCELL_2H_UP
# Passed: cat 51, mi = 0.002, pvalue = 0.000, ACCTGTTG_UNKNOWN
# Passed: cat 12297, mi = 0.002, pvalue = 0.000, GSE6090_UNSTIM_VS_DC-SIGN_STIM_DC_DN
# Passed: cat 8985, mi = 0.002, pvalue = 0.000, GSE17721_POLYIC_VS_CPG_8H_BMDC_DN
# Passed: cat 11086, mi = 0.002, pvalue = 0.000, GSE36392_TYPE_2_MYELOID_VS_MAC_IL25_TREATED_LUNG_UP
# Passed: cat 13821, mi = 0.002, pvalue = 0.000, MAHAJAN_RESPONSE_TO_IL1A_DN
# Passed: cat 13646, mi = 0.002, pvalue = 0.000, LEF1_UP.V1_DN
# Passed: cat 1591, mi = 0.002, pvalue = 0.000, GCM_MAP1B
# Passed: cat 16155, mi = 0.002, pvalue = 0.000, REICHERT_MITOSIS_LIN9_TARGETS
# Passed: cat 12751, mi = 0.002, pvalue = 0.001, GUILLAUMOND_KLF10_TARGETS_UP
# Passed: cat 13719, mi = 0.002, pvalue = 0.000, LIU_CDX2_TARGETS_UP
# Passed: cat 12540, mi = 0.002, pvalue = 0.001, GSE8515_CTRL_VS_IL6_4H_STIM_MAC_UP
# Passed: cat 8122, mi = 0.002, pvalue = 0.000, GSE13229_IMM_VS_INTMATURE_NKCELL_UP
# Passed: cat 9812, mi = 0.002, pvalue = 0.000, GSE22935_UNSTIM_VS_12H_MBOVIS_BCG_STIM_MACROPHAGE_UP
# Passed: cat 11743, mi = 0.002, pvalue = 0.000, GSE411_WT_VS_SOCS3_KO_MACROPHAGE_DN
# Passed: cat 6600, mi = 0.002, pvalue = 0.001, GO_REGULATION_OF_ORGANELLE_ASSEMBLY
# Passed: cat 15399, mi = 0.002, pvalue = 0.000, PTEN_DN.V1_DN
# Passed: cat 11078, mi = 0.002, pvalue = 0.001, GSE36392_EOSINOPHIL_VS_MAC_IL25_TREATED_LUNG_UP
# Passed: cat 17508, mi = 0.002, pvalue = 0.000, chr13q22
# Passed: cat 13343, mi = 0.002, pvalue = 0.000, KEGG_PANCREATIC_CANCER
# Passed: cat 8622, mi = 0.002, pvalue = 0.001, GSE16450_CTRL_VS_IFNA_6H_STIM_MATURE_NEURON_CELL_LINE_UP
# Passed: cat 224, mi = 0.002, pvalue = 0.001, ATGCTGG_MIR338
# Passed: cat 15814, mi = 0.002, pvalue = 0.000, REACTOME_METABOLISM_OF_POLYAMINES
# Passed: cat 10034, mi = 0.002, pvalue = 0.001, GSE24972_WT_VS_IRF8_KO_SPLEEN_FOLLICULAR_BCELL_UP
# Passed: cat 14072, mi = 0.002, pvalue = 0.001, MODULE_111
# Passed: cat 10303, mi = 0.002, pvalue = 0.001, GSE2770_IL12_VS_IL4_TREATED_ACT_CD4_TCELL_6H_DN
# Passed: cat 950, mi = 0.002, pvalue = 0.001, CHOI_ATL_STAGE_PREDICTOR
# Passed: cat 9532, mi = 0.002, pvalue = 0.001, GSE21670_UNTREATED_VS_TGFB_TREATED_CD4_TCELL_UP
# Passed: cat 16416, mi = 0.002, pvalue = 0.002, SENGUPTA_NASOPHARYNGEAL_CARCINOMA_WITH_LMP1_DN
# Passed: cat 6909, mi = 0.002, pvalue = 0.001, GO_REPRESSING_TRANSCRIPTION_FACTOR_BINDING
# Passed: cat 17731, mi = 0.002, pvalue = 0.001, chr7q11
# Passed: cat 7152, mi = 0.002, pvalue = 0.001, GO_RNA_MODIFICATION
# Passed: cat 9526, mi = 0.002, pvalue = 0.001, GSE21670_UNTREATED_VS_IL6_TREATED_STAT3_KO_CD4_TCELL_UP
# Passed: cat 16716, mi = 0.002, pvalue = 0.002, TAVAZOIE_METASTASIS
# Passed: cat 2889, mi = 0.002, pvalue = 0.003, GO_DETECTION_OF_ABIOTIC_STIMULUS
# Passed: cat 11435, mi = 0.002, pvalue = 0.002, GSE3982_BCELL_VS_CENT_MEMORY_CD4_TCELL_DN
# Passed: cat 849, mi = 0.002, pvalue = 0.001, CERVERA_SDHB_TARGETS_1_DN
# Passed: cat 12213, mi = 0.002, pvalue = 0.001, GSE557_CIITA_KO_VS_I_AB_KO_DC_DN
# Passed: cat 11169, mi = 0.001, pvalue = 0.003, GSE3720_LPS_VS_PMA_STIM_VD2_GAMMADELTA_TCELL_DN
# Passed: cat 16513, mi = 0.001, pvalue = 0.003, SMID_BREAST_CANCER_RELAPSE_IN_BRAIN_DN
# Passed: cat 2578, mi = 0.001, pvalue = 0.002, GO_CELL_RECOGNITION
# Passed: cat 13570, mi = 0.001, pvalue = 0.004, KYNG_WERNER_SYNDROM_AND_NORMAL_AGING_UP
# Passed: cat 15818, mi = 0.001, pvalue = 0.001, REACTOME_METABOLISM_OF_STEROID_HORMONES_AND_VITAMINS_A_AND_D
# Passed: cat 15278, mi = 0.001, pvalue = 0.004, PID_P38_ALPHA_BETA_DOWNSTREAM_PATHWAY
# Passed: cat 9005, mi = 0.001, pvalue = 0.003, GSE17721_POLYIC_VS_PAM3CSK4_0.5H_BMDC_DN
# Passed: cat 9682, mi = 0.001, pvalue = 0.004, GSE22601_IMMATURE_CD4_SINGLE_POSITIVE_VS_CD4_SINGLE_POSITIVE_THYMOCYTE_UP
# Passed: cat 8595, mi = 0.001, pvalue = 0.003, GSE16385_ROSIGLITAZONE_IL4_VS_IFNG_TNF_STIM_MACROPHAGE_DN
# Passed: cat 10344, mi = 0.001, pvalue = 0.003, GSE2770_UNTREATED_VS_ACT_CD4_TCELL_48H_UP
# Passed: cat 5257, mi = 0.001, pvalue = 0.004, GO_POSITIVE_REGULATION_OF_ATPASE_ACTIVITY
# Passed: cat 12673, mi = 0.001, pvalue = 0.004, GSE9946_MATURE_STIMULATORY_VS_PROSTAGLANDINE2_TREATED_MATURE_DC_DN
# Passed: cat 16418, mi = 0.001, pvalue = 0.004, SERVITJA_ISLET_HNF1A_TARGETS_DN
# Passed: cat 16921, mi = 0.001, pvalue = 0.004, URS_ADIPOCYTE_DIFFERENTIATION_UP
# Passed: cat 15094, mi = 0.001, pvalue = 0.003, PDGF_ERK_DN.V1_DN
# Passed: cat 1903, mi = 0.001, pvalue = 0.004, GO_ACETYLTRANSFERASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 17539, mi = 0.001, pvalue = 0.007, chr16q12
# Didn't pass (cutoff=0.0050): cat 13421, mi = 0.001, pvalue = 0.005, KIM_BIPOLAR_DISORDER_OLIGODENDROCYTE_DENSITY_CORR_DN
# Didn't pass (cutoff=0.0050): cat 631, mi = 0.001, pvalue = 0.006, BOYLAN_MULTIPLE_MYELOMA_PCA3_DN
# Passed: cat 720, mi = 0.001, pvalue = 0.003, BYSTRYKH_HEMATOPOIESIS_STEM_CELL_AND_BRAIN_QTL_TRANS
# Didn't pass (cutoff=0.0050): cat 15771, mi = 0.001, pvalue = 0.006, REACTOME_INTEGRIN_ALPHAIIB_BETA3_SIGNALING
# Didn't pass (cutoff=0.0050): cat 15919, mi = 0.001, pvalue = 0.006, REACTOME_PLATELET_AGGREGATION_PLUG_FORMATION
# Didn't pass (cutoff=0.0050): cat 15904, mi = 0.001, pvalue = 0.010, REACTOME_PHOSPHOLIPASE_C_MEDIATED_CASCADE
# Didn't pass (cutoff=0.0050): cat 13635, mi = 0.001, pvalue = 0.008, LEE_METASTASIS_AND_ALTERNATIVE_SPLICING_UP
# Passed: cat 15554, mi = 0.001, pvalue = 0.001, REACTOME_BASE_FREE_SUGAR_PHOSPHATE_REMOVAL_VIA_THE_SINGLE_NUCLEOTIDE_REPLACEMENT_PATHWAY
# Didn't pass (cutoff=0.0050): cat 7937, mi = 0.001, pvalue = 0.007, GSE11057_EFF_MEM_VS_CENT_MEM_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 7836, mi = 0.001, pvalue = 0.007, GRATIAS_RETINOBLASTOMA_16Q24
# Didn't pass (cutoff=0.0050): cat 14949, mi = 0.001, pvalue = 0.008, NOUZOVA_TRETINOIN_AND_H4_ACETYLATION
# Passed: cat 5053, mi = 0.001, pvalue = 0.004, GO_PEPTIDYL_PROLINE_HYDROXYLATION
# Didn't pass (cutoff=0.0050): cat 17410, mi = 0.001, pvalue = 0.012, ZHENG_IL22_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 16666, mi = 0.001, pvalue = 0.011, SWEET_KRAS_TARGETS_DN
# Didn't pass (cutoff=0.0050): cat 10197, mi = 0.001, pvalue = 0.008, GSE26559_TCF1_KO_VS_WT_LIN_NEG_CELL_DN
# Passed: cat 17511, mi = 0.001, pvalue = 0.002, chr13q33
# Didn't pass (cutoff=0.0050): cat 12675, mi = 0.001, pvalue = 0.010, GSE9960_GRAM_NEG_VS_GRAM_NEG_AND_POS_SEPSIS_PBMC_DN
# Didn't pass (cutoff=0.0050): cat 1671, mi = 0.001, pvalue = 0.014, GGARNTKYCCA_UNKNOWN
# Didn't pass (cutoff=0.0050): cat 7787, mi = 0.001, pvalue = 0.012, GO_WNT_PROTEIN_BINDING
# Didn't pass (cutoff=0.0050): cat 15174, mi = 0.001, pvalue = 0.018, PID_BMP_PATHWAY
# Didn't pass (cutoff=0.0050): cat 1638, mi = 0.001, pvalue = 0.012, GCTCTTG_MIR335
# Didn't pass (cutoff=0.0050): cat 10902, mi = 0.001, pvalue = 0.012, GSE34156_UNTREATED_VS_24H_TLR1_TLR2_LIGAND_TREATED_MONOCYTE_UP
# Didn't pass (cutoff=0.0050): cat 5920, mi = 0.001, pvalue = 0.017, GO_PROTEIN_SERINE_THREONINE_PHOSPHATASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 2013, mi = 0.001, pvalue = 0.023, GO_ALPHA_TUBULIN_BINDING
# Didn't pass (cutoff=0.0050): cat 2852, mi = 0.001, pvalue = 0.025, GO_DEATH_RECEPTOR_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 11246, mi = 0.001, pvalue = 0.015, GSE37336_LY6C_POS_VS_NEG_NAIVE_CD4_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 17621, mi = 0.001, pvalue = 0.025, chr2q11
# Didn't pass (cutoff=0.0050): cat 9093, mi = 0.001, pvalue = 0.017, GSE17974_IL4_AND_ANTI_IL12_VS_UNTREATED_4H_ACT_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 15342, mi = 0.001, pvalue = 0.028, PID_WNT_SIGNALING_PATHWAY
# Didn't pass (cutoff=0.0050): cat 772, mi = 0.001, pvalue = 0.008, CAIRO_HEPATOBLASTOMA_POOR_SURVIVAL
# Didn't pass (cutoff=0.0050): cat 2714, mi = 0.001, pvalue = 0.025, GO_COCHLEA_MORPHOGENESIS
# Didn't pass (cutoff=0.0050): cat 17733, mi = 0.001, pvalue = 0.022, chr7q22
# Didn't pass (cutoff=0.0050): cat 17749, mi = 0.001, pvalue = 0.034, chr8q21
# Didn't pass (cutoff=0.0050): cat 17682, mi = 0.001, pvalue = 0.032, chr4q35
# Didn't pass (cutoff=0.0050): cat 1362, mi = 0.001, pvalue = 0.023, FIGUEROA_AML_METHYLATION_CLUSTER_6_UP
# Didn't pass (cutoff=0.0050): cat 14714, mi = 0.001, pvalue = 0.036, MORI_IMMATURE_B_LYMPHOCYTE_UP
# Total number of categories evaluated = 2240.
# Number of categories that passed the tests = 110
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 15, 18, 0.00714208140212524
# best merge is 5, 15, 0.0087013491742054
# best merge is 27, 30, 0.0117305906775774
# best merge is 10, 54, 0.0120167285903385
# best merge is 6, 9, 0.012779702669598
# best merge is 28, 72, 0.0156765790980028
# best merge is 27, 48, 0.0172632413477362
# best merge is 5, 70, 0.0177040092548798
# best merge is 5, 8, 0.0286237247611344
# best merge is 10, 27, 0.0299817378192894
# best merge is 1, 38, 0.0357463840735578
# best merge is 2, 83, 0.0385121756043729
# best merge is 12, 43, 0.0432508188494468
# best merge is 5, 19, 0.0469254778480986
# best merge is 58, 68, 0.0536336171456625
# best merge is 53, 88, 0.0543340839193223
# best merge is 44, 47, 0.0554852482809521
# best merge is 5, 60, 0.0620168740842086
# best merge is 5, 109, 0.0750677444108656
# best merge is 34, 40, 0.0755469452839098
# best merge is 77, 100, 0.0760389460550173
# best merge is 1, 94, 0.0812641624693463
# best merge is 34, 98, 0.082930565915562
# best merge is 5, 10, 0.0833073571477728
# best merge is 59, 67, 0.0841465684173817
# best merge is 56, 64, 0.0843316476905299
# best merge is 14, 22, 0.0857547977265577
# best merge is 3, 4, 0.0861677682417782
# best merge is 5, 76, 0.0880272103614637
# best merge is 28, 53, 0.0889781224943155
# best merge is 12, 17, 0.0923628473143592
# best merge is 79, 80, 0.0930499720979524
# best merge is 3, 7, 0.0993179586737503
# best merge is 1, 50, 0.100030486932344
# best merge is 5, 62, 0.103161852710023
# best merge is 34, 101, 0.104837147094619
# best merge is 31, 86, 0.10571668317791
# best merge is 25, 69, 0.111742853861527
# best merge is 1, 21, 0.11640090012569
# best merge is 3, 14, 0.133148336140441
# best merge is 34, 91, 0.134308522372368
# best merge is 75, 84, 0.134558373972812
# best merge is 56, 92, 0.141369108568529
# best merge is 65, 89, 0.144856668157091
# best merge is 93, 96, 0.146570015159171
# best merge is 78, 106, 0.149790126186971
# best merge is 63, 97, 0.151805398393668
# best merge is 28, 29, 0.154715528078003
# best merge is 0, 2, 0.157516325406047
# best merge is 1, 13, 0.161283014052052
# best merge is 26, 44, 0.164369325760455
# best merge is 12, 66, 0.184695727947616
# best merge is 11, 23, 0.189414648348862
# best merge is 5, 24, 0.192262646351893
# best merge is 25, 58, 0.202307606194579
# best merge is 55, 63, 0.204648737287237
# best merge is 3, 51, 0.205273013363965
# best merge is 26, 33, 0.20987729194682
# best merge is 28, 56, 0.215616911668093
# best merge is 34, 102, 0.219410568928549
# best merge is 12, 65, 0.228166508732031
# best merge is 5, 79, 0.229533551949133
# best merge is 1, 75, 0.2408932957344
# best merge is 5, 34, 0.247122397425552
# best merge is 37, 87, 0.247884582480544
# best merge is 42, 81, 0.24967488302118
# best merge is 1, 39, 0.252550065237842
# best merge is 6, 46, 0.252843285486858
# best merge is 3, 55, 0.254398672495481
# best merge is 32, 78, 0.256686545549051
# best merge is 73, 82, 0.257342019534877
# best merge is 25, 31, 0.266446051975247
# best merge is 20, 77, 0.273239734035156
# best merge is 3, 26, 0.290562311674885
# best merge is 5, 41, 0.293346675193148
# best merge is 28, 61, 0.297691577325992
# best merge is 59, 107, 0.303805247915438
# best merge is 32, 108, 0.303960022277982
# best merge is 35, 93, 0.31388556453978
# best merge is 12, 42, 0.323465029792826
# best merge is 99, 105, 0.328658504291088
# best merge is 0, 16, 0.334670362001029
# best merge is 1, 57, 0.337097139835115
# best merge is 5, 6, 0.344352641772229
# best merge is 20, 59, 0.355975875823104
# best merge is 1, 28, 0.363692460110316
# best merge is 3, 99, 0.379569933380607
# best merge is 71, 85, 0.380418329466067
# best merge is 0, 3, 0.418925695008001
# best merge is 1, 37, 0.447288794824158
# best merge is 12, 20, 0.457560672026881
# best merge is 32, 95, 0.457829009957369
# best merge is 1, 25, 0.460655463441593
# best merge is 49, 52, 0.465436794805504
# best merge is 32, 45, 0.487623706202889
# best merge is 11, 104, 0.521869714217461
# best merge is 36, 49, 0.524891220383399
# best merge is 32, 35, 0.546531195715385
# best merge is 5, 90, 0.568172628721248
# best merge is 12, 32, 0.612551128354669
# best merge is 0, 74, 0.631911313638476
# best merge is 0, 12, 0.699470688507099
# best merge is 1, 71, 0.699593808262944
# best merge is 5, 103, 0.720196859052388
# best merge is 1, 5, 0.755053633137556
# best merge is 36, 73, 0.772201280005513
# order classes
# 43 - 1.42853456537335
# 59 - 1.00695006911179
# 3 - 10.0479221071271
# 3 - 12.3462308083669
# 2 - 7.07690553720912
# 1 38 94 50 21 13 75 84 39 57 28 72 53 88 29 56 64 92 61 37 87 25 69 58 68 31 86 71 85 5 15 18 70 8 19 60 109 10 54 27 30 48 76 62 24 79 80 34 40 98 101 91 102 41 6 9 46 90 103
# 0 2 83 16 3 4 7 14 22 51 55 63 97 26 44 47 33 99 105 74 12 43 17 66 65 89 42 81 20 77 100 59 67 107 32 78 106 108 95 45 35 93 96
# 11 23 104
# 36 49 52
# 73 82
# Done.Start drawing
# 23.77	0.00
# FISCHER_G1_S_CELL_CYCLE
# LOPES_METHYLATED_IN_COLON_CANCER_DN
# REACTOME_METABOLISM_OF_STEROID_HORMONES_AND_VITAMINS_A_AND_D
# CSR_LATE_UP.V1_DN
# VECCHI_GASTRIC_CANCER_ADVANCED_VS_EARLY_UP
# JOHNSTONE_PARVB_TARGETS_1_DN
# GSE24972_WT_VS_IRF8_KO_SPLEEN_FOLLICULAR_BCELL_UP
# GSE21670_UNTREATED_VS_IL6_TREATED_STAT3_KO_CD4_TCELL_UP
# GSE27786_NKCELL_VS_ERYTHROBLAST_DN
# MAHAJAN_RESPONSE_TO_IL1A_DN
# GSE19825_NAIVE_VS_DAY3_EFF_CD8_TCELL_UP
# GSE16450_CTRL_VS_IFNA_6H_STIM_MATURE_NEURON_CELL_LINE_UP
# ACCTGTTG_UNKNOWN
# CERVERA_SDHB_TARGETS_1_DN
# RICKMAN_HEAD_AND_NECK_CANCER_A
# GSE36392_TYPE_2_MYELOID_VS_MAC_IL25_TREATED_LUNG_UP
# GSE13229_IMM_VS_INTMATURE_NKCELL_UP
# GO_CELL_RECOGNITION
# GUILLAUMOND_KLF10_TARGETS_UP
# CCAWWNAAGG_SRF_Q4
# GSE3982_BCELL_VS_CENT_MEMORY_CD4_TCELL_DN
# GSE7218_IGM_VS_IGG_SIGNAL_THGOUGH_ANTIGEN_BCELL_DN
# LEF1_UP.V1_DN
# PTEN_DN.V1_DN
# CERVERA_SDHB_TARGETS_1_UP
# KEGG_PANCREATIC_CANCER
# TAVAZOIE_METASTASIS
# GSE17721_POLYIC_VS_CPG_8H_BMDC_DN
# GO_CELLULAR_RESPONSE_TO_AMINO_ACID_STARVATION
# GSE36888_UNTREATED_VS_IL2_TREATED_TCELL_2H_UP
# GCM_MLL
# GSE28237_EARLY_VS_LATE_GC_BCELL_DN
# GSE22886_IGM_MEMORY_BCELL_VS_BLOOD_PLASMA_CELL_DN
# GSE411_WT_VS_SOCS3_KO_MACROPHAGE_DN
# GSE17974_2.5H_VS_72H_IL4_AND_ANTI_IL12_ACT_CD4_TCELL_DN
# GO_REPRESSING_TRANSCRIPTION_FACTOR_BINDING
# GSE2770_IL12_VS_IL4_TREATED_ACT_CD4_TCELL_6H_DN
# GO_POSITIVE_REGULATION_OF_ATPASE_ACTIVITY
# GCM_MAP1B
# GO_REGULATION_OF_ORGANELLE_ASSEMBLY
# REACTOME_BASE_FREE_SUGAR_PHOSPHATE_REMOVAL_VIA_THE_SINGLE_NUCLEOTIDE_REPLACEMENT_PATHWAY
# INGRAM_SHH_TARGETS_UP
# GSE557_CIITA_KO_VS_I_AB_KO_DC_DN
# GSE3920_UNTREATED_VS_IFNG_TREATED_ENDOTHELIAL_CELL_DN
# BYSTRYKH_HEMATOPOIESIS_STEM_CELL_AND_BRAIN_QTL_TRANS
# GO_PEPTIDYL_PROLINE_HYDROXYLATION
# PID_P38_ALPHA_BETA_DOWNSTREAM_PATHWAY
# GSE22611_UNSTIM_VS_2H_MDP_STIM_MUTANT_NOD2_TRANSDUCED_HEK293T_CELL_DN
# GO_OUTER_MEMBRANE
# GO_SPLICEOSOMAL_COMPLEX
# GSE2770_UNTREATED_VS_ACT_CD4_TCELL_48H_UP
# GSE22935_UNSTIM_VS_12H_MBOVIS_BCG_STIM_MACROPHAGE_UP
# KYNG_WERNER_SYNDROM_AND_NORMAL_AGING_UP
# ATGCTGG_MIR338
# chr7q11
# GSE411_100MIN_VS_400MIN_IL6_STIM_MACROPHAGE_DN
# GSE27786_BCELL_VS_MONO_MAC_UP
# GSE14908_ATOPIC_VS_NONATOPIC_PATIENT_HDM_STIM_CD4_TCELL_UP
# GSE32533_WT_VS_MIR17_KO_ACT_CD4_TCELL_DN
# GO_ACETYLTRANSFERASE_ACTIVITY
# GSE17721_POLYIC_VS_PAM3CSK4_1H_BMDC_UP
# GSE17721_POLYIC_VS_PAM3CSK4_0.5H_BMDC_DN
# MORF_NPM1
# KEGG_OXIDATIVE_PHOSPHORYLATION
# GO_RNA_MODIFICATION
# REACTOME_SCFSKP2_MEDIATED_DEGRADATION_OF_P27_P21
# MORF_RAB1A
# GO_MITOCHONDRIAL_TRANSLATION
# GSE8515_CTRL_VS_IL6_4H_STIM_MAC_UP
# GSE22601_IMMATURE_CD4_SINGLE_POSITIVE_VS_CD4_SINGLE_POSITIVE_THYMOCYTE_UP
# GSE40666_UNTREATED_VS_IFNA_STIM_CD8_TCELL_90MIN_DN
# GSE9509_10MIN_VS_30MIN_LPS_STIM_IL10_KO_MACROPHAGE_UP
# REACTOME_METABOLISM_OF_POLYAMINES
# CHOI_ATL_STAGE_PREDICTOR
# GSE3720_LPS_VS_PMA_STIM_VD2_GAMMADELTA_TCELL_DN
# GSE13522_CTRL_VS_T_CRUZI_Y_STRAIN_INF_SKIN_IFNG_KO_UP
# chr17q25
# chrxp11
# GSE36392_EOSINOPHIL_VS_MAC_IL25_TREATED_LUNG_UP
# GO_DETECTION_OF_ABIOTIC_STIMULUS
# AIGNER_ZEB1_TARGETS
# NRSF_01
# chr13q32
# chr13q22
# MODULE_297
# chr13q34
# REICHERT_MITOSIS_LIN9_TARGETS
# chr13q33
# GO_HORMONE_ACTIVITY
# GSE6090_UNSTIM_VS_DC-SIGN_STIM_DC_DN
# KRAS.BREAST_UP.V1_UP
# CAHOY_NEURONAL
# RORIE_TARGETS_OF_EWSR1_FLI1_FUSION_DN
# MODULE_111
# LIU_CDX2_TARGETS_UP
# DCA_UP.V1_UP
# GSE21670_UNTREATED_VS_TGFB_TREATED_CD4_TCELL_UP
# SENGUPTA_NASOPHARYNGEAL_CARCINOMA_WITH_LMP1_DN
# GSE15750_WT_VS_TRAF6KO_DAY10_EFF_CD8_TCELL_DN
# GSE8921_UNSTIM_0H_VS_TLR1_2_STIM_MONOCYTE_3H_DN
# GSE16385_ROSIGLITAZONE_IL4_VS_IFNG_TNF_STIM_MACROPHAGE_DN
# GSE9946_MATURE_STIMULATORY_VS_PROSTAGLANDINE2_TREATED_MATURE_DC_DN
# SMID_BREAST_CANCER_RELAPSE_IN_BRAIN_DN
# SERVITJA_ISLET_HNF1A_TARGETS_DN
# GSE6674_UNSTIM_VS_ANTI_IGM_STIM_BCELL_DN
# chr13q14
# chr13q12
# chr7q31
# URS_ADIPOCYTE_DIFFERENTIATION_UP
# PDGF_ERK_DN.V1_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 15, 18, 0.00714208140212524
# best merge is 5, 15, 0.0087013491742054
# best merge is 27, 30, 0.0117305906775774
# best merge is 10, 54, 0.0120167285903385
# best merge is 6, 9, 0.012779702669598
# best merge is 28, 72, 0.0156765790980028
# best merge is 27, 48, 0.0172632413477362
# best merge is 5, 70, 0.0177040092548798
# best merge is 5, 8, 0.0286237247611344
# best merge is 10, 27, 0.0299817378192894
# best merge is 1, 38, 0.0357463840735578
# best merge is 2, 83, 0.0385121756043729
# best merge is 12, 43, 0.0432508188494468
# best merge is 5, 19, 0.0469254778480986
# best merge is 58, 68, 0.0536336171456625
# best merge is 53, 88, 0.0543340839193223
# best merge is 44, 47, 0.0554852482809521
# best merge is 5, 60, 0.0620168740842086
# best merge is 5, 109, 0.0750677444108656
# best merge is 34, 40, 0.0755469452839098
# best merge is 77, 100, 0.0760389460550173
# best merge is 1, 94, 0.0812641624693463
# best merge is 34, 98, 0.082930565915562
# best merge is 5, 10, 0.0833073571477728
# best merge is 59, 67, 0.0841465684173817
# best merge is 56, 64, 0.0843316476905299
# best merge is 14, 22, 0.0857547977265577
# best merge is 3, 4, 0.0861677682417782
# best merge is 5, 76, 0.0880272103614637
# best merge is 28, 53, 0.0889781224943155
# best merge is 12, 17, 0.0923628473143592
# best merge is 79, 80, 0.0930499720979524
# best merge is 3, 7, 0.0993179586737503
# best merge is 1, 50, 0.100030486932344
# best merge is 5, 62, 0.103161852710023
# best merge is 34, 101, 0.104837147094619
# best merge is 31, 86, 0.10571668317791
# best merge is 25, 69, 0.111742853861527
# best merge is 1, 21, 0.11640090012569
# best merge is 3, 14, 0.133148336140441
# best merge is 34, 91, 0.134308522372368
# best merge is 75, 84, 0.134558373972812
# best merge is 56, 92, 0.141369108568529
# best merge is 65, 89, 0.144856668157091
# best merge is 93, 96, 0.146570015159171
# best merge is 78, 106, 0.149790126186971
# best merge is 63, 97, 0.151805398393668
# best merge is 28, 29, 0.154715528078003
# best merge is 0, 2, 0.157516325406047
# best merge is 1, 13, 0.161283014052052
# best merge is 26, 44, 0.164369325760455
# best merge is 12, 66, 0.184695727947616
# best merge is 11, 23, 0.189414648348862
# best merge is 5, 24, 0.192262646351893
# best merge is 25, 58, 0.202307606194579
# best merge is 55, 63, 0.204648737287237
# best merge is 3, 51, 0.205273013363965
# best merge is 26, 33, 0.20987729194682
# best merge is 28, 56, 0.215616911668093
# best merge is 34, 102, 0.219410568928549
# best merge is 12, 65, 0.228166508732031
# best merge is 5, 79, 0.229533551949133
# best merge is 1, 75, 0.2408932957344
# best merge is 5, 34, 0.247122397425552
# best merge is 37, 87, 0.247884582480544
# best merge is 42, 81, 0.24967488302118
# best merge is 1, 39, 0.252550065237842
# best merge is 6, 46, 0.252843285486858
# best merge is 3, 55, 0.254398672495481
# best merge is 32, 78, 0.256686545549051
# best merge is 73, 82, 0.257342019534877
# best merge is 25, 31, 0.266446051975247
# best merge is 20, 77, 0.273239734035156
# best merge is 3, 26, 0.290562311674885
# best merge is 5, 41, 0.293346675193148
# best merge is 28, 61, 0.297691577325992
# best merge is 59, 107, 0.303805247915438
# best merge is 32, 108, 0.303960022277982
# best merge is 35, 93, 0.31388556453978
# best merge is 12, 42, 0.323465029792826
# best merge is 99, 105, 0.328658504291088
# best merge is 0, 16, 0.334670362001029
# best merge is 1, 57, 0.337097139835115
# best merge is 5, 6, 0.344352641772229
# best merge is 20, 59, 0.355975875823104
# best merge is 1, 28, 0.363692460110316
# best merge is 3, 99, 0.379569933380607
# best merge is 71, 85, 0.380418329466067
# best merge is 0, 3, 0.418925695008001
# best merge is 1, 37, 0.447288794824158
# best merge is 12, 20, 0.457560672026881
# best merge is 32, 95, 0.457829009957369
# best merge is 1, 25, 0.460655463441593
# best merge is 49, 52, 0.465436794805504
# best merge is 32, 45, 0.487623706202889
# best merge is 11, 104, 0.521869714217461
# best merge is 36, 49, 0.524891220383399
# best merge is 32, 35, 0.546531195715385
# best merge is 5, 90, 0.568172628721248
# best merge is 12, 32, 0.612551128354669
# best merge is 0, 74, 0.631911313638476
# best merge is 0, 12, 0.699470688507099
# best merge is 1, 71, 0.699593808262944
# best merge is 5, 103, 0.720196859052388
# best merge is 1, 5, 0.755053633137556
# best merge is 36, 73, 0.772201280005513
# order classes
# 43 - 1.42853456537335
# 59 - 1.00695006911179
# 3 - 10.0479221071271
# 3 - 12.3462308083669
# 2 - 7.07690553720912
# 1 38 94 50 21 13 75 84 39 57 28 72 53 88 29 56 64 92 61 37 87 25 69 58 68 31 86 71 85 5 15 18 70 8 19 60 109 10 54 27 30 48 76 62 24 79 80 34 40 98 101 91 102 41 6 9 46 90 103
# 0 2 83 16 3 4 7 14 22 51 55 63 97 26 44 47 33 99 105 74 12 43 17 66 65 89 42 81 20 77 100 59 67 107 32 78 106 108 95 45 35 93 96
# 11 23 104
# 36 49 52
# 73 82
# Done.-19.2932267564156	42	0
# -18.4450988641144	42	1.4135464871687
# -18.2153975599495	42	1.69625578460244
# -18.056373580143	42	1.87294909549853
# -17.8973496003366	42	2.0143037442154
# -17.7206562894405	42	2.19099705511149
# -17.51745898191	42	2.36769036600757
# -17.2082456878418	42	2.59739167017249
# 2.49305847707194	42	2.98611695414388
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM2_1.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM2_2.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM2_3.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM2_4.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM2_5.csv --species=human_ensembl_msigdb_full --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_full.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_full/human_ensembl_msigdb_full.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 17786
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	17786
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 17786
# cat 17137, mi = 0.01769397, WHITFIELD_CELL_CYCLE_G2
# cat 14627, mi = 0.01237509, MORF_NPM1
# cat 15897, mi = 0.01230166, REACTOME_PEPTIDE_CHAIN_ELONGATION
# cat 13373, mi = 0.01144138, KEGG_RIBOSOME
# cat 15480, mi = 0.01115946, REACTOME_3_UTR_MEDIATED_TRANSLATIONAL_REGULATION
# cat 16126, mi = 0.01102252, REACTOME_TRANSLATION
# cat 1742, mi = 0.01053003, GNF2_CDC20
# cat 15759, mi = 0.01049426, REACTOME_INFLUENZA_VIRAL_RNA_TRANSCRIPTION_AND_REPLICATION
# cat 16237, mi = 0.01047032, ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER
# cat 1733, mi = 0.01046176, GNF2_CCNB2
# cat 16072, mi = 0.01042370, REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANE
# cat 8520, mi = 0.01036369, GSE15750_DAY6_VS_DAY10_TRAF6KO_EFF_CD8_TCELL_UP
# cat 8518, mi = 0.01026584, GSE15750_DAY6_VS_DAY10_EFF_CD8_TCELL_UP
# cat 7604, mi = 0.01013899, GO_TRANSLATIONAL_INITIATION
# cat 14520, mi = 0.01012326, MORF_ACTG1
#
# RESULTS
# Passed: cat 17137, mi = 0.018, pvalue = 0.000, WHITFIELD_CELL_CYCLE_G2
# Passed: cat 14627, mi = 0.012, pvalue = 0.000, MORF_NPM1
# Passed: cat 13340, mi = 0.009, pvalue = 0.000, KEGG_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 15829, mi = 0.006, pvalue = 0.000, REACTOME_MITOTIC_PROMETAPHASE
# Passed: cat 13381, mi = 0.005, pvalue = 0.000, KEGG_SPLICEOSOME
# Passed: cat 11153, mi = 0.005, pvalue = 0.000, GSE369_IFNG_KO_VS_WT_LIVER_DN
# Passed: cat 14659, mi = 0.004, pvalue = 0.000, MORF_RAB1A
# Passed: cat 874, mi = 0.004, pvalue = 0.000, CHARAFE_BREAST_CANCER_BASAL_VS_MESENCHYMAL_UP
# Passed: cat 9557, mi = 0.004, pvalue = 0.000, GSE21927_SPLEEN_C57BL6_VS_EL4_TUMOR_BALBC_MONOCYTES_DN
# Passed: cat 12008, mi = 0.004, pvalue = 0.000, GSE45365_HEALTHY_VS_MCMV_INFECTION_CD11B_DC_IFNAR_KO_DN
# Passed: cat 15899, mi = 0.004, pvalue = 0.000, REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORS
# Passed: cat 17140, mi = 0.004, pvalue = 0.000, WHITFIELD_CELL_CYCLE_M_G1
# Passed: cat 14514, mi = 0.004, pvalue = 0.000, MOREAUX_MULTIPLE_MYELOMA_BY_TACI_DN
# Passed: cat 12598, mi = 0.004, pvalue = 0.000, GSE9006_HEALTHY_VS_TYPE_1_DIABETES_PBMC_1MONTH_POST_DX_UP
# Passed: cat 1613, mi = 0.003, pvalue = 0.000, GCM_RAB10
# Passed: cat 17136, mi = 0.003, pvalue = 0.000, WHITFIELD_CELL_CYCLE_G1_S
# Passed: cat 12381, mi = 0.003, pvalue = 0.000, GSE6674_UNSTIM_VS_ANTI_IGM_STIM_BCELL_DN
# Passed: cat 13439, mi = 0.003, pvalue = 0.000, KIM_RESPONSE_TO_TSA_AND_DECITABINE_UP
# Passed: cat 17603, mi = 0.003, pvalue = 0.000, chr21q22
# Passed: cat 9481, mi = 0.003, pvalue = 0.000, GSE21546_SAP1A_KO_VS_SAP1A_KO_AND_ELK1_KO_DP_THYMOCYTES_DN
# Passed: cat 12695, mi = 0.003, pvalue = 0.000, GSE9988_ANTI_TREM1_VS_CTRL_TREATED_MONOCYTES_DN
# Passed: cat 12792, mi = 0.003, pvalue = 0.000, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# Passed: cat 13495, mi = 0.003, pvalue = 0.000, KRAS.300_UP.V1_UP
# Passed: cat 9268, mi = 0.003, pvalue = 0.000, GSE19888_CTRL_VS_T_CELL_MEMBRANES_ACT_MAST_CELL_UP
# Passed: cat 9051, mi = 0.003, pvalue = 0.000, GSE17974_0H_VS_6H_IN_VITRO_ACT_CD4_TCELL_DN
# Passed: cat 9693, mi = 0.003, pvalue = 0.000, GSE22611_NOD2_TRANSD_VS_CTRL_TRANSD_HEK293_MDP_STIM_2H_DN
# Passed: cat 8189, mi = 0.003, pvalue = 0.000, GSE13485_DAY7_VS_DAY21_YF17D_VACCINE_PBMC_DN
# Passed: cat 11783, mi = 0.003, pvalue = 0.000, GSE41867_DAY8_VS_DAY15_LCMV_CLONE13_EFFECTOR_CD8_TCELL_DN
# Passed: cat 13508, mi = 0.003, pvalue = 0.000, KRAS.KIDNEY_UP.V1_DN
# Passed: cat 12635, mi = 0.003, pvalue = 0.000, GSE9509_LPS_VS_LPS_AND_IL10_STIM_IL10_KO_MACROPHAGE_10MIN_DN
# Passed: cat 12096, mi = 0.003, pvalue = 0.000, GSE46606_IRF4HIGH_VS_IRF4MID_CD40L_IL2_IL5_DAY3_STIMULATED_BCELL_UP
# Passed: cat 14072, mi = 0.003, pvalue = 0.000, MODULE_111
# Passed: cat 14847, mi = 0.003, pvalue = 0.000, NAKAYAMA_SOFT_TISSUE_TUMORS_PCA2_DN
# Passed: cat 7774, mi = 0.002, pvalue = 0.000, GO_VOLTAGE_GATED_POTASSIUM_CHANNEL_ACTIVITY
# Passed: cat 13113, mi = 0.002, pvalue = 0.000, JAK2_DN.V1_UP
# Passed: cat 9833, mi = 0.002, pvalue = 0.000, GSE23114_PERITONEAL_CAVITY_B1A_BCELL_VS_SPLEEN_BCELL_IN_SLE2C1_MOUSE_UP
# Passed: cat 201, mi = 0.002, pvalue = 0.000, ATAACCT_MIR154
# Passed: cat 11385, mi = 0.002, pvalue = 0.000, GSE3920_UNTREATED_VS_IFNB_TREATED_ENDOTHELIAL_CELL_DN
# Passed: cat 9001, mi = 0.002, pvalue = 0.000, GSE17721_POLYIC_VS_GARDIQUIMOD_6H_BMDC_DN
# Passed: cat 5796, mi = 0.002, pvalue = 0.000, GO_PROTEASOME_COMPLEX
# Passed: cat 12297, mi = 0.002, pvalue = 0.000, GSE6090_UNSTIM_VS_DC-SIGN_STIM_DC_DN
# Passed: cat 9312, mi = 0.002, pvalue = 0.000, GSE20198_IL12_VS_IFNA_TREATED_ACT_CD4_TCELL_UP
# Passed: cat 14228, mi = 0.002, pvalue = 0.000, MODULE_277
# Passed: cat 17504, mi = 0.002, pvalue = 0.000, chr13q12
# Passed: cat 9955, mi = 0.002, pvalue = 0.000, GSE24210_IL35_TREATED_VS_RESTING_TREG_DN
# Passed: cat 17510, mi = 0.002, pvalue = 0.000, chr13q32
# Passed: cat 11670, mi = 0.002, pvalue = 0.000, GSE40493_BCL6_KO_VS_WT_TREG_UP
# Passed: cat 9171, mi = 0.002, pvalue = 0.000, GSE18893_TCONV_VS_TREG_24H_TNF_STIM_DN
# Passed: cat 9818, mi = 0.002, pvalue = 0.000, GSE22935_UNSTIM_VS_24H_MBOVIS_BCG_STIM_MYD88_KO_MACROPHAGE_UP
# Passed: cat 10955, mi = 0.002, pvalue = 0.000, GSE36009_UNSTIM_VS_LPS_STIM_DC_DN
# Passed: cat 10683, mi = 0.002, pvalue = 0.000, GSE3039_CD4_TCELL_VS_NKT_CELL_DN
# Passed: cat 7564, mi = 0.002, pvalue = 0.000, GO_TRANSCRIPTION_ELONGATION_FROM_RNA_POLYMERASE_II_PROMOTER
# Passed: cat 17209, mi = 0.002, pvalue = 0.000, WYAAANNRNNNGCG_UNKNOWN
# Passed: cat 10420, mi = 0.002, pvalue = 0.000, GSE27786_LIN_NEG_VS_MONO_MAC_UP
# Passed: cat 13432, mi = 0.002, pvalue = 0.000, KIM_MYCN_AMPLIFICATION_TARGETS_DN
# Passed: cat 8521, mi = 0.002, pvalue = 0.000, GSE15750_WT_VS_TRAF6KO_DAY10_EFF_CD8_TCELL_DN
# Passed: cat 12046, mi = 0.002, pvalue = 0.000, GSE45382_UNTREATED_VS_TGFB_TREATED_MACROPHAGES_UP
# Passed: cat 3283, mi = 0.002, pvalue = 0.000, GO_FIBROBLAST_GROWTH_FACTOR_RECEPTOR_BINDING
# Passed: cat 17506, mi = 0.002, pvalue = 0.000, chr13q14
# Passed: cat 9175, mi = 0.002, pvalue = 0.000, GSE18893_TCONV_VS_TREG_2H_TNF_STIM_DN
# Passed: cat 7973, mi = 0.002, pvalue = 0.000, GSE11864_UNTREATED_VS_CSF1_IFNG_IN_MAC_DN
# Passed: cat 10364, mi = 0.002, pvalue = 0.000, GSE2770_UNTREATED_VS_TGFB_AND_IL12_TREATED_ACT_CD4_TCELL_6H_UP
# Passed: cat 13646, mi = 0.002, pvalue = 0.000, LEF1_UP.V1_DN
# Passed: cat 9532, mi = 0.002, pvalue = 0.000, GSE21670_UNTREATED_VS_TGFB_TREATED_CD4_TCELL_UP
# Passed: cat 11252, mi = 0.002, pvalue = 0.000, GSE37416_0H_VS_3H_F_TULARENSIS_LVS_NEUTROPHIL_UP
# Passed: cat 11544, mi = 0.002, pvalue = 0.000, GSE3982_MAST_CELL_VS_NEUTROPHIL_UP
# Passed: cat 11719, mi = 0.002, pvalue = 0.000, GSE41176_UNSTIM_VS_ANTI_IGM_STIM_TAK1_KO_BCELL_6H_DN
# Passed: cat 8326, mi = 0.002, pvalue = 0.000, GSE14350_TREG_VS_TEFF_UP
# Passed: cat 9131, mi = 0.002, pvalue = 0.000, GSE18791_CTRL_VS_NEWCASTLE_VIRUS_DC_18H_DN
# Passed: cat 8057, mi = 0.002, pvalue = 0.000, GSE12198_NK_VS_NK_ACT_EXPANSION_SYSTEM_DERIVED_NK_CELL_DN
# Passed: cat 12682, mi = 0.002, pvalue = 0.000, GSE9960_HEALTHY_VS_GRAM_NEG_AND_POS_SEPSIS_PBMC_UP
# Passed: cat 13538, mi = 0.002, pvalue = 0.000, KUNINGER_IGF1_VS_PDGFB_TARGETS_UP
# Passed: cat 8264, mi = 0.002, pvalue = 0.000, GSE14000_TRANSLATED_RNA_VS_MRNA_4H_LPS_DC_UP
# Passed: cat 10407, mi = 0.002, pvalue = 0.000, GSE27786_ERYTHROBLAST_VS_MONO_MAC_DN
# Passed: cat 8333, mi = 0.002, pvalue = 0.000, GSE14413_UNSTIM_VS_IFNB_STIM_RAW264_CELLS_DN
# Passed: cat 11799, mi = 0.002, pvalue = 0.000, GSE41867_NAIVE_VS_DAY30_LCMV_ARMSTRONG_MEMORY_CD8_TCELL_DN
# Passed: cat 12171, mi = 0.002, pvalue = 0.000, GSE5455_HEALTHY_VS_TUMOR_BEARING_MOUSE_SPLEEN_MONOCYTE_24H_INCUBATION_DN
# Passed: cat 11261, mi = 0.002, pvalue = 0.000, GSE37416_CTRL_VS_0H_F_TULARENSIS_LVS_NEUTROPHIL_DN
# Passed: cat 17512, mi = 0.002, pvalue = 0.000, chr13q34
# Passed: cat 3586, mi = 0.002, pvalue = 0.000, GO_HYDRO_LYASE_ACTIVITY
# Passed: cat 11336, mi = 0.002, pvalue = 0.000, GSE37605_C57BL6_VS_NOD_FOXP3_IRES_GFP_TREG_UP
# Passed: cat 10054, mi = 0.002, pvalue = 0.000, GSE25088_CTRL_VS_IL4_STIM_MACROPHAGE_UP
# Passed: cat 10963, mi = 0.002, pvalue = 0.000, GSE36078_UNTREATED_VS_AD5_INF_IL1R_KO_MOUSE_LUNG_DC_DN
# Passed: cat 4152, mi = 0.002, pvalue = 0.000, GO_MONOCARBOXYLIC_ACID_BINDING
# Passed: cat 5000, mi = 0.002, pvalue = 0.000, GO_OXYGEN_BINDING
# Passed: cat 9180, mi = 0.002, pvalue = 0.001, GSE19198_1H_VS_6H_IL21_TREATED_TCELL_UP
# Passed: cat 17769, mi = 0.002, pvalue = 0.000, chrxp11
# Passed: cat 7154, mi = 0.002, pvalue = 0.001, GO_RNA_PHOSPHODIESTER_BOND_HYDROLYSIS_ENDONUCLEOLYTIC
# Passed: cat 15233, mi = 0.002, pvalue = 0.001, PID_IL12_STAT4_PATHWAY
# Passed: cat 16682, mi = 0.002, pvalue = 0.001, TAGAACC_MIR182
# Passed: cat 1638, mi = 0.002, pvalue = 0.001, GCTCTTG_MIR335
# Passed: cat 8583, mi = 0.002, pvalue = 0.001, GSE16385_MONOCYTE_VS_12H_IL4_TREATED_MACROPHAGE_DN
# Passed: cat 13681, mi = 0.002, pvalue = 0.001, LIAN_LIPA_TARGETS_6M
# Passed: cat 15591, mi = 0.002, pvalue = 0.001, REACTOME_CIRCADIAN_REPRESSION_OF_EXPRESSION_BY_REV_ERBA
# Passed: cat 14946, mi = 0.002, pvalue = 0.002, NOUSHMEHR_GBM_SILENCED_BY_METHYLATION
# Passed: cat 17771, mi = 0.002, pvalue = 0.001, chrxp22
# Passed: cat 11740, mi = 0.002, pvalue = 0.001, GSE411_UNSTIM_VS_400MIN_IL6_STIM_MACROPHAGE_UP
# Passed: cat 11771, mi = 0.002, pvalue = 0.002, GSE41867_DAY6_VS_DAY15_LCMV_CLONE13_EFFECTOR_CD8_TCELL_DN
# Passed: cat 17691, mi = 0.002, pvalue = 0.002, chr5q14
# Passed: cat 8133, mi = 0.002, pvalue = 0.001, GSE13306_RA_VS_UNTREATED_TREG_DN
# Passed: cat 8406, mi = 0.002, pvalue = 0.002, GSE14769_UNSTIM_VS_20MIN_LPS_BMDM_UP
# Passed: cat 11629, mi = 0.002, pvalue = 0.002, GSE40274_EOS_VS_FOXP3_AND_EOS_TRANSDUCED_ACTIVATED_CD4_TCELL_DN
# Passed: cat 7365, mi = 0.002, pvalue = 0.002, GO_SPERM_PART
# Passed: cat 4023, mi = 0.002, pvalue = 0.001, GO_METALLO_SULFUR_CLUSTER_ASSEMBLY
# Passed: cat 17612, mi = 0.002, pvalue = 0.002, chr2p14
# Passed: cat 3504, mi = 0.002, pvalue = 0.001, GO_HETEROTRIMERIC_G_PROTEIN_COMPLEX
# Passed: cat 7854, mi = 0.001, pvalue = 0.002, GROSS_HYPOXIA_VIA_HIF1A_UP
# Passed: cat 12179, mi = 0.001, pvalue = 0.002, GSE5503_LIVER_DC_VS_PLN_DC_ACTIVATED_ALLOGENIC_TCELL_DN
# Passed: cat 11860, mi = 0.001, pvalue = 0.001, GSE42021_TREG_PLN_VS_CD24LO_TREG_THYMUS_UP
# Passed: cat 11779, mi = 0.001, pvalue = 0.002, GSE41867_DAY8_EFFECTOR_VS_DAY30_MEMORY_CD8_TCELL_LCMV_ARMSTRONG_DN
# Passed: cat 6082, mi = 0.001, pvalue = 0.000, GO_REGULATION_OF_ATTACHMENT_OF_SPINDLE_MICROTUBULES_TO_KINETOCHORE
# Passed: cat 17747, mi = 0.001, pvalue = 0.003, chr8q12
# Passed: cat 10192, mi = 0.001, pvalue = 0.002, GSE26495_NAIVE_VS_PD1HIGH_CD8_TCELL_UP
# Passed: cat 15278, mi = 0.001, pvalue = 0.004, PID_P38_ALPHA_BETA_DOWNSTREAM_PATHWAY
# Passed: cat 3703, mi = 0.001, pvalue = 0.004, GO_INTRINSIC_COMPONENT_OF_GOLGI_MEMBRANE
# Passed: cat 10895, mi = 0.001, pvalue = 0.003, GSE34156_TLR1_TLR2_LIGAND_VS_NOD2_AND_TLR1_TLR2_LIGAND_6H_TREATED_MONOCYTE_DN
# Passed: cat 10636, mi = 0.001, pvalue = 0.004, GSE29949_CD8_POS_DC_SPLEEN_VS_DC_BRAIN_UP
# Didn't pass (cutoff=0.0050): cat 13038, mi = 0.001, pvalue = 0.006, IIZUKA_LIVER_CANCER_PROGRESSION_G1_G2_DN
# Passed: cat 10389, mi = 0.001, pvalue = 0.003, GSE27786_CD4_TCELL_VS_NEUTROPHIL_DN
# Didn't pass (cutoff=0.0050): cat 3139, mi = 0.001, pvalue = 0.005, GO_EPITHELIAL_CELL_MORPHOGENESIS
# Didn't pass (cutoff=0.0050): cat 2422, mi = 0.001, pvalue = 0.006, GO_CELLULAR_RESPONSE_TO_AMINO_ACID_STARVATION
# Passed: cat 11128, mi = 0.001, pvalue = 0.004, GSE36888_STAT5_AB_KNOCKIN_VS_WT_TCELL_IL2_TREATED_6H_UP
# Didn't pass (cutoff=0.0050): cat 4436, mi = 0.001, pvalue = 0.006, GO_NEGATIVE_REGULATION_OF_GENE_EXPRESSION_EPIGENETIC
# Didn't pass (cutoff=0.0050): cat 3516, mi = 0.001, pvalue = 0.009, GO_HIPPO_SIGNALING
# Didn't pass (cutoff=0.0050): cat 2911, mi = 0.001, pvalue = 0.007, GO_DEVELOPMENTAL_PIGMENTATION
# Didn't pass (cutoff=0.0050): cat 9238, mi = 0.001, pvalue = 0.006, GSE19825_NAIVE_VS_IL2RAHIGH_DAY3_EFF_CD8_TCELL_UP
# Didn't pass (cutoff=0.0050): cat 5856, mi = 0.001, pvalue = 0.009, GO_PROTEIN_K63_LINKED_UBIQUITINATION
# Didn't pass (cutoff=0.0050): cat 17716, mi = 0.001, pvalue = 0.010, chr6q22
# Didn't pass (cutoff=0.0050): cat 11101, mi = 0.001, pvalue = 0.006, GSE36476_YOUNG_VS_OLD_DONOR_MEMORY_CD4_TCELL_16H_TSST_ACT_DN
# Didn't pass (cutoff=0.0050): cat 17225, mi = 0.001, pvalue = 0.009, XU_HGF_TARGETS_REPRESSED_BY_AKT1_DN
# Didn't pass (cutoff=0.0050): cat 14572, mi = 0.001, pvalue = 0.009, MORF_ERCC2
# Didn't pass (cutoff=0.0050): cat 17763, mi = 0.001, pvalue = 0.011, chr9q21
# Didn't pass (cutoff=0.0050): cat 1684, mi = 0.001, pvalue = 0.010, GGCNRNWCTTYS_UNKNOWN
# Didn't pass (cutoff=0.0050): cat 3949, mi = 0.001, pvalue = 0.014, GO_MANNOSYLTRANSFERASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 1593, mi = 0.001, pvalue = 0.011, GCM_MAPK10
# Didn't pass (cutoff=0.0050): cat 6047, mi = 0.001, pvalue = 0.013, GO_REGULATION_OF_ACTIN_FILAMENT_DEPOLYMERIZATION
# Passed: cat 1866, mi = 0.001, pvalue = 0.003, GOERING_BLOOD_HDL_CHOLESTEROL_QTL_TRANS
# Didn't pass (cutoff=0.0050): cat 2777, mi = 0.001, pvalue = 0.016, GO_CUL3_RING_UBIQUITIN_LIGASE_COMPLEX
# Didn't pass (cutoff=0.0050): cat 12388, mi = 0.001, pvalue = 0.017, GSE6681_DELETED_FOXP3_VS_WT_TREG_UP
# Didn't pass (cutoff=0.0050): cat 3718, mi = 0.001, pvalue = 0.022, GO_ION_ANTIPORTER_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 2127, mi = 0.001, pvalue = 0.020, GO_ASPARTATE_FAMILY_AMINO_ACID_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 17017, mi = 0.001, pvalue = 0.016, WAKABAYASHI_ADIPOGENESIS_PPARG_RXRA_BOUND_36HR
# Didn't pass (cutoff=0.0050): cat 8576, mi = 0.001, pvalue = 0.015, GSE16385_IFNG_TNF_VS_ROSIGLITAZONE_STIM_MACROPHAGE_UP
# Didn't pass (cutoff=0.0050): cat 13927, mi = 0.001, pvalue = 0.018, MCAATNNNNNGCG_UNKNOWN
# Didn't pass (cutoff=0.0050): cat 9543, mi = 0.001, pvalue = 0.016, GSE21927_BALBC_VS_C57BL6_MONOCYTE_SPLEEN_DN
# Didn't pass (cutoff=0.0050): cat 4217, mi = 0.001, pvalue = 0.029, GO_MULTI_ORGANISM_ORGANELLE_ORGANIZATION
# Didn't pass (cutoff=0.0050): cat 2876, mi = 0.001, pvalue = 0.015, GO_DENDRITIC_SPINE_ORGANIZATION
# Didn't pass (cutoff=0.0050): cat 1516, mi = 0.001, pvalue = 0.031, GAUSSMANN_MLL_AF4_FUSION_TARGETS_F_DN
# Didn't pass (cutoff=0.0050): cat 194, mi = 0.001, pvalue = 0.030, AR_03
# Didn't pass (cutoff=0.0050): cat 7121, mi = 0.001, pvalue = 0.033, GO_RIBONUCLEOSIDE_CATABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 17116, mi = 0.001, pvalue = 0.020, WENG_POR_TARGETS_GLOBAL_UP
# Didn't pass (cutoff=0.0050): cat 17765, mi = 0.001, pvalue = 0.034, chr9q31
# Didn't pass (cutoff=0.0050): cat 16635, mi = 0.001, pvalue = 0.034, ST_INTERLEUKIN_4_PATHWAY
# Didn't pass (cutoff=0.0050): cat 2171, mi = 0.001, pvalue = 0.012, GO_AXONEMAL_DYNEIN_COMPLEX_ASSEMBLY
# Didn't pass (cutoff=0.0050): cat 2038, mi = 0.001, pvalue = 0.016, GO_AMINO_SUGAR_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 7810, mi = 0.001, pvalue = 0.041, GRADE_COLON_VS_RECTAL_CANCER_UP
# Didn't pass (cutoff=0.0050): cat 6568, mi = 0.001, pvalue = 0.029, GO_REGULATION_OF_NEURON_PROJECTION_REGENERATION
# Total number of categories evaluated = 3292.
# Number of categories that passed the tests = 120
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 9, 0.0054920421229554
# best merge is 6, 65, 0.0142364755438534
# best merge is 44, 74, 0.0161598880066004
# best merge is 22, 63, 0.0170959793502785
# best merge is 7, 26, 0.0185295907240903
# best merge is 70, 84, 0.0185612165838507
# best merge is 10, 70, 0.020125688510004
# best merge is 32, 66, 0.0243215792656183
# best merge is 10, 57, 0.0275315121073355
# best merge is 40, 45, 0.0287460792496899
# best merge is 46, 90, 0.0289931819876428
# ...
# Didn't pass (cutoff=0.0050): cat 2228, mi = 0.001, pvalue = 0.009, GO_BLOC_COMPLEX
# Didn't pass (cutoff=0.0050): cat 12732, mi = 0.001, pvalue = 0.009, GTGCAAA_MIR507
# Didn't pass (cutoff=0.0050): cat 7631, mi = 0.001, pvalue = 0.012, GO_TRANS_GOLGI_NETWORK_TRANSPORT_VESICLE
# Didn't pass (cutoff=0.0050): cat 11107, mi = 0.001, pvalue = 0.010, GSE36476_YOUNG_VS_OLD_DONOR_MEMORY_CD4_TCELL_DN
# Didn't pass (cutoff=0.0050): cat 7134, mi = 0.001, pvalue = 0.014, GO_RIBOSOME_BINDING
# Didn't pass (cutoff=0.0050): cat 3503, mi = 0.001, pvalue = 0.012, GO_HETEROPHILIC_CELL_CELL_ADHESION_VIA_PLASMA_MEMBRANE_CELL_ADHESION_MOLECULES
# Didn't pass (cutoff=0.0050): cat 1945, mi = 0.001, pvalue = 0.021, GO_ACTIVATION_OF_JUN_KINASE_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 2363, mi = 0.001, pvalue = 0.011, GO_CATION_CATION_ANTIPORTER_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3451, mi = 0.001, pvalue = 0.011, GO_GUANOSINE_CONTAINING_COMPOUND_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 2817, mi = 0.001, pvalue = 0.016, GO_CYTOPLASMIC_EXOSOME_RNASE_COMPLEX_
# Didn't pass (cutoff=0.0050): cat 1364, mi = 0.001, pvalue = 0.011, FIGUEROA_AML_METHYLATION_CLUSTER_7_UP
# Didn't pass (cutoff=0.0050): cat 5163, mi = 0.001, pvalue = 0.017, GO_PHOTORECEPTOR_CELL_MAINTENANCE
# Didn't pass (cutoff=0.0050): cat 7099, mi = 0.001, pvalue = 0.020, GO_RETROGRADE_PROTEIN_TRANSPORT_ER_TO_CYTOSOL
# Didn't pass (cutoff=0.0050): cat 6543, mi = 0.001, pvalue = 0.023, GO_REGULATION_OF_MUSCLE_HYPERTROPHY
# Didn't pass (cutoff=0.0050): cat 4445, mi = 0.001, pvalue = 0.008, GO_NEGATIVE_REGULATION_OF_GLYCOPROTEIN_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 5178, mi = 0.001, pvalue = 0.022, GO_PIGMENT_GRANULE_ORGANIZATION
# Didn't pass (cutoff=0.0050): cat 15820, mi = 0.001, pvalue = 0.020, REACTOME_METAL_ION_SLC_TRANSPORTERS
# Didn't pass (cutoff=0.0050): cat 13568, mi = 0.001, pvalue = 0.022, KYNG_RESPONSE_TO_H2O2_VIA_ERCC6_UP
# Didn't pass (cutoff=0.0050): cat 3090, mi = 0.001, pvalue = 0.023, GO_ENDOPLASMIC_RETICULUM_TO_CYTOSOL_TRANSPORT
# Didn't pass (cutoff=0.0050): cat 5833, mi = 0.001, pvalue = 0.024, GO_PROTEIN_EXIT_FROM_ENDOPLASMIC_RETICULUM
# Total number of categories evaluated = 2664.
# Number of categories that passed the tests = 96
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 38, 56, 0.00216075950380712
# best merge is 0, 38, 0.010785089047444
# best merge is 12, 89, 0.0206065428845182
# best merge is 5, 22, 0.0220463688816502
# best merge is 0, 3, 0.0244148443773812
# best merge is 15, 34, 0.0256757561013183
# best merge is 39, 41, 0.0268132464742858
# best merge is 40, 49, 0.0309487601116935
# best merge is 0, 29, 0.030949659852065
# best merge is 12, 33, 0.0374132097677166
# best merge is 2, 7, 0.0463470255975756
# best merge is 0, 12, 0.0492165809694552
# best merge is 4, 40, 0.053090149475611
# best merge is 5, 31, 0.0552243608201837
# best merge is 0, 54, 0.0592415271958541
# best merge is 20, 53, 0.0659295131605609
# best merge is 8, 59, 0.0694302742260103
# best merge is 19, 50, 0.0763885796266458
# best merge is 30, 60, 0.0815670698972157
# best merge is 5, 9, 0.0845168879783155
# best merge is 2, 10, 0.084788871661008
# best merge is 43, 70, 0.0867388865467383
# best merge is 75, 83, 0.09735715625865
# best merge is 4, 84, 0.101093501918642
# best merge is 23, 25, 0.103619586609797
# best merge is 42, 61, 0.107273922917571
# best merge is 16, 85, 0.109254999002191
# best merge is 24, 46, 0.110214952303852
# best merge is 18, 91, 0.110714824391393
# best merge is 8, 30, 0.117522974462874
# best merge is 4, 15, 0.118977896121949
# best merge is 20, 42, 0.12273746815134
# best merge is 28, 43, 0.125933594052415
# best merge is 8, 45, 0.126334691435314
# best merge is 5, 39, 0.127864539185279
# best merge is 1, 57, 0.130144000743044
# best merge is 86, 93, 0.130200602681245
# best merge is 0, 77, 0.141757300016275
# best merge is 16, 35, 0.144722644344708
# best merge is 5, 36, 0.149315921222469
# best merge is 37, 66, 0.153052617394717
# best merge is 13, 14, 0.155571157594756
# best merge is 4, 24, 0.158002483642961
# best merge is 28, 72, 0.162043441246351
# best merge is 2, 6, 0.16409205834151
# best merge is 0, 67, 0.166990402918154
# best merge is 32, 76, 0.169678423412319
# best merge is 8, 11, 0.177590568558065
# best merge is 19, 20, 0.185007689851152
# best merge is 65, 73, 0.18657665190216
# best merge is 68, 80, 0.187556951056949
# best merge is 44, 51, 0.187733071301863
# best merge is 8, 78, 0.196661508529393
# best merge is 55, 87, 0.198782021846267
# best merge is 18, 62, 0.201649820266825
# best merge is 5, 21, 0.210468041764889
# best merge is 64, 92, 0.212654038254906
# best merge is 4, 5, 0.231823400601475
# best merge is 27, 90, 0.23856550151446
# best merge is 58, 86, 0.250043151356414
# best merge is 8, 13, 0.258059840413245
# best merge is 52, 75, 0.259230748795046
# best merge is 17, 81, 0.266179033295562
# best merge is 8, 16, 0.293794668853187
# best merge is 27, 44, 0.313253702961977
# best merge is 8, 26, 0.326827522594513
# best merge is 28, 32, 0.339867530727392
# best merge is 23, 47, 0.341916821562678
# best merge is 19, 55, 0.356282299653659
# best merge is 4, 58, 0.356479242897145
# best merge is 2, 37, 0.369762088747729
# best merge is 4, 17, 0.380994428908093
# best merge is 0, 82, 0.384657440606083
# best merge is 63, 64, 0.391419375125693
# best merge is 18, 23, 0.392631693575007
# best merge is 2, 8, 0.412631702477627
# best merge is 4, 65, 0.425180023459909
# best merge is 1, 28, 0.445541984855607
# best merge is 48, 52, 0.454613482807024
# best merge is 4, 19, 0.459854813302777
# best merge is 71, 94, 0.464556253293192
# best merge is 68, 74, 0.48697087800077
# best merge is 18, 27, 0.490915422555119
# best merge is 2, 48, 0.511513275764596
# best merge is 2, 95, 0.562738412383097
# best merge is 0, 63, 0.57874409603024
# best merge is 18, 68, 0.621156478442653
# best merge is 71, 88, 0.64963938073416
# best merge is 1, 2, 0.730136090094209
# best merge is 4, 18, 0.732732724895684
# best merge is 69, 71, 0.742615475294326
# best merge is 4, 79, 0.945805147254504
# order classes
# 15 - 1.73713748344932
# 32 - 1.51402882170358
# 44 - 1.12085763308933
# 4 - 11.9750443219335
# 4 40 49 84 15 34 24 46 5 22 31 9 39 41 36 21 58 86 93 17 81 65 73 19 50 20 53 42 61 55 87 18 91 62 23 25 47 27 90 44 51 68 80 74
# 1 57 28 43 70 72 32 76 2 7 10 6 37 66 8 59 30 60 45 11 78 13 14 16 85 35 26 48 52 75 83 95
# 0 38 56 3 29 12 89 33 54 77 67 82 63 64 92
# 69 71 94 88
# 79
# Done.Start drawing
# 11.42	0.00
# RUIZ_TNC_TARGETS_UP
# MODULE_113
# CROONQUIST_NRAS_VS_STROMAL_STIMULATION_UP
# GSE40666_WT_VS_STAT4_KO_CD8_TCELL_UP
# MODULE_436
# HALLMARK_COAGULATION
# GARCIA_TARGETS_OF_FLI1_AND_DAX1_UP
# BHAT_ESR1_TARGETS_VIA_AKT1_DN
# GSE32986_UNSTIM_VS_CURDLAN_HIGHDOSE_STIM_DC_DN
# GSE21546_WT_VS_SAP1A_KO_AND_ELK1_KO_ANTI_CD3_STIM_DP_THYMOCYTES_UP
# GSE24142_ADULT_VS_FETAL_EARLY_THYMIC_PROGENITOR_UP
# GSE22886_UNSTIM_VS_IL15_STIM_NKCELL_UP
# POOLA_INVASIVE_BREAST_CANCER_DN
# MIKKELSEN_IPS_LCP_WITH_H3K4ME3
# GSE39820_CTRL_VS_IL1B_IL6_CD4_TCELL_DN
# RPS14_DN.V1_UP
# GSE22282_HYPOXIA_VS_NORMOXIA_MYELOID_DC_DN
# GSE6674_ANTI_IGM_VS_CPG_STIM_BCELL_UP
# GSE23502_BM_VS_COLON_TUMOR_HDC_KO_MYELOID_DERIVED_SUPPRESSOR_CELL_UP
# LEF1_UP.V1_DN
# RELA_DN.V1_DN
# PTEN_DN.V1_UP
# HALMOS_CEBPA_TARGETS_UP
# LEE_LIVER_CANCER_CIPROFIBRATE_DN
# GSE13485_DAY3_VS_DAY21_YF17D_VACCINE_PBMC_DN
# GSE36392_EOSINOPHIL_VS_MAC_IL25_TREATED_LUNG_UP
# MODULE_478
# E2F3_UP.V1_DN
# GO_REGULATION_OF_PATHWAY_RESTRICTED_SMAD_PROTEIN_PHOSPHORYLATION
# GSE9509_LPS_VS_LPS_AND_IL10_STIM_IL10_KO_MACROPHAGE_20MIN_UP
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3
# GSE13485_CTRL_VS_DAY1_YF17D_VACCINE_PBMC_DN
# GSE15271_CXCR4_POS_VS_NEG_GC_BCELL_DN
# GSE2770_TGFB_AND_IL4_VS_IL4_TREATED_ACT_CD4_TCELL_2H_UP
# GSE13547_2H_VS_12_H_ANTI_IGM_STIM_ZFX_KO_BCELL_UP
# GO_INTRA_GOLGI_VESICLE_MEDIATED_TRANSPORT
# GSE32533_WT_VS_MIR17_OVEREXPRESS_ACT_CD4_TCELL_DN
# GSE19772_CTRL_VS_HCMV_INF_MONOCYTES_DN
# WENDT_COHESIN_TARGETS_UP
# GSE9239_CTRL_VS_TNF_INHIBITOR_TREATED_DC_UP
# GSE9006_TYPE_1_VS_TYPE_2_DIABETES_PBMC_AT_DX_DN
# GSE41867_DAY8_EFFECTOR_VS_DAY30_MEMORY_CD8_TCELL_LCMV_ARMSTRONG_UP
# GO_HISTONE_ACETYLTRANSFERASE_BINDING
# GSE41867_NAIVE_VS_DAY15_LCMV_EFFECTOR_CD8_TCELL_DN
# GSE2770_UNTREATED_VS_TGFB_AND_IL4_TREATED_ACT_CD4_TCELL_4H_UP
# IRF2_01
# GSE27291_0H_VS_7D_STIM_GAMMADELTA_TCELL_UP
# GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ENDOPLASMIC_RETICULUM
# GSE16522_MEMORY_VS_NAIVE_ANTI_CD3CD28_STIM_CD8_TCELL_UP
# GSE13484_UNSTIM_VS_YF17D_VACCINE_STIM_PBMC_UP
# GSE27786_ERYTHROBLAST_VS_MONO_MAC_DN
# GSE17974_0.5H_VS_72H_IL4_AND_ANTI_IL12_ACT_CD4_TCELL_UP
# GSE14308_TH2_VS_TH17_DN
# MORF_BECN1
# GO_HISTONE_METHYLTRANSFERASE_COMPLEX
# GSE17721_CPG_VS_GARDIQUIMOD_1H_BMDC_DN
# GSE19888_ADENOSINE_A3R_INH_VS_ACT_WITH_INHIBITOR_PRETREATMENT_IN_MAST_CELL_DN
# GSE23505_UNTREATED_VS_4DAY_IL6_IL1_TGFB_TREATED_CD4_TCELL_UP
# GO_OXIDOREDUCTASE_ACTIVITY_ACTING_ON_NAD_P_H
# GO_REGULATION_OF_EXECUTION_PHASE_OF_APOPTOSIS
# GSE46606_UNSTIM_VS_CD40L_IL2_IL5_DAY3_STIMULATED_BCELL_DN
# MORF_RAD23B
# GSE22601_DOUBLE_NEGATIVE_VS_CD4_SINGLE_POSITIVE_THYMOCYTE_DN
# DING_LUNG_CANCER_EXPRESSION_BY_COPY_NUMBER
# TOOKER_GEMCITABINE_RESISTANCE_DN
# GSE4748_CTRL_VS_CYANOBACTERIUM_LPSLIKE_STIM_DC_1H_UP
# GSE23321_CD8_STEM_CELL_MEMORY_VS_NAIVE_CD8_TCELL_UP
# MORF_DEAF1
# GCM_CSNK1A1
# GO_ALCOHOL_BIOSYNTHETIC_PROCESS
# GO_BAF_TYPE_COMPLEX
# GO_NEGATIVE_REGULATION_OF_PEPTIDE_SECRETION
# REACTOME_MRNA_PROCESSING
# ELVIDGE_HYPOXIA_DN
# GSE21927_BALBC_VS_C57BL6_MONOCYTE_TUMOR_UP
# GSE17721_POLYIC_VS_GARDIQUIMOD_6H_BMDC_DN
# GO_S_ACYLTRANSFERASE_ACTIVITY
# GSE24210_CTRL_VS_IL35_TREATED_TCONV_CD4_TCELL_DN
# GSE19888_ADENOSINE_A3R_INH_VS_ACT_IN_MAST_CELL_UP
# GSE29615_CTRL_VS_DAY7_LAIV_FLU_VACCINE_PBMC_UP
# SRC_UP.V1_UP
# GSE37301_LYMPHOID_PRIMED_MPP_VS_PRO_BCELL_UP
# GSE16451_IMMATURE_VS_MATURE_NEURON_CELL_LINE_WEST_EQUINE_ENC_VIRUS_DN
# HALLMARK_E2F_TARGETS
# MATHEW_FANCONI_ANEMIA_GENES
# GENTLES_LEUKEMIC_STEM_CELL_DN
# GO_DNA_PACKAGING_COMPLEX
# GO_CENTRIOLE_ASSEMBLY
# GSE40068_BCL6_POS_VS_NEG_CXCR5_POS_TFH_UP
# BOYLAN_MULTIPLE_MYELOMA_C_CLUSTER_UP
# GO_REGULATION_OF_CELL_CYCLE_CHECKPOINT
# GSE21670_UNTREATED_VS_TGFB_TREATED_CD4_TCELL_UP
# GO_ENDONUCLEASE_ACTIVITY_ACTIVE_WITH_EITHER_RIBO_OR_DEOXYRIBONUCLEIC_ACIDS_AND_PRODUCING_5_PHOSPHOMONOESTERS
# GSE27786_NKCELL_VS_MONO_MAC_DN
# GSE40493_BCL6_KO_VS_WT_TREG_DN
# CAGNWMCNNNGAC_UNKNOWN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_P_LVM1_3.csv_PAGE/filt_FC_P_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_P_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 38, 56, 0.00216075950380712
# best merge is 0, 38, 0.010785089047444
# best merge is 12, 89, 0.0206065428845182
# best merge is 5, 22, 0.0220463688816502
# best merge is 0, 3, 0.0244148443773812
# best merge is 15, 34, 0.0256757561013183
# best merge is 39, 41, 0.0268132464742858
# best merge is 40, 49, 0.0309487601116935
# best merge is 0, 29, 0.030949659852065
# best merge is 12, 33, 0.0374132097677166
# best merge is 2, 7, 0.0463470255975756
# best merge is 0, 12, 0.0492165809694552
# best merge is 4, 40, 0.053090149475611
# best merge is 5, 31, 0.0552243608201837
# best merge is 0, 54, 0.0592415271958541
# best merge is 20, 53, 0.0659295131605609
# best merge is 8, 59, 0.0694302742260103
# best merge is 19, 50, 0.0763885796266458
# best merge is 30, 60, 0.0815670698972157
# best merge is 5, 9, 0.0845168879783155
# best merge is 2, 10, 0.084788871661008
# best merge is 43, 70, 0.0867388865467383
# best merge is 75, 83, 0.09735715625865
# best merge is 4, 84, 0.101093501918642
# best merge is 23, 25, 0.103619586609797
# best merge is 42, 61, 0.107273922917571
# best merge is 16, 85, 0.109254999002191
# best merge is 24, 46, 0.110214952303852
# best merge is 18, 91, 0.110714824391393
# best merge is 8, 30, 0.117522974462874
# best merge is 4, 15, 0.118977896121949
# best merge is 20, 42, 0.12273746815134
# best merge is 28, 43, 0.125933594052415
# best merge is 8, 45, 0.126334691435314
# best merge is 5, 39, 0.127864539185279
# best merge is 1, 57, 0.130144000743044
# best merge is 86, 93, 0.130200602681245
# best merge is 0, 77, 0.141757300016275
# best merge is 16, 35, 0.144722644344708
# best merge is 5, 36, 0.149315921222469
# best merge is 37, 66, 0.153052617394717
# best merge is 13, 14, 0.155571157594756
# best merge is 4, 24, 0.158002483642961
# best merge is 28, 72, 0.162043441246351
# best merge is 2, 6, 0.16409205834151
# best merge is 0, 67, 0.166990402918154
# best merge is 32, 76, 0.169678423412319
# best merge is 8, 11, 0.177590568558065
# best merge is 19, 20, 0.185007689851152
# best merge is 65, 73, 0.18657665190216
# best merge is 68, 80, 0.187556951056949
# best merge is 44, 51, 0.187733071301863
# best merge is 8, 78, 0.196661508529393
# best merge is 55, 87, 0.198782021846267
# best merge is 18, 62, 0.201649820266825
# best merge is 5, 21, 0.210468041764889
# best merge is 64, 92, 0.212654038254906
# best merge is 4, 5, 0.231823400601475
# best merge is 27, 90, 0.23856550151446
# best merge is 58, 86, 0.250043151356414
# best merge is 8, 13, 0.258059840413245
# best merge is 52, 75, 0.259230748795046
# best merge is 17, 81, 0.266179033295562
# best merge is 8, 16, 0.293794668853187
# best merge is 27, 44, 0.313253702961977
# best merge is 8, 26, 0.326827522594513
# best merge is 28, 32, 0.339867530727392
# best merge is 23, 47, 0.341916821562678
# best merge is 19, 55, 0.356282299653659
# best merge is 4, 58, 0.356479242897145
# best merge is 2, 37, 0.369762088747729
# best merge is 4, 17, 0.380994428908093
# best merge is 0, 82, 0.384657440606083
# best merge is 63, 64, 0.391419375125693
# best merge is 18, 23, 0.392631693575007
# best merge is 2, 8, 0.412631702477627
# best merge is 4, 65, 0.425180023459909
# best merge is 1, 28, 0.445541984855607
# best merge is 48, 52, 0.454613482807024
# best merge is 4, 19, 0.459854813302777
# best merge is 71, 94, 0.464556253293192
# best merge is 68, 74, 0.48697087800077
# best merge is 18, 27, 0.490915422555119
# best merge is 2, 48, 0.511513275764596
# best merge is 2, 95, 0.562738412383097
# best merge is 0, 63, 0.57874409603024
# best merge is 18, 68, 0.621156478442653
# best merge is 71, 88, 0.64963938073416
# best merge is 1, 2, 0.730136090094209
# best merge is 4, 18, 0.732732724895684
# best merge is 69, 71, 0.742615475294326
# best merge is 4, 79, 0.945805147254504
# order classes
# 15 - 1.73713748344932
# 32 - 1.51402882170358
# 44 - 1.12085763308933
# 4 - 11.9750443219335
# 4 40 49 84 15 34 24 46 5 22 31 9 39 41 36 21 58 86 93 17 81 65 73 19 50 20 53 42 61 55 87 18 91 62 23 25 47 27 90 44 51 68 80 74
# 1 57 28 43 70 72 32 76 2 7 10 6 37 66 8 59 30 60 45 11 78 13 14 16 85 35 26 48 52 75 83 95
# 0 38 56 3 29 12 89 33 54 77 67 82 63 64 92
# 69 71 94 88
# 79
# Done.-19.1725043782837	42	0
# -18.1059544658494	42	1.65499124343257
# -17.7381786339755	42	2.13309982486865
# -17.4807355516637	42	2.39054290718039
# -17.223292469352	42	2.64798598949212
# -16.9658493870403	42	2.90542907180385
# -16.6348511383538	42	3.16287215411559
# -16.0831873905429	42	3.56742556917688
# 3.13309982486865	42	4.2661996497373
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_full/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# sem --wait done
