# %% [markdown]
# # This is used for running data vs human_msigdb_h annotations located in:
# ### /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import scipy.stats

# %% [markdown]
# ### get index of file names to loop through

# %%
# %%bash
#
# cd fc_values
# ls FC* > filelist.txt
# cd ..

# %% [markdown]
# ### get ensembl genes represented in iPAGE database

# %%
# %%bash
#
# cp /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h_index.txt human_ensembl_index.txt
# awk '{print $1}' human_ensembl_index.txt > ensembl_index.txt

# %% [markdown]
# ### make sure that genes in file match the index

# %%
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
###################REMEMBER TO SPECIFY INDEX USED IN THE IPAGE COMMAND!!!!!!!!
###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


#####################
#######read in data from logfc calculations
#####################
####define index file to loop through
index_file = "fc_values/filelist.txt"
####define matching ensg index
GO_index_filename = "ensembl_index.txt"
genes_with_GOs = []
with open(GO_index_filename,'r') as rf:
    for line in rf:
        gene_name = line.split('\n')[0]
        genes_with_GOs.append(gene_name)
genes_with_GOs_set = set(genes_with_GOs)
####open file and loop through each line
###
iPAGE_sh = "iPAGE_JY.sh"
cwd = os.getcwd()+"/"
os.system("rm "+iPAGE_sh)
###
with open(index_file,'r') as rf:
    for line in rf:
        #####do this to each file
        ###read in file into pandas df
        FC_file = "fc_values/"+line.split('\n')[0]
        FC_df = pd.read_csv(FC_file,sep=',',index_col=0)
        FC_df.columns = ['log2FoldChange']
        FC_df.index.names = ['Gene']
        ###filter
        FC_df = FC_df.loc[[x for x in FC_df.index if x in genes_with_GOs_set]]
        ###save
        save_file = "fc_values/filt_"+line.split('\n')[0]
        FC_df.to_csv(save_file,sep='\t',header=True)
        ###write final iPAGE command to an ipage .sh file
        iPAGE_cmd = "perl /nvme/bins/iPAGEv1.0/page.pl --expfile "+cwd+save_file+" --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9 \n"
        with open(iPAGE_sh, "a") as myfile:
            myfile.write(iPAGE_cmd)

# %% [markdown]
# ## then run the command from this folder:
#
# nohup sh run.sh iPAGE_JY.sh &

# %%
# %%bash
#
# nohup sh run.sh iPAGE_JY.sh &
# Out:
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 31, mi = 0.00402943, HALLMARK_MYC_TARGETS_V1
# cat 35, mi = 0.00364003, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 21, mi = 0.00316602, HALLMARK_HYPOXIA
# cat 28, mi = 0.00307932, HALLMARK_KRAS_SIGNALING_UP
# cat 14, mi = 0.00294816, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 13, mi = 0.00254662, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 15, mi = 0.00221399, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 12, mi = 0.00198122, HALLMARK_E2F_TARGETS
# cat 22, mi = 0.00150992, HALLMARK_IL2_STAT5_SIGNALING
# cat 27, mi = 0.00136738, HALLMARK_KRAS_SIGNALING_DN
# cat 3, mi = 0.00128901, HALLMARK_ANGIOGENESIS
# cat 45, mi = 0.00120339, HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# cat 4, mi = 0.00112512, HALLMARK_APICAL_JUNCTION
# cat 33, mi = 0.00111890, HALLMARK_MYOGENESIS
# cat 25, mi = 0.00098352, HALLMARK_INTERFERON_ALPHA_RESPONSE
#
# RESULTS
# Passed: cat 31, mi = 0.004, pvalue = 0.000, HALLMARK_MYC_TARGETS_V1
# Passed: cat 35, mi = 0.004, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 21, mi = 0.003, pvalue = 0.000, HALLMARK_HYPOXIA
# Passed: cat 27, mi = 0.001, pvalue = 0.004, HALLMARK_KRAS_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 25, mi = 0.001, pvalue = 0.041, HALLMARK_INTERFERON_ALPHA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 40, mi = 0.001, pvalue = 0.079, HALLMARK_PROTEIN_SECRETION
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.000, pvalue = 0.578, HALLMARK_PANCREAS_BETA_CELLS
# Number of categories that passed the tests = 4
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 1, 0.090057818570299
# order classes
# 0
# 1
# 2
# 3
# Done.Start drawing
# 23.77	0.00
# HALLMARK_HYPOXIA
# HALLMARK_MYC_TARGETS_V1
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_KRAS_SIGNALING_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv_PAGE/filt_FC_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 1, 0.090057818570299
# order classes
# 0
# 1
# 2
# 3
# Done.-19.2932267564156	42	0
# -18.4450988641144	42	1.4135464871687
# -18.2153975599495	42	1.69625578460244
# -18.056373580143	42	1.87294909549853
# -17.8973496003366	42	2.0143037442154
# -17.7206562894405	42	2.19099705511149
# -17.51745898191	42	2.36769036600757
# -17.2082456878418	42	2.59739167017249
# 2.49305847707194	42	2.98611695414388
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 17, mi = 0.00859296, HALLMARK_G2M_CHECKPOINT
# cat 35, mi = 0.00727555, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 31, mi = 0.00675726, HALLMARK_MYC_TARGETS_V1
# cat 29, mi = 0.00555860, HALLMARK_MITOTIC_SPINDLE
# cat 12, mi = 0.00414096, HALLMARK_E2F_TARGETS
# cat 13, mi = 0.00281477, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 30, mi = 0.00264392, HALLMARK_MTORC1_SIGNALING
# cat 28, mi = 0.00208604, HALLMARK_KRAS_SIGNALING_UP
# cat 21, mi = 0.00203456, HALLMARK_HYPOXIA
# cat 32, mi = 0.00187087, HALLMARK_MYC_TARGETS_V2
# cat 22, mi = 0.00178002, HALLMARK_IL2_STAT5_SIGNALING
# cat 44, mi = 0.00171004, HALLMARK_TNFA_SIGNALING_VIA_NFKB
# cat 14, mi = 0.00157140, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 15, mi = 0.00145578, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 11, mi = 0.00143991, HALLMARK_DNA_REPAIR
#
# RESULTS
# Passed: cat 17, mi = 0.009, pvalue = 0.000, HALLMARK_G2M_CHECKPOINT
# Passed: cat 35, mi = 0.007, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 13, mi = 0.003, pvalue = 0.000, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# Passed: cat 30, mi = 0.003, pvalue = 0.000, HALLMARK_MTORC1_SIGNALING
# Passed: cat 11, mi = 0.001, pvalue = 0.003, HALLMARK_DNA_REPAIR
# Didn't pass (cutoff=0.0050): cat 27, mi = 0.001, pvalue = 0.010, HALLMARK_KRAS_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.001, pvalue = 0.250, HALLMARK_PANCREAS_BETA_CELLS
# Number of categories that passed the tests = 5
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 2, 0.144634987105933
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.Start drawing
# 62.96	0.00
# HALLMARK_G2M_CHECKPOINT
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_DNA_REPAIR
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_MTORC1_SIGNALING
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv_PAGE/filt_FC_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 2, 0.144634987105933
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.-19.7198221092757	42	0
# -19.3562579415502	42	0.560355781448539
# -19.2195044472681	42	0.72712833545108
# -19.1227763659466	42	0.833862770012706
# -19.0360546378653	42	0.920584498094028
# -18.9459974587039	42	1.00730622617535
# -18.8359275730623	42	1.10069885641677
# -18.6558132147395	42	1.2274459974587
# 1.73046378653113	42	1.46092757306226
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 12, mi = 0.01451505, HALLMARK_E2F_TARGETS
# cat 17, mi = 0.00929300, HALLMARK_G2M_CHECKPOINT
# cat 31, mi = 0.00645276, HALLMARK_MYC_TARGETS_V1
# cat 35, mi = 0.00488353, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 13, mi = 0.00412606, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 21, mi = 0.00328139, HALLMARK_HYPOXIA
# cat 15, mi = 0.00260575, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 9, mi = 0.00218566, HALLMARK_COAGULATION
# cat 22, mi = 0.00216648, HALLMARK_IL2_STAT5_SIGNALING
# cat 29, mi = 0.00183171, HALLMARK_MITOTIC_SPINDLE
# cat 42, mi = 0.00175704, HALLMARK_SPERMATOGENESIS
# cat 24, mi = 0.00168529, HALLMARK_INFLAMMATORY_RESPONSE
# cat 10, mi = 0.00152896, HALLMARK_COMPLEMENT
# cat 44, mi = 0.00149798, HALLMARK_TNFA_SIGNALING_VIA_NFKB
# cat 43, mi = 0.00138563, HALLMARK_TGF_BETA_SIGNALING
#
# RESULTS
# Passed: cat 12, mi = 0.015, pvalue = 0.000, HALLMARK_E2F_TARGETS
# Passed: cat 35, mi = 0.005, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 13, mi = 0.004, pvalue = 0.000, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# Passed: cat 15, mi = 0.003, pvalue = 0.000, HALLMARK_ESTROGEN_RESPONSE_LATE
# Didn't pass (cutoff=0.0050): cat 27, mi = 0.001, pvalue = 0.006, HALLMARK_KRAS_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 19, mi = 0.001, pvalue = 0.013, HALLMARK_HEDGEHOG_SIGNALING
# Didn't pass (cutoff=0.0050): cat 40, mi = 0.001, pvalue = 0.009, HALLMARK_PROTEIN_SECRETION
# Didn't pass (cutoff=0.0050): cat 25, mi = 0.001, pvalue = 0.025, HALLMARK_INTERFERON_ALPHA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 26, mi = 0.001, pvalue = 0.056, HALLMARK_INTERFERON_GAMMA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.001, pvalue = 0.142, HALLMARK_PANCREAS_BETA_CELLS
# Didn't pass (cutoff=0.0050): cat 20, mi = 0.001, pvalue = 0.139, HALLMARK_HEME_METABOLISM
# Number of categories that passed the tests = 4
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 3, 0.199551099985471
# order classes
# 0
# 1
# 2
# 3
# Done.Start drawing
# 84.94	0.00
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_E2F_TARGETS
# HALLMARK_ESTROGEN_RESPONSE_LATE
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv_PAGE/filt_FC_LVM1_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 3, 0.199551099985471
# order classes
# 0
# 1
# 2
# 3
# Done.-19.849187661879	42	0
# -19.6588179891688	42	0.301624676242053
# -19.5920649870497	42	0.380739345420297
# -19.5401459854015	42	0.435130680480339
# -19.4931716505769	42	0.484577348716741
# -19.4437249823405	42	0.529079350129503
# -19.3769719802213	42	0.583470685189545
# -19.2706616435131	42	0.662585354367789
# 1.39804567930304	42	0.796091358606075
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 13, mi = 0.00395799, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 31, mi = 0.00388809, HALLMARK_MYC_TARGETS_V1
# cat 21, mi = 0.00346416, HALLMARK_HYPOXIA
# cat 35, mi = 0.00324975, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 44, mi = 0.00253590, HALLMARK_TNFA_SIGNALING_VIA_NFKB
# cat 30, mi = 0.00239465, HALLMARK_MTORC1_SIGNALING
# cat 45, mi = 0.00234484, HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# cat 11, mi = 0.00207305, HALLMARK_DNA_REPAIR
# cat 14, mi = 0.00175443, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 43, mi = 0.00164592, HALLMARK_TGF_BETA_SIGNALING
# cat 17, mi = 0.00154606, HALLMARK_G2M_CHECKPOINT
# cat 27, mi = 0.00153445, HALLMARK_KRAS_SIGNALING_DN
# cat 40, mi = 0.00141978, HALLMARK_PROTEIN_SECRETION
# cat 22, mi = 0.00127819, HALLMARK_IL2_STAT5_SIGNALING
# cat 24, mi = 0.00125099, HALLMARK_INFLAMMATORY_RESPONSE
#
# RESULTS
# Passed: cat 13, mi = 0.004, pvalue = 0.000, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# Passed: cat 31, mi = 0.004, pvalue = 0.000, HALLMARK_MYC_TARGETS_V1
# Passed: cat 14, mi = 0.002, pvalue = 0.000, HALLMARK_ESTROGEN_RESPONSE_EARLY
# Passed: cat 27, mi = 0.002, pvalue = 0.001, HALLMARK_KRAS_SIGNALING_DN
# Passed: cat 40, mi = 0.001, pvalue = 0.004, HALLMARK_PROTEIN_SECRETION
# Didn't pass (cutoff=0.0050): cat 16, mi = 0.001, pvalue = 0.018, HALLMARK_FATTY_ACID_METABOLISM
# Didn't pass (cutoff=0.0050): cat 41, mi = 0.001, pvalue = 0.082, HALLMARK_REACTIVE_OXIGEN_SPECIES_PATHWAY
# Didn't pass (cutoff=0.0050): cat 20, mi = 0.001, pvalue = 0.082, HALLMARK_HEME_METABOLISM
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.001, pvalue = 0.402, HALLMARK_PANCREAS_BETA_CELLS
# Didn't pass (cutoff=0.0050): cat 26, mi = 0.000, pvalue = 0.671, HALLMARK_INTERFERON_GAMMA_RESPONSE
# Number of categories that passed the tests = 5
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 2, 3, 0.0707572637932846
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.Start drawing
# 26.31	0.00
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_MYC_TARGETS_V1
# HALLMARK_PROTEIN_SECRETION
# HALLMARK_ESTROGEN_RESPONSE_EARLY
# HALLMARK_KRAS_SIGNALING_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv_PAGE/filt_FC_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv_PAGE/filt_FC_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 2, 3, 0.0707572637932846
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.-19.5290763968073	42	0
# -18.9064994298746	42	0.941847206385405
# -18.6590649942987	42	1.24515393386545
# -18.4754846066135	42	1.43671607753706
# -18.3158494868871	42	1.61231470923603
# -18.1641961231471	42	1.75598631698974
# -17.9806157354618	42	1.91562143671608
# -17.709236031927	42	2.12314709236032
# 2.22919042189282	42	2.45838084378563
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 35, mi = 0.00579370, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 31, mi = 0.00576601, HALLMARK_MYC_TARGETS_V1
# cat 13, mi = 0.00354515, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 21, mi = 0.00311282, HALLMARK_HYPOXIA
# cat 15, mi = 0.00284614, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 14, mi = 0.00228339, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 28, mi = 0.00219582, HALLMARK_KRAS_SIGNALING_UP
# cat 11, mi = 0.00204633, HALLMARK_DNA_REPAIR
# cat 27, mi = 0.00185440, HALLMARK_KRAS_SIGNALING_DN
# cat 33, mi = 0.00183134, HALLMARK_MYOGENESIS
# cat 19, mi = 0.00168289, HALLMARK_HEDGEHOG_SIGNALING
# cat 22, mi = 0.00168092, HALLMARK_IL2_STAT5_SIGNALING
# cat 42, mi = 0.00166832, HALLMARK_SPERMATOGENESIS
# cat 4, mi = 0.00135876, HALLMARK_APICAL_JUNCTION
# cat 24, mi = 0.00134864, HALLMARK_INFLAMMATORY_RESPONSE
#
# RESULTS
# Passed: cat 35, mi = 0.006, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 31, mi = 0.006, pvalue = 0.000, HALLMARK_MYC_TARGETS_V1
# Passed: cat 13, mi = 0.004, pvalue = 0.000, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# Passed: cat 15, mi = 0.003, pvalue = 0.000, HALLMARK_ESTROGEN_RESPONSE_LATE
# Passed: cat 27, mi = 0.002, pvalue = 0.000, HALLMARK_KRAS_SIGNALING_DN
# Passed: cat 19, mi = 0.002, pvalue = 0.001, HALLMARK_HEDGEHOG_SIGNALING
# Passed: cat 42, mi = 0.002, pvalue = 0.001, HALLMARK_SPERMATOGENESIS
# Didn't pass (cutoff=0.0050): cat 26, mi = 0.001, pvalue = 0.082, HALLMARK_INTERFERON_GAMMA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 40, mi = 0.001, pvalue = 0.117, HALLMARK_PROTEIN_SECRETION
# Number of categories that passed the tests = 7
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 1, 0.174509925218522
# best merge is 2, 5, 0.183257065402233
# best merge is 3, 4, 0.263893441316918
# order classes
# 2 - 0.305392369132414
# 2 - 0.320699864453908
# 0 1
# 2 5
# 3
# 4
# 6
# Done.Start drawing
# 70.09	0.00
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_HEDGEHOG_SIGNALING
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_MYC_TARGETS_V1
# HALLMARK_ESTROGEN_RESPONSE_LATE
# HALLMARK_KRAS_SIGNALING_DN
# HALLMARK_SPERMATOGENESIS
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv_PAGE/filt_FC_LVM2_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv_PAGE/filt_FC_LVM2_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 1, 0.174509925218522
# best merge is 2, 5, 0.183257065402233
# best merge is 3, 4, 0.263893441316918
# order classes
# 2 - 0.305392369132414
# 2 - 0.320699864453908
# 0 1
# 2 5
# 3
# 4
# 6
# Done.-19.784277357683	42	0
# -19.5056356113568	42	0.431445284634042
# -19.4037665858182	42	0.557283492652304
# -19.3318590383792	42	0.635183335711228
# -19.2689399343701	42	0.701098587530318
# -19.203024682551	42	0.761021543729491
# -19.1221286916821	42	0.832929091168498
# -18.9902981880439	42	0.922813525467256
# 1.54829504922243	42	1.09659009844486
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_1.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 35, mi = 0.00568825, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 31, mi = 0.00409662, HALLMARK_MYC_TARGETS_V1
# cat 12, mi = 0.00330719, HALLMARK_E2F_TARGETS
# cat 14, mi = 0.00281423, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 28, mi = 0.00264682, HALLMARK_KRAS_SIGNALING_UP
# cat 21, mi = 0.00263852, HALLMARK_HYPOXIA
# cat 27, mi = 0.00263243, HALLMARK_KRAS_SIGNALING_DN
# cat 13, mi = 0.00254945, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 17, mi = 0.00254541, HALLMARK_G2M_CHECKPOINT
# cat 15, mi = 0.00233855, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 22, mi = 0.00166764, HALLMARK_IL2_STAT5_SIGNALING
# cat 24, mi = 0.00144452, HALLMARK_INFLAMMATORY_RESPONSE
# cat 39, mi = 0.00136224, HALLMARK_PI3K_AKT_MTOR_SIGNALING
# cat 33, mi = 0.00122202, HALLMARK_MYOGENESIS
# cat 29, mi = 0.00120373, HALLMARK_MITOTIC_SPINDLE
#
# RESULTS
# Passed: cat 35, mi = 0.006, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 31, mi = 0.004, pvalue = 0.000, HALLMARK_MYC_TARGETS_V1
# Passed: cat 14, mi = 0.003, pvalue = 0.000, HALLMARK_ESTROGEN_RESPONSE_EARLY
# Passed: cat 28, mi = 0.003, pvalue = 0.000, HALLMARK_KRAS_SIGNALING_UP
# Passed: cat 27, mi = 0.003, pvalue = 0.000, HALLMARK_KRAS_SIGNALING_DN
# Passed: cat 39, mi = 0.001, pvalue = 0.004, HALLMARK_PI3K_AKT_MTOR_SIGNALING
# Didn't pass (cutoff=0.0050): cat 20, mi = 0.001, pvalue = 0.055, HALLMARK_HEME_METABOLISM
# Didn't pass (cutoff=0.0050): cat 19, mi = 0.001, pvalue = 0.088, HALLMARK_HEDGEHOG_SIGNALING
# Didn't pass (cutoff=0.0050): cat 34, mi = 0.001, pvalue = 0.154, HALLMARK_NOTCH_SIGNALING
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.000, pvalue = 0.558, HALLMARK_PANCREAS_BETA_CELLS
# Number of categories that passed the tests = 6
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 2, 4, 0.0428248126622739
# best merge is 2, 3, 0.0601115255477456
# order classes
# 2 - 0.0642372189934108
# 2 4
# 1
# 0
# 3
# 5
# Done.Start drawing
# 101.03	0.00
# HALLMARK_PI3K_AKT_MTOR_SIGNALING
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_MYC_TARGETS_V1
# HALLMARK_ESTROGEN_RESPONSE_EARLY
# HALLMARK_KRAS_SIGNALING_DN
# HALLMARK_KRAS_SIGNALING_UP
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv_PAGE/filt_FC_LVM2_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv_PAGE/filt_FC_LVM2_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 2, 4, 0.0428248126622739
# best merge is 2, 3, 0.0601115255477456
# order classes
# 2 - 0.0642372189934108
# 2 4
# 1
# 0
# 3
# 5
# Done.-19.8544986637632	42	0
# -19.6570325645848	42	0.291002672473523
# -19.5759675343957	42	0.394932198356924
# -19.5219241809364	42	0.453132732851628
# -19.4720380085123	42	0.503018905275661
# -19.417994655053	42	0.552905077699693
# -19.3514797584876	42	0.611105612194398
# -19.2454716420865	42	0.685934870830446
# 1.41156092249827	42	0.823121844996536
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_2.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 17, mi = 0.00993515, HALLMARK_G2M_CHECKPOINT
# cat 35, mi = 0.00645828, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 31, mi = 0.00617122, HALLMARK_MYC_TARGETS_V1
# cat 29, mi = 0.00598755, HALLMARK_MITOTIC_SPINDLE
# cat 12, mi = 0.00481975, HALLMARK_E2F_TARGETS
# cat 13, mi = 0.00331614, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 28, mi = 0.00260967, HALLMARK_KRAS_SIGNALING_UP
# cat 11, mi = 0.00244020, HALLMARK_DNA_REPAIR
# cat 32, mi = 0.00234564, HALLMARK_MYC_TARGETS_V2
# cat 21, mi = 0.00202155, HALLMARK_HYPOXIA
# cat 27, mi = 0.00194724, HALLMARK_KRAS_SIGNALING_DN
# cat 4, mi = 0.00176981, HALLMARK_APICAL_JUNCTION
# cat 15, mi = 0.00174878, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 14, mi = 0.00158778, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 39, mi = 0.00134164, HALLMARK_PI3K_AKT_MTOR_SIGNALING
#
# RESULTS
# Passed: cat 17, mi = 0.010, pvalue = 0.000, HALLMARK_G2M_CHECKPOINT
# Passed: cat 35, mi = 0.006, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 13, mi = 0.003, pvalue = 0.000, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# Passed: cat 11, mi = 0.002, pvalue = 0.000, HALLMARK_DNA_REPAIR
# Passed: cat 27, mi = 0.002, pvalue = 0.000, HALLMARK_KRAS_SIGNALING_DN
# Passed: cat 15, mi = 0.002, pvalue = 0.000, HALLMARK_ESTROGEN_RESPONSE_LATE
# Passed: cat 39, mi = 0.001, pvalue = 0.003, HALLMARK_PI3K_AKT_MTOR_SIGNALING
# Didn't pass (cutoff=0.0050): cat 25, mi = 0.001, pvalue = 0.006, HALLMARK_INTERFERON_ALPHA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 20, mi = 0.001, pvalue = 0.086, HALLMARK_HEME_METABOLISM
# Didn't pass (cutoff=0.0050): cat 48, mi = 0.001, pvalue = 0.381, HALLMARK_WNT_BETA_CATENIN_SIGNALING
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.000, pvalue = 0.878, HALLMARK_PANCREAS_BETA_CELLS
# Number of categories that passed the tests = 7
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 2, 0.0566657163570179
# best merge is 4, 5, 0.0854781911279826
# best merge is 1, 3, 0.266205201646975
# order classes
# 2 - 0.0991650036247813
# 2 - 0.14958683447397
# 0 2
# 1
# 3
# 4 5
# 6
# Done.Start drawing
# 69.14	0.00
# HALLMARK_G2M_CHECKPOINT
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_PI3K_AKT_MTOR_SIGNALING
# HALLMARK_DNA_REPAIR
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_KRAS_SIGNALING_DN
# HALLMARK_ESTROGEN_RESPONSE_LATE
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv_PAGE/filt_FC_LVM2_3.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv_PAGE/filt_FC_LVM2_3.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 2, 0.0566657163570179
# best merge is 4, 5, 0.0854781911279826
# best merge is 1, 3, 0.266205201646975
# order classes
# 2 - 0.0991650036247813
# 2 - 0.14958683447397
# 0 2
# 1
# 3
# 4 5
# 6
# Done.-19.7843505929997	42	0
# -19.4715070870697	42	0.431298814000579
# -19.3166039919005	42	0.625687011859994
# -19.2133352617877	42	0.741105004339022
# -19.1191784784495	42	0.832224472085623
# -19.0189470639283	42	0.929418571015331
# -18.8974544402661	42	1.03268730112815
# -18.7000289268152	42	1.1724038183396
# 1.71376916401504	42	1.42753832803008
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_3.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 12, mi = 0.01327034, HALLMARK_E2F_TARGETS
# cat 17, mi = 0.00797554, HALLMARK_G2M_CHECKPOINT
# cat 31, mi = 0.00722078, HALLMARK_MYC_TARGETS_V1
# cat 35, mi = 0.00629390, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 13, mi = 0.00283553, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 21, mi = 0.00270241, HALLMARK_HYPOXIA
# cat 15, mi = 0.00231761, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 9, mi = 0.00223698, HALLMARK_COAGULATION
# cat 29, mi = 0.00213774, HALLMARK_MITOTIC_SPINDLE
# cat 14, mi = 0.00211595, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 32, mi = 0.00188744, HALLMARK_MYC_TARGETS_V2
# cat 22, mi = 0.00154069, HALLMARK_IL2_STAT5_SIGNALING
# cat 24, mi = 0.00132321, HALLMARK_INFLAMMATORY_RESPONSE
# cat 44, mi = 0.00129493, HALLMARK_TNFA_SIGNALING_VIA_NFKB
# cat 27, mi = 0.00127936, HALLMARK_KRAS_SIGNALING_DN
#
# RESULTS
# Passed: cat 12, mi = 0.013, pvalue = 0.000, HALLMARK_E2F_TARGETS
# Passed: cat 35, mi = 0.006, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 13, mi = 0.003, pvalue = 0.000, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# Passed: cat 15, mi = 0.002, pvalue = 0.000, HALLMARK_ESTROGEN_RESPONSE_LATE
# Didn't pass (cutoff=0.0050): cat 27, mi = 0.001, pvalue = 0.007, HALLMARK_KRAS_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 19, mi = 0.001, pvalue = 0.011, HALLMARK_HEDGEHOG_SIGNALING
# Didn't pass (cutoff=0.0050): cat 40, mi = 0.001, pvalue = 0.013, HALLMARK_PROTEIN_SECRETION
# Didn't pass (cutoff=0.0050): cat 25, mi = 0.001, pvalue = 0.043, HALLMARK_INTERFERON_ALPHA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 20, mi = 0.001, pvalue = 0.044, HALLMARK_HEME_METABOLISM
# Didn't pass (cutoff=0.0050): cat 5, mi = 0.001, pvalue = 0.144, HALLMARK_APICAL_SURFACE
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.001, pvalue = 0.181, HALLMARK_PANCREAS_BETA_CELLS
# Didn't pass (cutoff=0.0050): cat 26, mi = 0.001, pvalue = 0.161, HALLMARK_INTERFERON_GAMMA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 48, mi = 0.001, pvalue = 0.196, HALLMARK_WNT_BETA_CATENIN_SIGNALING
# Number of categories that passed the tests = 4
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 3, 0.0776273099173319
# order classes
# 0
# 1
# 2
# 3
# Done.Start drawing
# 100.30	0.00
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_E2F_TARGETS
# HALLMARK_ESTROGEN_RESPONSE_LATE
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv_PAGE/filt_FC_LVM2_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv_PAGE/filt_FC_LVM2_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 3, 0.0776273099173319
# order classes
# 0
# 1
# 2
# 3
# Done.-19.8911266201396	42	0
# -19.7403788634098	42	0.217746759720837
# -19.6712861415753	42	0.301495513459621
# -19.621036889332	42	0.355932203389831
# -19.5728813559322	42	0.401994017946162
# -19.5163509471585	42	0.452243270189432
# -19.4451645064806	42	0.515054835493519
# -19.3321036889332	42	0.594616151545364
# 1.37058823529411	42	0.741176470588235
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_4.csv_PAGE/pvmatrix.txt
# DONE
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_3.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# done
# perl /nvme/bins/iPAGEv1.0/page.pl --expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv --species=human_ensembl_msigdb_h --exptype=continuous --ebins=9
# done
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 31, mi = 0.00486083, HALLMARK_MYC_TARGETS_V1
# cat 35, mi = 0.00427599, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 21, mi = 0.00356645, HALLMARK_HYPOXIA
# cat 13, mi = 0.00310161, HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# cat 14, mi = 0.00275426, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 28, mi = 0.00263490, HALLMARK_KRAS_SIGNALING_UP
# cat 15, mi = 0.00231143, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 11, mi = 0.00230817, HALLMARK_DNA_REPAIR
# cat 30, mi = 0.00226446, HALLMARK_MTORC1_SIGNALING
# cat 27, mi = 0.00218641, HALLMARK_KRAS_SIGNALING_DN
# cat 17, mi = 0.00208046, HALLMARK_G2M_CHECKPOINT
# cat 9, mi = 0.00178802, HALLMARK_COAGULATION
# cat 19, mi = 0.00174904, HALLMARK_HEDGEHOG_SIGNALING
# cat 32, mi = 0.00169142, HALLMARK_MYC_TARGETS_V2
# cat 12, mi = 0.00163933, HALLMARK_E2F_TARGETS
#
# RESULTS
# Passed: cat 31, mi = 0.005, pvalue = 0.000, HALLMARK_MYC_TARGETS_V1
# Passed: cat 35, mi = 0.004, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 21, mi = 0.004, pvalue = 0.000, HALLMARK_HYPOXIA
# Passed: cat 11, mi = 0.002, pvalue = 0.000, HALLMARK_DNA_REPAIR
# Passed: cat 27, mi = 0.002, pvalue = 0.000, HALLMARK_KRAS_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 40, mi = 0.001, pvalue = 0.066, HALLMARK_PROTEIN_SECRETION
# Didn't pass (cutoff=0.0050): cat 43, mi = 0.001, pvalue = 0.122, HALLMARK_TGF_BETA_SIGNALING
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.000, pvalue = 0.735, HALLMARK_PANCREAS_BETA_CELLS
# Number of categories that passed the tests = 5
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 1, 0.0812669693707017
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.Start drawing
# 66.19	0.00
# HALLMARK_HYPOXIA
# HALLMARK_MYC_TARGETS_V1
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_DNA_REPAIR
# HALLMARK_KRAS_SIGNALING_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv_PAGE/filt_FC_LVM2_5.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv_PAGE/filt_FC_LVM2_5.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 1, 0.0812669693707017
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.-19.8477111346125	42	0
# -19.6224505212268	42	0.304577730775042
# -19.501888502795	42	0.450521226771416
# -19.4130533313189	42	0.545701767638616
# -19.330563529234	42	0.628191569723523
# -19.2480737271491	42	0.71068137180843
# -19.1528931862819	42	0.793171173893337
# -19.0196404290678	42	0.901042453542831
# 1.52983834416075	42	1.0596766883215
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_LVM2_5.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# ...
# -18.1059544658494	42	1.65499124343257
# -17.7381786339755	42	2.13309982486865
# -17.4807355516637	42	2.39054290718039
# -17.223292469352	42	2.64798598949212
# -16.9658493870403	42	2.90542907180385
# -16.6348511383538	42	3.16287215411559
# -16.0831873905429	42	3.56742556917688
# 3.13309982486865	42	4.2661996497373
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_3.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 31, mi = 0.01594744, HALLMARK_MYC_TARGETS_V1
# cat 35, mi = 0.00712526, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 12, mi = 0.00626337, HALLMARK_E2F_TARGETS
# cat 17, mi = 0.00375703, HALLMARK_G2M_CHECKPOINT
# cat 30, mi = 0.00314134, HALLMARK_MTORC1_SIGNALING
# cat 11, mi = 0.00260539, HALLMARK_DNA_REPAIR
# cat 45, mi = 0.00217824, HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# cat 46, mi = 0.00164600, HALLMARK_UV_RESPONSE_DN
# cat 2, mi = 0.00131286, HALLMARK_ANDROGEN_RESPONSE
# cat 16, mi = 0.00120573, HALLMARK_FATTY_ACID_METABOLISM
# cat 0, mi = 0.00119267, HALLMARK_ADIPOGENESIS
# cat 32, mi = 0.00111981, HALLMARK_MYC_TARGETS_V2
# cat 14, mi = 0.00108704, HALLMARK_ESTROGEN_RESPONSE_EARLY
# cat 47, mi = 0.00100546, HALLMARK_UV_RESPONSE_UP
# cat 24, mi = 0.00098405, HALLMARK_INFLAMMATORY_RESPONSE
#
# RESULTS
# Passed: cat 31, mi = 0.016, pvalue = 0.000, HALLMARK_MYC_TARGETS_V1
# Passed: cat 35, mi = 0.007, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 11, mi = 0.003, pvalue = 0.000, HALLMARK_DNA_REPAIR
# Passed: cat 46, mi = 0.002, pvalue = 0.001, HALLMARK_UV_RESPONSE_DN
# Didn't pass (cutoff=0.0050): cat 42, mi = 0.001, pvalue = 0.054, HALLMARK_SPERMATOGENESIS
# Didn't pass (cutoff=0.0050): cat 40, mi = 0.001, pvalue = 0.118, HALLMARK_PROTEIN_SECRETION
# Didn't pass (cutoff=0.0050): cat 25, mi = 0.001, pvalue = 0.172, HALLMARK_INTERFERON_ALPHA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 23, mi = 0.001, pvalue = 0.198, HALLMARK_IL6_JAK_STAT3_SIGNALING
# Didn't pass (cutoff=0.0050): cat 26, mi = 0.001, pvalue = 0.216, HALLMARK_INTERFERON_GAMMA_RESPONSE
# Didn't pass (cutoff=0.0050): cat 15, mi = 0.001, pvalue = 0.367, HALLMARK_ESTROGEN_RESPONSE_LATE
# Didn't pass (cutoff=0.0050): cat 5, mi = 0.000, pvalue = 0.642, HALLMARK_APICAL_SURFACE
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.000, pvalue = 0.710, HALLMARK_PANCREAS_BETA_CELLS
# Number of categories that passed the tests = 4
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 1, 0.00347218802716864
# order classes
# 0
# 1
# 2
# 3
# Done.Start drawing
# 280.55	0.00
# HALLMARK_MYC_TARGETS_V1
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_DNA_REPAIR
# HALLMARK_UV_RESPONSE_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv_PAGE/filt_FC_P_LVM1_1.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv_PAGE/filt_FC_P_LVM1_1.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 1, 0.00347218802716864
# order classes
# 0
# 1
# 2
# 3
# Done.-19.9985029406523	42	0
# -19.9962573516307	42	0.00299411869541971
# -19.9940117626092	42	0.00449117804312957
# -19.9917661735876	42	0.00748529673854928
# -19.989520584566	42	0.00898235608625913
# -19.9872749955445	42	0.0119764747816788
# -19.9169132062021	42	0.0134735341293887
# -19.7559793263233	42	0.152700053466405
# 1.1676706469435	42	0.335341293887008
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_1.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 17, mi = 0.01210989, HALLMARK_G2M_CHECKPOINT
# cat 35, mi = 0.00911778, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 29, mi = 0.00662460, HALLMARK_MITOTIC_SPINDLE
# cat 12, mi = 0.00648252, HALLMARK_E2F_TARGETS
# cat 32, mi = 0.00334699, HALLMARK_MYC_TARGETS_V2
# cat 31, mi = 0.00320227, HALLMARK_MYC_TARGETS_V1
# cat 42, mi = 0.00265366, HALLMARK_SPERMATOGENESIS
# cat 16, mi = 0.00194287, HALLMARK_FATTY_ACID_METABOLISM
# cat 27, mi = 0.00179634, HALLMARK_KRAS_SIGNALING_DN
# cat 23, mi = 0.00177970, HALLMARK_IL6_JAK_STAT3_SIGNALING
# cat 30, mi = 0.00137250, HALLMARK_MTORC1_SIGNALING
# cat 4, mi = 0.00128332, HALLMARK_APICAL_JUNCTION
# cat 15, mi = 0.00118795, HALLMARK_ESTROGEN_RESPONSE_LATE
# cat 43, mi = 0.00118230, HALLMARK_TGF_BETA_SIGNALING
# cat 20, mi = 0.00117882, HALLMARK_HEME_METABOLISM
#
# RESULTS
# Passed: cat 17, mi = 0.012, pvalue = 0.000, HALLMARK_G2M_CHECKPOINT
# Passed: cat 35, mi = 0.009, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 32, mi = 0.003, pvalue = 0.000, HALLMARK_MYC_TARGETS_V2
# Passed: cat 27, mi = 0.002, pvalue = 0.000, HALLMARK_KRAS_SIGNALING_DN
# Passed: cat 23, mi = 0.002, pvalue = 0.001, HALLMARK_IL6_JAK_STAT3_SIGNALING
# Didn't pass (cutoff=0.0050): cat 4, mi = 0.001, pvalue = 0.006, HALLMARK_APICAL_JUNCTION
# Didn't pass (cutoff=0.0050): cat 20, mi = 0.001, pvalue = 0.014, HALLMARK_HEME_METABOLISM
# Didn't pass (cutoff=0.0050): cat 40, mi = 0.001, pvalue = 0.035, HALLMARK_PROTEIN_SECRETION
# Didn't pass (cutoff=0.0050): cat 33, mi = 0.001, pvalue = 0.037, HALLMARK_MYOGENESIS
# Didn't pass (cutoff=0.0050): cat 11, mi = 0.001, pvalue = 0.068, HALLMARK_DNA_REPAIR
# Didn't pass (cutoff=0.0050): cat 19, mi = 0.001, pvalue = 0.219, HALLMARK_HEDGEHOG_SIGNALING
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.001, pvalue = 0.371, HALLMARK_PANCREAS_BETA_CELLS
# Didn't pass (cutoff=0.0050): cat 5, mi = 0.000, pvalue = 0.510, HALLMARK_APICAL_SURFACE
# Number of categories that passed the tests = 5
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 2, 3, 0.537939192601153
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.Start drawing
# 5.29	0.00
# HALLMARK_G2M_CHECKPOINT
# HALLMARK_IL6_JAK_STAT3_SIGNALING
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_MYC_TARGETS_V2
# HALLMARK_KRAS_SIGNALING_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv_PAGE/filt_FC_P_LVM1_2.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv_PAGE/filt_FC_P_LVM1_2.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 2, 3, 0.537939192601153
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.-16.8638941398866	42	0
# -13.2117202268431	42	6.27221172022684
# -12.3780718336484	42	7.30434782608696
# -11.8223062381853	42	7.93950850661626
# -11.3856332703214	42	8.41587901701323
# -10.9092627599244	42	8.81285444234405
# -10.3137996219282	42	9.36862003780718
# -9.44045368620038	42	10.0037807183365
# 6.55765595463138	42	11.1153119092628
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_2.csv_PAGE/pvmatrix.txt
# DONE
# homologiesfile:
# genelist:
# REMOVING DUPLICATES
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/remove_homologous_sequences_withseed.pl -expfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv -quantized 0 -genelist /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/seqnames/human_ensembl_msigdb_h.txt -dupfile /nvme/bins/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_msigdb_h/human_ensembl_msigdb_h.homologies -outfile /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv.nodups -ebins 9
#
# DUPLICATION REMOVAL CANCELLED -- homologiesfile does not exist
#
# Reading expression data ... 1 by 12086... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 50
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 12086 out of 12086
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 12086	50
# Done.
# Writing internal quantized groups ...Done
# 1343 hits go_terms_num = 50
# cat 31, mi = 0.01325592, HALLMARK_MYC_TARGETS_V1
# cat 35, mi = 0.01103035, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# cat 30, mi = 0.00333845, HALLMARK_MTORC1_SIGNALING
# cat 12, mi = 0.00266843, HALLMARK_E2F_TARGETS
# cat 11, mi = 0.00222996, HALLMARK_DNA_REPAIR
# cat 17, mi = 0.00215795, HALLMARK_G2M_CHECKPOINT
# cat 27, mi = 0.00159562, HALLMARK_KRAS_SIGNALING_DN
# cat 39, mi = 0.00148593, HALLMARK_PI3K_AKT_MTOR_SIGNALING
# cat 36, mi = 0.00144163, HALLMARK_P53_PATHWAY
# cat 32, mi = 0.00139602, HALLMARK_MYC_TARGETS_V2
# cat 47, mi = 0.00129933, HALLMARK_UV_RESPONSE_UP
# cat 0, mi = 0.00128207, HALLMARK_ADIPOGENESIS
# cat 45, mi = 0.00125141, HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# cat 41, mi = 0.00111675, HALLMARK_REACTIVE_OXIGEN_SPECIES_PATHWAY
# cat 23, mi = 0.00110297, HALLMARK_IL6_JAK_STAT3_SIGNALING
#
# RESULTS
# Passed: cat 31, mi = 0.013, pvalue = 0.000, HALLMARK_MYC_TARGETS_V1
# Passed: cat 35, mi = 0.011, pvalue = 0.000, HALLMARK_OXIDATIVE_PHOSPHORYLATION
# Passed: cat 27, mi = 0.002, pvalue = 0.001, HALLMARK_KRAS_SIGNALING_DN
# Passed: cat 39, mi = 0.001, pvalue = 0.002, HALLMARK_PI3K_AKT_MTOR_SIGNALING
# Didn't pass (cutoff=0.0050): cat 8, mi = 0.001, pvalue = 0.072, HALLMARK_CHOLESTEROL_HOMEOSTASIS
# Didn't pass (cutoff=0.0050): cat 20, mi = 0.001, pvalue = 0.067, HALLMARK_HEME_METABOLISM
# Didn't pass (cutoff=0.0050): cat 34, mi = 0.001, pvalue = 0.234, HALLMARK_NOTCH_SIGNALING
# Didn't pass (cutoff=0.0050): cat 19, mi = 0.001, pvalue = 0.240, HALLMARK_HEDGEHOG_SIGNALING
# Didn't pass (cutoff=0.0050): cat 37, mi = 0.001, pvalue = 0.268, HALLMARK_PANCREAS_BETA_CELLS
# Didn't pass (cutoff=0.0050): cat 33, mi = 0.001, pvalue = 0.290, HALLMARK_MYOGENESIS
# Didn't pass (cutoff=0.0050): cat 15, mi = 0.000, pvalue = 0.476, HALLMARK_ESTROGEN_RESPONSE_LATE
# Didn't pass (cutoff=0.0050): cat 5, mi = 0.000, pvalue = 0.620, HALLMARK_APICAL_SURFACE
# Didn't pass (cutoff=0.0050): cat 3, mi = 0.000, pvalue = 0.796, HALLMARK_ANGIOGENESIS
# Number of categories that passed the tests = 4
# Number of clusters: 9
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 0, 1, 0.0288504050490969
# order classes
# 0
# 1
# 2
# 3
# Done.Start drawing
# 110.21	0.00
# HALLMARK_MYC_TARGETS_V1
# HALLMARK_OXIDATIVE_PHOSPHORYLATION
# HALLMARK_PI3K_AKT_MTOR_SIGNALING
# HALLMARK_KRAS_SIGNALING_DN
# Outputing EPS file /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.eps
# Convert to PDF /avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv_PAGE/filt_FC_P_LVM1_4.csv.summary.pdf
# Finished.
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt --expfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 0, 1, 0.0288504050490969
# order classes
# 0
# 1
# 2
# 3
# Done.-19.9980945467743	42	0
# -19.9923781870974	42	0.00381090645132021
# -19.9847563741947	42	0.0114327193539606
# -19.9790400145177	42	0.019054532256601
# -19.9733236548408	42	0.0228654387079212
# -19.9676072951638	42	0.0304872516105617
# -19.8361310225932	42	0.0342981580618819
# -19.4912439887488	42	0.293439796751656
# 1.36203611287542	42	0.724072225750839
# perl /nvme/bins/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=/avicenna/Johnny/scRNAseq/metastatic_evolution/ipage_human_ensembl_msigdb_h/fc_values/filt_FC_P_LVM1_4.csv_PAGE/pvmatrix.txt
# DONE
# sem --wait done
